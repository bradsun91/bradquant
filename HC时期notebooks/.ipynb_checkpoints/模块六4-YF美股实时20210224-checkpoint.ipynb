# %%
import pandas as pd
import yfinance as yf

# %% [markdown]
# https://blog.quantinsti.com/historical-market-data-python-api/

# %%
# 定义每个筛选模型

# 1. MACD
def MACD(df, price_col, n_fast, n_slow): # n_fast = 12, n_slow = 26
    """
    http://stockcharts.com/docs/doku.php?id=scans:indicators
    MACD, MACD Signal and MACD difference, rationale CHECKED, code CHECKED, updated
    # Conventional look-back window for calculating MACDsign is 9
    """
    EMAfast = df[price_col].ewm(span = n_fast, min_periods = n_fast - 1).mean()
    EMAslow = df[price_col].ewm(span = n_slow, min_periods = n_slow - 1).mean()
    diff = pd.Series(EMAfast - EMAslow)
    dea = diff.ewm(span = 9, min_periods = 8).mean()
    macd = (pd.Series(diff - dea))*2
    df["DIFF"] = diff
    df["DEA"] = dea
    df["MACD"] = macd
    return df

# 在MACD模型下的开平仓算法

def macd_updown_signals(df, signal_spread_col, date_col, ticker_col):
    ticker = df[ticker_col].values[-1]
    df.dropna(inplace = True)
    df.reset_index(inplace = True)
    del df['index']
    listLongShort = []
    listDate = []
    macd = df[signal_spread_col].values
    
    for i in range(1, len(df)):
        last_date = df[date_col][i]
        
        if macd[i]>macd[i-1] and macd[i-1]<macd[i-2]:
            
            listLongShort.append("BUY")
            listDate.append(last_date)
        #                          # The other way around
        elif macd[i]<macd[i-1] and macd[i-1]>macd[i-2]:
            listLongShort.append("SELL")
            listDate.append(last_date)
        #                          # Do nothing if not satisfied
        elif macd[i]<macd[i-1]:
            listLongShort.append("HOLD SHORT")
            listDate.append(last_date)
            
        elif macd[i]>macd[i-1]:
            listLongShort.append("HOLD LONG")
            listDate.append(last_date)           
            
    return ticker, listDate[-1], listLongShort[-1]
#     df['Advice'] = listLongShort
    # The advice column means "Buy/Sell/Hold" at the end of this day or
    #  at the beginning of the next day, since the market will be closed
    
def macd_cross_signals(df, signal_spread_col, date_col, ticker_col):
    ticker = df[ticker_col].values[-1]
    df.dropna(inplace = True)
    df.reset_index(inplace = True)
    del df['index']
    listLongShort = []
    listDate = []
    macd = df[signal_spread_col].values
    
    for i in range(1, len(df)):
        last_date = df[date_col][i]
        #                          # If the MACD crosses the signal line upward
        if macd[i] >0 and macd[i - 1] <0:
            listLongShort.append("BUY")
            listDate.append(last_date)
        #                          # The other way around
        elif macd[i] < 0 and macd[i - 1] >0:
            listLongShort.append("SELL")
            listDate.append(last_date)
        #                          # Do nothing if not crossed
        else: # 还要改，再增加点条件
            listLongShort.append("HOLD")
            listDate.append(last_date)
#     print("Ticker: ", ticker)
#     print("Last Date", listDate[-1])
#     print("Last Signal", listLongShort[-1])
    return ticker, listDate[-1], listLongShort[-1]
#     df['Advice'] = listLongShort
    # The advice column means "Buy/Sell/Hold" at the end of this day or
    #  at the beginning of the next day, since the market will be closed

# %%
# Define Ticker List:
us_major_tech_stk = ['V','MA','NFLX','CSCO','ADBE','MSFT','CRM','TSLA','GOOG','FB','GOOGL','TSM',
                        'AMZN','AAPL','PYPL','INTC','NVDA','QCOM','MU','BABA']

us_blockchain_stk = ['EBON','CAN','LFIN','CNET','AMD','FB','NVDA','XNET','SRAX','RENN','OSTK','RIOT',
                 'GBTC','MARA','NCTY']

us_saas_stk = ['HUBS','CDAY','ORCL','WDAY','COUP','INTU','SMAR','OKTA','ADP','PAYC','WORK','ADBE','MSFT','SPLK',
           'ZM','RNG','CRM','SAP','GDDY','DBX','VEEV','NOW','TEAM','ZEN','ADSK',
          'TTD','DDOG','TWLO','SHOP','DOCU','SQ','CRWD']

us_biotech_stk = ['AHPI','INO','IBIO','MRNA','VIR','NNVC','GILD','AZN','PFE','JNJ','BNTX','ABT','CBLI','ARPO','VCNX','HTBX','NVAX',
                 'VXRT','CRVS','APT','CODX','EQ','ACOR','LAKE','AEMD','DFFN']

us_new_energy_stk = ['TSLA','NIO','LI','XPEV','SQM','ALB','LTHM','FMC','LAC',
                     'QS','VLDR','LAZR','SBE','BLNK','XL','ENPH','PLUG','RUN','FLS',
                    'NOVA','FCEL']

# %%
# Define all variables:
folder_name = "C:/Users/Administrator/CE_github_2/data_pipeline/Signals/"
file_name = "Macd_Updown_Signals_2021-02-23_D_W.csv"
file_name_intraday_to_csv = "Macd_Updown_Signals_2021-02-23_15M_D_W.csv"

# %%
"""
====================每十五分钟执行一次===================
"""


"""
=================================================================================================
STEP 1: Load All Data

"""

all_tickers = us_major_tech_stk+us_blockchain_stk+us_saas_stk+us_biotech_stk+us_new_energy_stk
len_tickers = len(all_tickers)
load_count = 1
all_df_list = []
for ticker in all_tickers:
    print("Loading No.{} out of {}: {}".format(load_count, len_tickers, ticker))
    data = yf.download(
            tickers=[ticker],
            # use "period" instead of start/end
            # valid periods: 1d,5d,1mo,3mo,6mo,1y,2y,5y,10y,ytd,max
            # (optional, default is '1mo')
            period="5d",
            # fetch data by interval (including intraday if period < 60 days)
            # valid intervals: 1m,2m,5m,15m,30m,60m,90m,1h,1d,5d,1wk,1mo,3mo
            # (optional, default is '1d')
            interval="15m")
    data["Ticker"] = ticker
    all_df_list.append(data)
    load_count+=1
    
print("All Data Loaded")
all_df = pd.concat(all_df_list)
all_df.reset_index(inplace = True)



"""
=================================================================================================
STEP 2: Calculating Signals
"""

stock_list = []
date_list = []
signal_list = []
len_ = 1
date_col = "Datetime"
price_col = "Adj Close"
ticker_col = "Ticker"
signal_df = pd.DataFrame()
model_freq = "15M"
model_name = "Macd_Updown_Signals"
total_number = len_tickers


for ticker in all_tickers:
    print ("Calculating Signals for No.{} : {}".format(len_, ticker))
    data = all_df[all_df[ticker_col]==ticker]
    try:
        data_macd = MACD(data, price_col, 12, 26)
        ticker, last_date, last_signal = macd_updown_signals(data_macd, "MACD", date_col, ticker_col)
        stock_list.append(ticker)
        date_list.append(last_date)
        signal_list.append(last_signal)
    except Exception as e:
        print(e)
    len_+= 1
signal_df['Ticker'] = stock_list
signal_df['Last_Timestamp'] = date_list
signal_df['Signal'] = signal_list
signal_df['model_name'] = model_name
signal_df['model_freq'] = model_freq
print("All Done!")

"""
=================================================================================================
STEP 3: Process Data
"""
daily_weekly_data = pd.read_csv(folder_name+file_name)
try:
    del daily_weekly_data['Unnamed: 0']
except:
    pass

merged_all = signal_df.merge(daily_weekly_data, on = "Ticker")
merged_all_buy_ = merged_all[((merged_all['Signal_x']=="BUY")&(merged_all['Signal_y']=='BUY')) |\
                             ((merged_all['Signal_x']=='BUY')&(merged_all['Signal_y']=='HOLD LONG')) |
                             ((merged_all['Signal_x']=='HOLD LONG')&(merged_all['Signal_y']=='HOLD LONG'))]
merged_all_buy_hold_long = merged_all_buy_[(merged_all_buy_["Signal"]=="BUY")|(merged_all_buy_["Signal"]=="HOLD LONG")]
merged_all_buy_hold_long.drop_duplicates(inplace = True)
# Out:
# Loading No.1 out of 114: V
# [*********************100%***********************]  1 of 1 completed
# Loading No.2 out of 114: MA
# [*********************100%***********************]  1 of 1 completed
# Loading No.3 out of 114: NFLX
# [*********************100%***********************]  1 of 1 completed
# Loading No.4 out of 114: CSCO
# [*********************100%***********************]  1 of 1 completed
# Loading No.5 out of 114: ADBE
# [*********************100%***********************]  1 of 1 completed
# Loading No.6 out of 114: MSFT
# [*********************100%***********************]  1 of 1 completed
# Loading No.7 out of 114: CRM
# [*********************100%***********************]  1 of 1 completed
# Loading No.8 out of 114: TSLA
# [*********************100%***********************]  1 of 1 completed
# Loading No.9 out of 114: GOOG
# [*********************100%***********************]  1 of 1 completed
# Loading No.10 out of 114: FB
# [*********************100%***********************]  1 of 1 completed
# Loading No.11 out of 114: GOOGL
# [*********************100%***********************]  1 of 1 completed
# Loading No.12 out of 114: TSM
# [*********************100%***********************]  1 of 1 completed
# Loading No.13 out of 114: AMZN
# [*********************100%***********************]  1 of 1 completed
# Loading No.14 out of 114: AAPL
# [*********************100%***********************]  1 of 1 completed
# Loading No.15 out of 114: PYPL
# [*********************100%***********************]  1 of 1 completed
# Loading No.16 out of 114: INTC
# [*********************100%***********************]  1 of 1 completed
# Loading No.17 out of 114: NVDA
# [*********************100%***********************]  1 of 1 completed
# Loading No.18 out of 114: QCOM
# [*********************100%***********************]  1 of 1 completed
# Loading No.19 out of 114: MU
# [*********************100%***********************]  1 of 1 completed
# Loading No.20 out of 114: BABA
# [*********************100%***********************]  1 of 1 completed
# Loading No.21 out of 114: EBON
# [*********************100%***********************]  1 of 1 completed
# Loading No.22 out of 114: CAN
# [*********************100%***********************]  1 of 1 completed
# Loading No.23 out of 114: LFIN
# [*********************100%***********************]  1 of 1 completed
# Loading No.24 out of 114: CNET
# [*********************100%***********************]  1 of 1 completed
# Loading No.25 out of 114: AMD
# [*********************100%***********************]  1 of 1 completed
# Loading No.26 out of 114: FB
# [*********************100%***********************]  1 of 1 completed
# Loading No.27 out of 114: NVDA
# [*********************100%***********************]  1 of 1 completed
# Loading No.28 out of 114: XNET
# [*********************100%***********************]  1 of 1 completed
# Loading No.29 out of 114: SRAX
# [*********************100%***********************]  1 of 1 completed
# Loading No.30 out of 114: RENN
# [*********************100%***********************]  1 of 1 completed
# Loading No.31 out of 114: OSTK
# [*********************100%***********************]  1 of 1 completed
# Loading No.32 out of 114: RIOT
# [*********************100%***********************]  1 of 1 completed
# Loading No.33 out of 114: GBTC
# [*********************100%***********************]  1 of 1 completed
# Loading No.34 out of 114: MARA
# [*********************100%***********************]  1 of 1 completed
# Loading No.35 out of 114: NCTY
# [*********************100%***********************]  1 of 1 completed
# Loading No.36 out of 114: HUBS
# [*********************100%***********************]  1 of 1 completed
# Loading No.37 out of 114: CDAY
# [*********************100%***********************]  1 of 1 completed
# Loading No.38 out of 114: ORCL
# [*********************100%***********************]  1 of 1 completed
# Loading No.39 out of 114: WDAY
# [*********************100%***********************]  1 of 1 completed
# Loading No.40 out of 114: COUP
# [*********************100%***********************]  1 of 1 completed
# Loading No.41 out of 114: INTU
# [*********************100%***********************]  1 of 1 completed
# Loading No.42 out of 114: SMAR
# [*********************100%***********************]  1 of 1 completed
# Loading No.43 out of 114: OKTA
# [*********************100%***********************]  1 of 1 completed
# Loading No.44 out of 114: ADP
# [*********************100%***********************]  1 of 1 completed
# Loading No.45 out of 114: PAYC
# [*********************100%***********************]  1 of 1 completed
# Loading No.46 out of 114: WORK
# [*********************100%***********************]  1 of 1 completed
# Loading No.47 out of 114: ADBE
# [*********************100%***********************]  1 of 1 completed
# Loading No.48 out of 114: MSFT
# [*********************100%***********************]  1 of 1 completed
# Loading No.49 out of 114: SPLK
# [*********************100%***********************]  1 of 1 completed
# Loading No.50 out of 114: ZM
# [*********************100%***********************]  1 of 1 completed
# Loading No.51 out of 114: RNG
# [*********************100%***********************]  1 of 1 completed
# Loading No.52 out of 114: CRM
# [*********************100%***********************]  1 of 1 completed
# Loading No.53 out of 114: SAP
# [*********************100%***********************]  1 of 1 completed
# Loading No.54 out of 114: GDDY
# [*********************100%***********************]  1 of 1 completed
# Loading No.55 out of 114: DBX
# [*********************100%***********************]  1 of 1 completed
# Loading No.56 out of 114: VEEV
# [*********************100%***********************]  1 of 1 completed
# Loading No.57 out of 114: NOW
# [*********************100%***********************]  1 of 1 completed
# Loading No.58 out of 114: TEAM
# [*********************100%***********************]  1 of 1 completed
# Loading No.59 out of 114: ZEN
# [*********************100%***********************]  1 of 1 completed
# Loading No.60 out of 114: ADSK
# [*********************100%***********************]  1 of 1 completed
# Loading No.61 out of 114: TTD
# [*********************100%***********************]  1 of 1 completed
# Loading No.62 out of 114: DDOG
# [*********************100%***********************]  1 of 1 completed
# Loading No.63 out of 114: TWLO
# [*********************100%***********************]  1 of 1 completed
# Loading No.64 out of 114: SHOP
# [*********************100%***********************]  1 of 1 completed
# Loading No.65 out of 114: DOCU
# [*********************100%***********************]  1 of 1 completed
# Loading No.66 out of 114: SQ
# [*********************100%***********************]  1 of 1 completed
# Loading No.67 out of 114: CRWD
# [*********************100%***********************]  1 of 1 completed
# Loading No.68 out of 114: AHPI
# [*********************100%***********************]  1 of 1 completed
# Loading No.69 out of 114: INO
# [*********************100%***********************]  1 of 1 completed
# Loading No.70 out of 114: IBIO
# [*********************100%***********************]  1 of 1 completed
# Loading No.71 out of 114: MRNA
# [*********************100%***********************]  1 of 1 completed
# Loading No.72 out of 114: VIR
# [*********************100%***********************]  1 of 1 completed
# Loading No.73 out of 114: NNVC
# [*********************100%***********************]  1 of 1 completed
# Loading No.74 out of 114: GILD
# [*********************100%***********************]  1 of 1 completed
# Loading No.75 out of 114: AZN
# [*********************100%***********************]  1 of 1 completed
# Loading No.76 out of 114: PFE
# [*********************100%***********************]  1 of 1 completed
# Loading No.77 out of 114: JNJ
# [*********************100%***********************]  1 of 1 completed
# Loading No.78 out of 114: BNTX
# [*********************100%***********************]  1 of 1 completed
# Loading No.79 out of 114: ABT
# [*********************100%***********************]  1 of 1 completed
# Loading No.80 out of 114: CBLI
# [*********************100%***********************]  1 of 1 completed
# Loading No.81 out of 114: ARPO
# [*********************100%***********************]  1 of 1 completed
# Loading No.82 out of 114: VCNX
# [*********************100%***********************]  1 of 1 completed
# Loading No.83 out of 114: HTBX
# [*********************100%***********************]  1 of 1 completed
# Loading No.84 out of 114: NVAX
# [*********************100%***********************]  1 of 1 completed
# Loading No.85 out of 114: VXRT
# [*********************100%***********************]  1 of 1 completed
# Loading No.86 out of 114: CRVS
# [*********************100%***********************]  1 of 1 completed
# Loading No.87 out of 114: APT
# [*********************100%***********************]  1 of 1 completed
# Loading No.88 out of 114: CODX
# [*********************100%***********************]  1 of 1 completed
# Loading No.89 out of 114: EQ
# [*********************100%***********************]  1 of 1 completed
# Loading No.90 out of 114: ACOR
# [*********************100%***********************]  1 of 1 completed
# Loading No.91 out of 114: LAKE
# [*********************100%***********************]  1 of 1 completed
# Loading No.92 out of 114: AEMD
# [*********************100%***********************]  1 of 1 completed
# Loading No.93 out of 114: DFFN
# [*********************100%***********************]  1 of 1 completed
# Loading No.94 out of 114: TSLA
# [*********************100%***********************]  1 of 1 completed
# Loading No.95 out of 114: NIO
# [*********************100%***********************]  1 of 1 completed
# Loading No.96 out of 114: LI
# [*********************100%***********************]  1 of 1 completed
# Loading No.97 out of 114: XPEV
# [*********************100%***********************]  1 of 1 completed
# Loading No.98 out of 114: SQM
# [*********************100%***********************]  1 of 1 completed
# Loading No.99 out of 114: ALB
# [*********************100%***********************]  1 of 1 completed
# Loading No.100 out of 114: LTHM
# [*********************100%***********************]  1 of 1 completed
# Loading No.101 out of 114: FMC
# [*********************100%***********************]  1 of 1 completed
# Loading No.102 out of 114: LAC
# [*********************100%***********************]  1 of 1 completed
# Loading No.103 out of 114: QS
# [*********************100%***********************]  1 of 1 completed
# Loading No.104 out of 114: VLDR
# [*********************100%***********************]  1 of 1 completed
# Loading No.105 out of 114: LAZR
# [*********************100%***********************]  1 of 1 completed
# Loading No.106 out of 114: SBE
# [*********************100%***********************]  1 of 1 completed
# Loading No.107 out of 114: BLNK
# [*********************100%***********************]  1 of 1 completed
# Loading No.108 out of 114: XL
# [*********************100%***********************]  1 of 1 completed
# Loading No.109 out of 114: ENPH
# [*********************100%***********************]  1 of 1 completed
# Loading No.110 out of 114: PLUG
# [*********************100%***********************]  1 of 1 completed
# Loading No.111 out of 114: RUN
# [*********************100%***********************]  1 of 1 completed
# Loading No.112 out of 114: FLS
# [*********************100%***********************]  1 of 1 completed
# Loading No.113 out of 114: NOVA
# [*********************100%***********************]  1 of 1 completed
# Loading No.114 out of 114: FCEL
# [*********************100%***********************]  1 of 1 completed
# All Data Loaded
# Calculating Signals for No.1 : V
# Calculating Signals for No.2 : MA
# Calculating Signals for No.3 : NFLX
# Calculating Signals for No.4 : CSCO
# Calculating Signals for No.5 : ADBE
# Calculating Signals for No.6 : MSFT
# Calculating Signals for No.7 : CRM
# Calculating Signals for No.8 : TSLA
# Calculating Signals for No.9 : GOOG
# Calculating Signals for No.10 : FB
# Calculating Signals for No.11 : GOOGL
# Calculating Signals for No.12 : TSM
# Calculating Signals for No.13 : AMZN
# <ipython-input-91-b8490d96d521>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["DIFF"] = diff
# <ipython-input-91-b8490d96d521>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["DEA"] = dea
# <ipython-input-91-b8490d96d521>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["MACD"] = macd
# <ipython-input-91-b8490d96d521>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(inplace = True)
# <ipython-input-91-b8490d96d521>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["DIFF"] = diff
# <ipython-input-91-b8490d96d521>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["DEA"] = dea
# <ipython-input-91-b8490d96d521>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["MACD"] = macd
# <ipython-input-91-b8490d96d521>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(inplace = True)
# <ipython-input-91-b8490d96d521>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["DIFF"] = diff
# <ipython-input-91-b8490d96d521>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["DEA"] = dea
# <ipython-input-91-b8490d96d521>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["MACD"] = macd
# <ipython-input-91-b8490d96d521>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(inplace = True)
# <ipython-input-91-b8490d96d521>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["DIFF"] = diff
# <ipython-input-91-b8490d96d521>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["DEA"] = dea
# <ipython-input-91-b8490d96d521>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["MACD"] = macd
# <ipython-input-91-b8490d96d521>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(inplace = True)
# <ipython-input-91-b8490d96d521>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["DIFF"] = diff
# <ipython-input-91-b8490d96d521>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["DEA"] = dea
# <ipython-input-91-b8490d96d521>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["MACD"] = macd
# <ipython-input-91-b8490d96d521>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(inplace = True)
# <ipython-input-91-b8490d96d521>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["DIFF"] = diff
# <ipython-input-91-b8490d96d521>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["DEA"] = dea
# <ipython-input-91-b8490d96d521>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["MACD"] = macd
# <ipython-input-91-b8490d96d521>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(inplace = True)
# <ipython-input-91-b8490d96d521>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["DIFF"] = diff
# <ipython-input-91-b8490d96d521>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["DEA"] = dea
# <ipython-input-91-b8490d96d521>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["MACD"] = macd
# <ipython-input-91-b8490d96d521>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(inplace = True)
# <ipython-input-91-b8490d96d521>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["DIFF"] = diff
# <ipython-input-91-b8490d96d521>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["DEA"] = dea
# <ipython-input-91-b8490d96d521>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["MACD"] = macd
# <ipython-input-91-b8490d96d521>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(inplace = True)
# <ipython-input-91-b8490d96d521>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["DIFF"] = diff
# <ipython-input-91-b8490d96d521>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["DEA"] = dea
# <ipython-input-91-b8490d96d521>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["MACD"] = macd
# <ipython-input-91-b8490d96d521>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(inplace = True)
# <ipython-input-91-b8490d96d521>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["DIFF"] = diff
# <ipython-input-91-b8490d96d521>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["DEA"] = dea
# <ipython-input-91-b8490d96d521>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["MACD"] = macd
# <ipython-input-91-b8490d96d521>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(inplace = True)
# <ipython-input-91-b8490d96d521>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["DIFF"] = diff
# <ipython-input-91-b8490d96d521>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["DEA"] = dea
# <ipython-input-91-b8490d96d521>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["MACD"] = macd
# <ipython-input-91-b8490d96d521>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(inplace = True)
# <ipython-input-91-b8490d96d521>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["DIFF"] = diff
# <ipython-input-91-b8490d96d521>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["DEA"] = dea
# <ipython-input-91-b8490d96d521>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["MACD"] = macd
# <ipython-input-91-b8490d96d521>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(inplace = True)
# <ipython-input-91-b8490d96d521>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["DIFF"] = diff
# <ipython-input-91-b8490d96d521>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["DEA"] = dea
# <ipython-input-91-b8490d96d521>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["MACD"] = macd
# <ipython-input-91-b8490d96d521>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(inplace = True)
# <ipython-input-91-b8490d96d521>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["DIFF"] = diff
# <ipython-input-91-b8490d96d521>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["DEA"] = dea
# <ipython-input-91-b8490d96d521>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["MACD"] = macd
# <ipython-input-91-b8490d96d521>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(inplace = True)
# <ipython-input-91-b8490d96d521>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["DIFF"] = diff
# <ipython-input-91-b8490d96d521>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["DEA"] = dea
# <ipython-input-91-b8490d96d521>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["MACD"] = macd
# <ipython-input-91-b8490d96d521>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(inplace = True)
# <ipython-input-91-b8490d96d521>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["DIFF"] = diff
# <ipython-input-91-b8490d96d521>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["DEA"] = dea
# <ipython-input-91-b8490d96d521>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["MACD"] = macd
# <ipython-input-91-b8490d96d521>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(inplace = True)
# <ipython-input-91-b8490d96d521>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["DIFF"] = diff
# <ipython-input-91-b8490d96d521>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["DEA"] = dea
# <ipython-input-91-b8490d96d521>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["MACD"] = macd
# <ipython-input-91-b8490d96d521>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(inplace = True)
# <ipython-input-91-b8490d96d521>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["DIFF"] = diff
# <ipython-input-91-b8490d96d521>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["DEA"] = dea
# <ipython-input-91-b8490d96d521>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["MACD"] = macd
# <ipython-input-91-b8490d96d521>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(inplace = True)
# <ipython-input-91-b8490d96d521>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["DIFF"] = diff
# <ipython-input-91-b8490d96d521>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["DEA"] = dea
# <ipython-input-91-b8490d96d521>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["MACD"] = macd
# <ipython-input-91-b8490d96d521>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(inplace = True)
# <ipython-input-91-b8490d96d521>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["DIFF"] = diff
# <ipython-input-91-b8490d96d521>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["DEA"] = dea
# Calculating Signals for No.14 : AAPL
# Calculating Signals for No.15 : PYPL
# Calculating Signals for No.16 : INTC
# Calculating Signals for No.17 : NVDA
# Calculating Signals for No.18 : QCOM
# Calculating Signals for No.19 : MU
# Calculating Signals for No.20 : BABA
# Calculating Signals for No.21 : EBON
# Calculating Signals for No.22 : CAN
# Calculating Signals for No.23 : LFIN
# Calculating Signals for No.24 : CNET
# Calculating Signals for No.25 : AMD
# Calculating Signals for No.26 : FB
# Calculating Signals for No.27 : NVDA
# Calculating Signals for No.28 : XNET
# Calculating Signals for No.29 : SRAX
# Calculating Signals for No.30 : RENN
# Calculating Signals for No.31 : OSTK
# Calculating Signals for No.32 : RIOT
# Calculating Signals for No.33 : GBTC
# Calculating Signals for No.34 : MARA
# <ipython-input-91-b8490d96d521>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["MACD"] = macd
# <ipython-input-91-b8490d96d521>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(inplace = True)
# <ipython-input-91-b8490d96d521>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["DIFF"] = diff
# <ipython-input-91-b8490d96d521>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["DEA"] = dea
# <ipython-input-91-b8490d96d521>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["MACD"] = macd
# <ipython-input-91-b8490d96d521>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(inplace = True)
# <ipython-input-91-b8490d96d521>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["DIFF"] = diff
# <ipython-input-91-b8490d96d521>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["DEA"] = dea
# <ipython-input-91-b8490d96d521>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["MACD"] = macd
# <ipython-input-91-b8490d96d521>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(inplace = True)
# <ipython-input-91-b8490d96d521>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["DIFF"] = diff
# <ipython-input-91-b8490d96d521>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["DEA"] = dea
# <ipython-input-91-b8490d96d521>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["MACD"] = macd
# <ipython-input-91-b8490d96d521>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(inplace = True)
# <ipython-input-91-b8490d96d521>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["DIFF"] = diff
# <ipython-input-91-b8490d96d521>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["DEA"] = dea
# <ipython-input-91-b8490d96d521>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["MACD"] = macd
# <ipython-input-91-b8490d96d521>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(inplace = True)
# <ipython-input-91-b8490d96d521>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["DIFF"] = diff
# <ipython-input-91-b8490d96d521>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["DEA"] = dea
# <ipython-input-91-b8490d96d521>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["MACD"] = macd
# <ipython-input-91-b8490d96d521>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(inplace = True)
# <ipython-input-91-b8490d96d521>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["DIFF"] = diff
# <ipython-input-91-b8490d96d521>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["DEA"] = dea
# <ipython-input-91-b8490d96d521>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["MACD"] = macd
# <ipython-input-91-b8490d96d521>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(inplace = True)
# <ipython-input-91-b8490d96d521>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["DIFF"] = diff
# <ipython-input-91-b8490d96d521>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["DEA"] = dea
# <ipython-input-91-b8490d96d521>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...
#   df["DEA"] = dea
# <ipython-input-91-b8490d96d521>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["MACD"] = macd
# <ipython-input-91-b8490d96d521>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(inplace = True)
# <ipython-input-91-b8490d96d521>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["DIFF"] = diff
# <ipython-input-91-b8490d96d521>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["DEA"] = dea
# <ipython-input-91-b8490d96d521>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["MACD"] = macd
# <ipython-input-91-b8490d96d521>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(inplace = True)
# <ipython-input-91-b8490d96d521>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["DIFF"] = diff
# <ipython-input-91-b8490d96d521>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["DEA"] = dea
# <ipython-input-91-b8490d96d521>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["MACD"] = macd
# <ipython-input-91-b8490d96d521>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(inplace = True)
# <ipython-input-91-b8490d96d521>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["DIFF"] = diff
# <ipython-input-91-b8490d96d521>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["DEA"] = dea
# <ipython-input-91-b8490d96d521>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["MACD"] = macd
# <ipython-input-91-b8490d96d521>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(inplace = True)
# Calculating Signals for No.100 : LTHM
# Calculating Signals for No.101 : FMC
# Calculating Signals for No.102 : LAC
# Calculating Signals for No.103 : QS
# Calculating Signals for No.104 : VLDR
# Calculating Signals for No.105 : LAZR
# Calculating Signals for No.106 : SBE
# Calculating Signals for No.107 : BLNK
# Calculating Signals for No.108 : XL
# Calculating Signals for No.109 : ENPH
# Calculating Signals for No.110 : PLUG
# Calculating Signals for No.111 : RUN
# Calculating Signals for No.112 : FLS
# Calculating Signals for No.113 : NOVA
# Calculating Signals for No.114 : FCEL
# All Done!
# <ipython-input-91-b8490d96d521>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["DIFF"] = diff
# <ipython-input-91-b8490d96d521>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["DEA"] = dea
# <ipython-input-91-b8490d96d521>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["MACD"] = macd
# <ipython-input-91-b8490d96d521>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(inplace = True)
# <ipython-input-91-b8490d96d521>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["DIFF"] = diff
# <ipython-input-91-b8490d96d521>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["DEA"] = dea
# <ipython-input-91-b8490d96d521>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["MACD"] = macd
# <ipython-input-91-b8490d96d521>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(inplace = True)
# <ipython-input-91-b8490d96d521>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["DIFF"] = diff
# <ipython-input-91-b8490d96d521>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["DEA"] = dea
# <ipython-input-91-b8490d96d521>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["MACD"] = macd
# <ipython-input-91-b8490d96d521>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(inplace = True)
# <ipython-input-91-b8490d96d521>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["DIFF"] = diff
# <ipython-input-91-b8490d96d521>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["DEA"] = dea
# <ipython-input-91-b8490d96d521>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["MACD"] = macd
# <ipython-input-91-b8490d96d521>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(inplace = True)
# <ipython-input-91-b8490d96d521>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["DIFF"] = diff
# <ipython-input-91-b8490d96d521>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["DEA"] = dea
# <ipython-input-91-b8490d96d521>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["MACD"] = macd
# <ipython-input-91-b8490d96d521>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(inplace = True)
# <ipython-input-91-b8490d96d521>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["DIFF"] = diff
# <ipython-input-91-b8490d96d521>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["DEA"] = dea
# <ipython-input-91-b8490d96d521>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["MACD"] = macd
# <ipython-input-91-b8490d96d521>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(inplace = True)
# <ipython-input-91-b8490d96d521>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["DIFF"] = diff
# <ipython-input-91-b8490d96d521>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["DEA"] = dea
# <ipython-input-91-b8490d96d521>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["MACD"] = macd
# <ipython-input-91-b8490d96d521>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(inplace = True)
# <ipython-input-91-b8490d96d521>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["DIFF"] = diff
# <ipython-input-91-b8490d96d521>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["DEA"] = dea
# <ipython-input-91-b8490d96d521>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["MACD"] = macd
# <ipython-input-91-b8490d96d521>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(inplace = True)
# Empty DataFrame
# Columns: [Ticker, Last_Timestamp, Signal, model_name, model_freq, Last_Date_x, Signal_x, model_name_x, model_freq_x, Last_Date_y, Signal_y, model_name_y, model_freq_y]
# Index: []

# %%
data
# Out:
#                     Datetime       Open       High        Low      Close  \
# 0  2021-02-18 10:45:00-05:00  19.280001  19.629999  19.151100  19.209999
# 1  2021-02-18 11:00:00-05:00  19.200001  19.500000  18.940001  19.199900
# 2  2021-02-18 11:15:00-05:00  19.209999  19.500000  19.209999  19.360001
# 3  2021-02-18 11:30:00-05:00  19.360001  19.650000  19.285000  19.480000
# 4  2021-02-18 11:45:00-05:00  19.485001  19.495001  19.184999  19.309999
# ..                       ...        ...        ...        ...        ...
# 94 2021-02-23 14:45:00-05:00  17.080000  17.089199  16.850000  17.059999
# 95 2021-02-23 15:00:00-05:00  17.059999  17.250000  16.955000  17.209999
# 96 2021-02-23 15:15:00-05:00  17.205000  17.459999  17.160000  17.375000
# 97 2021-02-23 15:30:00-05:00  17.379900  17.415001  17.106001  17.209999
# 98 2021-02-23 15:45:00-05:00  17.215000  17.270000  17.080000  17.160000
#
#     Adj Close   Volume Ticker      DIFF       DEA      MACD
# 0   19.209999  2096501   FCEL -0.628385 -0.408469 -0.439832
# 1   19.199900  2138750   FCEL -0.676165 -0.470308 -0.411714
# 2   19.360001  1212925   FCEL -0.693799 -0.520383 -0.346832
# 3   19.480000  1284490   FCEL -0.690612 -0.557629 -0.265968
# 4   19.309999   920584   FCEL -0.692952 -0.586690 -0.212523
# ..        ...      ...    ...       ...       ...       ...
# 94  17.059999   624002   FCEL -0.217062 -0.381022  0.327921
# 95  17.209999   643916   FCEL -0.176016 -0.340021  0.328010
# 96  17.375000   894791   FCEL -0.128689 -0.297754  0.338130
# 97  17.209999  1053459   FCEL -0.103306 -0.258865  0.311118
# 98  17.160000  1755150   FCEL -0.086229 -0.224338  0.276217
#
# [99 rows x 11 columns]

# %%
merged_all
# Out:
#     Ticker            Last_Timestamp      Signal           model_name  \
# 0        V 2021-02-23 15:45:00-05:00  HOLD SHORT  Macd_Updown_Signals
# 1       MA 2021-02-23 15:45:00-05:00  HOLD SHORT  Macd_Updown_Signals
# 2     NFLX 2021-02-23 15:45:00-05:00  HOLD SHORT  Macd_Updown_Signals
# 3     CSCO 2021-02-23 15:45:00-05:00   HOLD LONG  Macd_Updown_Signals
# 4     ADBE 2021-02-23 15:45:00-05:00  HOLD SHORT  Macd_Updown_Signals
# ..     ...                       ...         ...                  ...
# 109   PLUG 2021-02-23 15:45:00-05:00  HOLD SHORT  Macd_Updown_Signals
# 110    RUN 2021-02-23 15:45:00-05:00        SELL  Macd_Updown_Signals
# 111    FLS 2021-02-23 15:45:00-05:00         BUY  Macd_Updown_Signals
# 112   NOVA 2021-02-23 15:45:00-05:00  HOLD SHORT  Macd_Updown_Signals
# 113   FCEL 2021-02-23 15:45:00-05:00  HOLD SHORT  Macd_Updown_Signals
#
#     model_freq Last_Date_x    Signal_x         model_name_x model_freq_x  \
# 0          15M  2021-02-23         BUY  Macd_Updown_Signals            D
# 1          15M  2021-02-23   HOLD LONG  Macd_Updown_Signals            D
# 2          15M  2021-02-23         BUY  Macd_Updown_Signals            D
# 3          15M  2021-02-23  HOLD SHORT  Macd_Updown_Signals            D
# 4          15M  2021-02-23  HOLD SHORT  Macd_Updown_Signals            D
# ..         ...         ...         ...                  ...          ...
# 109        15M  2021-02-23  HOLD SHORT  Macd_Updown_Signals            D
# 110        15M  2021-02-23  HOLD SHORT  Macd_Updown_Signals            D
# 111        15M  2021-02-23         BUY  Macd_Updown_Signals            D
# 112        15M  2021-02-23  HOLD SHORT  Macd_Updown_Signals            D
# 113        15M  2021-02-23  HOLD SHORT  Macd_Updown_Signals            D
#
#     Last_Date_y    Signal_y         model_name_y model_freq_y
# 0    2021-02-23         BUY  Macd_Updown_Signals            W
# 1    2021-02-23         BUY  Macd_Updown_Signals            W
# 2    2021-02-23  HOLD SHORT  Macd_Updown_Signals            W
# 3    2021-02-23  HOLD SHORT  Macd_Updown_Signals            W
# 4    2021-02-23  HOLD SHORT  Macd_Updown_Signals            W
# ..          ...         ...                  ...          ...
# 109  2021-02-23  HOLD SHORT  Macd_Updown_Signals            W
# 110  2021-02-23  HOLD SHORT  Macd_Updown_Signals            W
# 111  2021-02-23  HOLD SHORT  Macd_Updown_Signals            W
# 112  2021-02-23  HOLD SHORT  Macd_Updown_Signals            W
# 113  2021-02-23  HOLD SHORT  Macd_Updown_Signals            W
#
# [114 rows x 13 columns]

# %%
merged_all.drop_duplicates(inplace = True)
merged_all[['Ticker','Last_Timestamp','model_name','Signal','model_freq',
                                                   'Signal_x', 'model_freq_x',
                                                   'Signal_y', 'model_freq_y']]
# Out:
#     Ticker            Last_Timestamp           model_name      Signal  \
# 0        V 2021-02-23 15:45:00-05:00  Macd_Updown_Signals  HOLD SHORT
# 1       MA 2021-02-23 15:45:00-05:00  Macd_Updown_Signals  HOLD SHORT
# 2     NFLX 2021-02-23 15:45:00-05:00  Macd_Updown_Signals  HOLD SHORT
# 3     CSCO 2021-02-23 15:45:00-05:00  Macd_Updown_Signals   HOLD LONG
# 4     ADBE 2021-02-23 15:45:00-05:00  Macd_Updown_Signals  HOLD SHORT
# ..     ...                       ...                  ...         ...
# 109   PLUG 2021-02-23 15:45:00-05:00  Macd_Updown_Signals  HOLD SHORT
# 110    RUN 2021-02-23 15:45:00-05:00  Macd_Updown_Signals        SELL
# 111    FLS 2021-02-23 15:45:00-05:00  Macd_Updown_Signals         BUY
# 112   NOVA 2021-02-23 15:45:00-05:00  Macd_Updown_Signals  HOLD SHORT
# 113   FCEL 2021-02-23 15:45:00-05:00  Macd_Updown_Signals  HOLD SHORT
#
#     model_freq    Signal_x model_freq_x    Signal_y model_freq_y
# 0          15M         BUY            D         BUY            W
# 1          15M   HOLD LONG            D         BUY            W
# 2          15M         BUY            D  HOLD SHORT            W
# 3          15M  HOLD SHORT            D  HOLD SHORT            W
# 4          15M  HOLD SHORT            D  HOLD SHORT            W
# ..         ...         ...          ...         ...          ...
# 109        15M  HOLD SHORT            D  HOLD SHORT            W
# 110        15M  HOLD SHORT            D  HOLD SHORT            W
# 111        15M         BUY            D  HOLD SHORT            W
# 112        15M  HOLD SHORT            D  HOLD SHORT            W
# 113        15M  HOLD SHORT            D  HOLD SHORT            W
#
# [108 rows x 9 columns]

# %%
merged_all.to_csv(folder_name+file_name_intraday_to_csv)

# %% [markdown]
# # 发邮件

# %%
import smtplib
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
from email.mime.base import MIMEBase
from email import encoders
import datetime as dt

# %%
signal_data = merged_all_buy_hold_long[['Ticker','Last_Timestamp','model_name','Signal','model_freq',
                                                   'Signal_x', 'model_freq_x',
                                                   'Signal_y', 'model_freq_y']]

# %%
merged_all_buy_hold_long
# Out:
# Empty DataFrame
# Columns: [Ticker, Last_Timestamp, Signal, model_name, model_freq, Last_Date_x, Signal_x, model_name_x, model_freq_x, Last_Date_y, Signal_y, model_name_y, model_freq_y]
# Index: []

# %%
signal_data
# Out:
# Empty DataFrame
# Columns: [Ticker, Last_Timestamp, model_name, Signal, model_freq, Signal_x, model_freq_x, Signal_y, model_freq_y]
# Index: []

# %%
(169/164)-1
# Out:
# 0.030487804878048808

# %%
signal_data
# Out:
# Empty DataFrame
# Columns: [Ticker, Last_Timestamp, model_name, Signal, model_freq, Signal_x, model_freq_x, Signal_y, model_freq_y]
# Index: []

# %%
signal_output
# Out:
# '<p><table border="0" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th style = "background-color: #FFFFFF;font-family: Century Gothic;font-size: medium;color: #305496;text-align: left;border-bottom: 2px solid #305496;padding: 0px 20px 0px 0px">Ticker</th>\n      <th style = "background-color: #FFFFFF;font-family: Century Gothic;font-size: medium;color: #305496;text-align: left;border-bottom: 2px solid #305496;padding: 0px 20px 0px 0px">Last_Timestamp</th>\n      <th style = "background-color: #FFFFFF;font-family: Century Gothic;font-size: medium;color: #305496;text-align: left;border-bottom: 2px solid #305496;padding: 0px 20px 0px 0px">model_name</th>\n      <th style = "background-color: #FFFFFF;font-family: Century Gothic;font-size: medium;color: #305496;text-align: left;border-bottom: 2px solid #305496;padding: 0px 20px 0px 0px">Signal</th>\n      <th style = "background-color: #FFFFFF;font-family: Century Gothic;font-size: medium;color: #305496;text-align: left;border-bottom: 2px solid #305496;padding: 0px 20px 0px 0px">model_freq</th>\n      <th style = "background-color: #FFFFFF;font-family: Century Gothic;font-size: medium;color: #305496;text-align: left;border-bottom: 2px solid #305496;padding: 0px 20px 0px 0px">Signal_x</th>\n      <th style = "background-color: #FFFFFF;font-family: Century Gothic;font-size: medium;color: #305496;text-align: left;border-bottom: 2px solid #305496;padding: 0px 20px 0px 0px">model_freq_x</th>\n      <th style = "background-color: #FFFFFF;font-family: Century Gothic;font-size: medium;color: #305496;text-align: left;border-bottom: 2px solid #305496;padding: 0px 20px 0px 0px">Signal_y</th>\n      <th style = "background-color: #FFFFFF;font-family: Century Gothic;font-size: medium;color: #305496;text-align: left;border-bottom: 2px solid #305496;padding: 0px 20px 0px 0px">model_freq_y</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <td style = "background-color: #D9E1F2;font-family: Century Gothic;font-size: medium;text-align: left;padding: 0px 20px 0px 0px">LFIN</td>\n      <td style = "background-color: #D9E1F2;font-family: Century Gothic;font-size: medium;text-align: left;padding: 0px 20px 0px 0px">2021-02-22 15:45:00-05:00</td>\n      <td style = "background-color: #D9E1F2;font-family: Century Gothic;font-size: medium;text-align: left;padding: 0px 20px 0px 0px">Macd_Updown_Signals</td>\n      <td style = "background-color: #D9E1F2;font-family: Century Gothic;font-size: medium;text-align: left;padding: 0px 20px 0px 0px">HOLD LONG</td>\n      <td style = "background-color: #D9E1F2;font-family: Century Gothic;font-size: medium;text-align: left;padding: 0px 20px 0px 0px">15M</td>\n      <td style = "background-color: #D9E1F2;font-family: Century Gothic;font-size: medium;text-align: left;padding: 0px 20px 0px 0px">HOLD LONG</td>\n      <td style = "background-color: #D9E1F2;font-family: Century Gothic;font-size: medium;text-align: left;padding: 0px 20px 0px 0px">D</td>\n      <td style = "background-color: #D9E1F2;font-family: Century Gothic;font-size: medium;text-align: left;padding: 0px 20px 0px 0px">HOLD LONG</td>\n      <td style = "background-color: #D9E1F2;font-family: Century Gothic;font-size: medium;text-align: left;padding: 0px 20px 0px 0px">W</td>\n    </tr>\n    <tr>\n      <td style = "background-color: #FFFFFF;font-family: Century Gothic;font-size: medium;text-align: left;padding: 0px 20px 0px 0px">NCTY</td>\n      <td style = "background-color: #FFFFFF;font-family: Century Gothic;font-size: medium;text-align: left;padding: 0px 20px 0px 0px">2021-02-22 15:45:00-05:00</td>\n      <td style = "background-color: #FFFFFF;font-family: Century Gothic;font-size: medium;text-align: left;padding: 0px 20px 0px 0px">Macd_Updown_Signals</td>\n      <td style = "background-color: #FFFFFF;font-family: Century Gothic;font-size: medium;text-align: left;padding: 0px 20px 0px 0px">BUY</td>\n      <td style = "background-color: #FFFFFF;font-family: Century Gothic ...

# %%
# def send_mail(body):

#     message = MIMEMultipart()
#     message['Subject'] = 'Top 5 Economies of the World!'
#     message['From'] = '<sender>@gmail.com'
#     message['To'] = '<receiver>@gmail.com'

#     body_content = body
#     message.attach(MIMEText(body_content, "html"))
#     msg_body = message.as_string()

#     server = SMTP('smtp.gmail.com', 587)
#     server.starttls()
#     server.login(message['From'], 'Unique password')
#     server.sendmail(message['From'], message['To'], msg_body)
#     server.quit()
    

    
from pretty_html_table import build_table

signal_output = build_table(signal_data, 'blue_light')

sender = 'bradsun9108@163.com'
receiver = list(['bradsun91@163.com','sunmy1991811@qq.com',
#                  '1021580489@qq.com',#东东
#                  'pengfeilian2@creditease.cn',
#                  "1245816903@qq.com"#Michelle
                ])#接收者列表
copyReceive = list()#抄送者列表
copyReceive.append(sender)#将发件人添加到抄送列表
username = 'bradsun9108@163.com'#发件人邮箱账号
password = '1q2w3e4rasdf'#授权密码
mailall=MIMEMultipart()
mailall['Subject'] = "Signals" #记住一定要设置，并且要稍微正式点
mailall['From'] = sender #发件人邮箱
mailall['To'] = ';'.join(receiver) #收件人邮箱,不同收件人邮箱之间用;分割
mailall['CC'] = ';'.join(copyReceive)  #抄送邮箱
mailcontent = "TEST"

mailall.attach(MIMEText(signal_output, 'html'))
mailAttach = '测试邮件附件内容'
contype = 'application/octet-stream'
maintype, subtype = contype.split('/', 1)
# filename = '附加文件.txt'#附件文件所在路径
# attfile = MIMEBase(maintype, subtype)
# attfile.set_payload(open(filename, 'rb').read())
# attfile.add_header('Content-Disposition', 'attachment',filename=('utf-8', '', filename))#必须加上第三个参数，用于格式化输出
# mailall.attach(attfile)
fullmailtext = mailall.as_string()
smtp = smtplib.SMTP()
smtp.connect('smtp.163.com')
smtp.login(username, password)
smtp.sendmail(sender, receiver+copyReceive, fullmailtext)#发送的时候需要将收件人和抄送者全部添加到函数第二个参数里
smtp.quit()
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-111-1f69be12c9a8> in <module>
#      20 from pretty_html_table import build_table
#      21
# ---> 22 signal_output = build_table(signal_data, 'blue_light')
#      23
#      24 sender = 'bradsun9108@163.com'
#
# ~\anaconda3\lib\site-packages\pretty_html_table\pretty_html_table.py in build_table(df, color, font_size, font_family, text_align)
#     139             a += 1
#     140
# --> 141     body = body + """</p>"""
#     142
#     143     body = body.replace("""</td>
#
# UnboundLocalError: local variable 'body' referenced before assignment
