# %%
import pandas as pd, numpy as np
from datetime import datetime
import statsmodels.api as sm
import yfinance as yf
import time, urllib
import glob
import os

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set(context='notebook', style='darkgrid', palette='deep', font='sans-serif', font_scale=1, color_codes=False, rc=None)

# 导入自己的模块
from data_download_US_HK import *
from strategies import *
from positions import *

# %% [markdown]
# # 模块一：下载数据到csv文件

# %%
us_tickers_to_load = list(set(US_TICKERS_POOL.us_tech_stocks() + \
			              US_TICKERS_POOL.us_blockchain_stocks() + \
			              US_TICKERS_POOL.us_saas_stocks() + \
			              US_TICKERS_POOL.us_biotech_stocks() + \
			              US_TICKERS_POOL.us_new_energy_stocks() + \
			              US_TICKERS_POOL.global_etfs() + \
			              US_TICKERS_POOL.sector_etf() + \
			              US_TICKERS_POOL.global_indices() +\
			              US_TICKERS_POOL.us_healthcare_stocks() +\
			              US_TICKERS_POOL.us_fin_stocks() +\
			              US_TICKERS_POOL.us_utilities_stocks() +\
			              US_TICKERS_POOL.us_materials_stocks() +\
			              US_TICKERS_POOL.other_us_stocks() +\
                            US_TICKERS_POOL.us_consumer_discretionary_stocks() +\
                            US_TICKERS_POOL.us_consumer_staples_stocks() +\
                            US_TICKERS_POOL.us_industrial_stocks() +\
                            US_TICKERS_POOL.us_real_estate_stocks() +\
                            US_TICKERS_POOL.us_tele_entertainment_stocks()))

hk_tickers_to_load = HK_TICERS_POOL.HK_tickers()

CN_mutual_funds = CN_TICKERS_POOL.CN_fund_tickers()

all_tickers_to_load = all_tickers()

start = "2005-01-01"
today = LOAD_DATA.today_dt()
end = today

# 如果用这个yesterday，则代表着只需要到昨天的数据
# end_yesterday = "2021-03-02"

us_db_path = "C:/Users/Administrator/CE_github_2/data_pipeline/Data/"
# Out:
# All Tickers: 320

# %%
# Download data from Sina:
# LOAD_DATA.download_data_from_Sina(CN_mutual_funds, start, end, us_db_path)

# %%
data_list_selected = LOAD_DATA.read_data_from_folders(CN_mutual_funds, us_db_path)
# Out:
# Loadig Data from DB: No.1 / 16: 161005
# Loadig Data from DB: No.2 / 16: 010358
# Loadig Data from DB: No.3 / 16: 001888
# Loadig Data from DB: No.4 / 16: 004851
# Loadig Data from DB: No.5 / 16: 161725
# Loadig Data from DB: No.6 / 16: 003096
# Loadig Data from DB: No.7 / 16: 000452
# Loadig Data from DB: No.8 / 16: 004233
# Loadig Data from DB: No.9 / 16: 005827
# Loadig Data from DB: No.10 / 16: 009865
# Loadig Data from DB: No.11 / 16: 001508
# Loadig Data from DB: No.12 / 16: 006792
# Loadig Data from DB: No.13 / 16: 001838
# Loadig Data from DB: No.14 / 16: 011609
# Loadig Data from DB: No.15 / 16: 010849
# Loadig Data from DB: No.16 / 16: 110011

# %%
# Generate signals
daily_macd_updown_signals = GENERATE_SIGNALS.generate_signals_macd_updown_ma_slope( 
                                                                           data_list_selected,
#                                                                            CN_fund_data,
                                                                          "Macd_Updown_MA_Slope_Signals", 
                                                                          "Date", 
                                                                          "Adj Close", 
                                                                          "Ticker", 
                                                                          "D")
# Out:
# Signals(D) Prepared for No.1 : 161005
# Signals(D) Prepared for No.2 : 10358
# Signals(D) Prepared for No.3 : 1888
# Signals(D) Prepared for No.4 : 4851
# Signals(D) Prepared for No.5 : 161725
# Signals(D) Prepared for No.6 : 3096
# Signals(D) Prepared for No.7 : 452
# Signals(D) Prepared for No.8 : 4233
# Signals(D) Prepared for No.9 : 5827
# Signals(D) Prepared for No.10 : 9865
# Signals(D) Prepared for No.11 : 1508
# Signals(D) Prepared for No.12 : 6792
# Signals(D) Prepared for No.13 : 1838
# Signals(D) Prepared for No.14 : 11609
# Signals(D) Prepared for No.15 : 10849
# Signals(D) Prepared for No.16 : 110011
# -------------------------
# All Done!

# %%
daily_macd_updown_signals
# Out:
#     Ticker   Last_Date Signal                    model_name model_freq
# 0   161005  2021-03-25   其他状态  Macd_Updown_MA_Slope_Signals          D
# 1    10358  2021-03-19   其他状态  Macd_Updown_MA_Slope_Signals          D
# 2     1888  2021-03-25   空头持有  Macd_Updown_MA_Slope_Signals          D
# 3     4851  2021-03-25   多头持有  Macd_Updown_MA_Slope_Signals          D
# 4   161725  2021-03-25   其他状态  Macd_Updown_MA_Slope_Signals          D
# 5     3096  2021-03-25   多头持有  Macd_Updown_MA_Slope_Signals          D
# 6      452  2021-03-25   多头持有  Macd_Updown_MA_Slope_Signals          D
# 7     4233  2021-03-25   空头持有  Macd_Updown_MA_Slope_Signals          D
# 8     5827  2021-03-25   空头持有  Macd_Updown_MA_Slope_Signals          D
# 9     9865  2021-03-25   其他状态  Macd_Updown_MA_Slope_Signals          D
# 10    1508  2021-03-25   其他状态  Macd_Updown_MA_Slope_Signals          D
# 11    6792  2021-03-24   空头持有  Macd_Updown_MA_Slope_Signals          D
# 12    1838  2021-03-25   其他状态  Macd_Updown_MA_Slope_Signals          D
# 13   11609  2021-03-19   其他状态  Macd_Updown_MA_Slope_Signals          D
# 14   10849  2021-03-25   其他状态  Macd_Updown_MA_Slope_Signals          D
# 15  110011  2021-03-25   其他状态  Macd_Updown_MA_Slope_Signals          D

# %%
daily_macd_updown_signals_to_present = daily_macd_updown_signals[daily_macd_updown_signals['Signal']=="买入"]
daily_macd_updown_signals_to_present["满足的趋势形态"] = "前一日MACD值开始向上反转，并且价格收盘于5日均线之上，并且10日均线处于上升状态"
daily_macd_updown_signals_to_present.columns = ['股票代号','最新收盘日','信号','模型名称','模型频率','满足的趋势形态']

# %%
daily_macd_updown_signals_to_present[['股票代号','最新收盘日','满足的趋势形态']]
# Out:
# Empty DataFrame
# Columns: [股票代号, 最新收盘日, 满足的趋势形态]
# Index: []

# %%
daily_macd_updown_signals
# Out:
#     Ticker   Last_Date Signal                    model_name model_freq
# 0      BLK  2021-03-25   其他状态  Macd_Updown_MA_Slope_Signals          D
# 1     AAPL  2021-03-25   空头持有  Macd_Updown_MA_Slope_Signals          D
# 2     VLDR  2021-03-25   空头持有  Macd_Updown_MA_Slope_Signals          D
# 3     CHWY  2021-03-25   空头持有  Macd_Updown_MA_Slope_Signals          D
# 4      SRE  2021-03-25     买入  Macd_Updown_MA_Slope_Signals          D
# ..     ...         ...    ...                           ...        ...
# 238    STZ  2021-03-25   其他状态  Macd_Updown_MA_Slope_Signals          D
# 239   UVXY  2021-03-25   其他状态  Macd_Updown_MA_Slope_Signals          D
# 240    DIS  2021-03-25   空头持有  Macd_Updown_MA_Slope_Signals          D
# 241    DLR  2021-03-25   其他状态  Macd_Updown_MA_Slope_Signals          D
# 242    TSN  2021-03-25   其他状态  Macd_Updown_MA_Slope_Signals          D
#
# [243 rows x 5 columns]

# %%
signal_path = "C:/Users/Administrator/CE_github_2/data_pipeline/Signals/"

###################################
signal_file = signal_path+end+"_signals"+"_D_US_mkt"+".csv"
###################################

# merged_daily_weekly.to_csv(signal_file)
daily_macd_updown_signals.to_csv(signal_file)

# %%
signal = pd.read_csv(signal_file)
perf = pd.read_csv("C:/Users/Administrator/CE_github_2/data_pipeline/Performance/US_performance_MACD_UPDOWN_MA_SLOPE_W_COMM_all.csv")
# support and resistance:
# sar_signal = pd.read_csv("C:/Users/Administrator/CE_github_2/data_pipeline/Signals/2021-03-24_SAR_signals_D_US_mkt.csv")

# %%
merged = perf.merge(signal, on = "Ticker")
# merged.dropna(inplace = True)
# merged = merged.merge(sar_signal, on = "Ticker")

# %%
merged_buy = merged[merged['Signal']=='买入']

# %%
merged_buy
# Out:
#     Ticker  total_commission  gross_profit  net_profit commission_impact  \
# 93     APD               278       1243.75      965.75            22.35%
# 130    AZO               226        439.98      213.98            51.37%
# 182    JNJ               264       -383.49     -647.49            68.84%
# 183    JNJ               264       -285.69     -549.69            92.41%
#
#      win %  PL Ratio  overall_score            strat_name  commission  ...  \
# 93   42.03      1.82           0.18  MACD_UPDOWN_MA_SLOPE           2  ...
# 130  44.64      1.31           0.03  MACD_UPDOWN_MA_SLOPE           2  ...
# 182  43.94      1.08          -0.09  MACD_UPDOWN_MA_SLOPE           2  ...
# 183  42.42      1.12          -0.10  MACD_UPDOWN_MA_SLOPE           2  ...
#
#     Unnamed: 11  Unnamed: 12  Unnamed: 13  Unnamed: 14  Unnamed: 15  \
# 93          NaN          NaN          NaN          NaN          NaN
# 130         NaN          NaN          NaN          NaN          NaN
# 182         NaN          NaN          NaN          NaN          NaN
# 183         NaN          NaN          NaN          NaN          NaN
#
#      Unnamed: 0   Last_Date Signal                    model_name model_freq
# 93          234  2021-03-24     买入  Macd_Updown_MA_Slope_Signals          D
# 130          88  2021-03-24     买入  Macd_Updown_MA_Slope_Signals          D
# 182         236  2021-03-24     买入  Macd_Updown_MA_Slope_Signals          D
# 183         236  2021-03-24     买入  Macd_Updown_MA_Slope_Signals          D
#
# [4 rows x 21 columns]

# %%
merged_buy_os = merged_buy[merged_buy['overall_score']>0]

# %%
merged_buy
# Out:
#    Ticker  total_commission  gross_profit  net_profit commission_impact  \
# 13    CMG               268       3171.74     2903.74             8.45%
# 31  GOOGL               268       1396.69     1128.69            19.19%
# 32  GOOGL               268        977.00      709.00            27.43%
# 35   GOOG               268       1127.56      859.56            23.77%
# 60     SO               296         29.31     -266.69          1010.03%
# 78   CHTR               284      -1524.35    -1808.35            18.63%
#
#     win %  PL Ratio  overall_score            strat_name  commission  ...  \
# 13  46.27      2.04           0.41  MACD_UPDOWN_MA_SLOPE           2  ...
# 31  50.75      1.23           0.13  MACD_UPDOWN_MA_SLOPE           2  ...
# 32  49.25      1.26           0.11  MACD_UPDOWN_MA_SLOPE           2  ...
# 35  49.25      1.22           0.09  MACD_UPDOWN_MA_SLOPE           2  ...
# 60  35.14      1.69          -0.05  MACD_UPDOWN_MA_SLOPE           2  ...
# 78  38.03      1.06          -0.22  MACD_UPDOWN_MA_SLOPE           2  ...
#
#    Unnamed: 0_x   Last_Date  Signal                    model_name  model_freq  \
# 13          113  2021-03-23      买入  Macd_Updown_MA_Slope_Signals           D
# 31          216  2021-03-23      买入  Macd_Updown_MA_Slope_Signals           D
# 32          216  2021-03-23      买入  Macd_Updown_MA_Slope_Signals           D
# 35          198  2021-03-23      买入  Macd_Updown_MA_Slope_Signals           D
# 60           61  2021-03-23      买入  Macd_Updown_MA_Slope_Signals           D
# 78           42  2021-03-23      买入  Macd_Updown_MA_Slope_Signals           D
#
#     Unnamed: 0_y        Date    Signal_Info   Last_Price Nearest_Level
# 13             7  2021-03-23  形成支撑点:1442.94  1451.290039   1442.939941
# 31            14  2021-03-23  形成支撑点:2002.93  2041.329956   2002.930054
# 32            14  2021-03-23  形成支撑点:2002.93  2041.329956   2002.930054
# 35           210  2021-03-23  形成支撑点:2017.68  2052.959961   2017.680054
# 60             6  2021-03-23     形成支撑点:60.5    60.630001     60.501568
# 78           117  2021-03-23   形成支撑点:642.79   645.450012    642.789978
#
# [6 rows x 26 columns]

# %%
merged_buy_os_to_present = merged_buy_os[['Ticker','Last_Date','Signal_Info','Nearest_Level',"overall_score"]]

# %%
merged_buy_os_to_present.columns = ['股票代号','最新收盘日','满足点位形态','最近点位','回测分数']

# %%
merged_buy_os_to_present[['股票代号','最新收盘日','满足点位形态']].drop_duplicates()
# Out:
#      股票代号       最新收盘日         满足点位形态
# 13    CMG  2021-03-23  形成支撑点:1442.94
# 31  GOOGL  2021-03-23  形成支撑点:2002.93
# 35   GOOG  2021-03-23  形成支撑点:2017.68

# %%
# current portfolio & calculate correlations inside the portfolio

current_portfolio_tickers = ["ARKG",# 跌穿120日均线则止损
                             "BABA",#若当日收盘MACD死叉，则第二日平仓
#                              "BNTX",# 跌下5日均线则平仓，或者涨上111则止盈
#                              "LOW",#涨上183.5止盈；或者跌下5日均线;
                             "TSLA",# 跌穿120日均线则止损
                             "PAYC",
#                              "VZ",# 若当日收盘于5日均线以下，第二天平仓
                             "UPS"#
                            ]

# %%
new_portfolio_tickers = ["GOOGL","CMG","UUP"]

# %%
all_pportfolio_tickers = current_portfolio_tickers+new_portfolio_tickers

# %%
all_pportfolio_tickers
# Out:
# ['ARKG', 'BABA', 'TSLA', 'PAYC', 'UPS', 'GOOGL', 'CMG', 'UUP']

# %%
def stock_list_to_calculate_corr(all_csvs, date_col, price_col, ticker_col):
	len_ = 0
	for fname in glob.glob(all_csvs)[:]:
		try:
			stock = pd.read_csv(fname)
			stock = stock.sort_values(date_col)
			ticker = stock[ticker_col].values[-1]
			print(ticker)
			stock = stock[[date_col,price_col]]
			stock['pct_chg'] = stock[price_col].pct_change()
			stock.columns = [date_col, price_col, ticker]
			stock = stock[[date_col, ticker]].dropna()
			stock[date_col] = pd.to_datetime(stock[date_col])
			#     stock.set_index('date', inplace=True)
			stock_list.append(stock)
			print ("Length of {}: {}".format(ticker, len(stock)))
			len_ = len_+len(stock)
			print ("Total length:{}".format(len_))
			print ("===========")
		except Exception as e:
			print("Error on: {}, {}".format(fname, e))
	return stock_list

# %%
all_csvs = "C:/Users/Administrator/CE_github_2/data_pipeline/Data/*.csv"
date_col = "Date"
price_col = "Adj Close"
ticker_col = "Ticker"
stock_list = []
stock_list = stock_list_to_calculate_corr(all_csvs, date_col, price_col, ticker_col)
merged_all = reduce(merge_df, stock_list)
merged_all.set_index(date_col, inplace=True)
# Out:
# 000001.SS
# Length of 000001.SS: 3936
# Total length:3936
# ===========
# 452
# Length of 452: 1712
# Total length:5648
# ===========
# 0005.HK
# Length of 0005.HK: 3992
# Total length:9640
# ===========
# 0008.HK
# Length of 0008.HK: 3957
# Total length:13597
# ===========
# 1508
# Length of 1508: 1373
# Total length:14970
# ===========
# 1838
# Length of 1838: 1279
# Total length:16249
# ===========
# 1888
# Length of 1888: 1335
# Total length:17584
# ===========
# 3096
# Length of 3096: 1080
# Total length:18664
# ===========
# 4233
# Length of 4233: 1022
# Total length:19686
# ===========
# 4851
# Length of 4851: 866
# Total length:20552
# ===========
# 5827
# Length of 5827: 591
# Total length:21143
# ===========
# 6792
# Length of 6792: 458
# Total length:21601
# ===========
# 9865
# Length of 9865: 51
# Total length:21652
# ===========
# 10358
# Length of 10358: 10
# Total length:21662
# ===========
# 10849
# Length of 10849: 26
# Total length:21688
# ===========
# 11609
# Length of 11609: 3
# Total length:21691
# ===========
# 0142.HK
# Length of 0142.HK: 3985
# Total length:25676
# ===========
# 0151.HK
# Length of 0151.HK: 3195
# Total length:28871
# ===========
# 0175.HK
# Length of 0175.HK: 3803
# Total length:32674
# ===========
# 0186.HK
# Length of 0186.HK: 3988
# Total length:36662
# ===========
# 0215.HK
# Length of 0215.HK: 3988
# Total length:40650
# ===========
# 0241.HK
# Length of 0241.HK: 3975
# Total length:44625
# ===========
# 0268.HK
# Length of 0268.HK: 3809
# Total length:48434
# ===========
# 0285.HK
# Length of 0285.HK: 3255
# Total length:51689
# ===========
# 0302.HK
# Length of 0302.HK: 339
# Total length:52028
# ===========
# 0303.HK
# Length of 0303.HK: 3990
# Total length:56018
# ===========
# 0315.HK
# Length of 0315.HK: 3984
# Total length:60002
# ===========
# 0418.HK
# Length of 0418.HK: 3984
# Total length:63986
# ===========
# 0419.HK
# Length of 0419.HK: 3947
# Total length:67933
# ===========
# 0439.HK
# Length of 0439.HK: 3360
# Total length:71293
# ===========
# 0493.HK
# Length of 0493.HK: 3992
# Total length:75285
# ===========
# 0522.HK
# Length of 0522.HK: 3992
# Total length:79277
# ===========
# 0552.HK
# Length of 0552.HK: 3511
# Total length:82788
# ===========
# 0596.HK
# Length of 0596.HK: 3259
# Total length:86047
# ===========
# 0698.HK
# Length of 0698.HK: 3989
# Total length:90036
# ===========
# 0700.HK
# Length of 0700.HK: 3991
# Total length:94027
# ===========
# 0728.HK
# Length of 0728.HK: 3979
# Total length:98006
# ===========
# 0732.HK
# Length of 0732.HK: 3991
# Total length:101997
# ===========
# 0751.HK
# Length of 0751.HK: 3990
# Total length:105987
# ===========
# 0762.HK
# Length of 0762.HK: 3982
# Total length:109969
# ===========
# 0763.HK
# Length of 0763.HK: 3991
# Total length:113960
# ===========
# 0777.HK
# Length of 0777.HK: 3290
# Total length:117250
# ===========
# 0788.HK
# Length of 0788.HK: 642
# Total length:117892
# ===========
# 0797.HK
# Length of 0797.HK: 657
# Total length:118549
# ===========
# 0799.HK
# Length of 0799.HK: 1828
# Total length:120377
# ===========
# 0941.HK
# Length of 0941.HK: 3988
# Total length:124365
# ===========
# 0981.HK
# Length of 0981.HK: 3988
# Total length:128353
# ===========
# 1024.HK
# Length of 1024.HK: 25
# Total length:128378
# ===========
# 1070.HK
# Length of 1070.HK: 3978
# Total length:132356
# ===========
# 110011
# Length of 110011: 3065
# Total length:135421
# ===========
# 1119.HK
# Length of 1119.HK: 559
# Total length:135980
# ===========
# 1137.HK
# Length of 1137.HK: 3958
# Total length:139938
# ===========
# 1310.HK
# Length of 1310.HK: 1483
# Total length:141421
# ===========
# 1347.HK
# Length of 1347.HK: 1584
# Total length:143005
# ===========
# 1385.HK
# Length of 1385.HK: 3814
# Total length:146819
# ===========
# 1415.HK
# Length of 1415.HK: 1470
# Total length:148289
# ===========
# 1458.HK
# Length of 1458.HK: 1070
# Total length:149359
# ===========
# 1475.HK
# Length of 1475.HK: 802
# Total length:150161
# ===========
# 1478.HK
# Length of 1478.HK: 1550
# Total length:151711
# ===========
# 1566.HK
# Length of 1566.HK: 1483
# Total length:153194
# ===========
# 1588.HK
# Length of 1588.HK: 1586
# Total length:154780
# ===========
# 1610.HK
# Length of 1610.HK: 1078
# Total length:155858
# ===========
# 161005
# Length of 161005: 3749
# Total length:159607
# ===========
# 161725
# Length of 161725: 1419
# Total length:161026
# ===========
# 1675.HK
# Length of 1675.HK: 550
# Total length:161576
# ===========
# 1810.HK
# Length of 1810.HK: 664
# Total length:162240
# ===========
# 1833.HK
# Length of 1833.HK: 707
# Total length:162947
# ===========
# 1883.HK
# Length of 1883.HK: 3431
# Total length:166378
# ===========
# 1909.HK
# Length of 1909.HK: 1253
# Total length:167631
# ===========
# 1979.HK
# Length of 1979.HK: 1297
# Total length:168928
# ===========
# 2018.HK
# Length of 2018.HK: 3843
# Total length:172771
# ===========
# 2038.HK
# Length of 2038.HK: 3955
# Total length:176726
# ===========
# 2051.HK
# Length of 2051.HK: 660
# Total length:177386
# ===========
# 2100.HK
# Length of 2100.HK: 1709
# Total length:179095
# ===========
# 2255.HK
# Length of 2255.HK: 1729
# Total length:180824
# ===========
# 2309.HK
# Length of 2309.HK: 3705
# Total length:184529
# ===========
# 2318.HK
# Length of 2318.HK: 3943
# Total length:188472
# ===========
# 2342.HK
# Length of 2342.HK: 3992
# Total length:192464
# ===========
# 2369.HK
# Length of 2369.HK: 3983
# Total length:196447
# ===========
# 2382.HK
# Length of 2382.HK: 3383
# Total length:199830
# ===========
# 2400.HK
# Length of 2400.HK: 309
# Total length:200139
# ===========
# 3690.HK
# Length of 3690.HK: 611
# Total length:200750
# ===========
# 3738.HK
# Length of 3738.HK: 787
# Total length:201537
# ===========
# 3798.HK
# Length of 3798.HK: 420
# Total length:201957
# ===========
# 3799.HK
# Length of 3799.HK: 1312
# Total length:203269
# ===========
# 3888.HK
# Length of 3888.HK: 3308
# Total length:206577
# ===========
# 6055.HK
# Length of 6055.HK: 437
# Total length:207014
# ===========
# 6060.HK
# Length of 6060.HK: 850
# Total length:207864
# ===========
# 6088.HK
# Length of 6088.HK: 905
# Total length:208769
# ===========
# 6188.HK
# Length of 6188.HK: 1652
# Total length:210421
# ===========
# 6618.HK
# Length of 6618.HK: 66
# Total length:210487
# ===========
# 6820.HK
# Length of 6820.HK: 356
# Total length:210843
# ===========
# 6823.HK
# Length of 6823.HK: 3955
# Total length:214798
# ===========
# 6862.HK
# Length of 6862.HK: 606
# Total length:215404
# ===========
# 6869.HK
# Length of 6869.HK: 1544
# Total length:216948
# ===========
# 6969.HK
# Length of 6969.HK: 169
# Total length:217117
# ===========
# 6993.HK
# Length of 6993.HK: 60
# Total length:217177
# ===========
# 8029.HK
# Length of 8029.HK: 3618
# Total length:220795
# ===========
# 8032.HK
# Length of 8032.HK: 3553
# Total length:224348
# ===========
# 9988.HK
# Length of 9988.HK: 321
# Total length:224669
# ===========
# 9990.HK
# Length of 9990.HK: 166
# Total length:224835
# ===========
# 9992.HK
# Length of 9992.HK: 63
# Total length:224898
# ===========
# 9999.HK
# Length of 9999.HK: 188
# Total length:225086
# ===========
# AAPL
# Length of AAPL: 4082
# Total length:229168
# ===========
# ABBV
# Length of ABBV: 2069
# Total length:231237
# ===========
# ABT
# Length of ABT: 4083
# Total length:235320
# ===========
# ACOR
# Length of ACOR: 3801
# Total length:239121
# ===========
# ADBE
# Length of ADBE: 4083
# Total length:243204
# ===========
# ADP
# Length of ADP: 4083
# Total length:247287
# ===========
# ADSK
# Length of ADSK: 4083
# Total length:251370
# ===========
# AEMD
# Length of AEMD: 4081
# Total length:255451
# ===========
# AEP
# Length of AEP: 4083
# Total length:259534
# ===========
# AHPI
# Length of AHPI: 4081
# Total length:263615
# ===========
# ALB
# Length of ALB: 4083
# Total length:267698
# ===========
# AMD
# Length of AMD: 4083
# Total length:271781
# ===========
# AMGN
# Length of AMGN: 4083
# Total length:275864
# ===========
# AMT
# Length of AMT: 4083
# Total length:279947
# ===========
# AMZN
# Length of AMZN: 4083
# Total length:284030
# ===========
# APD
# Length of APD: 4083
# Total length:288113
# ===========
# APT
# Length of APT: 4081
# Total length:292194
# ===========
# ARKF
# Length of ARKF: 537
# Total length:292731
# ===========
# ARKG
# Length of ARKG: 1607
# Total length:294338
# ===========
# ARKK
# Length of ARKK: 1607
# Total length:295945
# ===========
# ARKQ
# Length of ARKQ: 1630
# Total length:297575
# ===========
# ARKW
# Length of ARKW: 1630
# Total length:299205
# ===========
# ARPO
# Length of ARPO: 776
# Total length:299981
# ===========
# ATVI
# Length of ATVI: 4083
# Total length:304064
# ===========
# AXP
# Length of AXP: 4083
# Total length:308147
# ===========
# AZN
# Length of AZN: 4083
# Total length:312230
# ===========
# AZO
# Length of AZO: 4083
# Total length:316313
# ===========
# BA
# Length of BA: 4083
# Total length:320396
# ===========
# BABA
# Length of BABA: 1637
# Total length:322033
# ===========
# BAC
# Length of BAC: 4083
# Total length:326116
# ===========
# BBY
# Length of BBY: 4083
# Total length:330199
# ===========
# BILI
# Length of BILI: 751
# Total length:330950
# ===========
# BLK
# Length of BLK: 4083
# Total length:335033
# ===========
# BLNK
# Length of BLNK: 2831
# Total length:337864
# ===========
# BMY
# Length of BMY: 4083
# Total length:341947
# ===========
# BNTX
# Length of BNTX: 364
# Total length:342311
# ===========
# BX
# Length of BX: 3461
# Total length:345772
# ===========
# C
# Length of C: 4083
# Total length:349855
# ===========
# CAN
# Length of CAN: 335
# Total length:350190
# ===========
# CAT
# Length of CAT: 4083
# Total length:354273
# ===========
# CB
# Length of CB: 4083
# Total length:358356
# ===========
# CBLI
# Length of CBLI: 3688
# Total length:362044
# ===========
# CCI
# Length of CCI: 4083
# Total length:366127
# ===========
# CDAY
# Length of CDAY: 731
# Total length:366858
# ===========
# CHTR
# Length of CHTR: 2822
# Total length:369680
# ===========
# CHWY
# Length of CHWY: 446
# Total length:370126
# ===========
# CL
# Length of CL: 4083
# Total length:374209
# ===========
# CMCSA
# Length of CMCSA: 4083
# Total length:378292
# ===========
# CMG
# Length of CMG: 3814
# Total length:382106
# ===========
# CNET
# Length of CNET: 2918
# Total length:385024
# ===========
# CODX
# Length of CODX: 928
# Total length:385952
# ===========
# COST
# Length of COST: 4083
# Total length:390035
# ===========
# COUP
# Length of COUP: 1121
# Total length:391156
# ===========
# CRM
# Length of CRM: 4083
# Total length:395239
# ===========
# CRVS
# Length of CRVS: 1256
# Total length:396495
# ===========
# CRWD
# Length of CRWD: 448
# Total length:396943
# ===========
# CSCO
# Length of CSCO: 4083
# Total length:401026
# ===========
# CVS
# Length of CVS: 4083
# Total length:405109
# ===========
# CYB
# Length of CYB: 3230
# Total length:408339
# ===========
# CZR
# Length of CZR: 1636
# Total length:409975
# ===========
# D
# Length of D: 4083
# Total length:414058
# ===========
# DBA
# Length of DBA: 3577
# Total length:417635
# ===========
# DBC
# Length of DBC: 3807
# Total length:421442
# ===========
# DBX
# Length of DBX: 754
# Total length:422196
# ===========
# DD
# Length of DD: 4083
# Total length:426279
# ===========
# DDOG
# Length of DDOG: 379
# Total length:426658
# ===========
# DFFN
# Length of DFFN: 3227
# Total length:429885
# ===========
# DHR
# Length of DHR: 4083
# Total length:433968
# ===========
# DIS
# Length of DIS: 4083
# Total length:438051
# ===========
# DLR
# Length of DLR: 4083
# Total length:442134
# ===========
# DOCU
# Length of DOCU: 730
# Total length:442864
# ===========
# DUK
# Length of DUK: 4083
# Total length:446947
# ===========
# EBAY
# Length of EBAY: 4083
# Total length:451030
# ===========
# EBON
# Length of EBON: 185
# Total length:451215
# ===========
# ECL
# Length of ECL: 4083
# Total length:455298
# ===========
# EL
# Length of EL: 4083
# Total length:459381
# ===========
# ENPH
# Length of ENPH: 2258
# Total length:461639
# ===========
# EQ
# Length of EQ: 611
# Total length:462250
# ===========
# EQIX
# Length of EQIX: 4083
# Total length:466333
# ===========
# ES
# Length of ES: 4083
# Total length:470416
# ===========
# EWA
# Length of EWA: 4083
# Total length:474499
# ===========
# EWC
# Length of EWC: 4083
# Total length:478582
# ===========
# EWG
# Length of EWG: 4083
# Total length:482665
# ===========
# EWH
# Length of EWH: 4083
# Total length:486748
# ===========
# EWJ
# Length of EWJ: 4083
# Total length:490831
# ===========
# EWL
# Length of EWL: 4083
# Total length:494914
# ===========
# EWT
# Length of EWT: 4083
# Total length:498997
# ===========
# EWU
# Length of EWU: 4083
# Total length:503080
# ===========
# EWW
# Length of EWW: 4083
# Total length:507163
# ===========
# EWY
# Length of EWY: 4083
# Total length:511246
# ===========
# EWZ
# Length of EWZ: 4083
# Total length:515329
# ===========
# EXC
# Length of EXC: 4083
# Total length:519412
# ===========
# FB
# Length of FB: 2224
# Total length:521636
# ===========
# FCEL
# Length of FCEL: 4083
# Total length:525719
# ===========
# FLS
# Length of FLS: 4083
# Total length:529802
# ===========
# FMC
# Length of FMC: 4083
# Total length:533885
# ===========
# FXB
# Length of FXB: 3710
# Total length:537595
# ===========
# FXE
# Length of FXE: 3844
# Total length:541439
# ===========
# FXF
# Length of FXF: 3710
# Total length:545149
# ===========
# FXI
# Length of FXI: 4083
# Total length:549232
# ===========
# FXY
# Length of FXY: 3551
# Total length:552783
# ===========
# GBTC
# Length of GBTC: 1477
# Total length:554260
# ===========
# GDDY
# Length of GDDY: 1505
# Total length:555765
# ===========
# GDX
# Length of GDX: 3734
# Total length:559499
# ===========
# GE
# Length of GE: 4083
# Total length:563582
# ===========
# GILD
# Length of GILD: 4083
# Total length:567665
# ===========
# GLD
# Length of GLD: 4083
# Total length:571748
# ===========
# GOOG
# Length of GOOG: 4083
# Total length:575831
# ===========
# GOOGL
# Length of GOOGL: 4083
# Total length:579914
# ===========
# GS
# Length of GS: 4083
# Total length:583997
# ===========
# HD
# Length of HD: 4083
# Total length:588080
# ===========
# HON
# Length of HON: 4083
# Total length:592163
# ===========
# HTBX
# Length of HTBX: 1927
# Total length:594090
# ===========
# HUBS
# Length of HUBS: 1623
# Total length:595713
# ===========
# IBIO
# Length of IBIO: 3167
# Total length:598880
# ===========
# IEF
# Length of IEF: 4083
# Total length:602963
# ===========
# INDA
# Length of INDA: 2297
# Total length:605260
# ===========
# INO
# Length of INO: 4083
# Total length:609343
# ===========
# INTC
# Length of INTC: 4083
# Total length:613426
# ===========
# INTU
# Length of INTU: 4083
# Total length:617509
# ===========
# ISRG
# Length of ISRG: 4083
# Total length:621592
# ===========
# JD
# Length of JD: 1720
# Total length:623312
# ===========
# JNJ
# Length of JNJ: 4083
# Total length:627395
# ===========
# JPM
# Length of JPM: 4083
# Total length:631478
# ===========
# KHC
# Length of KHC: 1439
# Total length:632917
# ===========
# KO
# Length of KO: 4083
# Total length:637000
# ===========
# LAC
# Length of LAC: 3148
# Total length:640148
# ===========
# LAKE
# Length of LAKE: 4081
# Total length:644229
# ===========
# LAZR
# Length of LAZR: 503
# Total length:644732
# ===========
# LFIN
# Length of LFIN: 821
# Total length:645553
# ===========
# LI
# Length of LI: 162
# Total length:645715
# ===========
# LIN
# Length of LIN: 4083
# Total length:649798
# ===========
# LLY
# Length of LLY: 4083
# Total length:653881
# ===========
# LMT
# Length of LMT: 4083
# Total length:657964
# ===========
# LOW
# Length of LOW: 4083
# Total length:662047
# ===========
# LTHM
# Length of LTHM: 614
# Total length:662661
# ===========
# LULU
# Length of LULU: 3436
# Total length:666097
# ===========
# LVS
# Length of LVS: 4083
# Total length:670180
# ===========
# MA
# Length of MA: 3731
# Total length:673911
# ===========
# MARA
# Length of MARA: 2234
# Total length:676145
# ===========
# MCD
# Length of MCD: 4083
# Total length:680228
# ===========
# MDT
# Length of MDT: 4083
# Total length:684311
# ===========
# MET
# Length of MET: 4083
# Total length:688394
# ===========
# MMM
# Length of MMM: 4083
# Total length:692477
# ===========
# MRK
# Length of MRK: 4083
# Total length:696560
# ===========
# MRNA
# Length of MRNA: 575
# Total length:697135
# ===========
# MS
# Length of MS: 4083
# Total length:701218
# ===========
# MSFT
# Length of MSFT: 4083
# Total length:705301
# ===========
# MU
# Length of MU: 4083
# Total length:709384
# ===========
# NCTY
# Length of NCTY: 4081
# Total length:713465
# ===========
# NEE
# Length of NEE: 4083
# Total length:717548
# ===========
# NEM
# Length of NEM: 4083
# Total length:721631
# ===========
# NFLX
# Length of NFLX: 4083
# Total length:725714
# ===========
# NIO
# Length of NIO: 635
# Total length:726349
# ===========
# NKE
# Length of NKE: 4083
# Total length:730432
# ===========
# NNVC
# Length of NNVC: 3874
# Total length:734306
# ===========
# NOVA
# Length of NOVA: 418
# Total length:734724
# ===========
# NOW
# Length of NOW: 2195
# Total length:736919
# ===========
# NVAX
# Length of NVAX: 4083
# Total length:741002
# ===========
# NVDA
# Length of NVDA: 4083
# Total length:745085
# ===========
# OKTA
# Length of OKTA: 995
# Total length:746080
# ===========
# OPEN
# Length of OPEN: 191
# Total length:746271
# ===========
# ORCL
# Length of ORCL: 4083
# Total length:750354
# ===========
# OSTK
# Length of OSTK: 4083
# Total length:754437
# ===========
# PAYC
# Length of PAYC: 1746
# Total length:756183
# ===========
# PDD
# Length of PDD: 668
# Total length:756851
# ===========
# PEP
# Length of PEP: 4083
# Total length:760934
# ===========
# PFE
# Length of PFE: 4083
# Total length:765017
# ===========
# PG
# Length of PG: 4083
# Total length:769100
# ===========
# PLD
# Length of PLD: 4083
# Total length:773183
# ===========
# PLUG
# Length of PLUG: 4083
# Total length:777266
# ===========
# PM
# Length of PM: 3277
# Total length:780543
# ===========
# PSA
# Length of PSA: 4083
# Total length:784626
# ===========
# PTON
# Length of PTON: 374
# Total length:785000
# ===========
# PYPL
# Length of PYPL: 1439
# Total length:786439
# ===========
# QCOM
# Length of QCOM: 4083
# Total length:790522
# ===========
# QQQ
# Length of QQQ: 4083
# Total length:794605
# ===========
# QS
# Length of QS: 150
# Total length:794755
# ===========
# RACE
# Length of RACE: 1363
# Total length:796118
# ===========
# RENN
# Length of RENN: 2485
# Total length:798603
# ===========
# RIOT
# Length of RIOT: 1253
# Total length:799856
# ===========
# RNG
# Length of RNG: 1883
# Total length:801739
# ===========
# RSX
# Length of RSX: 3499
# Total length:805238
# ===========
# RTX
# Length of RTX: 4083
# Total length:809321
# ===========
# RUN
# Length of RUN: 1417
# Total length:810738
# ===========
# SAM
# Length of SAM: 4083
# Total length:814821
# ===========
# SAP
# Length of SAP: 4083
# Total length:818904
# ===========
# SBAC
# Length of SBAC: 4083
# Total length:822987
# ===========
# SBE
# Length of SBE: 382
# Total length:823369
# ===========
# SBUX
# Length of SBUX: 4083
# Total length:827452
# ===========
# SCCO
# Length of SCCO: 4083
# Total length:831535
# ===========
# SHOP
# Length of SHOP: 1470
# Total length:833005
# ===========
# SHW
# Length of SHW: 4083
# Total length:837088
# ===========
# SMAR
# Length of SMAR: 730
# Total length:837818
# ===========
# SO
# Length of SO: 4083
# Total length:841901
# ===========
# SPLK
# Length of SPLK: 2245
# Total length:844146
# ===========
# SPOT
# Length of SPOT: 748
# Total length:844894
# ===========
# SPY
# Length of SPY: 4083
# Total length:848977
# ===========
# SQ
# Length of SQ: 1342
# Total length:850319
# ===========
# SQM
# Length of SQM: 4083
# Total length:854402
# ===========
# SRAX
# Length of SRAX: 2117
# Total length:856519
# ===========
# SRE
# Length of SRE: 4083
# Total length:860602
# ===========
# STZ
# Length of STZ: 4083
# Total length:864685
# ===========
# T
# Length of T: 4083
# Total length:868768
# ===========
# TEAM
# Length of TEAM: 1329
# Total length:870097
# ===========
# TGT
# Length of TGT: 4083
# Total length:874180
# ===========
# TLT
# Length of TLT: 4083
# Total length:878263
# ===========
# TMO
# Length of TMO: 4083
# Total length:882346
# ===========
# TMUS
# Length of TMUS: 3506
# Total length:885852
# ===========
# TQQQ
# Length of TQQQ: 2796
# Total length:888648
# ===========
# TSLA
# Length of TSLA: 2701
# Total length:891349
# ===========
# TSM
# Length of TSM: 4083
# Total length:895432
# ===========
# TSN
# Length of TSN: 4083
# Total length:899515
# ===========
# TTD
# Length of TTD: 1132
# Total length:900647
# ===========
# TWLO
# Length of TWLO: 1194
# Total length:901841
# ===========
# UNH
# Length of UNH: 4083
# Total length:905924
# ===========
# UNP
# Length of UNP: 4083
# Total length:910007
# ===========
# UPS
# Length of UPS: 4083
# Total length:914090
# ===========
# UUP
# Length of UUP: 3540
# Total length:917630
# ===========
# UVXY
# Length of UVXY: 2381
# Total length:920011
# ===========
# V
# Length of V: 3275
# Total length:923286
# ===========
# VCNX
# Length of VCNX: 658
# Total length:923944
# ===========
# VEEV
# Length of VEEV: 1870
# Total length:925814
# ===========
# VIR
# Length of VIR: 363
# Total length:926177
# ===========
# VLDR
# Length of VLDR: 603
# Total length:926780
# ===========
# VXRT
# Length of VXRT: 4081
# Total length:930861
# ===========
# VXX
# Length of VXX: 794
# Total length:931655
# ===========
# VZ
# Length of VZ: 4083
# Total length:935738
# ===========
# WDAY
# Length of WDAY: 2122
# Total length:937860
# ===========
# WES
# Length of WES: 2084
# Total length:939944
# ===========
# WFC
# Length of WFC: 4083
# Total length:944027
# ===========
# WMT
# Length of WMT: 4083
# Total length:948110
# ===========
# WORK
# Length of WORK: 442
# Total length:948552
# ===========
# XEL
# Length of XEL: 4083
# Total length:952635
# ===========
# XL
# Length of XL: 391
# Total length:953026
# ===========
# XLB
# Length of XLB: 4083
# Total length:957109
# ===========
# XLC
# Length of XLC: 694
# Total length:957803
# ===========
# XLE
# Length of XLE: 4083
# Total length:961886
# ===========
# XLF
# Length of XLF: 4083
# Total length:965969
# ===========
# XLI
# Length of XLI: 4083
# Total length:970052
# ===========
# XLK
# Length of XLK: 4083
# Total length:974135
# ===========
# XLP
# Length of XLP: 4083
# Total length:978218
# ===========
# XLRE
# Length of XLRE: 1372
# Total length:979590
# ===========
# XLU
# Length of XLU: 4083
# Total length:983673
# ===========
# XLV
# Length of XLV: 4083
# Total length:987756
# ===========
# XLY
# Length of XLY: 4083
# Total length:991839
# ===========
# XNET
# Length of XNET: 1696
# Total length:993535
# ===========
# XPEV
# Length of XPEV: 142
# Total length:993677
# ===========
# ZEN
# Length of ZEN: 1725
# Total length:995402
# ===========
# ZM
# Length of ZM: 485
# Total length:995887
# ===========
# ^DJI
# Length of ^DJI: 4083
# Total length:999970
# ===========
# ^GSPC
# Length of ^GSPC: 4083
# Total length:1004053
# ===========
# ^HSI
# Length of ^HSI: 3991
# Total length:1008044
# ===========
# ^IXIC
# Length of ^IXIC: 4083
# Total length:1012127
# ===========

# %%
def plot_heatmap_corrleation(data, stock_list):
    plt.figure(figsize=(13, 10))
    sns.heatmap(data[stock_list].corr(), annot=True, cmap = 'Blues', vmax = 1.0, vmin = -1.0)
    plt.xlabel('stocks')
    plt.ylabel('stocks')
    plt.show()

# %%
plot_heatmap_corrleation(merged_all,all_pportfolio_tickers)

# %%
corr_matrix = merged_all[new_portfolio_tickers].corr()
each_corr_mean = corr_matrix[corr_matrix!=1].mean()

# %%
each_corr_mean
# Out:
# GOOGL    0.147221
# CMG      0.157818
# UUP     -0.057501
# dtype: float64

# %%
selected_new_tickers = [
#                         'UPS',#处于上升通道下沿，上穿5日均线，MACD值反转上升。到168左右止盈（0323）
#                         'PAYC', #走出一个三角楔形形态，形成支撑点:376.89	，上穿5日均线，到396.278左右止盈，MACD翻绿即止损（0323）
#                        'CSCO',#限价单49.74买入入场，形成支撑点49.74，并上穿5日均线，趋势向上；止损点48.15，止盈52.3(0323)
#                        'QS'#形成支撑点:59.99，并在5、10、20日均线之上，止损62.6(0323)
                        "GOOGL",
                        "CMG",
                        "UUP"
                       ]

# %%
final_target_portfolio_tickers = current_portfolio_tickers+selected_new_tickers

# %%
stocks_path = "C:/Users/Administrator/CE_github_2/data_pipeline/Data/"
date_col = 'Date'
code_col = 'Ticker'
price_col = 'Adj Close'
ticker_type = 'string'
asset_name = "code"

risk_parity = RiskParity(stocks_path,
                          final_target_portfolio_tickers,
                          date_col,
                          code_col,
                          price_col,
                          ticker_type,
                          asset_name,
                          True)

# %%
df_weights = risk_parity.df_wts.sort_values("weight", ascending=False)

# %%
df_weights
# Out:
#     code    weight
# 7    UUP  0.521881
# 4    UPS  0.101474
# 5  GOOGL  0.077684
# 6    CMG  0.072494
# 1   BABA  0.069954
# 0   ARKG  0.062384
# 3   PAYC  0.048487
# 2   TSLA  0.045642

# %%
largest_pos_wts = 0.1
smallest_pos = 0.05234
benchmark_ratio = largest_pos_wts/df_weights['weight'].values[0]
benchmark_ratio_ = 
df_weights['target_wts'] = df_weights['weight']*benchmark_ratio

# %%
def read_data_from_folders(ticker_list, csv_folder):
    # csv_folder = "C:/Users/Administrator/CE_github_2/data_pipeline/Data/"
    load_count = 1
    last_price_list = []
    last_date_list = []
    len_tickers = len(ticker_list)
    df = pd.DataFrame()
    for ticker in ticker_list:
        print(ticker)
        try:
            data = pd.read_csv(csv_folder+ticker+".csv")
            last_close_price = data['Adj Close'].values[-1]
            last_date = data['Date'].values[-1]
            last_price_list.append(last_close_price)
            last_date_list.append(last_date)
            print ("Data Loaded from DB: No.{} / {}: {}, date:{}".format(load_count, len_tickers, ticker, last_date))
        except Exception as e:
            print(ticker, "Error:", e)
        load_count +=1
    df['adj close'] = last_price_list
    df['code'] = ticker_list
    df['date'] = last_date_list
    return df

# %%
df_portfolio_close = read_data_from_folders(final_target_portfolio_tickers, us_db_path)
# Out:
# ARKG
# Data Loaded from DB: No.1 / 8: ARKG, date:2021-03-23
# BABA
# Data Loaded from DB: No.2 / 8: BABA, date:2021-03-23
# TSLA
# Data Loaded from DB: No.3 / 8: TSLA, date:2021-03-23
# PAYC
# Data Loaded from DB: No.4 / 8: PAYC, date:2021-03-23
# UPS
# Data Loaded from DB: No.5 / 8: UPS, date:2021-03-23
# GOOGL
# Data Loaded from DB: No.6 / 8: GOOGL, date:2021-03-23
# CMG
# Data Loaded from DB: No.7 / 8: CMG, date:2021-03-23
# UUP
# Data Loaded from DB: No.8 / 8: UUP, date:2021-03-23

# %%
df_portfolio_close
# Out:
#      adj close   code        date
# 0    89.320000   ARKG  2021-03-23
# 1   237.669998   BABA  2021-03-23
# 2   662.159973   TSLA  2021-03-23
# 3   373.890015   PAYC  2021-03-23
# 4   159.860001    UPS  2021-03-23
# 5  2041.329956  GOOGL  2021-03-23
# 6  1451.290039    CMG  2021-03-23
# 7    24.879999    UUP  2021-03-23

# %%
df_weights
# Out:
#     code    weight  target_wts
# 7    UUP  0.521881    0.100000
# 4    UPS  0.101474    0.019444
# 5  GOOGL  0.077684    0.014885
# 6    CMG  0.072494    0.013891
# 1   BABA  0.069954    0.013404
# 0   ARKG  0.062384    0.011954
# 3   PAYC  0.048487    0.009291
# 2   TSLA  0.045642    0.008746

# %%
df_weights_close_price = df_weights.merge(df_portfolio_close, on = "code")

# %%
df_weights_close_price['portfolio_asset'] = 100000

# %%
df_weights_close_price
# Out:
#     code    weight  target_wts    adj close        date  portfolio_asset
# 0    UUP  0.521881    0.100000    24.879999  2021-03-23           100000
# 1    UPS  0.101474    0.019444   159.860001  2021-03-23           100000
# 2  GOOGL  0.077684    0.014885  2041.329956  2021-03-23           100000
# 3    CMG  0.072494    0.013891  1451.290039  2021-03-23           100000
# 4   BABA  0.069954    0.013404   237.669998  2021-03-23           100000
# 5   ARKG  0.062384    0.011954    89.320000  2021-03-23           100000
# 6   PAYC  0.048487    0.009291   373.890015  2021-03-23           100000
# 7   TSLA  0.045642    0.008746   662.159973  2021-03-23           100000

# %%
df_weights_close_price["shares"] = round(df_weights_close_price["portfolio_asset"]*df_weights_close_price["target_wts"]/df_weights_close_price['adj close'],0)                 
df_weights_close_price['target_dollar_position'] = df_weights_close_price['adj close']*df_weights_close_price['shares']

# %%
df_weights_close_price[df_weights_close_price["code"].isin(selected_new_tickers)]
# Out:
#     code    weight  target_wts    adj close        date  portfolio_asset  \
# 2  GOOGL  0.132765    0.109849  2041.329956  2021-03-23           100000
# 3    CMG  0.125944    0.104205  1451.290039  2021-03-23           100000
#
#    shares  target_dollar_position
# 2     5.0            10206.649780
# 3     7.0            10159.030273

# %%
df_weights_close_price[df_weights_close_price["code"].isin(selected_new_tickers)][['date','code','target_wts']]
# Out:
#          date   code  target_wts
# 2  2021-03-23  GOOGL    0.109849
# 3  2021-03-23    CMG    0.104205

# %%
selected_new_tickers = ['UPS',#处于上升通道下沿，上穿5日均线，MACD值反转上升。止损点设为到168左右止盈（0323）
                        'PAYC', #走出一个三角楔形形态，形成支撑点:376.89	，上穿5日均线，到396.278左右止盈，MACD翻绿即止损（0323）
                       'CSCO',#限价单49.74买入入场，向上突破近期高点，并形成49.74附近的支撑点，并上穿5日均线，趋势向上；止损点48.15，止盈52.3
                       'QS'#形成支撑点:59.99，并在5、10、20日均线之上，止损62.6
                       ]

# %%
# current portfolio & calculate correlations inside the portfolio

current_portfolio_tickers = ["ARKG",# 跌穿120日均线则止损
                             "BABA",#若当日收盘MACD死叉，则第二日平仓
                             "BNTX",# 跌下5日均线则平仓，或者涨上111则止盈
                             "LOW",#涨上183.5止盈；或者跌下5日均线;
                             "TSLA",# 跌穿120日均线则止损
                             "VZ"# 若当日收盘于5日均线以下，第二天平仓
                            ]

# %% [markdown]
# 您订阅的【华彩智盈】操作计划更新了：
# 代码：CMG
# 时间：2021/3/24
# 价格：
# 方向：买入
# 仓位：10.4%
# 理由：上穿5日均线，并且短期趋势向上
# 平仓计划：若当日收盘在5日均线之下，第二日平仓
#
# 您订阅的【华彩智盈】操作计划更新了：
# 代码：UPS
# 时间：2021/3/23
# 价格：
# 方向：买入
# 仓位：9.6%
# 理由：处于上升通道下沿，上穿5日均线，MACD值反转上升
# 平仓计划：止损点设为156
#
# 您订阅的【华彩智盈】操作计划更新了：
# 代码：PAYC
# 时间：2021/3/23
# 价格：
# 方向：买入
# 仓位：5.4%
# 理由：近期走出一个三角楔形形态，收盘价在支撑点376.89附近之上，并且上穿5日均线
# 平仓计划：MACD翻绿即止损平仓
#
# 您订阅的【华彩智盈】操作计划更新了：
# 代码：QS
# 时间：2021/3/23
# 价格：
# 方向：买入
# 仓位：2%
# 理由：最新收盘价在近期支撑点59.99附近之上，并收于5、10、20日均线之上，短期有向上趋势
# 平仓计划：止损点设为62.6
#
# 以上仅为嘉宾操作计划展示，不构成任何投资建议，交易有风险，据此操作风险自负！

# %%
开盘后

UPS 止损点设为156
CSCO限价单49.74买入，11.2%
