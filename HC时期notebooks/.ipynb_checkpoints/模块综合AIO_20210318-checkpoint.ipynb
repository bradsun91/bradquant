# %%
import pandas as pd, numpy as np
from datetime import datetime
import statsmodels.api as sm
import yfinance as yf
import time, urllib
import glob
import os

# %%
import matplotlib.pyplot as plt

import seaborn as sns
# %matplotlib inline
sns.set(context='notebook', style='darkgrid', palette='deep', font='sans-serif', font_scale=1, color_codes=False, rc=None)

# %%
# 导入自己的模块
from data_download_US_HK import *
from strategies import *
from positions import *

# %% [markdown]
# # 模块一：下载数据到csv文件

# %%
us_tickers_to_load = list(set(US_TICKERS_POOL.us_tech_stocks() + \
			              US_TICKERS_POOL.us_blockchain_stocks() + \
			              US_TICKERS_POOL.us_saas_stocks() + \
			              US_TICKERS_POOL.us_biotech_stocks() + \
			              US_TICKERS_POOL.us_new_energy_stocks() + \
			              US_TICKERS_POOL.global_etfs() + \
			              US_TICKERS_POOL.sector_etf() + \
			              US_TICKERS_POOL.global_indices() +\
			              US_TICKERS_POOL.us_healthcare_stocks() +\
			              US_TICKERS_POOL.us_fin_stocks() +\
			              US_TICKERS_POOL.us_utilities_stocks() +\
			              US_TICKERS_POOL.us_materials_stocks() +\
			              US_TICKERS_POOL.other_us_stocks() +\
                            US_TICKERS_POOL.us_consumer_discretionary_stocks() +\
                            US_TICKERS_POOL.us_consumer_staples_stocks() +\
                            US_TICKERS_POOL.us_industrial_stocks() +\
                            US_TICKERS_POOL.us_real_estate_stocks() +\
                            US_TICKERS_POOL.us_tele_entertainment_stocks()))

hk_tickers_to_load = HK_TICERS_POOL.HK_tickers()

CN_mutual_funds = CN_TICKERS_POOL.CN_fund_tickers()

all_tickers_to_load = all_tickers()

start = "2005-01-01"
today = LOAD_DATA.today_dt()
end = today

# 如果用这个yesterday，则代表着只需要到昨天的数据
# end_yesterday = "2021-03-02"

us_db_path = "C:/Users/Administrator/CE_github_2/data_pipeline/Data/"
# Out:
# All Tickers: 326

# %%
# download data to csv files
LOAD_DATA.easy_download(start, end, us_db_path, us_tickers_to_load)
# LOAD_DATA.easy_download(start, end, us_db_path, ["^HSI"])
# Out:
# [*********************100%***********************]  1 of 1 completed
# No.1: BLNK data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.2: SPLK data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.3: STZ data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.4: T data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.5: INTU data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.6: GILD data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.7: AEMD data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.8: KHC data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.9: AEP data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.10: PEP data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.11: WMT data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.12: WFC data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.13: FMC data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.14: WDAY data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.15: CHWY data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.16: PFE data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.17: APD data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.18: CRWD data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.19: CBLI data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.20: ARKW data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.21: CB data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.22: XLP data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.23: BNTX data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.24: LAZR data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.25: KO data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.26: AZO data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.27: NCTY data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.28: FXE data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.29: AMGN data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.30: IEF data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.31: NFLX data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.32: SBE data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.33: AMD data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.34: BLK data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.35: LVS data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.36: TGT data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.37: FXY data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.38: UPS data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.39: ADSK data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.40: ACOR data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.41: XNET data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.42: CSCO data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.43: CVS data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.44: ARKQ data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.45: UUP data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.46: VEEV data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.47: GBTC data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.48: CRM data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.49: BABA data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.50: TSM data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.51: RUN data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.52: FXB data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.53: LLY data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.54: ES data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.55: OKTA data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.56: MA data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.57: ARKF data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.58: GDX data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.59: ARKG data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.60: PDD data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.61: LAC data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.62: NVDA data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.63: ^HSI data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.64: DBX data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.65: DIS data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.66: INO data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.67: ORCL data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.68: CZR data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.69: BMY data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.70: GDDY data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.71: ZM data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.72: ARKK data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.73: NEE data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.74: CRVS data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.75: SMAR data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.76: TTD data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.77: JPM data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.78: MSFT data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.79: WORK data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.80: ADP data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.81: SAP data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.82: WES data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.83: JD data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.84: VCNX data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.85: MS data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.86: FCEL data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.87: RACE data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.88: CDAY data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.89: C data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.90: MMM data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.91: APT data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.92: AAPL data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.93: XLU data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.94: GOOG data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.95: CODX data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.96: SBUX data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.97: PM data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.98: VZ data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.99: DBC data file created: 2021-03-21
# =======================Sleeping======================
# [*********************100%***********************]  1 of 1 completed
# No.101: SQM data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.102: EL data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.103: TWLO data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.104: HUBS data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.105: XLY data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.106: DUK data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.107: PSA data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.108: ALB data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.109: RENN data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.110: PLD data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.111: CNET data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.112: SRAX data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.113: FB data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.114: TQQQ data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.115: LTHM data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.116: GS data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.117: EQ data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.118: PLUG data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.119: FXF data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.120: EBON data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.121: BX data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.122: RNG data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.123: BILI data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.124: SHOP data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.125: BBY data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.126: NKE data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.127: XLRE data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.128: ZEN data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.129: DBA data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.130: CL data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.131: VXRT data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.132: VLDR data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.133: 000001.SS data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.134: SHW data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.135: OSTK data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.136: AZN data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.137: SCCO data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.138: ISRG data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.139: LFIN data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.140: MARA data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.141: CMG data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.142: HTBX data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.143: TEAM data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.144: XLB data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.145: XEL data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.146: DOCU data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.147: MRK data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.148: MET data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.149: NIO data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.150: IBIO data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.151: BAC data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.152: PG data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.153: ENPH data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.154: VXX data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.155: JNJ data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.156: XLE data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.157: ADBE data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.158: AMT data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.159: MU data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.160: DFFN data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.161: UVXY data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.162: ABBV data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.163: RTX data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.164: XL data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.165: DHR data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.166: GOOGL data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.167: ^GSPC data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.168: SQ data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.169: TSLA data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.170: TSN data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.171: D data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.172: EQIX data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.173: QS data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.174: SPOT data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.175: ^IXIC data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.176: NEM data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.177: COUP data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.178: BA data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.179: SAM data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.180: CYB data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.181: PAYC data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.182: SPY data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.183: MDT data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.184: V data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.185: ECL data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.186: CCI data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.187: SO data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.188: XLI data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.189: DDOG data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.190: LULU data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.191: ABT data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.192: AHPI data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.193: LAKE data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.194: EXC data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.195: LOW data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.196: PTON data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.197: EBAY data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.198: GLD data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.199: NOVA data file created: 2021-03-21
# =======================Sleeping======================
# [*********************100%***********************]  1 of 1 completed
# No.201: COST data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.202: OPEN data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.203: QQQ data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.204: AMZN data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.205: LIN data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.206: UNP data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.207: LI data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.208: ATVI data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.209: RIOT data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.210: TMO data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.211: LMT data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.212: SBAC data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.213: CAT data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.214: DLR data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.215: ARPO data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.216: NNVC data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.217: XLV data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.218: CAN data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.219: MRNA data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.220: UNH data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.221: NOW data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.222: XLK data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.223: VIR data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.224: DD data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.225: GE data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.226: INTC data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.227: TLT data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.228: CHTR data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.229: AXP data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.230: QCOM data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.231: SRE data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.232: HON data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.233: NVAX data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.234: FLS data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.235: PYPL data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.236: TMUS data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.237: ^DJI data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.238: CMCSA data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.239: XPEV data file created: 2021-03-21
# [*********************100%***********************]  1 of 1 completed
# No.240: MCD data file created: 2021-03-21
# -----------------------------
# All done for 2021-03-21!

# %%
# Download data from Sina:
LOAD_DATA.download_data_from_Sina(CN_mutual_funds, start, end, us_db_path)
# Out:
# Downloading from SinaFinance: No.1 / 16: 161725
# Downloading from SinaFinance: No.2 / 16: 009865
# Downloading from SinaFinance: No.3 / 16: 010358
# Downloading from SinaFinance: No.4 / 16: 001508
# Downloading from SinaFinance: No.5 / 16: 010849
# Downloading from SinaFinance: No.6 / 16: 006792
# Downloading from SinaFinance: No.7 / 16: 011609
# Downloading from SinaFinance: No.8 / 16: 004233
# Downloading from SinaFinance: No.9 / 16: 003096
# Downloading from SinaFinance: No.10 / 16: 004851
# Downloading from SinaFinance: No.11 / 16: 001888
# Downloading from SinaFinance: No.12 / 16: 161005
# Downloading from SinaFinance: No.13 / 16: 110011
# Downloading from SinaFinance: No.14 / 16: 005827
# Downloading from SinaFinance: No.15 / 16: 000452
# Downloading from SinaFinance: No.16 / 16: 001838
# All Data Downloaded

# %%
# # Load CN funds from sina
# CN_fund_data = LOAD_DATA.read_data_from_Sina(CN_mutual_funds, "2020-01-01", end)

# %%
data_list_selected = LOAD_DATA.read_data_from_folders(us_tickers_to_load, us_db_path)
# Out:
# Loadig Data from DB: No.1 / 240: BLNK
# Loadig Data from DB: No.2 / 240: SPLK
# Loadig Data from DB: No.3 / 240: STZ
# Loadig Data from DB: No.4 / 240: T
# Loadig Data from DB: No.5 / 240: INTU
# Loadig Data from DB: No.6 / 240: GILD
# Loadig Data from DB: No.7 / 240: AEMD
# Loadig Data from DB: No.8 / 240: KHC
# Loadig Data from DB: No.9 / 240: AEP
# Loadig Data from DB: No.10 / 240: PEP
# Loadig Data from DB: No.11 / 240: WMT
# Loadig Data from DB: No.12 / 240: WFC
# Loadig Data from DB: No.13 / 240: FMC
# Loadig Data from DB: No.14 / 240: WDAY
# Loadig Data from DB: No.15 / 240: CHWY
# Loadig Data from DB: No.16 / 240: PFE
# Loadig Data from DB: No.17 / 240: APD
# Loadig Data from DB: No.18 / 240: CRWD
# Loadig Data from DB: No.19 / 240: CBLI
# Loadig Data from DB: No.20 / 240: ARKW
# Loadig Data from DB: No.21 / 240: CB
# Loadig Data from DB: No.22 / 240: XLP
# Loadig Data from DB: No.23 / 240: BNTX
# Loadig Data from DB: No.24 / 240: LAZR
# Loadig Data from DB: No.25 / 240: KO
# Loadig Data from DB: No.26 / 240: AZO
# Loadig Data from DB: No.27 / 240: NCTY
# Loadig Data from DB: No.28 / 240: FXE
# Loadig Data from DB: No.29 / 240: AMGN
# Loadig Data from DB: No.30 / 240: IEF
# Loadig Data from DB: No.31 / 240: NFLX
# Loadig Data from DB: No.32 / 240: SBE
# Loadig Data from DB: No.33 / 240: AMD
# Loadig Data from DB: No.34 / 240: BLK
# Loadig Data from DB: No.35 / 240: LVS
# Loadig Data from DB: No.36 / 240: TGT
# Loadig Data from DB: No.37 / 240: FXY
# Loadig Data from DB: No.38 / 240: UPS
# Loadig Data from DB: No.39 / 240: ADSK
# Loadig Data from DB: No.40 / 240: ACOR
# Loadig Data from DB: No.41 / 240: XNET
# Loadig Data from DB: No.42 / 240: CSCO
# Loadig Data from DB: No.43 / 240: CVS
# Loadig Data from DB: No.44 / 240: ARKQ
# Loadig Data from DB: No.45 / 240: UUP
# Loadig Data from DB: No.46 / 240: VEEV
# Loadig Data from DB: No.47 / 240: GBTC
# Loadig Data from DB: No.48 / 240: CRM
# Loadig Data from DB: No.49 / 240: BABA
# Loadig Data from DB: No.50 / 240: TSM
# Loadig Data from DB: No.51 / 240: RUN
# Loadig Data from DB: No.52 / 240: FXB
# Loadig Data from DB: No.53 / 240: LLY
# Loadig Data from DB: No.54 / 240: ES
# Loadig Data from DB: No.55 / 240: OKTA
# Loadig Data from DB: No.56 / 240: MA
# Loadig Data from DB: No.57 / 240: ARKF
# Loadig Data from DB: No.58 / 240: GDX
# Loadig Data from DB: No.59 / 240: ARKG
# Loadig Data from DB: No.60 / 240: PDD
# Loadig Data from DB: No.61 / 240: LAC
# Loadig Data from DB: No.62 / 240: NVDA
# Loadig Data from DB: No.63 / 240: ^HSI
# Loadig Data from DB: No.64 / 240: DBX
# Loadig Data from DB: No.65 / 240: DIS
# Loadig Data from DB: No.66 / 240: INO
# Loadig Data from DB: No.67 / 240: ORCL
# Loadig Data from DB: No.68 / 240: CZR
# Loadig Data from DB: No.69 / 240: BMY
# Loadig Data from DB: No.70 / 240: GDDY
# Loadig Data from DB: No.71 / 240: ZM
# Loadig Data from DB: No.72 / 240: ARKK
# Loadig Data from DB: No.73 / 240: NEE
# Loadig Data from DB: No.74 / 240: CRVS
# Loadig Data from DB: No.75 / 240: SMAR
# Loadig Data from DB: No.76 / 240: TTD
# Loadig Data from DB: No.77 / 240: JPM
# Loadig Data from DB: No.78 / 240: MSFT
# Loadig Data from DB: No.79 / 240: WORK
# Loadig Data from DB: No.80 / 240: ADP
# Loadig Data from DB: No.81 / 240: SAP
# Loadig Data from DB: No.82 / 240: WES
# Loadig Data from DB: No.83 / 240: JD
# Loadig Data from DB: No.84 / 240: VCNX
# Loadig Data from DB: No.85 / 240: MS
# Loadig Data from DB: No.86 / 240: FCEL
# Loadig Data from DB: No.87 / 240: RACE
# Loadig Data from DB: No.88 / 240: CDAY
# Loadig Data from DB: No.89 / 240: C
# Loadig Data from DB: No.90 / 240: MMM
# Loadig Data from DB: No.91 / 240: APT
# Loadig Data from DB: No.92 / 240: AAPL
# Loadig Data from DB: No.93 / 240: XLU
# Loadig Data from DB: No.94 / 240: GOOG
# Loadig Data from DB: No.95 / 240: CODX
# Loadig Data from DB: No.96 / 240: SBUX
# Loadig Data from DB: No.97 / 240: PM
# Loadig Data from DB: No.98 / 240: VZ
# Loadig Data from DB: No.99 / 240: DBC
# Loadig Data from DB: No.100 / 240: HD
# Loadig Data from DB: No.101 / 240: SQM
# Loadig Data from DB: No.102 / 240: EL
# Loadig Data from DB: No.103 / 240: TWLO
# Loadig Data from DB: No.104 / 240: HUBS
# Loadig Data from DB: No.105 / 240: XLY
# Loadig Data from DB: No.106 / 240: DUK
# Loadig Data from DB: No.107 / 240: PSA
# Loadig Data from DB: No.108 / 240: ALB
# Loadig Data from DB: No.109 / 240: RENN
# Loadig Data from DB: No.110 / 240: PLD
# Loadig Data from DB: No.111 / 240: CNET
# Loadig Data from DB: No.112 / 240: SRAX
# Loadig Data from DB: No.113 / 240: FB
# Loadig Data from DB: No.114 / 240: TQQQ
# Loadig Data from DB: No.115 / 240: LTHM
# Loadig Data from DB: No.116 / 240: GS
# Loadig Data from DB: No.117 / 240: EQ
# Loadig Data from DB: No.118 / 240: PLUG
# Loadig Data from DB: No.119 / 240: FXF
# Loadig Data from DB: No.120 / 240: EBON
# Loadig Data from DB: No.121 / 240: BX
# Loadig Data from DB: No.122 / 240: RNG
# Loadig Data from DB: No.123 / 240: BILI
# Loadig Data from DB: No.124 / 240: SHOP
# Loadig Data from DB: No.125 / 240: BBY
# Loadig Data from DB: No.126 / 240: NKE
# Loadig Data from DB: No.127 / 240: XLRE
# Loadig Data from DB: No.128 / 240: ZEN
# Loadig Data from DB: No.129 / 240: DBA
# Loadig Data from DB: No.130 / 240: CL
# Loadig Data from DB: No.131 / 240: VXRT
# Loadig Data from DB: No.132 / 240: VLDR
# Loadig Data from DB: No.133 / 240: 000001.SS
# Loadig Data from DB: No.134 / 240: SHW
# Loadig Data from DB: No.135 / 240: OSTK
# Loadig Data from DB: No.136 / 240: AZN
# Loadig Data from DB: No.137 / 240: SCCO
# Loadig Data from DB: No.138 / 240: ISRG
# Loadig Data from DB: No.139 / 240: LFIN
# Loadig Data from DB: No.140 / 240: MARA
# Loadig Data from DB: No.141 / 240: CMG
# Loadig Data from DB: No.142 / 240: HTBX
# Loadig Data from DB: No.143 / 240: TEAM
# Loadig Data from DB: No.144 / 240: XLB
# Loadig Data from DB: No.145 / 240: XEL
# Loadig Data from DB: No.146 / 240: DOCU
# Loadig Data from DB: No.147 / 240: MRK
# Loadig Data from DB: No.148 / 240: MET
# Loadig Data from DB: No.149 / 240: NIO
# Loadig Data from DB: No.150 / 240: IBIO
# Loadig Data from DB: No.151 / 240: BAC
# Loadig Data from DB: No.152 / 240: PG
# Loadig Data from DB: No.153 / 240: ENPH
# Loadig Data from DB: No.154 / 240: VXX
# Loadig Data from DB: No.155 / 240: JNJ
# Loadig Data from DB: No.156 / 240: XLE
# Loadig Data from DB: No.157 / 240: ADBE
# Loadig Data from DB: No.158 / 240: AMT
# Loadig Data from DB: No.159 / 240: MU
# Loadig Data from DB: No.160 / 240: DFFN
# Loadig Data from DB: No.161 / 240: UVXY
# Loadig Data from DB: No.162 / 240: ABBV
# Loadig Data from DB: No.163 / 240: RTX
# Loadig Data from DB: No.164 / 240: XL
# Loadig Data from DB: No.165 / 240: DHR
# Loadig Data from DB: No.166 / 240: GOOGL
# Loadig Data from DB: No.167 / 240: ^GSPC
# Loadig Data from DB: No.168 / 240: SQ
# Loadig Data from DB: No.169 / 240: TSLA
# Loadig Data from DB: No.170 / 240: TSN
# Loadig Data from DB: No.171 / 240: D
# Loadig Data from DB: No.172 / 240: EQIX
# Loadig Data from DB: No.173 / 240: QS
# Loadig Data from DB: No.174 / 240: SPOT
# Loadig Data from DB: No.175 / 240: ^IXIC
# Loadig Data from DB: No.176 / 240: NEM
# Loadig Data from DB: No.177 / 240: COUP
# Loadig Data from DB: No.178 / 240: BA
# Loadig Data from DB: No.179 / 240: SAM
# Loadig Data from DB: No.180 / 240: CYB
# Loadig Data from DB: No.181 / 240: PAYC
# Loadig Data from DB: No.182 / 240: SPY
# Loadig Data from DB: No.183 / 240: MDT
# Loadig Data from DB: No.184 / 240: V
# Loadig Data from DB: No.185 / 240: ECL
# Loadig Data from DB: No.186 / 240: CCI
# Loadig Data from DB: No.187 / 240: SO
# Loadig Data from DB: No.188 / 240: XLI
# Loadig Data from DB: No.189 / 240: DDOG
# Loadig Data from DB: No.190 / 240: LULU
# Loadig Data from DB: No.191 / 240: ABT
# Loadig Data from DB: No.192 / 240: AHPI
# Loadig Data from DB: No.193 / 240: LAKE
# Loadig Data from DB: No.194 / 240: EXC
# Loadig Data from DB: No.195 / 240: LOW
# Loadig Data from DB: No.196 / 240: PTON
# Loadig Data from DB: No.197 / 240: EBAY
# Loadig Data from DB: No.198 / 240: GLD
# Loadig Data from DB: No.199 / 240: NOVA
# Loadig Data from DB: No.200 / 240: XLF
# Loadig Data from DB: No.201 / 240: COST
# Loadig Data from DB: No.202 / 240: OPEN
# Loadig Data from DB: No.203 / 240: QQQ
# Loadig Data from DB: No.204 / 240: AMZN
# Loadig Data from DB: No.205 / 240: LIN
# Loadig Data from DB: No.206 / 240: UNP
# Loadig Data from DB: No.207 / 240: LI
# Loadig Data from DB: No.208 / 240: ATVI
# Loadig Data from DB: No.209 / 240: RIOT
# Loadig Data from DB: No.210 / 240: TMO
# Loadig Data from DB: No.211 / 240: LMT
# Loadig Data from DB: No.212 / 240: SBAC
# Loadig Data from DB: No.213 / 240: CAT
# Loadig Data from DB: No.214 / 240: DLR
# Loadig Data from DB: No.215 / 240: ARPO
# Loadig Data from DB: No.216 / 240: NNVC
# Loadig Data from DB: No.217 / 240: XLV
# Loadig Data from DB: No.218 / 240: CAN
# Loadig Data from DB: No.219 / 240: MRNA
# Loadig Data from DB: No.220 / 240: UNH
# Loadig Data from DB: No.221 / 240: NOW
# Loadig Data from DB: No.222 / 240: XLK
# Loadig Data from DB: No.223 / 240: VIR
# Loadig Data from DB: No.224 / 240: DD
# Loadig Data from DB: No.225 / 240: GE
# Loadig Data from DB: No.226 / 240: INTC
# Loadig Data from DB: No.227 / 240: TLT
# Loadig Data from DB: No.228 / 240: CHTR
# Loadig Data from DB: No.229 / 240: AXP
# Loadig Data from DB: No.230 / 240: QCOM
# Loadig Data from DB: No.231 / 240: SRE
# Loadig Data from DB: No.232 / 240: HON
# Loadig Data from DB: No.233 / 240: NVAX
# Loadig Data from DB: No.234 / 240: FLS
# Loadig Data from DB: No.235 / 240: PYPL
# Loadig Data from DB: No.236 / 240: TMUS
# Loadig Data from DB: No.237 / 240: ^DJI
# Loadig Data from DB: No.238 / 240: CMCSA
# Loadig Data from DB: No.239 / 240: XPEV
# Loadig Data from DB: No.240 / 240: MCD

# %% [markdown]
# # 模块二：选择股票池

# %%
# # 方式一
# data_list= LOAD_DATA.read_downloaded_data("C:/Users/Administrator/bradsun_windows_creditease_github/data_pipelines/US_Data/Data/*.csv")

# %%
# # 方式二: 直接从yahoo finance拿数据,需要加入time.sleep()，否则调用太频繁会被卡
# data_list_D = LOAD_DATA.read_data_from_yf_D(hk_tickers_to_load)
# # data_list_D = LOAD_DATA.read_data_from_yf_D(["1909.HK"])

# %%
# data_list_W = LOAD_DATA.read_data_from_yf_W(hk_tickers_to_load)

# %% [markdown]
# # 模块三：选择策略

# %% [markdown]
# ## MACD - 红绿柱上涨

# %% [markdown]
# ### 日线信号 & 周线信号

# %%
daily_macd_updown_signals = GENERATE_SIGNALS.generate_signals_macd_updown_ma_slope( 
                                                                           data_list_selected,
#                                                                            CN_fund_data,
                                                                          "Macd_Updown_MA_Slope_Signals", 
                                                                          "Date", 
                                                                          "Adj Close", 
                                                                          "Ticker", 
                                                                          "D")
# Out:
# Signals(D) Prepared for No.1 : BLNK
# Signals(D) Prepared for No.2 : SPLK
# Signals(D) Prepared for No.3 : STZ
# Signals(D) Prepared for No.4 : T
# Signals(D) Prepared for No.5 : INTU
# Signals(D) Prepared for No.6 : GILD
# Signals(D) Prepared for No.7 : AEMD
# Signals(D) Prepared for No.8 : KHC
# Signals(D) Prepared for No.9 : AEP
# Signals(D) Prepared for No.10 : PEP
# Signals(D) Prepared for No.11 : WMT
# Signals(D) Prepared for No.12 : WFC
# Signals(D) Prepared for No.13 : FMC
# Signals(D) Prepared for No.14 : WDAY
# Signals(D) Prepared for No.15 : CHWY
# Signals(D) Prepared for No.16 : PFE
# Signals(D) Prepared for No.17 : APD
# Signals(D) Prepared for No.18 : CRWD
# Signals(D) Prepared for No.19 : CBLI
# Signals(D) Prepared for No.20 : ARKW
# Signals(D) Prepared for No.21 : CB
# Signals(D) Prepared for No.22 : XLP
# Signals(D) Prepared for No.23 : BNTX
# Signals(D) Prepared for No.24 : LAZR
# Signals(D) Prepared for No.25 : KO
# Signals(D) Prepared for No.26 : AZO
# Signals(D) Prepared for No.27 : NCTY
# Signals(D) Prepared for No.28 : FXE
# Signals(D) Prepared for No.29 : AMGN
# Signals(D) Prepared for No.30 : IEF
# Signals(D) Prepared for No.31 : NFLX
# Signals(D) Prepared for No.32 : SBE
# Signals(D) Prepared for No.33 : AMD
# Signals(D) Prepared for No.34 : BLK
# Signals(D) Prepared for No.35 : LVS
# Signals(D) Prepared for No.36 : TGT
# Signals(D) Prepared for No.37 : FXY
# Signals(D) Prepared for No.38 : UPS
# Signals(D) Prepared for No.39 : ADSK
# Signals(D) Prepared for No.40 : ACOR
# Signals(D) Prepared for No.41 : XNET
# Signals(D) Prepared for No.42 : CSCO
# Signals(D) Prepared for No.43 : CVS
# Signals(D) Prepared for No.44 : ARKQ
# Signals(D) Prepared for No.45 : UUP
# Signals(D) Prepared for No.46 : VEEV
# Signals(D) Prepared for No.47 : GBTC
# Signals(D) Prepared for No.48 : CRM
# Signals(D) Prepared for No.49 : BABA
# Signals(D) Prepared for No.50 : TSM
# Signals(D) Prepared for No.51 : RUN
# Signals(D) Prepared for No.52 : FXB
# Signals(D) Prepared for No.53 : LLY
# Signals(D) Prepared for No.54 : ES
# Signals(D) Prepared for No.55 : OKTA
# Signals(D) Prepared for No.56 : MA
# Signals(D) Prepared for No.57 : ARKF
# Signals(D) Prepared for No.58 : GDX
# Signals(D) Prepared for No.59 : ARKG
# Signals(D) Prepared for No.60 : PDD
# Signals(D) Prepared for No.61 : LAC
# Signals(D) Prepared for No.62 : NVDA
# Signals(D) Prepared for No.63 : ^HSI
# Signals(D) Prepared for No.64 : DBX
# Signals(D) Prepared for No.65 : DIS
# Signals(D) Prepared for No.66 : INO
# Signals(D) Prepared for No.67 : ORCL
# Signals(D) Prepared for No.68 : CZR
# Signals(D) Prepared for No.69 : BMY
# Signals(D) Prepared for No.70 : GDDY
# Signals(D) Prepared for No.71 : ZM
# Signals(D) Prepared for No.72 : ARKK
# Signals(D) Prepared for No.73 : NEE
# Signals(D) Prepared for No.74 : CRVS
# Signals(D) Prepared for No.75 : SMAR
# Signals(D) Prepared for No.76 : TTD
# Signals(D) Prepared for No.77 : JPM
# Signals(D) Prepared for No.78 : MSFT
# Signals(D) Prepared for No.79 : WORK
# Signals(D) Prepared for No.80 : ADP
# Signals(D) Prepared for No.81 : SAP
# Signals(D) Prepared for No.82 : WES
# Signals(D) Prepared for No.83 : JD
# Signals(D) Prepared for No.84 : VCNX
# Signals(D) Prepared for No.85 : MS
# Signals(D) Prepared for No.86 : FCEL
# Signals(D) Prepared for No.87 : RACE
# Signals(D) Prepared for No.88 : CDAY
# Signals(D) Prepared for No.89 : C
# Signals(D) Prepared for No.90 : MMM
# Signals(D) Prepared for No.91 : APT
# Signals(D) Prepared for No.92 : AAPL
# Signals(D) Prepared for No.93 : XLU
# Signals(D) Prepared for No.94 : GOOG
# Signals(D) Prepared for No.95 : CODX
# Signals(D) Prepared for No.96 : SBUX
# Signals(D) Prepared for No.97 : PM
# Signals(D) Prepared for No.98 : VZ
# Signals(D) Prepared for No.99 : DBC
# Signals(D) Prepared for No.100 : HD
# Signals(D) Prepared for No.101 : SQM
# Signals(D) Prepared for No.102 : EL
# Signals(D) Prepared for No.103 : TWLO
# Signals(D) Prepared for No.104 : HUBS
# Signals(D) Prepared for No.105 : XLY
# Signals(D) Prepared for No.106 : DUK
# Signals(D) Prepared for No.107 : PSA
# Signals(D) Prepared for No.108 : ALB
# Signals(D) Prepared for No.109 : RENN
# Signals(D) Prepared for No.110 : PLD
# Signals(D) Prepared for No.111 : CNET
# Signals(D) Prepared for No.112 : SRAX
# Signals(D) Prepared for No.113 : FB
# Signals(D) Prepared for No.114 : TQQQ
# Signals(D) Prepared for No.115 : LTHM
# Signals(D) Prepared for No.116 : GS
# Signals(D) Prepared for No.117 : EQ
# Signals(D) Prepared for No.118 : PLUG
# Signals(D) Prepared for No.119 : FXF
# Signals(D) Prepared for No.120 : EBON
# Signals(D) Prepared for No.121 : BX
# Signals(D) Prepared for No.122 : RNG
# Signals(D) Prepared for No.123 : BILI
# Signals(D) Prepared for No.124 : SHOP
# Signals(D) Prepared for No.125 : BBY
# Signals(D) Prepared for No.126 : NKE
# Signals(D) Prepared for No.127 : XLRE
# Signals(D) Prepared for No.128 : ZEN
# Signals(D) Prepared for No.129 : DBA
# Signals(D) Prepared for No.130 : CL
# Signals(D) Prepared for No.131 : VXRT
# Signals(D) Prepared for No.132 : VLDR
# Signals(D) Prepared for No.133 : 000001.SS
# Signals(D) Prepared for No.134 : SHW
# Signals(D) Prepared for No.135 : OSTK
# Signals(D) Prepared for No.136 : AZN
# Signals(D) Prepared for No.137 : SCCO
# Signals(D) Prepared for No.138 : ISRG
# Signals(D) Prepared for No.139 : LFIN
# Signals(D) Prepared for No.140 : MARA
# Signals(D) Prepared for No.141 : CMG
# Signals(D) Prepared for No.142 : HTBX
# Signals(D) Prepared for No.143 : TEAM
# Signals(D) Prepared for No.144 : XLB
# Signals(D) Prepared for No.145 : XEL
# Signals(D) Prepared for No.146 : DOCU
# Signals(D) Prepared for No.147 : MRK
# Signals(D) Prepared for No.148 : MET
# Signals(D) Prepared for No.149 : NIO
# Signals(D) Prepared for No.150 : IBIO
# Signals(D) Prepared for No.151 : BAC
# Signals(D) Prepared for No.152 : PG
# Signals(D) Prepared for No.153 : ENPH
# Signals(D) Prepared for No.154 : VXX
# Signals(D) Prepared for No.155 : JNJ
# Signals(D) Prepared for No.156 : XLE
# Signals(D) Prepared for No.157 : ADBE
# Signals(D) Prepared for No.158 : AMT
# Signals(D) Prepared for No.159 : MU
# Signals(D) Prepared for No.160 : DFFN
# Signals(D) Prepared for No.161 : UVXY
# Signals(D) Prepared for No.162 : ABBV
# Signals(D) Prepared for No.163 : RTX
# Signals(D) Prepared for No.164 : XL
# Signals(D) Prepared for No.165 : DHR
# Signals(D) Prepared for No.166 : GOOGL
# Signals(D) Prepared for No.167 : ^GSPC
# Signals(D) Prepared for No.168 : SQ
# Signals(D) Prepared for No.169 : TSLA
# Signals(D) Prepared for No.170 : TSN
# Signals(D) Prepared for No.171 : D
# Signals(D) Prepared for No.172 : EQIX
# Signals(D) Prepared for No.173 : QS
# Signals(D) Prepared for No.174 : SPOT
# Signals(D) Prepared for No.175 : ^IXIC
# Signals(D) Prepared for No.176 : NEM
# Signals(D) Prepared for No.177 : COUP
# Signals(D) Prepared for No.178 : BA
# Signals(D) Prepared for No.179 : SAM
# Signals(D) Prepared for No.180 : CYB
# Signals(D) Prepared for No.181 : PAYC
# Signals(D) Prepared for No.182 : SPY
# Signals(D) Prepared for No.183 : MDT
# Signals(D) Prepared for No.184 : V
# Signals(D) Prepared for No.185 : ECL
# Signals(D) Prepared for No.186 : CCI
# Signals(D) Prepared for No.187 : SO
# Signals(D) Prepared for No.188 : XLI
# Signals(D) Prepared for No.189 : DDOG
# Signals(D) Prepared for No.190 : LULU
# Signals(D) Prepared for No.191 : ABT
# Signals(D) Prepared for No.192 : AHPI
# Signals(D) Prepared for No.193 : LAKE
# Signals(D) Prepared for No.194 : EXC
# Signals(D) Prepared for No.195 : LOW
# Signals(D) Prepared for No.196 : PTON
# Signals(D) Prepared for No.197 : EBAY
# Signals(D) Prepared for No.198 : GLD
# Signals(D) Prepared for No.199 : NOVA
# Signals(D) Prepared for No.200 : XLF
# Signals(D) Prepared for No.201 : COST
# Signals(D) Prepared for No.202 : OPEN
# Signals(D) Prepared for No.203 : QQQ
# Signals(D) Prepared for No.204 : AMZN
# Signals(D) Prepared for No.205 : LIN
# Signals(D) Prepared for No.206 : UNP
# Signals(D) Prepared for No.207 : LI
# Signals(D) Prepared for No.208 : ATVI
# Signals(D) Prepared for No.209 : RIOT
# Signals(D) Prepared for No.210 : TMO
# Signals(D) Prepared for No.211 : LMT
# Signals(D) Prepared for No.212 : SBAC
# Signals(D) Prepared for No.213 : CAT
# Signals(D) Prepared for No.214 : DLR
# Signals(D) Prepared for No.215 : ARPO
# Signals(D) Prepared for No.216 : NNVC
# Signals(D) Prepared for No.217 : XLV
# Signals(D) Prepared for No.218 : CAN
# Signals(D) Prepared for No.219 : MRNA
# Signals(D) Prepared for No.220 : UNH
# Signals(D) Prepared for No.221 : NOW
# Signals(D) Prepared for No.222 : XLK
# Signals(D) Prepared for No.223 : VIR
# Signals(D) Prepared for No.224 : DD
# Signals(D) Prepared for No.225 : GE
# Signals(D) Prepared for No.226 : INTC
# Signals(D) Prepared for No.227 : TLT
# Signals(D) Prepared for No.228 : CHTR
# Signals(D) Prepared for No.229 : AXP
# Signals(D) Prepared for No.230 : QCOM
# Signals(D) Prepared for No.231 : SRE
# Signals(D) Prepared for No.232 : HON
# Signals(D) Prepared for No.233 : NVAX
# Signals(D) Prepared for No.234 : FLS
# Signals(D) Prepared for No.235 : PYPL
# Signals(D) Prepared for No.236 : TMUS
# Signals(D) Prepared for No.237 : ^DJI
# Signals(D) Prepared for No.238 : CMCSA
# Signals(D) Prepared for No.239 : XPEV
# Signals(D) Prepared for No.240 : MCD
# -------------------------
# All Done!

# %%
daily_macd_updown_signals
# Out:
#     Ticker   Last_Date Signal                    model_name model_freq
# 0     BLNK  2021-03-19   其他状态  Macd_Updown_MA_Slope_Signals          D
# 1     SPLK  2021-03-19   其他状态  Macd_Updown_MA_Slope_Signals          D
# 2      STZ  2021-03-19     买入  Macd_Updown_MA_Slope_Signals          D
# 3        T  2021-03-19   空头持有  Macd_Updown_MA_Slope_Signals          D
# 4     INTU  2021-03-19   空头持有  Macd_Updown_MA_Slope_Signals          D
# ..     ...         ...    ...                           ...        ...
# 235   TMUS  2021-03-19   空头持有  Macd_Updown_MA_Slope_Signals          D
# 236   ^DJI  2021-03-19   空头持有  Macd_Updown_MA_Slope_Signals          D
# 237  CMCSA  2021-03-19   空头持有  Macd_Updown_MA_Slope_Signals          D
# 238   XPEV  2021-03-19     买入  Macd_Updown_MA_Slope_Signals          D
# 239    MCD  2021-03-19   其他状态  Macd_Updown_MA_Slope_Signals          D
#
# [240 rows x 5 columns]

# %%
daily_macd_updown_signals[daily_macd_updown_signals['Signal']=="买入"]
# Out:
#     Ticker   Last_Date Signal                    model_name model_freq
# 2      STZ  2021-03-19     买入  Macd_Updown_MA_Slope_Signals          D
# 8      AEP  2021-03-19     买入  Macd_Updown_MA_Slope_Signals          D
# 9      PEP  2021-03-19     买入  Macd_Updown_MA_Slope_Signals          D
# 16     APD  2021-03-19     买入  Macd_Updown_MA_Slope_Signals          D
# 22    BNTX  2021-03-19     买入  Macd_Updown_MA_Slope_Signals          D
# 23    LAZR  2021-03-19     买入  Macd_Updown_MA_Slope_Signals          D
# 25     AZO  2021-03-19     买入  Macd_Updown_MA_Slope_Signals          D
# 33     BLK  2021-03-19     买入  Macd_Updown_MA_Slope_Signals          D
# 46    GBTC  2021-03-19     买入  Macd_Updown_MA_Slope_Signals          D
# 80     SAP  2021-03-19     买入  Macd_Updown_MA_Slope_Signals          D
# 86    RACE  2021-03-19     买入  Macd_Updown_MA_Slope_Signals          D
# 112     FB  2021-03-19     买入  Macd_Updown_MA_Slope_Signals          D
# 130   VXRT  2021-03-19     买入  Macd_Updown_MA_Slope_Signals          D
# 139   MARA  2021-03-19     买入  Macd_Updown_MA_Slope_Signals          D
# 141   HTBX  2021-03-19     买入  Macd_Updown_MA_Slope_Signals          D
# 178    SAM  2021-03-19     买入  Macd_Updown_MA_Slope_Signals          D
# 194    LOW  2021-03-19     买入  Macd_Updown_MA_Slope_Signals          D
# 195   PTON  2021-03-19     买入  Macd_Updown_MA_Slope_Signals          D
# 200   COST  2021-03-19     买入  Macd_Updown_MA_Slope_Signals          D
# 206     LI  2021-03-19     买入  Macd_Updown_MA_Slope_Signals          D
# 222    VIR  2021-03-19     买入  Macd_Updown_MA_Slope_Signals          D
# 238   XPEV  2021-03-19     买入  Macd_Updown_MA_Slope_Signals          D

# %%
# list_left_to_download = list(daily_macd_updown_signals[daily_macd_updown_signals['Last_Date']=='2021-03-09']['Ticker'].values)

# %%
signal_path = "C:/Users/Administrator/CE_github_2/data_pipeline/Signals/"

###################################
signal_file = signal_path+end+"_signals"+"_D_US_mkt"+".csv"
###################################


# merged_daily_weekly.to_csv(signal_file)
daily_macd_updown_signals.to_csv(signal_file)

# %%
daily_macd_updown_signals
# Out:
#     Ticker   Last_Date Signal                    model_name model_freq
# 0     BLNK  2021-03-19   其他状态  Macd_Updown_MA_Slope_Signals          D
# 1     SPLK  2021-03-19   其他状态  Macd_Updown_MA_Slope_Signals          D
# 2      STZ  2021-03-19     买入  Macd_Updown_MA_Slope_Signals          D
# 3        T  2021-03-19   空头持有  Macd_Updown_MA_Slope_Signals          D
# 4     INTU  2021-03-19   空头持有  Macd_Updown_MA_Slope_Signals          D
# ..     ...         ...    ...                           ...        ...
# 235   TMUS  2021-03-19   空头持有  Macd_Updown_MA_Slope_Signals          D
# 236   ^DJI  2021-03-19   空头持有  Macd_Updown_MA_Slope_Signals          D
# 237  CMCSA  2021-03-19   空头持有  Macd_Updown_MA_Slope_Signals          D
# 238   XPEV  2021-03-19     买入  Macd_Updown_MA_Slope_Signals          D
# 239    MCD  2021-03-19   其他状态  Macd_Updown_MA_Slope_Signals          D
#
# [240 rows x 5 columns]

# %% [markdown]
# # 模块四：个股回测

# %% [markdown]
# # 合并回测结果+每日信号文件

# %%
signal = pd.read_csv("C:/Users/Administrator/CE_github_2/data_pipeline/Signals/2021-03-21_signals_D_US_mkt.csv")
perf = pd.read_csv("C:/Users/Administrator/CE_github_2/data_pipeline/Performance/US_performance_MACD_UPDOWN_MA_SLOPE_W_COMM_all.csv")

# %%
sar_signal = pd.read_csv("C:/Users/Administrator/CE_github_2/data_pipeline/Signals/2021-03-22_SAR_signals_D_US_mkt.csv")

# %%
signal
# Out:
#      Unnamed: 0 Ticker   Last_Date Signal                    model_name  \
# 0             0   BLNK  2021-03-19   其他状态  Macd_Updown_MA_Slope_Signals
# 1             1   SPLK  2021-03-19   其他状态  Macd_Updown_MA_Slope_Signals
# 2             2    STZ  2021-03-19     买入  Macd_Updown_MA_Slope_Signals
# 3             3      T  2021-03-19   空头持有  Macd_Updown_MA_Slope_Signals
# 4             4   INTU  2021-03-19   空头持有  Macd_Updown_MA_Slope_Signals
# ..          ...    ...         ...    ...                           ...
# 235         235   TMUS  2021-03-19   空头持有  Macd_Updown_MA_Slope_Signals
# 236         236   ^DJI  2021-03-19   空头持有  Macd_Updown_MA_Slope_Signals
# 237         237  CMCSA  2021-03-19   空头持有  Macd_Updown_MA_Slope_Signals
# 238         238   XPEV  2021-03-19     买入  Macd_Updown_MA_Slope_Signals
# 239         239    MCD  2021-03-19   其他状态  Macd_Updown_MA_Slope_Signals
#
#     model_freq
# 0            D
# 1            D
# 2            D
# 3            D
# 4            D
# ..         ...
# 235          D
# 236          D
# 237          D
# 238          D
# 239          D
#
# [240 rows x 6 columns]

# %%
sar_signal
# Out:
#     Unnamed: 0        Date Ticker     Signal_Info    Last_Price  Nearest_Level
# 0            0  2021-03-19   NVDA    形成支撑点:513.76    513.830017     513.760010
# 1            2  2021-03-19   BLNK     形成支撑点:36.61     38.240002      36.610001
# 2            6  2021-03-19   SRAX      形成支撑点:4.05      4.310000       4.050000
# 3            7  2021-03-19    MET     形成支撑点:61.26     61.290001      61.259998
# 4            9  2021-03-19    LOW    形成支撑点:179.42    179.490005     179.420500
# ..         ...         ...    ...             ...           ...            ...
# 89         214  2021-03-19    LIN    形成支撑点:267.63    269.119995     267.625654
# 90         215  2021-03-19   TQQQ     形成支撑点:86.34     86.480003      86.339996
# 91         216  2021-03-19   TSLA    形成支撑点:654.32    654.869995     654.320007
# 92         217  2021-03-19   ^HSI  形成支撑点:28775.38  28990.939453   28775.380859
# 93         219  2021-03-19   SCCO     形成支撑点:71.14     72.139999      71.135705
#
# [94 rows x 6 columns]

# %%
perf.head(2)
# Out:
#   Ticker  total_commission  gross_profit  net_profit commission_impact  win %  \
# 0     QS                24      19130.37    19106.37             0.13%  66.67
# 1   LAZR               148      13942.45    13794.45             1.06%  18.92
#
#    PL Ratio  overall_score            strat_name  commission  \
# 0     15.93          10.29  MACD_UPDOWN_MA_SLOPE           2
# 1     22.19           3.39  MACD_UPDOWN_MA_SLOPE           2
#
#       backtest_memo  Unnamed: 11  Unnamed: 12  Unnamed: 13  Unnamed: 14  \
# 0  US_first_bracket          NaN          NaN          NaN          NaN
# 1  US_first_bracket          NaN          NaN          NaN          NaN
#
#    Unnamed: 15
# 0          NaN
# 1          NaN

# %%
merged = perf.merge(signal, on = "Ticker")
# merged.dropna(inplace = True)
merged = merged.merge(sar_signal, on = "Ticker")

# %%
merged_buy = merged[merged['Signal']=='买入']

# %%
merged_buy
# Out:
#    Ticker  total_commission  gross_profit  net_profit commission_impact  \
# 0    LAZR               148      13942.45    13794.45             1.06%
# 6    HTBX               188      19340.82    19152.82             0.97%
# 15   PTON               124       5080.93     4956.93             2.44%
# 24   BNTX               116       4509.01     4393.01             2.57%
# 48    LOW               240       1017.82      777.82            23.58%
# 59    AZO               226        439.98      213.98            51.37%
#
#     win %  PL Ratio  overall_score            strat_name  commission  ...  \
# 0   18.92     22.19           3.39  MACD_UPDOWN_MA_SLOPE           2  ...
# 6   29.79      5.36           0.89  MACD_UPDOWN_MA_SLOPE           2  ...
# 15  45.16      2.31           0.50  MACD_UPDOWN_MA_SLOPE           2  ...
# 24  48.28      1.72           0.31  MACD_UPDOWN_MA_SLOPE           2  ...
# 48  46.67      1.33           0.09  MACD_UPDOWN_MA_SLOPE           2  ...
# 59  44.64      1.31           0.03  MACD_UPDOWN_MA_SLOPE           2  ...
#
#    Unnamed: 0_x   Last_Date  Signal                    model_name  model_freq  \
# 0            23  2021-03-19      买入  Macd_Updown_MA_Slope_Signals           D
# 6           141  2021-03-19      买入  Macd_Updown_MA_Slope_Signals           D
# 15          195  2021-03-19      买入  Macd_Updown_MA_Slope_Signals           D
# 24           22  2021-03-19      买入  Macd_Updown_MA_Slope_Signals           D
# 48          194  2021-03-19      买入  Macd_Updown_MA_Slope_Signals           D
# 59           25  2021-03-19      买入  Macd_Updown_MA_Slope_Signals           D
#
#     Unnamed: 0_y        Date    Signal_Info   Last_Price Nearest_Level
# 0             52  2021-03-19     形成支撑点:30.2    30.660000     30.200001
# 6             79  2021-03-19     形成支撑点:8.54     8.590000      8.540000
# 15            32  2021-03-19   形成支撑点:108.18   108.309998    108.180000
# 24           111  2021-03-19   形成支撑点:107.36   107.589996    107.360001
# 48             9  2021-03-19   形成支撑点:179.42   179.490005    179.420500
# 59           107  2021-03-19  形成支撑点:1297.82  1324.760010   1297.819946
#
# [6 rows x 26 columns]

# %%
merged_buy[['Ticker','Date','Signal_Info']]
# Out:
#    Ticker        Date    Signal_Info
# 0    LAZR  2021-03-19     形成支撑点:30.2
# 6    HTBX  2021-03-19     形成支撑点:8.54
# 15   PTON  2021-03-19   形成支撑点:108.18
# 24   BNTX  2021-03-19   形成支撑点:107.36
# 48    LOW  2021-03-19   形成支撑点:179.42
# 59    AZO  2021-03-19  形成支撑点:1297.82

# %%
merged_buy.to_csv("C:/Users/Administrator/CE_github_2/data_pipeline/Performance/20210322_MACD_updown_slope_perf_sar.csv")

# %%
merged_buy
# Out:
#    Ticker  total_commission  gross_profit  net_profit commission_impact  \
# 40    JPM               232       1360.13     1128.13            17.06%
# 57     VZ               252        376.65      124.65            66.91%
# 61    MET               266        384.91      118.91            69.11%
# 65    BAC               244        143.46     -100.54           170.09%
# 71    UNP               300        -10.25     -310.25          2927.58%
#
#     win %  PL Ratio  overall_score            strat_name  commission  ...  \
# 40  43.10      1.78           0.20  MACD_UPDOWN_MA_SLOPE           2  ...
# 57  42.86      1.40           0.03  MACD_UPDOWN_MA_SLOPE           2  ...
# 61  46.97      1.16           0.01  MACD_UPDOWN_MA_SLOPE           2  ...
# 65  32.79      2.00          -0.02  MACD_UPDOWN_MA_SLOPE           2  ...
# 71  36.00      1.65          -0.05  MACD_UPDOWN_MA_SLOPE           2  ...
#
#    Unnamed: 0_x   Last_Date  Signal                    model_name  model_freq  \
# 40           76  2021-03-18      买入  Macd_Updown_MA_Slope_Signals           D
# 57           97  2021-03-18      买入  Macd_Updown_MA_Slope_Signals           D
# 61          147  2021-03-18      买入  Macd_Updown_MA_Slope_Signals           D
# 65          150  2021-03-18      买入  Macd_Updown_MA_Slope_Signals           D
# 71          205  2021-03-18      买入  Macd_Updown_MA_Slope_Signals           D
#
#     Unnamed: 0_y        Date   Signal_Info  Last_Price Nearest_Level
# 40            53  2021-03-18  形成支撑点:154.98  157.649994    154.979996
# 57           160  2021-03-18   形成支撑点:56.15   56.310001     56.150002
# 61             7  2021-03-18   形成支撑点:61.26   61.759998     61.259998
# 65            72  2021-03-18   形成支撑点:38.18   38.939999     38.180000
# 71            20  2021-03-18  形成支撑点:214.43  215.360001    214.430381
#
# [5 rows x 26 columns]

# %% [markdown]
# # 模块五：相关性计算

# %%
from positions import *

# %%
target_pos_to_calculate_corr = ["ARKG","BABA", "TSLA", "VZ", "LOW","BNTX"]

# %%
def stock_list_to_calculate_corr(all_csvs, date_col, price_col, ticker_col):
	len_ = 0
	for fname in glob.glob(all_csvs)[:]:
		try:
			stock = pd.read_csv(fname)
			stock = stock.sort_values(date_col)
			ticker = stock[ticker_col].values[-1]
			print(ticker)
			stock = stock[[date_col,price_col]]
			stock['pct_chg'] = stock[price_col].pct_change()
			stock.columns = [date_col, price_col, ticker]
			stock = stock[[date_col, ticker]].dropna()
			stock[date_col] = pd.to_datetime(stock[date_col])
			#     stock.set_index('date', inplace=True)
			stock_list.append(stock)
			print ("Length of {}: {}".format(ticker, len(stock)))
			len_ = len_+len(stock)
			print ("Total length:{}".format(len_))
			print ("===========")
		except:
			print("Error on: {}".format(fname))
	return stock_list

# %%
all_csvs = "C:/Users/Administrator/CE_github_2/data_pipeline/Data/*.csv"
date_col = "Date"
price_col = "Adj Close"
ticker_col = "Ticker"
stock_list = []
stock_list = stock_list_to_calculate_corr(all_csvs, date_col, price_col, ticker_col)
merged_all = reduce(merge_df, stock_list)
merged_all.set_index(date_col, inplace=True)
# Out:
# 000001.SS
# Length of 000001.SS: 3932
# Total length:3932
# ===========
# 452
# Length of 452: 1707
# Total length:5639
# ===========
# 0005.HK
# Length of 0005.HK: 3992
# Total length:9631
# ===========
# 0008.HK
# Length of 0008.HK: 3957
# Total length:13588
# ===========
# 1508
# Length of 1508: 1368
# Total length:14956
# ===========
# 1838
# Length of 1838: 1274
# Total length:16230
# ===========
# 1888
# Length of 1888: 1330
# Total length:17560
# ===========
# 3096
# Length of 3096: 1075
# Total length:18635
# ===========
# 4233
# Length of 4233: 1017
# Total length:19652
# ===========
# 4851
# Length of 4851: 861
# Total length:20513
# ===========
# 5827
# Length of 5827: 586
# Total length:21099
# ===========
# 6792
# Length of 6792: 453
# Total length:21552
# ===========
# 9865
# Length of 9865: 46
# Total length:21598
# ===========
# 10358
# Length of 10358: 9
# Total length:21607
# ===========
# 10849
# Length of 10849: 21
# Total length:21628
# ===========
# 11609
# Length of 11609: 2
# Total length:21630
# ===========
# 0142.HK
# Length of 0142.HK: 3985
# Total length:25615
# ===========
# 0151.HK
# Length of 0151.HK: 3195
# Total length:28810
# ===========
# 0175.HK
# Length of 0175.HK: 3803
# Total length:32613
# ===========
# 0186.HK
# Length of 0186.HK: 3988
# Total length:36601
# ===========
# 0215.HK
# Length of 0215.HK: 3988
# Total length:40589
# ===========
# 0241.HK
# Length of 0241.HK: 3975
# Total length:44564
# ===========
# 0268.HK
# Length of 0268.HK: 3809
# Total length:48373
# ===========
# 0285.HK
# Length of 0285.HK: 3255
# Total length:51628
# ===========
# 0302.HK
# Length of 0302.HK: 339
# Total length:51967
# ===========
# 0303.HK
# Length of 0303.HK: 3990
# Total length:55957
# ===========
# 0315.HK
# Length of 0315.HK: 3984
# Total length:59941
# ===========
# 0418.HK
# Length of 0418.HK: 3984
# Total length:63925
# ===========
# 0419.HK
# Length of 0419.HK: 3947
# Total length:67872
# ===========
# 0439.HK
# Length of 0439.HK: 3360
# Total length:71232
# ===========
# 0493.HK
# Length of 0493.HK: 3992
# Total length:75224
# ===========
# 0522.HK
# Length of 0522.HK: 3992
# Total length:79216
# ===========
# 0552.HK
# Length of 0552.HK: 3511
# Total length:82727
# ===========
# 0596.HK
# Length of 0596.HK: 3259
# Total length:85986
# ===========
# 0698.HK
# Length of 0698.HK: 3989
# Total length:89975
# ===========
# 0700.HK
# Length of 0700.HK: 3991
# Total length:93966
# ===========
# 0728.HK
# Length of 0728.HK: 3979
# Total length:97945
# ===========
# 0732.HK
# Length of 0732.HK: 3991
# Total length:101936
# ===========
# 0751.HK
# Length of 0751.HK: 3990
# Total length:105926
# ===========
# 0762.HK
# Length of 0762.HK: 3982
# Total length:109908
# ===========
# 0763.HK
# Length of 0763.HK: 3991
# Total length:113899
# ===========
# 0777.HK
# Length of 0777.HK: 3290
# Total length:117189
# ===========
# 0788.HK
# Length of 0788.HK: 642
# Total length:117831
# ===========
# 0797.HK
# Length of 0797.HK: 657
# Total length:118488
# ===========
# 0799.HK
# Length of 0799.HK: 1828
# Total length:120316
# ===========
# 0941.HK
# Length of 0941.HK: 3988
# Total length:124304
# ===========
# 0981.HK
# Length of 0981.HK: 3988
# Total length:128292
# ===========
# 1024.HK
# Length of 1024.HK: 25
# Total length:128317
# ===========
# 1070.HK
# Length of 1070.HK: 3978
# Total length:132295
# ===========
# 110011
# Length of 110011: 3060
# Total length:135355
# ===========
# 1119.HK
# Length of 1119.HK: 559
# Total length:135914
# ===========
# 1137.HK
# Length of 1137.HK: 3958
# Total length:139872
# ===========
# 1310.HK
# Length of 1310.HK: 1483
# Total length:141355
# ===========
# 1347.HK
# Length of 1347.HK: 1584
# Total length:142939
# ===========
# 1385.HK
# Length of 1385.HK: 3814
# Total length:146753
# ===========
# 1415.HK
# Length of 1415.HK: 1470
# Total length:148223
# ===========
# 1458.HK
# Length of 1458.HK: 1070
# Total length:149293
# ===========
# 1475.HK
# Length of 1475.HK: 802
# Total length:150095
# ===========
# 1478.HK
# Length of 1478.HK: 1550
# Total length:151645
# ===========
# 1566.HK
# Length of 1566.HK: 1483
# Total length:153128
# ===========
# 1588.HK
# Length of 1588.HK: 1586
# Total length:154714
# ===========
# 1610.HK
# Length of 1610.HK: 1078
# Total length:155792
# ===========
# 161005
# Length of 161005: 3744
# Total length:159536
# ===========
# 161725
# Length of 161725: 1414
# Total length:160950
# ===========
# 1675.HK
# Length of 1675.HK: 550
# Total length:161500
# ===========
# 1810.HK
# Length of 1810.HK: 664
# Total length:162164
# ===========
# 1833.HK
# Length of 1833.HK: 707
# Total length:162871
# ===========
# 1883.HK
# Length of 1883.HK: 3431
# Total length:166302
# ===========
# 1909.HK
# Length of 1909.HK: 1253
# Total length:167555
# ===========
# 1979.HK
# Length of 1979.HK: 1297
# Total length:168852
# ===========
# 2018.HK
# Length of 2018.HK: 3843
# Total length:172695
# ===========
# 2038.HK
# Length of 2038.HK: 3955
# Total length:176650
# ===========
# 2051.HK
# Length of 2051.HK: 660
# Total length:177310
# ===========
# 2100.HK
# Length of 2100.HK: 1709
# Total length:179019
# ===========
# 2255.HK
# Length of 2255.HK: 1729
# Total length:180748
# ===========
# 2309.HK
# Length of 2309.HK: 3705
# Total length:184453
# ===========
# 2318.HK
# Length of 2318.HK: 3943
# Total length:188396
# ===========
# 2342.HK
# Length of 2342.HK: 3992
# Total length:192388
# ===========
# 2369.HK
# Length of 2369.HK: 3983
# Total length:196371
# ===========
# 2382.HK
# Length of 2382.HK: 3383
# Total length:199754
# ===========
# 2400.HK
# Length of 2400.HK: 309
# Total length:200063
# ===========
# 3690.HK
# Length of 3690.HK: 611
# Total length:200674
# ===========
# 3738.HK
# Length of 3738.HK: 787
# Total length:201461
# ===========
# 3798.HK
# Length of 3798.HK: 420
# Total length:201881
# ===========
# 3799.HK
# Length of 3799.HK: 1312
# Total length:203193
# ===========
# 3888.HK
# Length of 3888.HK: 3308
# Total length:206501
# ===========
# 6055.HK
# Length of 6055.HK: 437
# Total length:206938
# ===========
# 6060.HK
# Length of 6060.HK: 850
# Total length:207788
# ===========
# 6088.HK
# Length of 6088.HK: 905
# Total length:208693
# ===========
# 6188.HK
# Length of 6188.HK: 1652
# Total length:210345
# ===========
# 6618.HK
# Length of 6618.HK: 66
# Total length:210411
# ===========
# 6820.HK
# Length of 6820.HK: 356
# Total length:210767
# ===========
# 6823.HK
# Length of 6823.HK: 3955
# Total length:214722
# ===========
# 6862.HK
# Length of 6862.HK: 606
# Total length:215328
# ===========
# 6869.HK
# Length of 6869.HK: 1544
# Total length:216872
# ===========
# 6969.HK
# Length of 6969.HK: 169
# Total length:217041
# ===========
# 6993.HK
# Length of 6993.HK: 60
# Total length:217101
# ===========
# 8029.HK
# Length of 8029.HK: 3618
# Total length:220719
# ===========
# 8032.HK
# Length of 8032.HK: 3553
# Total length:224272
# ===========
# 9988.HK
# Length of 9988.HK: 321
# Total length:224593
# ===========
# 9990.HK
# Length of 9990.HK: 166
# Total length:224759
# ===========
# 9992.HK
# Length of 9992.HK: 63
# Total length:224822
# ===========
# 9999.HK
# Length of 9999.HK: 188
# Total length:225010
# ===========
# AAPL
# Length of AAPL: 4079
# Total length:229089
# ===========
# ABBV
# Length of ABBV: 2065
# Total length:231154
# ===========
# ABT
# Length of ABT: 4079
# Total length:235233
# ===========
# ACOR
# Length of ACOR: 3799
# Total length:239032
# ===========
# ADBE
# Length of ADBE: 4079
# Total length:243111
# ===========
# ADP
# Length of ADP: 4079
# Total length:247190
# ===========
# ADSK
# Length of ADSK: 4079
# Total length:251269
# ===========
# AEMD
# Length of AEMD: 4079
# Total length:255348
# ===========
# AEP
# Length of AEP: 4079
# Total length:259427
# ===========
# AHPI
# Length of AHPI: 4079
# Total length:263506
# ===========
# ALB
# Length of ALB: 4079
# Total length:267585
# ===========
# AMD
# Length of AMD: 4079
# Total length:271664
# ===========
# AMGN
# Length of AMGN: 4079
# Total length:275743
# ===========
# AMT
# Length of AMT: 4079
# Total length:279822
# ===========
# AMZN
# Length of AMZN: 4079
# Total length:283901
# ===========
# APD
# Length of APD: 4079
# Total length:287980
# ===========
# APT
# Length of APT: 4079
# Total length:292059
# ===========
# ARKF
# Length of ARKF: 533
# Total length:292592
# ===========
# ARKG
# Length of ARKG: 1603
# Total length:294195
# ===========
# ARKK
# Length of ARKK: 1603
# Total length:295798
# ===========
# ARKQ
# Length of ARKQ: 1626
# Total length:297424
# ===========
# ARKW
# Length of ARKW: 1626
# Total length:299050
# ===========
# ARPO
# Length of ARPO: 774
# Total length:299824
# ===========
# ATVI
# Length of ATVI: 4079
# Total length:303903
# ===========
# AXP
# Length of AXP: 4079
# Total length:307982
# ===========
# AZN
# Length of AZN: 4079
# Total length:312061
# ===========
# AZO
# Length of AZO: 4079
# Total length:316140
# ===========
# BA
# Length of BA: 4079
# Total length:320219
# ===========
# BABA
# Length of BABA: 1633
# Total length:321852
# ===========
# BAC
# Length of BAC: 4079
# Total length:325931
# ===========
# BBY
# Length of BBY: 4079
# Total length:330010
# ===========
# BILI
# Length of BILI: 747
# Total length:330757
# ===========
# BLK
# Length of BLK: 4079
# Total length:334836
# ===========
# BLNK
# Length of BLNK: 2827
# Total length:337663
# ===========
# BMY
# Length of BMY: 4079
# Total length:341742
# ===========
# BNTX
# Length of BNTX: 360
# Total length:342102
# ===========
# BX
# Length of BX: 3457
# Total length:345559
# ===========
# C
# Length of C: 4079
# Total length:349638
# ===========
# CAN
# Length of CAN: 331
# Total length:349969
# ===========
# CAT
# Length of CAT: 4079
# Total length:354048
# ===========
# CB
# Length of CB: 4079
# Total length:358127
# ===========
# CBLI
# Length of CBLI: 3686
# Total length:361813
# ===========
# CCI
# Length of CCI: 4079
# Total length:365892
# ===========
# CDAY
# Length of CDAY: 727
# Total length:366619
# ===========
# CHTR
# Length of CHTR: 2818
# Total length:369437
# ===========
# CHWY
# Length of CHWY: 442
# Total length:369879
# ===========
# CL
# Length of CL: 4079
# Total length:373958
# ===========
# CMCSA
# Length of CMCSA: 4079
# Total length:378037
# ===========
# CMG
# Length of CMG: 3810
# Total length:381847
# ===========
# CNET
# Length of CNET: 2916
# Total length:384763
# ===========
# CODX
# Length of CODX: 926
# Total length:385689
# ===========
# COST
# Length of COST: 4079
# Total length:389768
# ===========
# COUP
# Length of COUP: 1117
# Total length:390885
# ===========
# CRM
# Length of CRM: 4079
# Total length:394964
# ===========
# CRVS
# Length of CRVS: 1254
# Total length:396218
# ===========
# CRWD
# Length of CRWD: 444
# Total length:396662
# ===========
# CSCO
# Length of CSCO: 4079
# Total length:400741
# ===========
# CVS
# Length of CVS: 4079
# Total length:404820
# ===========
# CYB
# Length of CYB: 3226
# Total length:408046
# ===========
# CZR
# Length of CZR: 1632
# Total length:409678
# ===========
# D
# Length of D: 4079
# Total length:413757
# ===========
# DBA
# Length of DBA: 3573
# Total length:417330
# ===========
# DBC
# Length of DBC: 3803
# Total length:421133
# ===========
# DBX
# Length of DBX: 750
# Total length:421883
# ===========
# DD
# Length of DD: 4079
# Total length:425962
# ===========
# DDOG
# Length of DDOG: 375
# Total length:426337
# ===========
# DFFN
# Length of DFFN: 3225
# Total length:429562
# ===========
# DHR
# Length of DHR: 4079
# Total length:433641
# ===========
# DIS
# Length of DIS: 4079
# Total length:437720
# ===========
# DLR
# Length of DLR: 4079
# Total length:441799
# ===========
# DOCU
# Length of DOCU: 726
# Total length:442525
# ===========
# DUK
# Length of DUK: 4079
# Total length:446604
# ===========
# EBAY
# Length of EBAY: 4079
# Total length:450683
# ===========
# EBON
# Length of EBON: 181
# Total length:450864
# ===========
# ECL
# Length of ECL: 4079
# Total length:454943
# ===========
# EL
# Length of EL: 4079
# Total length:459022
# ===========
# ENPH
# Length of ENPH: 2254
# Total length:461276
# ===========
# EQ
# Length of EQ: 609
# Total length:461885
# ===========
# EQIX
# Length of EQIX: 4079
# Total length:465964
# ===========
# ES
# Length of ES: 4079
# Total length:470043
# ===========
# EXC
# Length of EXC: 4079
# Total length:474122
# ===========
# FB
# Length of FB: 2220
# Total length:476342
# ===========
# FCEL
# Length of FCEL: 4079
# Total length:480421
# ===========
# FLS
# Length of FLS: 4079
# Total length:484500
# ===========
# FMC
# Length of FMC: 4079
# Total length:488579
# ===========
# FXB
# Length of FXB: 3706
# Total length:492285
# ===========
# FXE
# Length of FXE: 3840
# Total length:496125
# ===========
# FXF
# Length of FXF: 3706
# Total length:499831
# ===========
# FXY
# Length of FXY: 3547
# Total length:503378
# ===========
# GBTC
# Length of GBTC: 1473
# Total length:504851
# ===========
# GDDY
# Length of GDDY: 1501
# Total length:506352
# ===========
# GDX
# Length of GDX: 3730
# Total length:510082
# ===========
# GE
# Length of GE: 4079
# Total length:514161
# ===========
# GILD
# Length of GILD: 4079
# Total length:518240
# ===========
# GLD
# Length of GLD: 4079
# Total length:522319
# ===========
# GOOG
# Length of GOOG: 4079
# Total length:526398
# ===========
# GOOGL
# Length of GOOGL: 4079
# Total length:530477
# ===========
# GS
# Length of GS: 4079
# Total length:534556
# ===========
# HD
# Length of HD: 4078
# Total length:538634
# ===========
# HON
# Length of HON: 4079
# Total length:542713
# ===========
# HTBX
# Length of HTBX: 1925
# Total length:544638
# ===========
# HUBS
# Length of HUBS: 1619
# Total length:546257
# ===========
# IBIO
# Length of IBIO: 3165
# Total length:549422
# ===========
# IEF
# Length of IEF: 4079
# Total length:553501
# ===========
# INO
# Length of INO: 4079
# Total length:557580
# ===========
# INTC
# Length of INTC: 4079
# Total length:561659
# ===========
# INTU
# Length of INTU: 4079
# Total length:565738
# ===========
# ISRG
# Length of ISRG: 4079
# Total length:569817
# ===========
# JD
# Length of JD: 1716
# Total length:571533
# ===========
# JNJ
# Length of JNJ: 4079
# Total length:575612
# ===========
# JPM
# Length of JPM: 4079
# Total length:579691
# ===========
# KHC
# Length of KHC: 1435
# Total length:581126
# ===========
# KO
# Length of KO: 4079
# Total length:585205
# ===========
# LAC
# Length of LAC: 3144
# Total length:588349
# ===========
# LAKE
# Length of LAKE: 4079
# Total length:592428
# ===========
# LAZR
# Length of LAZR: 499
# Total length:592927
# ===========
# LFIN
# Length of LFIN: 819
# Total length:593746
# ===========
# LI
# Length of LI: 158
# Total length:593904
# ===========
# LIN
# Length of LIN: 4079
# Total length:597983
# ===========
# LLY
# Length of LLY: 4079
# Total length:602062
# ===========
# LMT
# Length of LMT: 4079
# Total length:606141
# ===========
# LOW
# Length of LOW: 4079
# Total length:610220
# ===========
# LTHM
# Length of LTHM: 610
# Total length:610830
# ===========
# LULU
# Length of LULU: 3433
# Total length:614263
# ===========
# LVS
# Length of LVS: 4079
# Total length:618342
# ===========
# MA
# Length of MA: 3727
# Total length:622069
# ===========
# MARA
# Length of MARA: 2230
# Total length:624299
# ===========
# MCD
# Length of MCD: 4079
# Total length:628378
# ===========
# MDT
# Length of MDT: 4079
# Total length:632457
# ===========
# MET
# Length of MET: 4079
# Total length:636536
# ===========
# MMM
# Length of MMM: 4079
# Total length:640615
# ===========
# MRK
# Length of MRK: 4079
# Total length:644694
# ===========
# MRNA
# Length of MRNA: 571
# Total length:645265
# ===========
# MS
# Length of MS: 4079
# Total length:649344
# ===========
# MSFT
# Length of MSFT: 4079
# Total length:653423
# ===========
# MU
# Length of MU: 4079
# Total length:657502
# ===========
# NCTY
# Length of NCTY: 4079
# Total length:661581
# ===========
# NEE
# Length of NEE: 4079
# Total length:665660
# ===========
# NEM
# Length of NEM: 4079
# Total length:669739
# ===========
# NFLX
# Length of NFLX: 4079
# Total length:673818
# ===========
# NIO
# Length of NIO: 631
# Total length:674449
# ===========
# NKE
# Length of NKE: 4079
# Total length:678528
# ===========
# NNVC
# Length of NNVC: 3872
# Total length:682400
# ===========
# NOVA
# Length of NOVA: 414
# Total length:682814
# ===========
# NOW
# Length of NOW: 2191
# Total length:685005
# ===========
# NVAX
# Length of NVAX: 4079
# Total length:689084
# ===========
# NVDA
# Length of NVDA: 4079
# Total length:693163
# ===========
# OKTA
# Length of OKTA: 991
# Total length:694154
# ===========
# OPEN
# Length of OPEN: 187
# Total length:694341
# ===========
# ORCL
# Length of ORCL: 4079
# Total length:698420
# ===========
# OSTK
# Length of OSTK: 4079
# Total length:702499
# ===========
# PAYC
# Length of PAYC: 1742
# Total length:704241
# ===========
# PDD
# Length of PDD: 664
# Total length:704905
# ===========
# PEP
# Length of PEP: 4079
# Total length:708984
# ===========
# PFE
# Length of PFE: 4079
# Total length:713063
# ===========
# PG
# Length of PG: 4079
# Total length:717142
# ===========
# PLD
# Length of PLD: 4079
# Total length:721221
# ===========
# PLUG
# Length of PLUG: 4079
# Total length:725300
# ===========
# PM
# Length of PM: 3273
# Total length:728573
# ===========
# PSA
# Length of PSA: 4079
# Total length:732652
# ===========
# PTON
# Length of PTON: 370
# Total length:733022
# ===========
# PYPL
# Length of PYPL: 1435
# Total length:734457
# ===========
# QCOM
# Length of QCOM: 4079
# Total length:738536
# ===========
# QQQ
# Length of QQQ: 4079
# Total length:742615
# ===========
# QS
# Length of QS: 146
# Total length:742761
# ===========
# RACE
# Length of RACE: 1359
# Total length:744120
# ===========
# RENN
# Length of RENN: 2483
# Total length:746603
# ===========
# RIOT
# Length of RIOT: 1249
# Total length:747852
# ===========
# RNG
# Length of RNG: 1879
# Total length:749731
# ===========
# RTX
# Length of RTX: 4079
# Total length:753810
# ===========
# RUN
# Length of RUN: 1413
# Total length:755223
# ===========
# SAM
# Length of SAM: 4079
# Total length:759302
# ===========
# SAP
# Length of SAP: 4079
# Total length:763381
# ===========
# SBAC
# Length of SBAC: 4079
# Total length:767460
# ===========
# SBE
# Length of SBE: 378
# Total length:767838
# ===========
# SBUX
# Length of SBUX: 4079
# Total length:771917
# ===========
# SCCO
# Length of SCCO: 4079
# Total length:775996
# ===========
# SHOP
# Length of SHOP: 1466
# Total length:777462
# ===========
# SHW
# Length of SHW: 4079
# Total length:781541
# ===========
# SMAR
# Length of SMAR: 726
# Total length:782267
# ===========
# SO
# Length of SO: 4079
# Total length:786346
# ===========
# SPLK
# Length of SPLK: 2241
# Total length:788587
# ===========
# SPOT
# Length of SPOT: 744
# Total length:789331
# ===========
# SPY
# Length of SPY: 4079
# Total length:793410
# ===========
# SQ
# Length of SQ: 1338
# Total length:794748
# ===========
# SQM
# Length of SQM: 4079
# Total length:798827
# ===========
# SRAX
# Length of SRAX: 2115
# Total length:800942
# ===========
# SRE
# Length of SRE: 4079
# Total length:805021
# ===========
# STZ
# Length of STZ: 4079
# Total length:809100
# ===========
# T
# Length of T: 4079
# Total length:813179
# ===========
# TEAM
# Length of TEAM: 1325
# Total length:814504
# ===========
# TGT
# Length of TGT: 4079
# Total length:818583
# ===========
# TLT
# Length of TLT: 4079
# Total length:822662
# ===========
# TMO
# Length of TMO: 4079
# Total length:826741
# ===========
# TMUS
# Length of TMUS: 3502
# Total length:830243
# ===========
# TQQQ
# Length of TQQQ: 2792
# Total length:833035
# ===========
# TSLA
# Length of TSLA: 2697
# Total length:835732
# ===========
# TSM
# Length of TSM: 4079
# Total length:839811
# ===========
# TSN
# Length of TSN: 4079
# Total length:843890
# ===========
# TTD
# Length of TTD: 1128
# Total length:845018
# ===========
# TWLO
# Length of TWLO: 1190
# Total length:846208
# ===========
# UNH
# Length of UNH: 4079
# Total length:850287
# ===========
# UNP
# Length of UNP: 4079
# Total length:854366
# ===========
# UPS
# Length of UPS: 4079
# Total length:858445
# ===========
# UUP
# Length of UUP: 3536
# Total length:861981
# ===========
# UVXY
# Length of UVXY: 2377
# Total length:864358
# ===========
# V
# Length of V: 3271
# Total length:867629
# ===========
# VCNX
# Length of VCNX: 654
# Total length:868283
# ===========
# VEEV
# Length of VEEV: 1866
# Total length:870149
# ===========
# VIR
# Length of VIR: 359
# Total length:870508
# ===========
# VLDR
# Length of VLDR: 599
# Total length:871107
# ===========
# VXRT
# Length of VXRT: 4079
# Total length:875186
# ===========
# VXX
# Length of VXX: 790
# Total length:875976
# ===========
# VZ
# Length of VZ: 4079
# Total length:880055
# ===========
# WDAY
# Length of WDAY: 2118
# Total length:882173
# ===========
# WES
# Length of WES: 2080
# Total length:884253
# ===========
# WFC
# Length of WFC: 4079
# Total length:888332
# ===========
# WMT
# Length of WMT: 4079
# Total length:892411
# ===========
# WORK
# Length of WORK: 438
# Total length:892849
# ===========
# XEL
# Length of XEL: 4079
# Total length:896928
# ===========
# XL
# Length of XL: 387
# Total length:897315
# ===========
# XLB
# Length of XLB: 4079
# Total length:901394
# ===========
# XLE
# Length of XLE: 4079
# Total length:905473
# ===========
# XLF
# Length of XLF: 4078
# Total length:909551
# ===========
# XLI
# Length of XLI: 4079
# Total length:913630
# ===========
# XLK
# Length of XLK: 4079
# Total length:917709
# ===========
# XLP
# Length of XLP: 4079
# Total length:921788
# ===========
# XLRE
# Length of XLRE: 1368
# Total length:923156
# ===========
# XLU
# Length of XLU: 4079
# Total length:927235
# ===========
# XLV
# Length of XLV: 4079
# Total length:931314
# ===========
# XLY
# Length of XLY: 4079
# Total length:935393
# ===========
# XNET
# Length of XNET: 1694
# Total length:937087
# ===========
# XPEV
# Length of XPEV: 138
# Total length:937225
# ===========
# ZEN
# Length of ZEN: 1721
# Total length:938946
# ===========
# ZM
# Length of ZM: 481
# Total length:939427
# ===========
# ^DJI
# Length of ^DJI: 4079
# Total length:943506
# ===========
# ^GSPC
# Length of ^GSPC: 4079
# Total length:947585
# ===========
# ^HSI
# Length of ^HSI: 3987
# Total length:951572
# ===========
# ^IXIC
# Length of ^IXIC: 4079
# Total length:955651
# ===========

# %%
# hsi = pd.read_csv(us_db_path+"^HSI.csv")
# spx = pd.read_csv(us_db_path+"^GSPC.csv")

# hsi['Adj Close HK'] = hsi['Adj Close'].shift(-1)

# hsi = hsi[['Date','Adj Close HK']]
# spx = spx[['Date','Adj Close']]

# hsi['HSI'] = hsi['Adj Close HK'].pct_change()
# spx['SPX'] = spx['Adj Close'].pct_change()

# hsi.dropna(inplace = True)
# spx.dropna(inplace = True)

# hsi[(hsi['Date']>"2021/2/17") | (hsi['Date']<"2021/3/4")]

# %%
merged_all.dropna(inplace= True)

# %%
plot_heatmap_corrleation(merged_all,target_pos_to_calculate_corr)

# %%
corr_matrix = merged_all[target_pos_to_calculate_corr].corr()
each_corr_mean = corr_matrix[corr_matrix!=1].mean()

# %%
each_corr_mean
# Out:
# TSLA    0.255080
# MU      0.290576
# ABBV    0.235786
# CMG     0.246123
# dtype: float64

# %% [markdown]
# # 模块六：RP模型计算目标仓位

# %%
stocks_path = "C:/Users/Administrator/CE_github_2/data_pipeline/Data/"
date_col = 'Date'
code_col = 'Ticker'
price_col = 'Adj Close'
ticker_type = 'string'
asset_name = "code"

risk_parity = RiskParity(stocks_path,
                          target_pos_to_calculate_corr,
                          date_col,
                          code_col,
                          price_col,
                          ticker_type,
                          asset_name,
                          True)

# %%
0.083*0.667
# Out:
# 0.05536100000000001

# %%
# QS: 涨不到5日均线以上，就平仓
# RIOT：下穿5日均线
#

# %%
4000/58.90
# Out:
# 67.91171477079797

# %%
risk_parity.df_wts['target_wts'] = risk_parity.df_wts['weight']*0.6*0.5

# %%
risk_parity.df_wts
# Out:
#    code    weight  target_wts
# 0  TSLA  0.168954    0.050686
# 1    MU  0.203781    0.061134
# 2  ABBV  0.344762    0.103429
# 3   CMG  0.282504    0.084751

# %%
# MU:
round(102800*0.204/89.30)
# done
# Out:
# 235

# %%
# TSLA
round(102800*0.169/673.58)
# done
# Out:
# 26

# %%
# CMG
round(102800*0.283/1427.61)
# Out:
# 72

# %%
# ABBV
round(102800*0.345/106.79)
# Out:
# 120

# %%
round()

# %%
11000*(30.7/46.1)
# Out:
# 7325.379609544468

# %% [markdown]
# # 模块七：实时计算仓位

# %%
def target_HK_shares(ticker, last_price, target_pos_pct, available_dollar):

#     last_price = 13.3
#     target_pos_pct = 0.5
#     stop_loss = 27.9518.2
#     available_dollar = 100000
    target_pos_dollar = target_pos_pct*available_dollar
    USD_HKD_exchange_rate = 7.5
    target_pos_HKD = target_pos_dollar*USD_HKD_exchange_rate
    target_HK_shares = round(target_pos_HKD/last_price)
    print("Ticker: {}".format(ticker))
    print("Target_Shares: ", target_HK_shares)
    return target_HK_shares, target_pos_HKD


def target_US_shares(ticker, last_price, target_pos_pct, position_values):

#     last_price = 13.3
#     target_pos_pct = 0.5
#     stop_loss = 27.9518.2
#     available_dollar = 100000
    target_pos_dollar = target_pos_pct*available_dollar
    USD_HKD_exchange_rate = 1
    target_pos_HKD = target_pos_dollar*USD_HKD_exchange_rate
    target_HK_shares = round(target_pos_HKD/last_price)
    print("Ticker: {}".format(ticker))
    print("Target_Shares: ", target_HK_shares)
    return target_HK_shares, target_pos_HKD


def HK_expected_loss(target_HK_shares, target_pos_HKD, ex_price_w_cost, stop_loss_price, portfolio_value):
    USD_HKD_exchange_rate = 7.5
    single_trade_expected_loss_pct = stop_loss_price/ex_price_w_cost-1
    single_trade_expected_loss_USD = single_trade_expected_loss_pct*target_pos_HKD/USD_HKD_exchange_rate
    port_expected_loss_pct = single_trade_expected_loss_USD/portfolio_value

    print("单笔交易止损损失%: ", round(single_trade_expected_loss_pct*100, 3), "%")
    print("账户产生的止损损失%: ", round(port_expected_loss_pct*100, 3), "%")
    print("账户止损损失美元价值: ", "$",round(single_trade_expected_loss_USD, 2))
    print("Breakeven Price w commissions:", round(ex_price_w_cost*1.0015, 2))
    print("1% Profits w commissions:", round(ex_price_w_cost*1.01, 2))
    print("2% Profits w commissions:", round(ex_price_w_cost*1.02, 2))

# %%
target_HK_shares, target_pos_HKD = target_HK_shares("AAPL", 127.79, 0.128, 107055)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-46-d2ec43837c00> in <module>
# ----> 1 target_HK_shares, target_pos_HKD = target_HK_shares("AAPL", 127.79, 0.128, 107055)
#
# TypeError: 'int' object is not callable
