# %%
import pandas as pd, numpy as np
np.set_printoptions(suppress=True)# 关掉科学计数法
import glob
import os
import csv
# 一次性merge多个pct_chg
from functools import reduce
from datetime import datetime, timedelta
import statsmodels.api as sm
from statsmodels import regression
import time, urllib

# import matplotlib
import matplotlib.pyplot as plt

import seaborn as sns
# %matplotlib inline
sns.set(context='notebook', style='darkgrid', palette='deep', font='sans-serif', font_scale=1, color_codes=False, rc=None)

# %% [markdown]
# # 1. MACD系列

# %%
# 定义每个筛选模型

# 1. MACD
def MACD(df, price_col, n_fast, n_slow): # n_fast = 12, n_slow = 26
    """
    http://stockcharts.com/docs/doku.php?id=scans:indicators
    MACD, MACD Signal and MACD difference, rationale CHECKED, code CHECKED, updated
    # Conventional look-back window for calculating MACDsign is 9
    """
    EMAfast = df[price_col].ewm(span = n_fast, min_periods = n_fast - 1).mean()
    EMAslow = df[price_col].ewm(span = n_slow, min_periods = n_slow - 1).mean()
    diff = pd.Series(EMAfast - EMAslow)
    dea = diff.ewm(span = 9, min_periods = 8).mean()
    macd = (pd.Series(diff - dea))*2
    df["DIFF"] = diff
    df["DEA"] = dea
    df["MACD"] = macd
    return df

# %%
# 在MACD模型下的开平仓算法

def macd_updown_signals(df, signal_spread_col, date_col, ticker_col):
    ticker = df[ticker_col].values[-1]
    df.dropna(inplace = True)
    df.reset_index(inplace = True)
    del df['index']
    listLongShort = []
    listDate = []
    macd = df[signal_spread_col].values
    
    for i in range(1, len(df)):
        last_date = df[date_col][i]
        
        if macd[i]>macd[i-1] and macd[i-1]<macd[i-2]:
            
            listLongShort.append("BUY")
            listDate.append(last_date)
        #                          # The other way around
        elif macd[i]<macd[i-1] and macd[i-1]>macd[i-2]:
            listLongShort.append("SELL")
            listDate.append(last_date)
        #                          # Do nothing if not satisfied
        elif macd[i]<macd[i-1]:
            listLongShort.append("HOLD SHORT")
            listDate.append(last_date)
            
        elif macd[i]>macd[i-1]:
            listLongShort.append("HOLD LONG")
            listDate.append(last_date)           
            
    return ticker, listDate[-1], listLongShort[-1]
#     df['Advice'] = listLongShort
    # The advice column means "Buy/Sell/Hold" at the end of this day or
    #  at the beginning of the next day, since the market will be closed

# %%
def macd_cross_signals(df, signal_spread_col, date_col, ticker_col):
    ticker = df[ticker_col].values[-1]
    df.dropna(inplace = True)
    df.reset_index(inplace = True)
    del df['index']
    listLongShort = []
    listDate = []
    macd = df[signal_spread_col].values
    
    for i in range(1, len(df)):
        last_date = df[date_col][i]
        #                          # If the MACD crosses the signal line upward
        if macd[i] >0 and macd[i - 1] <0:
            listLongShort.append("BUY")
            listDate.append(last_date)
        #                          # The other way around
        elif macd[i] < 0 and macd[i - 1] >0:
            listLongShort.append("SELL")
            listDate.append(last_date)
        #                          # Do nothing if not crossed
        else: # 还要改，再增加点条件
            listLongShort.append("HOLD")
            listDate.append(last_date)
#     print("Ticker: ", ticker)
#     print("Last Date", listDate[-1])
#     print("Last Signal", listLongShort[-1])
    return ticker, listDate[-1], listLongShort[-1]
#     df['Advice'] = listLongShort
    # The advice column means "Buy/Sell/Hold" at the end of this day or
    #  at the beginning of the next day, since the market will be closed

# %% [markdown]
# ## 日线 - MACD

# %%
all_csvs = "C:/Users/Administrator/CE_github_2/data_pipeline/Data/*.csv"
stock_list = []
date_list = []
signal_list = []
len_ = 1
date_col = "Date"
price_col = "Adj Close"
model_freq = "D"
signal_df = pd.DataFrame()
model_name = "Macd_Updown_Signals"
total_number = len(glob.glob(all_csvs)[:])


for fname in glob.glob(all_csvs)[:]:
    print ("Calculating Signals for No.{} : {}".format(len_, fname))
    data = pd.read_csv(fname)
    try:
        data_macd = MACD(data, "Adj Close", 12, 26)
        ticker, last_date, last_signal = macd_updown_signals(data_macd, "MACD", "Date", 'Ticker')
        stock_list.append(ticker)
        date_list.append(last_date)
        signal_list.append(last_signal)
    except Exception as e:
        print(e)
    len_+= 1
signal_df['Ticker'] = stock_list
signal_df['Last_Date'] = date_list
signal_df['Signal'] = signal_list
signal_df['model_name'] = model_name
signal_df['model_freq'] = model_freq
signal_df_daily = signal_df.copy()
print("All Done!")
# def merge_df(df1, df2):
#     df1.sort_values(date_col, inplace = True)
#     merged = df1.merge(df2, on = date_col, how = 'outer')
#     merged.sort_values(date_col, inplace = True)
#     return merged

# merged_all = reduce(merge_df, stock_list)
# merged_all.set_index(date_col, inplace=True)
# Out:
# Calculating Signals for No.1 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\000001.SS.csv
# Calculating Signals for No.2 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\0005.HK.csv
# Calculating Signals for No.3 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\0008.HK.csv
# Calculating Signals for No.4 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\0142.HK.csv
# Calculating Signals for No.5 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\0151.HK.csv
# Calculating Signals for No.6 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\0175.HK.csv
# Calculating Signals for No.7 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\0186.HK.csv
# Calculating Signals for No.8 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\0215.HK.csv
# Calculating Signals for No.9 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\0241.HK.csv
# Calculating Signals for No.10 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\0268.HK.csv
# Calculating Signals for No.11 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\0285.HK.csv
# Calculating Signals for No.12 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\0302.HK.csv
# Calculating Signals for No.13 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\0303.HK.csv
# Calculating Signals for No.14 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\0315.HK.csv
# Calculating Signals for No.15 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\0418.HK.csv
# Calculating Signals for No.16 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\0419.HK.csv
# Calculating Signals for No.17 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\0439.HK.csv
# Calculating Signals for No.18 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\0493.HK.csv
# Calculating Signals for No.19 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\0522.HK.csv
# Calculating Signals for No.20 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\0552.HK.csv
# Calculating Signals for No.21 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\0596.HK.csv
# Calculating Signals for No.22 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\0698.HK.csv
# Calculating Signals for No.23 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\0700.HK.csv
# Calculating Signals for No.24 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\0728.HK.csv
# Calculating Signals for No.25 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\0732.HK.csv
# Calculating Signals for No.26 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\0751.HK.csv
# Calculating Signals for No.27 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\0762.HK.csv
# Calculating Signals for No.28 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\0763.HK.csv
# Calculating Signals for No.29 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\0777.HK.csv
# Calculating Signals for No.30 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\0788.HK.csv
# Calculating Signals for No.31 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\0797.HK.csv
# Calculating Signals for No.32 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\0799.HK.csv
# Calculating Signals for No.33 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\0941.HK.csv
# Calculating Signals for No.34 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\0981.HK.csv
# Calculating Signals for No.35 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\1024.HK.csv
# list index out of range
# Calculating Signals for No.36 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\1070.HK.csv
# Calculating Signals for No.37 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\1119.HK.csv
# Calculating Signals for No.38 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\1137.HK.csv
# Calculating Signals for No.39 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\1310.HK.csv
# Calculating Signals for No.40 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\1347.HK.csv
# Calculating Signals for No.41 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\1385.HK.csv
# Calculating Signals for No.42 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\1415.HK.csv
# Calculating Signals for No.43 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\1458.HK.csv
# Calculating Signals for No.44 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\1475.HK.csv
# Calculating Signals for No.45 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\1566.HK.csv
# Calculating Signals for No.46 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\1588.HK.csv
# Calculating Signals for No.47 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\1610.HK.csv
# Calculating Signals for No.48 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\1675.HK.csv
# Calculating Signals for No.49 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\1810.HK.csv
# Calculating Signals for No.50 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\1833.HK.csv
# Calculating Signals for No.51 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\1883.HK.csv
# Calculating Signals for No.52 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\1909.HK.csv
# Calculating Signals for No.53 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\1979.HK.csv
# Calculating Signals for No.54 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\2018.HK.csv
# Calculating Signals for No.55 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\2038.HK.csv
# Calculating Signals for No.56 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\2051.HK.csv
# Calculating Signals for No.57 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\2100.HK.csv
# Calculating Signals for No.58 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\2255.HK.csv
# Calculating Signals for No.59 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\2309.HK.csv
# Calculating Signals for No.60 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\2318.HK.csv
# Calculating Signals for No.61 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\2342.HK.csv
# Calculating Signals for No.62 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\2369.HK.csv
# Calculating Signals for No.63 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\2382.HK.csv
# Calculating Signals for No.64 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\2400.HK.csv
# Calculating Signals for No.65 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\3690.HK.csv
# Calculating Signals for No.66 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\3738.HK.csv
# Calculating Signals for No.67 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\3798.HK.csv
# Calculating Signals for No.68 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\3799.HK.csv
# Calculating Signals for No.69 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\3888.HK.csv
# Calculating Signals for No.70 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\6055.HK.csv
# Calculating Signals for No.71 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\6060.HK.csv
# Calculating Signals for No.72 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\6088.HK.csv
# Calculating Signals for No.73 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\6188.HK.csv
# Calculating Signals for No.74 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\6618.HK.csv
# Calculating Signals for No.75 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\6820.HK.csv
# Calculating Signals for No.76 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\6823.HK.csv
# Calculating Signals for No.77 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\6862.HK.csv
# Calculating Signals for No.78 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\6869.HK.csv
# Calculating Signals for No.79 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\6969.HK.csv
# Calculating Signals for No.80 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\6993.HK.csv
# Calculating Signals for No.81 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\8029.HK.csv
# Calculating Signals for No.82 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\8032.HK.csv
# Calculating Signals for No.83 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\9988.HK.csv
# Calculating Signals for No.84 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\9990.HK.csv
# Calculating Signals for No.85 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\9992.HK.csv
# Calculating Signals for No.86 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\9999.HK.csv
# Calculating Signals for No.87 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\AAPL.csv
# Calculating Signals for No.88 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\ABT.csv
# Calculating Signals for No.89 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\ACOR.csv
# Calculating Signals for No.90 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\ADBE.csv
# Calculating Signals for No.91 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\ADP.csv
# Calculating Signals for No.92 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\ADSK.csv
# Calculating Signals for No.93 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\AEMD.csv
# Calculating Signals for No.94 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\AHPI.csv
# Calculating Signals for No.95 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\ALB.csv
# Calculating Signals for No.96 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\AMD.csv
# Calculating Signals for No.97 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\AMZN.csv
# Calculating Signals for No.98 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\APT.csv
# Calculating Signals for No.99 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\ARKF.csv
# Calculating Signals for No.100 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\ARKG.csv
# Calculating Signals for No.101 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\ARKK.csv
# Calculating Signals for No.102 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\ARKQ.csv
# Calculating Signals for No.103 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\ARKW.csv
# Calculating Signals for No.104 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\ARPO.csv
# Calculating Signals for No.105 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\AZN.csv
# Calculating Signals for No.106 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\BABA.csv
# Calculating Signals for No.107 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\BLNK.csv
# Calculating Signals for No.108 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\BNTX.csv
# Calculating Signals for No.109 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\CAN.csv
# Calculating Signals for No.110 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\CBLI.csv
# Calculating Signals for No.111 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\CDAY.csv
# Calculating Signals for No.112 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\CNET.csv
# Calculating Signals for No.113 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\CODX.csv
# Calculating Signals for No.114 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\COUP.csv
# Calculating Signals for No.115 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\CRM.csv
# Calculating Signals for No.116 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\CRVS.csv
# Calculating Signals for No.117 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\CRWD.csv
# Calculating Signals for No.118 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\CSCO.csv
# Calculating Signals for No.119 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\CYB.csv
# Calculating Signals for No.120 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\DBA.csv
# Calculating Signals for No.121 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\DBC.csv
# Calculating Signals for No.122 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\DBX.csv
# Calculating Signals for No.123 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\DDOG.csv
# Calculating Signals for No.124 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\DFFN.csv
# Calculating Signals for No.125 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\DOCU.csv
# Calculating Signals for No.126 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\EBON.csv
# Calculating Signals for No.127 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\ENPH.csv
# Calculating Signals for No.128 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\EQ.csv
# Calculating Signals for No.129 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\FB.csv
# Calculating Signals for No.130 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\FCEL.csv
# Calculating Signals for No.131 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\FLS.csv
# Calculating Signals for No.132 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\FMC.csv
# Calculating Signals for No.133 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\FXB.csv
# Calculating Signals for No.134 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\FXE.csv
# Calculating Signals for No.135 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\FXF.csv
# Calculating Signals for No.136 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\FXY.csv
# Calculating Signals for No.137 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\GBTC.csv
# Calculating Signals for No.138 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\GDDY.csv
# Calculating Signals for No.139 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\GDX.csv
# Calculating Signals for No.140 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\GILD.csv
# Calculating Signals for No.141 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\GLD.csv
# Calculating Signals for No.142 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\GOOG.csv
# Calculating Signals for No.143 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\GOOGL.csv
# Calculating Signals for No.144 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\HTBX.csv
# Calculating Signals for No.145 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\HUBS.csv
# Calculating Signals for No.146 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\IBIO.csv
# Calculating Signals for No.147 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\IEF.csv
# Calculating Signals for No.148 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\INO.csv
# Calculating Signals for No.149 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\INTC.csv
# Calculating Signals for No.150 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\INTU.csv
# Calculating Signals for No.151 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\JNJ.csv
# Calculating Signals for No.152 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\LAC.csv
# Calculating Signals for No.153 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\LAKE.csv
# Calculating Signals for No.154 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\LAZR.csv
# Calculating Signals for No.155 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\LFIN.csv
# Calculating Signals for No.156 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\LI.csv
# Calculating Signals for No.157 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\LTHM.csv
# Calculating Signals for No.158 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\MA.csv
# Calculating Signals for No.159 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\MARA.csv
# Calculating Signals for No.160 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\MRNA.csv
# Calculating Signals for No.161 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\MSFT.csv
# Calculating Signals for No.162 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\MU.csv
# Calculating Signals for No.163 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\NCTY.csv
# Calculating Signals for No.164 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\NFLX.csv
# Calculating Signals for No.165 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\NIO.csv
# Calculating Signals for No.166 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\NNVC.csv
# Calculating Signals for No.167 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\NOVA.csv
# Calculating Signals for No.168 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\NOW.csv
# Calculating Signals for No.169 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\NVAX.csv
# Calculating Signals for No.170 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\NVDA.csv
# Calculating Signals for No.171 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\OKTA.csv
# Calculating Signals for No.172 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\OPEN.csv
# Calculating Signals for No.173 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\ORCL.csv
# Calculating Signals for No.174 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\OSTK.csv
# Calculating Signals for No.175 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\PAYC.csv
# Calculating Signals for No.176 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\PFE.csv
# Calculating Signals for No.177 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\PLUG.csv
# Calculating Signals for No.178 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\PYPL.csv
# Calculating Signals for No.179 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\QCOM.csv
# Calculating Signals for No.180 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\QQQ.csv
# Calculating Signals for No.181 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\QS.csv
# Calculating Signals for No.182 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\RENN.csv
# Calculating Signals for No.183 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\RIOT.csv
# Calculating Signals for No.184 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\RNG.csv
# Calculating Signals for No.185 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\RUN.csv
# Calculating Signals for No.186 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\SAP.csv
# Calculating Signals for No.187 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\SBE.csv
# Calculating Signals for No.188 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\SHOP.csv
# Calculating Signals for No.189 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\SMAR.csv
# Calculating Signals for No.190 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\SPLK.csv
# Calculating Signals for No.191 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\SPY.csv
# Calculating Signals for No.192 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\SQ.csv
# Calculating Signals for No.193 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\SQM.csv
# Calculating Signals for No.194 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\SRAX.csv
# Calculating Signals for No.195 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\TEAM.csv
# Calculating Signals for No.196 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\TLT.csv
# Calculating Signals for No.197 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\TSLA.csv
# Calculating Signals for No.198 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\TSM.csv
# Calculating Signals for No.199 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\TTD.csv
# Calculating Signals for No.200 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\TWLO.csv
# Calculating Signals for No.201 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\UUP.csv
# Calculating Signals for No.202 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\UVXY.csv
# Calculating Signals for No.203 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\V.csv
# Calculating Signals for No.204 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\VCNX.csv
# Calculating Signals for No.205 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\VEEV.csv
# Calculating Signals for No.206 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\VIR.csv
# Calculating Signals for No.207 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\VLDR.csv
# Calculating Signals for No.208 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\VXRT.csv
# Calculating Signals for No.209 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\VXX.csv
# Calculating Signals for No.210 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\WDAY.csv
# Calculating Signals for No.211 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\WORK.csv
# Calculating Signals for No.212 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\XL.csv
# Calculating Signals for No.213 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\XLB.csv
# Calculating Signals for No.214 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\XLE.csv
# Calculating Signals for No.215 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\XLF.csv
# Calculating Signals for No.216 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\XLI.csv
# Calculating Signals for No.217 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\XLK.csv
# Calculating Signals for No.218 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\XLP.csv
# Calculating Signals for No.219 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\XLRE.csv
# Calculating Signals for No.220 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\XLREARKG.csv
# index -1 is out of bounds for axis 0 with size 0
# Calculating Signals for No.221 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\XLU.csv
# Calculating Signals for No.222 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\XLV.csv
# Calculating Signals for No.223 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\XLY.csv
# Calculating Signals for No.224 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\XNET.csv
# Calculating Signals for No.225 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\XPEV.csv
# Calculating Signals for No.226 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\ZEN.csv
# Calculating Signals for No.227 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\ZM.csv
# Calculating Signals for No.228 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\^DJI.csv
# Calculating Signals for No.229 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\^GSPC.csv
# Calculating Signals for No.230 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\^IXIC.csv
# All Done!

# %%
signal_path = "C:/Users/Administrator/CE_github_2/data_pipeline/Signals/"
signal_file = signal_path+model_name+"_"+last_date+".csv"
signal_df_daily.to_csv(signal_file)

# %%
signal_df_daily
# Out:
#         Ticker   Last_Date      Signal           model_name model_freq
# 0    000001.SS  2021-02-26  HOLD SHORT  Macd_Updown_Signals          D
# 1      0005.HK  2021-02-26        SELL  Macd_Updown_Signals          D
# 2      0008.HK  2021-02-26  HOLD SHORT  Macd_Updown_Signals          D
# 3      0142.HK  2021-02-26        SELL  Macd_Updown_Signals          D
# 4      0151.HK  2021-02-26  HOLD SHORT  Macd_Updown_Signals          D
# ..         ...         ...         ...                  ...        ...
# 223        ZEN  2021-02-26  HOLD SHORT  Macd_Updown_Signals          D
# 224         ZM  2021-02-26  HOLD SHORT  Macd_Updown_Signals          D
# 225       ^DJI  2021-02-26  HOLD SHORT  Macd_Updown_Signals          D
# 226      ^GSPC  2021-02-26  HOLD SHORT  Macd_Updown_Signals          D
# 227      ^IXIC  2021-02-26  HOLD SHORT  Macd_Updown_Signals          D
#
# [228 rows x 5 columns]

# %% [markdown]
# ## 周线 - MACD

# %%
all_csvs = "C:/Users/Administrator/CE_github_2/data_pipeline/Data/*.csv"
stock_list = []
date_list = []
signal_list = []
len_ = 1
date_col = "Date"
price_col = "Adj Close"
signal_df = pd.DataFrame()
model_name = "Macd_Updown_Signals"
model_freq = "W"
total_number = len(glob.glob(all_csvs)[:])


for fname in glob.glob(all_csvs)[:]:
    print ("Calculating Signals for No.{} : {}".format(len_, fname))
    data = pd.read_csv(fname)
    data.index = pd.to_datetime(data[date_col])
    data = data.resample(model_freq).last()
    data.reset_index(drop = True, inplace = True)
    try:
        data_macd = MACD(data, "Adj Close", 12, 26)
        ticker, last_date, last_signal = macd_updown_signals(data_macd, "MACD", "Date", 'Ticker')
        stock_list.append(ticker)
        date_list.append(last_date)
        signal_list.append(last_signal)
    except Exception as e:
        print(e)
    len_+= 1
signal_df['Ticker'] = stock_list
signal_df['Last_Date'] = date_list
signal_df['Signal'] = signal_list
signal_df['model_name'] = model_name
signal_df['model_freq'] = model_freq
signal_df_weekly = signal_df.copy()
print("All Done!")
# Out:
# Calculating Signals for No.1 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\000001.SS.csv
# Calculating Signals for No.2 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\0005.HK.csv
# Calculating Signals for No.3 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\0008.HK.csv
# Calculating Signals for No.4 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\0142.HK.csv
# Calculating Signals for No.5 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\0151.HK.csv
# Calculating Signals for No.6 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\0175.HK.csv
# Calculating Signals for No.7 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\0186.HK.csv
# Calculating Signals for No.8 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\0215.HK.csv
# Calculating Signals for No.9 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\0241.HK.csv
# Calculating Signals for No.10 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\0268.HK.csv
# Calculating Signals for No.11 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\0285.HK.csv
# Calculating Signals for No.12 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\0302.HK.csv
# Calculating Signals for No.13 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\0303.HK.csv
# Calculating Signals for No.14 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\0315.HK.csv
# Calculating Signals for No.15 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\0418.HK.csv
# Calculating Signals for No.16 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\0419.HK.csv
# Calculating Signals for No.17 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\0439.HK.csv
# Calculating Signals for No.18 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\0493.HK.csv
# Calculating Signals for No.19 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\0522.HK.csv
# Calculating Signals for No.20 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\0552.HK.csv
# Calculating Signals for No.21 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\0596.HK.csv
# Calculating Signals for No.22 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\0698.HK.csv
# Calculating Signals for No.23 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\0700.HK.csv
# Calculating Signals for No.24 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\0728.HK.csv
# Calculating Signals for No.25 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\0732.HK.csv
# Calculating Signals for No.26 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\0751.HK.csv
# Calculating Signals for No.27 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\0762.HK.csv
# Calculating Signals for No.28 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\0763.HK.csv
# Calculating Signals for No.29 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\0777.HK.csv
# Calculating Signals for No.30 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\0788.HK.csv
# Calculating Signals for No.31 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\0797.HK.csv
# Calculating Signals for No.32 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\0799.HK.csv
# Calculating Signals for No.33 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\0941.HK.csv
# Calculating Signals for No.34 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\0981.HK.csv
# Calculating Signals for No.35 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\1024.HK.csv
# list index out of range
# Calculating Signals for No.36 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\1070.HK.csv
# Calculating Signals for No.37 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\1119.HK.csv
# Calculating Signals for No.38 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\1137.HK.csv
# Calculating Signals for No.39 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\1310.HK.csv
# Calculating Signals for No.40 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\1347.HK.csv
# Calculating Signals for No.41 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\1385.HK.csv
# Calculating Signals for No.42 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\1415.HK.csv
# Calculating Signals for No.43 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\1458.HK.csv
# Calculating Signals for No.44 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\1475.HK.csv
# Calculating Signals for No.45 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\1566.HK.csv
# Calculating Signals for No.46 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\1588.HK.csv
# Calculating Signals for No.47 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\1610.HK.csv
# Calculating Signals for No.48 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\1675.HK.csv
# Calculating Signals for No.49 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\1810.HK.csv
# Calculating Signals for No.50 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\1833.HK.csv
# Calculating Signals for No.51 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\1883.HK.csv
# Calculating Signals for No.52 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\1909.HK.csv
# Calculating Signals for No.53 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\1979.HK.csv
# Calculating Signals for No.54 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\2018.HK.csv
# Calculating Signals for No.55 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\2038.HK.csv
# Calculating Signals for No.56 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\2051.HK.csv
# Calculating Signals for No.57 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\2100.HK.csv
# Calculating Signals for No.58 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\2255.HK.csv
# Calculating Signals for No.59 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\2309.HK.csv
# Calculating Signals for No.60 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\2318.HK.csv
# Calculating Signals for No.61 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\2342.HK.csv
# Calculating Signals for No.62 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\2369.HK.csv
# Calculating Signals for No.63 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\2382.HK.csv
# Calculating Signals for No.64 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\2400.HK.csv
# Calculating Signals for No.65 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\3690.HK.csv
# Calculating Signals for No.66 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\3738.HK.csv
# Calculating Signals for No.67 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\3798.HK.csv
# Calculating Signals for No.68 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\3799.HK.csv
# Calculating Signals for No.69 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\3888.HK.csv
# Calculating Signals for No.70 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\6055.HK.csv
# Calculating Signals for No.71 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\6060.HK.csv
# Calculating Signals for No.72 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\6088.HK.csv
# Calculating Signals for No.73 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\6188.HK.csv
# Calculating Signals for No.74 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\6618.HK.csv
# list index out of range
# Calculating Signals for No.75 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\6820.HK.csv
# Calculating Signals for No.76 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\6823.HK.csv
# Calculating Signals for No.77 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\6862.HK.csv
# Calculating Signals for No.78 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\6869.HK.csv
# Calculating Signals for No.79 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\6969.HK.csv
# Calculating Signals for No.80 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\6993.HK.csv
# list index out of range
# Calculating Signals for No.81 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\8029.HK.csv
# Calculating Signals for No.82 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\8032.HK.csv
# Calculating Signals for No.83 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\9988.HK.csv
# Calculating Signals for No.84 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\9990.HK.csv
# Calculating Signals for No.85 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\9992.HK.csv
# list index out of range
# Calculating Signals for No.86 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\9999.HK.csv
# Calculating Signals for No.87 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\AAPL.csv
# Calculating Signals for No.88 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\ABT.csv
# Calculating Signals for No.89 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\ACOR.csv
# Calculating Signals for No.90 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\ADBE.csv
# Calculating Signals for No.91 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\ADP.csv
# Calculating Signals for No.92 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\ADSK.csv
# Calculating Signals for No.93 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\AEMD.csv
# Calculating Signals for No.94 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\AHPI.csv
# Calculating Signals for No.95 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\ALB.csv
# Calculating Signals for No.96 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\AMD.csv
# Calculating Signals for No.97 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\AMZN.csv
# Calculating Signals for No.98 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\APT.csv
# Calculating Signals for No.99 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\ARKF.csv
# Calculating Signals for No.100 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\ARKG.csv
# Calculating Signals for No.101 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\ARKK.csv
# Calculating Signals for No.102 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\ARKQ.csv
# Calculating Signals for No.103 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\ARKW.csv
# Calculating Signals for No.104 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\ARPO.csv
# Calculating Signals for No.105 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\AZN.csv
# Calculating Signals for No.106 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\BABA.csv
# Calculating Signals for No.107 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\BLNK.csv
# Calculating Signals for No.108 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\BNTX.csv
# Calculating Signals for No.109 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\CAN.csv
# Calculating Signals for No.110 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\CBLI.csv
# Calculating Signals for No.111 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\CDAY.csv
# Calculating Signals for No.112 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\CNET.csv
# Calculating Signals for No.113 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\CODX.csv
# Calculating Signals for No.114 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\COUP.csv
# Calculating Signals for No.115 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\CRM.csv
# Calculating Signals for No.116 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\CRVS.csv
# Calculating Signals for No.117 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\CRWD.csv
# Calculating Signals for No.118 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\CSCO.csv
# Calculating Signals for No.119 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\CYB.csv
# Calculating Signals for No.120 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\DBA.csv
# Calculating Signals for No.121 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\DBC.csv
# Calculating Signals for No.122 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\DBX.csv
# Calculating Signals for No.123 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\DDOG.csv
# Calculating Signals for No.124 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\DFFN.csv
# Calculating Signals for No.125 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\DOCU.csv
# Calculating Signals for No.126 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\EBON.csv
# Calculating Signals for No.127 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\ENPH.csv
# Calculating Signals for No.128 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\EQ.csv
# Calculating Signals for No.129 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\FB.csv
# Calculating Signals for No.130 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\FCEL.csv
# Calculating Signals for No.131 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\FLS.csv
# Calculating Signals for No.132 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\FMC.csv
# Calculating Signals for No.133 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\FXB.csv
# Calculating Signals for No.134 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\FXE.csv
# Calculating Signals for No.135 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\FXF.csv
# Calculating Signals for No.136 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\FXY.csv
# Calculating Signals for No.137 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\GBTC.csv
# Calculating Signals for No.138 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\GDDY.csv
# Calculating Signals for No.139 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\GDX.csv
# Calculating Signals for No.140 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\GILD.csv
# Calculating Signals for No.141 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\GLD.csv
# Calculating Signals for No.142 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\GOOG.csv
# Calculating Signals for No.143 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\GOOGL.csv
# Calculating Signals for No.144 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\HTBX.csv
# Calculating Signals for No.145 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\HUBS.csv
# Calculating Signals for No.146 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\IBIO.csv
# Calculating Signals for No.147 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\IEF.csv
# Calculating Signals for No.148 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\INO.csv
# Calculating Signals for No.149 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\INTC.csv
# Calculating Signals for No.150 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\INTU.csv
# Calculating Signals for No.151 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\JNJ.csv
# Calculating Signals for No.152 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\LAC.csv
# Calculating Signals for No.153 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\LAKE.csv
# Calculating Signals for No.154 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\LAZR.csv
# Calculating Signals for No.155 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\LFIN.csv
# Calculating Signals for No.156 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\LI.csv
# list index out of range
# Calculating Signals for No.157 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\LTHM.csv
# Calculating Signals for No.158 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\MA.csv
# Calculating Signals for No.159 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\MARA.csv
# Calculating Signals for No.160 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\MRNA.csv
# Calculating Signals for No.161 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\MSFT.csv
# Calculating Signals for No.162 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\MU.csv
# Calculating Signals for No.163 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\NCTY.csv
# Calculating Signals for No.164 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\NFLX.csv
# Calculating Signals for No.165 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\NIO.csv
# Calculating Signals for No.166 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\NNVC.csv
# Calculating Signals for No.167 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\NOVA.csv
# Calculating Signals for No.168 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\NOW.csv
# Calculating Signals for No.169 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\NVAX.csv
# Calculating Signals for No.170 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\NVDA.csv
# Calculating Signals for No.171 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\OKTA.csv
# Calculating Signals for No.172 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\OPEN.csv
# Calculating Signals for No.173 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\ORCL.csv
# Calculating Signals for No.174 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\OSTK.csv
# Calculating Signals for No.175 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\PAYC.csv
# Calculating Signals for No.176 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\PFE.csv
# Calculating Signals for No.177 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\PLUG.csv
# Calculating Signals for No.178 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\PYPL.csv
# Calculating Signals for No.179 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\QCOM.csv
# Calculating Signals for No.180 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\QQQ.csv
# Calculating Signals for No.181 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\QS.csv
# list index out of range
# Calculating Signals for No.182 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\RENN.csv
# Calculating Signals for No.183 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\RIOT.csv
# Calculating Signals for No.184 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\RNG.csv
# Calculating Signals for No.185 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\RUN.csv
# Calculating Signals for No.186 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\SAP.csv
# Calculating Signals for No.187 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\SBE.csv
# Calculating Signals for No.188 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\SHOP.csv
# Calculating Signals for No.189 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\SMAR.csv
# Calculating Signals for No.190 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\SPLK.csv
# Calculating Signals for No.191 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\SPY.csv
# Calculating Signals for No.192 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\SQ.csv
# Calculating Signals for No.193 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\SQM.csv
# Calculating Signals for No.194 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\SRAX.csv
# Calculating Signals for No.195 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\TEAM.csv
# Calculating Signals for No.196 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\TLT.csv
# Calculating Signals for No.197 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\TSLA.csv
# Calculating Signals for No.198 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\TSM.csv
# Calculating Signals for No.199 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\TTD.csv
# Calculating Signals for No.200 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\TWLO.csv
# Calculating Signals for No.201 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\UUP.csv
# Calculating Signals for No.202 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\UVXY.csv
# Calculating Signals for No.203 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\V.csv
# Calculating Signals for No.204 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\VCNX.csv
# Calculating Signals for No.205 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\VEEV.csv
# Calculating Signals for No.206 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\VIR.csv
# Calculating Signals for No.207 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\VLDR.csv
# Calculating Signals for No.208 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\VXRT.csv
# Calculating Signals for No.209 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\VXX.csv
# Calculating Signals for No.210 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\WDAY.csv
# Calculating Signals for No.211 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\WORK.csv
# Calculating Signals for No.212 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\XL.csv
# Calculating Signals for No.213 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\XLB.csv
# Calculating Signals for No.214 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\XLE.csv
# Calculating Signals for No.215 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\XLF.csv
# Calculating Signals for No.216 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\XLI.csv
# Calculating Signals for No.217 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\XLK.csv
# Calculating Signals for No.218 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\XLP.csv
# Calculating Signals for No.219 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\XLRE.csv
# Calculating Signals for No.220 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\XLREARKG.csv
# index -1 is out of bounds for axis 0 with size 0
# Calculating Signals for No.221 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\XLU.csv
# Calculating Signals for No.222 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\XLV.csv
# Calculating Signals for No.223 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\XLY.csv
# Calculating Signals for No.224 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\XNET.csv
# Calculating Signals for No.225 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\XPEV.csv
# list index out of range
# Calculating Signals for No.226 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\ZEN.csv
# Calculating Signals for No.227 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\ZM.csv
# Calculating Signals for No.228 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\^DJI.csv
# Calculating Signals for No.229 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\^GSPC.csv
# Calculating Signals for No.230 : C:/Users/Administrator/CE_github_2/data_pipeline/Data\^IXIC.csv
# All Done!

# %%
merged_daily_weekly = signal_df_daily.merge(signal_df_weekly, on = "Ticker", how = "outer")
daily_weekly_buy = merged_daily_weekly[((merged_daily_weekly['Signal_x']=="BUY")&(merged_daily_weekly['Signal_y']=='BUY')) |\
                                       ((merged_daily_weekly['Signal_x']=='BUY')&(merged_daily_weekly['Signal_y']=='HOLD LONG'))]

daily_weekly_short = merged_daily_weekly[((merged_daily_weekly['Signal_x']=="SELL")&(merged_daily_weekly['Signal_y']=='SELL')) |\
                                       ((merged_daily_weekly['Signal_x']=='SELL')&(merged_daily_weekly['Signal_y']=='HOLD SHORT'))]

# %%
signal_path = "C:/Users/Administrator/CE_github_2/data_pipeline/Signals/"
signal_file = signal_path+model_name+"_"+last_date+"_D_W"+".csv"
merged_daily_weekly.to_csv(signal_file)

# %%
daily_weekly_buy
# Out:
#      Ticker Last_Date_x Signal_x         model_name_x model_freq_x  \
# 76  6869.HK  2021-02-26      BUY  Macd_Updown_Signals            D
#
#    Last_Date_y   Signal_y         model_name_y model_freq_y
# 76  2021-02-26  HOLD LONG  Macd_Updown_Signals            W

# %%
daily_weekly_short
# Out:
#       Ticker Last_Date_x Signal_x         model_name_x model_freq_x  \
# 18   0522.HK  2021-02-26     SELL  Macd_Updown_Signals            D
# 33   0981.HK  2021-02-26     SELL  Macd_Updown_Signals            D
# 36   1137.HK  2021-02-26     SELL  Macd_Updown_Signals            D
# 77   6969.HK  2021-02-26     SELL  Macd_Updown_Signals            D
# 116     CSCO  2021-02-26     SELL  Macd_Updown_Signals            D
# 132      FXE  2021-02-26     SELL  Macd_Updown_Signals            D
# 149      JNJ  2021-02-26     SELL  Macd_Updown_Signals            D
# 162     NFLX  2021-02-26     SELL  Macd_Updown_Signals            D
# 174      PFE  2021-02-26     SELL  Macd_Updown_Signals            D
#
#     Last_Date_y    Signal_y         model_name_y model_freq_y
# 18   2021-02-26  HOLD SHORT  Macd_Updown_Signals            W
# 33   2021-02-26        SELL  Macd_Updown_Signals            W
# 36   2021-02-26  HOLD SHORT  Macd_Updown_Signals            W
# 77   2021-02-26  HOLD SHORT  Macd_Updown_Signals            W
# 116  2021-02-26  HOLD SHORT  Macd_Updown_Signals            W
# 132  2021-02-26  HOLD SHORT  Macd_Updown_Signals            W
# 149  2021-02-26  HOLD SHORT  Macd_Updown_Signals            W
# 162  2021-02-26  HOLD SHORT  Macd_Updown_Signals            W
# 174  2021-02-26  HOLD SHORT  Macd_Updown_Signals            W

# %% [markdown]
# # 2. BOLL布林线系列

# %%
def BBANDS(df, price_col, num_of_std): # n = 20
    """
    Bollinger Bands, rationale CHECKED, code CHECKED
    Create the common bbands which I understand instead of using the one from Quantopian forum.
    """
    rlng_mean = df[price_col].ewm(span = 20).mean().rename('Rolling_{}_Day_Mean'.format(20))
    rlng_std  = df[price_col].rolling(window = 20).std()
    u_band = (rlng_mean + rlng_std*num_of_std)
    l_band = (rlng_mean - rlng_std*num_of_std)
    df['MA_20'] = rlng_mean
    df['LOW_BAND'] = l_band
    df['UP_BAND'] = u_band
    return df

# %%
def bolling_upcross_lband(df, price_col, date_col, ticker_col):
    ticker = df[ticker_col].values[-1]
    df.dropna(inplace = True)
    df.reset_index(inplace = True)
    del df['index']
    listLongShort = []
    listDate = []
    close = df[price_col].values
    up_band = df['UP_BAND'].values
    low_band = df['LOW_BAND'].values
    
    for i in range(1, len(df)):
        last_date = df[date_col][i]
        
        if close[i]>low_band[i] and close[i-1]<low_band[i-1] and close[i-2]>low_band[i-2]:
            listLongShort.append("BUY")
            listDate.append(last_date)
        else:
            listLongShort.append("NO SIGNAL")
            listDate.append(last_date)
            
    return ticker, listDate[-1], listLongShort[-1]

# %%
all_csvs = "C:/Users/Administrator/CE_github_2/data_pipeline/Data/*.csv"
stock_list = []
date_list = []
signal_list = []
len_ = 1
date_col = "Date"
price_col = "Adj Close"
signal_df = pd.DataFrame()
model_name = "Boll_Upcross_Lband"
total_number = len(glob.glob(all_csvs)[:])


for fname in glob.glob(all_csvs)[:]:
    print ("Calculating Signals for No.{} : {}".format(len_, fname))
    data = pd.read_csv(fname)
    try:
        data_boll = BBANDS(data, "Adj Close", 2)
        ticker, last_date, last_signal = bolling_upcross_lband(data_boll, "Adj Close", "Date", 'Ticker')
        stock_list.append(ticker)
        date_list.append(last_date)
        signal_list.append(last_signal)
    except Exception as e:
        print(e)
    len_+= 1
signal_df['Ticker'] = stock_list
signal_df['Last_Date'] = date_list
signal_df['Signal'] = signal_list
signal_df['model_name'] = model_name
print("All Done!")
# def merge_df(df1, df2):
#     df1.sort_values(date_col, inplace = True)
#     merged = df1.merge(df2, on = date_col, how = 'outer')
#     merged.sort_values(date_col, inplace = True)
#     return merged

# merged_all = reduce(merge_df, stock_list)
# merged_all.set_index(date_col, inplace=True)

# %%
signal_path = "C:/Users/Administrator/CE_github_2/data_pipeline/Signals/"
signal_file = signal_path+model_name+"_"+last_date+".csv"
signal_df.to_csv(signal_file)

# %% [markdown]
# # 跨周期信号代码：

# %%
# def MACD(df, n_fast, n_slow, n_macd, price_col): # n_fast = 12, n_slow = 26
#     """
#     http://stockcharts.com/docs/doku.php?id=scans:indicators
#     MACD, MACD Signal and MACD difference, rationale CHECKED, code CHECKED, updated
#     # Conventional look-back window for calculating MACDsign is 9
#     """
#     EMAfast = df[price_col].ewm(span = n_fast, min_periods = n_fast - 1).mean()
#     EMAslow = df[price_col].ewm(span = n_slow, min_periods = n_slow - 1).mean()
#     MACD = pd.Series(EMAfast - EMAslow, name = 'MACD_' + str(n_fast) + '_' + str(n_slow))
#     MACDsign = MACD.ewm(span = n_macd, min_periods = n_macd-1).mean().rename('MACDsign_' + str(n_fast) + '_' + str(n_slow))
#     MACDdiff = pd.Series(MACD - MACDsign, name = 'MACDdiff_' + str(n_fast) + '_' + str(n_slow))
#     df['MACD_Diff'] = MACD
#     df['MACD_Diff_EMA'] = MACDsign
#     df['MACD'] = MACDdiff
#     df['SIGNAL_STATUS'] = df['MACD'].apply(lambda x: "多头状态" if x>0 else ("空头状态" if x<0 else "无信号状态"))
#     return df

# %%
# indicator_df = MACD(df, 12, 26, 9, 'close')
# indicator_df.index = pd.to_datetime(indicator_df['trade_date'])

# %%
# # 查看周线：

# period_type = "W"
# df_copy = df.copy()
# weekly_df = df_copy.resample(period_type).last()
# weekly_indicator_df = MACD(weekly_df, 12, 26, 9, 'close')

# last_daily_signal = indicator_df['SIGNAL_STATUS'].values[-1]
# last_weekly_signal = weekly_indicator_df['SIGNAL_STATUS'].values[-1]
# last_price_vol_date = indicator_df['trade_date'].values[-1]
