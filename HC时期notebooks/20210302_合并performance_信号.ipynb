# %%
import pandas as pd, numpy as np
import csv

# %%
import matplotlib

# %%
signal = pd.read_csv("C:/Users/Administrator/bradsun_windows_creditease_github/data_pipelines/DailySignals/2021-03-02_signals__D_W_US_mkt.csv", encoding='ANSI')
perf = pd.read_csv("C:/Users/Administrator/bradsun_windows_creditease_github/CE_github_2_代码模块20210219/US_performance_MACD_UPDOWN_MA.csv", encoding='ANSI')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-f6d40834e595> in <module>()
# ----> 1 signal = pd.read_csv("C:/Users/Administrator/bradsun_windows_creditease_github/data_pipelines/DailySignals/2021-03-02_signals__D_W_US_mkt.csv", encoding='ANSI')
#       2 perf = pd.read_csv("C:/Users/Administrator/bradsun_windows_creditease_github/CE_github_2_代码模块20210219/US_performance_MACD_UPDOWN_MA.csv", encoding='ANSI')
#
# ...

# %%
perf
# Out:
#     Ticker  total_commission  gross_profit  net_profit commission_impact  \
# 0       QS                 0     221776.11   221776.11             0.00%
# 1      SBE                 0      95399.96    95399.96             0.00%
# 2     LAZR                 0     142090.76   142090.76             0.00%
# 3     FCEL                 0     697681.95   697681.95             0.00%
# 4      CAN                 0     246526.42   246526.42             0.00%
# 5     ARKQ                 0      51237.54    51237.54             0.00%
# 6     BLNK                 0     486676.47   486676.47             0.00%
# 7     MRNA                 0     202619.91   202619.91             0.00%
# 8     NVAX                 0     431612.50   431612.50             0.00%
# 9     UVXY                 0     413407.25   413407.25             0.00%
# 10    PLUG                 0     222161.92   222161.92             0.00%
# 11    IBIO                 0     373335.35   373335.35             0.00%
# ...

# %%
merged = perf.merge(signal, on = "Ticker")

# %%
merged[merged['Signal_x']=='BUY']
# Out:
#     Ticker  total_commission  gross_profit  net_profit commission_impact  \
# 2     LAZR                 0     142090.76   142090.76             0.00%
# 4      CAN                 0     246526.42   246526.42             0.00%
# 5     ARKQ                 0      51237.54    51237.54             0.00%
# 8     NVAX                 0     431612.50   431612.50             0.00%
# 14    ARKG                 0      62981.86    62981.86             0.00%
# 15    CRWD                 0      95828.83    95828.83             0.00%
# 16    RIOT                 0     303055.13   303055.13             0.00%
# 17    ARKF                 0      45016.91    45016.91             0.00%
# 18     NIO                 0     180196.58   180196.58             0.00%
# 19      ZM                 0      98649.28    98649.28             0.00%
# 23     RNG                 0     128546.07   128546.07             0.00%
# 26     INO                 0     199251.84   199251.84             0.00%
# ...

# %%
(349.46/59.909)**(1/10)-1
# Out:
# 0.1928629238843953

# %%
2000/98.09
# Out:
# 20.389438270975635
