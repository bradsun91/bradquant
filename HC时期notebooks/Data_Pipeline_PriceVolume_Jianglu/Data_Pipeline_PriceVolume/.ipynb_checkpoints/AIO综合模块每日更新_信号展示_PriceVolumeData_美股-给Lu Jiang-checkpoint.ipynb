# %%
import pandas as pd, numpy as np
from datetime import datetime
import statsmodels.api as sm
import yfinance as yf
import time, urllib
import glob
import os

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set(context='notebook', style='darkgrid', palette='deep', font='sans-serif', font_scale=1, color_codes=False, rc=None)

# 导入自己的模块
from data_download_US_HK import *
from strategies import *
from positions import *

# %% [markdown]
# # 模块一：下载数据到csv文件

# %%
us_tickers = list(set(US_TICKERS_POOL.us_tech_stocks() + \
			              US_TICKERS_POOL.us_blockchain_stocks() + \
			              US_TICKERS_POOL.us_saas_stocks() + \
			              US_TICKERS_POOL.us_biotech_stocks() + \
			              US_TICKERS_POOL.us_new_energy_stocks() + \
			              US_TICKERS_POOL.global_etfs() + \
			              US_TICKERS_POOL.sector_etf() + \
			              US_TICKERS_POOL.global_indices() +\
			              US_TICKERS_POOL.us_healthcare_stocks() +\
			              US_TICKERS_POOL.us_fin_stocks() +\
			              US_TICKERS_POOL.us_utilities_stocks() +\
			              US_TICKERS_POOL.us_materials_stocks() +\
			              US_TICKERS_POOL.other_us_stocks() +\
                            US_TICKERS_POOL.us_consumer_discretionary_stocks() +\
                            US_TICKERS_POOL.us_consumer_staples_stocks() +\
                            US_TICKERS_POOL.us_industrial_stocks() +\
                            US_TICKERS_POOL.us_real_estate_stocks() +\
                            US_TICKERS_POOL.us_tele_entertainment_stocks()
                          ))

# global_etfs_leveraged = list(set(["TQQQ",#纳指100x3
# 					"UPRO",#标普x3                        
# 					"UDOW",#道指x3
                        

# 					"USD", # 半导体行业x2
# 					"SOXL", # 半导体行业x3
# 					"UYG",# 金融双倍做多
# 					"URE",# 房地产双倍做多
# 					"DRN",#x3
# 					"DIG",# 能源双倍做多
# 					"ERX",#x3
# 					"UYM",# 原材料双倍做多 
# 					"MATL",#x3
# 					"NUGT",#黄金矿业三倍做多
# 					"EET",# 新兴市场指数双倍做多
# 					"EDC",#x3
# 					"XPP",# 中国股票指数x2
# 					"UCO",# 石油x2
# 					"DGP",# 黄金x2
# 					"UGL",# 黄金x2
# 					"AGQ",# 白银x2
# 					"EUO",# 美元x2
# 					"UBT",# 政府长期债券x2
# 					"TMF"# x3
# 					]))
futures_tickers = FUTURES.futures()
hk_tickers = HK_TICERS_POOL.HK_tickers()
CN_mutual_funds_tickers = CN_TICKERS_POOL.CN_fund_tickers()

tickers_to_load = list(set(us_tickers+futures_tickers+hk_tickers))
print("Length of all tickers here:", len(tickers_to_load))

start = "2005-01-01"
today = LOAD_DATA.today_dt()
end = today

# 如果用这个yesterday，则代表着只需要到昨天的数据
# end_yesterday = "2021-03-02"

us_db_path = "/Users/jianglu/data_pipeline/data/"
# Out:
# Length of all tickers here: 360

# %%
# download data to csv files
# LOAD_DATA.easy_download(start, end, us_db_path, all_tickers_to_load[53:242])
LOAD_DATA.easy_download(start, end, us_db_path,tickers_to_load)
# LOAD_DATA.easy_download(start, end, us_db_path, ["^HSI"])
# Out:
# [*********************100%***********************]  1 of 1 completed
# No.1: 2382.HK data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.2: HD data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.3: 1979.HK data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.4: TME data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.5: SHW data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.6: 0302.HK data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.7: 0493.HK data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.8: FB data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.9: 0151.HK data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.10: 0285.HK data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.11: GBTC data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.12: 0419.HK data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.13: SQ data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.14: ENPH data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.15: FXB data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.16: DRN data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.17: EWG data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.18: MS data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.19: 1070.HK data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.20: XLK data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.21: LI data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.22: DHR data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.23: C data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.24: AMZN data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.25: WFC data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.26: 6862.HK data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.27: 0751.HK data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.28: UUP data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.29: CB data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.30: EWL data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.31: 9999.HK data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - MATL: No data found for this date range, symbol may be delisted
# No.32: MATL data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.33: 0552.HK data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.34: 0418.HK data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.35: GDX data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.36: DIG data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.37: ^GSPC data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.38: MRK data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.39: TNA data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.40: XAU=F data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.41: NVAX data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.42: 0005.HK data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.43: SO data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.44: TWLO data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.45: UYG data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.46: CMG data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.47: USD data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.48: YM=F data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.49: PSA data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.50: 2255.HK data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.51: NFLX data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.52: HUBS data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.53: IEF data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.54: 0596.HK data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.55: 1478.HK data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.56: NOW data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.57: PBW data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.58: ARKW data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.59: MCD data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.60: AMGN data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.61: VLDR data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.62: GILD data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.63: TEAM data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.64: OSTK data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.65: 0728.HK data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.66: DOCU data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.67: STZ data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.68: RACE data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.69: GDDY data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.70: XLB data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.71: XLY data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.72: 6188.HK data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.73: ^DJI data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.74: PLD data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.75: ERX data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.76: NUGT data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.77: XLI data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.78: EXC data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.79: PM data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.80: XLV data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.81: NKE data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.82: BA data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.83: BLNK data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.84: PAVE data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.85: RTX data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.86: CL=F data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.87: FMC data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.88: CHTR data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.89: VZ data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.90: LVS data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.91: GC=F data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.92: ARKK data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.93: 1883.HK data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.94: INTU data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.95: TLT data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.96: 9988.HK data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.97: 2318.HK data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.98: SBUX data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.99: 6993.HK data file created: 2021-04-08
# =======================Sleeping======================
# [*********************100%***********************]  1 of 1 completed
# No.101: TSM data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.102: 0215.HK data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.103: OKTA data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.104: 1566.HK data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.105: APD data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.106: QS data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.107: DDOG data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.108: EWZ data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.109: ABBV data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.110: 2038.HK data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.111: 6618.HK data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.112: UCO data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.113: BILI data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.114: 8032.HK data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.115: CVS data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.116: 3888.HK data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.117: UVXY data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.118: SBAC data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.119: COST data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.120: LTHM data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.121: 3799.HK data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.122: 0700.HK data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.123: PDD data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.124: DD data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.125: UBT data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.126: PG data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.127: 0142.HK data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.128: BABA data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.129: QQQ data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.130: YINN data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.131: 3738.HK data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.132: WES data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.133: DBC data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.134: TQQQ data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.135: OPEN data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.136: PTON data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.137: ZEN data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.138: 1310.HK data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.139: QCOM data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.140: PEP data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.141: 1347.HK data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.142: TMUS data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.143: TMF data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.144: 0186.HK data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.145: RB=F data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.146: 8029.HK data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.147: 0732.HK data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.148: LOW data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.149: ARKF data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.150: AAPL data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.151: ALI=F data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.152: EDC data file created: 2021-04-08
# [*********************100%***********************]  1 of 1 completed
# No.153: ^IXIC data file created: 2021-04-08

# %%
# Download data from Sina:
LOAD_DATA.download_data_from_Sina(CN_mutual_funds_tickers, start, end, us_db_path)

# %%
data_list_selected = LOAD_DATA.read_data_from_folders(us_tickers, us_db_path)

# %%
# Generate signals
daily_macd_updown_signals = GENERATE_SIGNALS.generate_signals_macd_updown_ma_slope( 
                                                                           data_list_selected,
#                                                                            CN_fund_data,
                                                                          "Macd_Updown_MA_Slope_Signals", 
                                                                          "Date", 
                                                                          "Adj Close", 
                                                                          "Ticker", 
                                                                          "D")

# %%
daily_macd_updown_signals_to_present = daily_macd_updown_signals[daily_macd_updown_signals['Signal']=="买入"]
daily_macd_updown_signals_to_present["满足的趋势形态"] = "前一日MACD值开始向上反转，并且价格收盘于5日均线之上，并且10日均线处于上升状态"
daily_macd_updown_signals_to_present.columns = ['股票代号','最新收盘日','信号','模型名称','模型频率','满足的趋势形态']

# %%
daily_macd_updown_signals_to_present[['股票代号','最新收盘日','满足的趋势形态']]

# %%
daily_macd_updown_signals[daily_macd_updown_signals["Ticker"]=="TQQQ"]

# %%
signal_path = "/Users/jianglu/data_pipeline/Signals/"

###################################
signal_file = signal_path+end+"_signals"+"_D_US_mkt"+".csv"
###################################

# merged_daily_weekly.to_csv(signal_file)
daily_macd_updown_signals.to_csv(signal_file)
