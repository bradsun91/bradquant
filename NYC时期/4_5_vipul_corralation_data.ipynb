# %%
import pandas as pd
import random

# %%
price=pd.read_csv('price_change_pct.csv')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-10-8b2ec155dd76> in <module>()
# ----> 1 price=pd.read_csv('price_change_pct.csv')
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
# ...

# %%
article_count=pd.read_csv('source_ticker_sp500_for_price.csv')

# %%
article_count.head()
# Out:
#          date        story_source entity_ticker     avg  count
# 0  2015-03-13  0024watchworld.com          GOOG  8750.0      1
# 1  2015-06-22  0024watchworld.com            RL     0.0      1
# 2  2014-03-28          002mag.com            FB  8060.0      1
# 3  2014-11-03          002mag.com            FB  8060.0      1
# 4  2014-12-02          002mag.com            FB  8060.0      1

# %%
ticker='RL'
tick_article=article_count[article_count['entity_ticker']==ticker]
source_list=tick_article['story_source'].unique().tolist()

# %%
source_list
# Out:
# ['0024watchworld.com',
#  '100milefreepress.net',
#  '100pour100-velo.com',
#  '101thefox.net',
#  '1041kqth.com',
#  '1057ezrock.com',
#  '1063word.com',
#  '10magazine.com',
#  '10news.com',
#  '10thousandcouples.com',
#  '10tv.com',
#  '11alive.com',
#  '123jump.com',
#  '12newsnow.com',
#  '13abc.com',
#  '13wmaz.com',
#  '1470wmbd.com',
#  '1490wosh.com',
#  '14news.com',
#  '1888pressrelease.com',
#  '2020mag.com',
#  '24-7pressrelease.com',
#  '247sports.com',
#  '247wallst.com',
#  '24hrs.ca',
#  '27east.com',
#  '2br.co.uk',
#  '2oceansvibe.com',
#  '2paragraphs.com',
#  '360nobs.com',
#  '3d-car-shows.com',
#  '4029tv.com',
#  '4-traders.com',
#  '570news.com',
#  '590kid.com',
#  '5tjt.com',
#  '610cktb.com',
#  '630wpro.com',
#  '660news.com',
#  '670kboi.com',
#  '680news.com',
#  '6abc.com',
#  '6speedonline.com',
#  '710knus.com',
#  '760kfmb.com',
#  '770kkob.com',
#  '8020fashionsblog.com',
#  '927thevan.com',
#  '929wlmi.com',
#  '939thebeat.com',
# ...

# %%
tick_price=price[['Date',ticker]]

# %%
story_source='streetinsider.com'

# %%
price_count_tick=pd.merge(tick_price,tick_article[tick_article['story_source']==story_source],how='left',left_on='Date',right_on='date')

# %%
price_count_tick
# Out:
#             Date        RL        date       story_source entity_ticker  avg  \
# 0            NaN       NaN         NaN                NaN           NaN  NaN
# 1     2013-07-31       NaN         NaN                NaN           NaN  NaN
# 2     2013-08-01  2.707902         NaN                NaN           NaN  NaN
# 3     2013-08-02  0.556176         NaN                NaN           NaN  NaN
# 4     2013-08-05  0.143596         NaN                NaN           NaN  NaN
# 5     2013-08-06  0.642587         NaN                NaN           NaN  NaN
# 6     2013-08-07 -8.643338  2013-08-07  streetinsider.com            RL  0.0
# 7     2013-08-08  2.639630         NaN                NaN           NaN  NaN
# 8     2013-08-09  0.703433         NaN                NaN           NaN  NaN
# 9     2013-08-12 -0.486167         NaN                NaN           NaN  NaN
# 10    2013-08-13  0.252694         NaN                NaN           NaN  NaN
# ...

# %%
tick_article[tick_article['story_source']=='streetinsider.com']
# Out:
#                date       story_source entity_ticker          avg  count
# 4818963  2013-08-07  streetinsider.com            RL     0.000000      1
# 4818964  2013-09-19  streetinsider.com            RL  3776.290000      1
# 4818965  2013-12-19  streetinsider.com            RL  1592.640000      1
# 4818966  2014-01-08  streetinsider.com            RL  2476.160000      1
# 4818967  2014-01-16  streetinsider.com            RL   269.235000      2
# 4818968  2014-02-05  streetinsider.com            RL    50.000000      2
# 4818969  2014-02-14  streetinsider.com            RL  2380.800000      1
# 4818970  2014-02-26  streetinsider.com            RL  1962.360000      1
# 4818971  2014-04-22  streetinsider.com            RL  2417.760000      1
# 4818972  2014-05-09  streetinsider.com            RL  5024.970000      1
# 4818973  2014-05-12  streetinsider.com            RL -4610.280000      1
# 4818974  2014-08-06  streetinsider.com            RL  4380.000000      1
# ...

# %%
price_count_tick['RL']=price_count_tick['RL'].fillna(0.0)
price_count_tick['date']=price_count_tick['date'].fillna('2013-07-13')
price_count_tick['story_source']=price_count_tick['story_source'].fillna(story_source)
price_count_tick['entity_ticker']=price_count_tick['entity_ticker'].fillna(ticker)
price_count_tick['avg']=price_count_tick['avg'].fillna(0.0)
price_count_tick['count']=price_count_tick['count'].fillna(0)

# %%
price_count_tick
# Out:
#             Date        RL        date       story_source entity_ticker  avg  \
# 0            NaN  0.000000  2013-07-13  streetinsider.com            RL  0.0
# 1     2013-07-31  0.000000  2013-07-13  streetinsider.com            RL  0.0
# 2     2013-08-01  2.707902  2013-07-13  streetinsider.com            RL  0.0
# 3     2013-08-02  0.556176  2013-07-13  streetinsider.com            RL  0.0
# 4     2013-08-05  0.143596  2013-07-13  streetinsider.com            RL  0.0
# 5     2013-08-06  0.642587  2013-07-13  streetinsider.com            RL  0.0
# 6     2013-08-07 -8.643338  2013-08-07  streetinsider.com            RL  0.0
# 7     2013-08-08  2.639630  2013-07-13  streetinsider.com            RL  0.0
# 8     2013-08-09  0.703433  2013-07-13  streetinsider.com            RL  0.0
# 9     2013-08-12 -0.486167  2013-07-13  streetinsider.com            RL  0.0
# 10    2013-08-13  0.252694  2013-07-13  streetinsider.com            RL  0.0
# ...

# %%
price_count_tick[price_count_tick['count']>0]
# Out:
#            Date         RL        date       story_source entity_ticker  \
# 6    2013-08-07  -8.643338  2013-08-07  streetinsider.com            RL
# 36   2013-09-19   0.113016  2013-09-19  streetinsider.com            RL
# 100  2013-12-19  -1.101133  2013-12-19  streetinsider.com            RL
# 112  2014-01-08  -1.755979  2014-01-08  streetinsider.com            RL
# 118  2014-01-16  -2.837937  2014-01-16  streetinsider.com            RL
# 131  2014-02-05  -3.547792  2014-02-05  streetinsider.com            RL
# 138  2014-02-14   1.434521  2014-02-14  streetinsider.com            RL
# 145  2014-02-26   1.331327  2014-02-26  streetinsider.com            RL
# 183  2014-04-22   0.610709  2014-04-22  streetinsider.com            RL
# 196  2014-05-09  -2.092247  2014-05-09  streetinsider.com            RL
# 197  2014-05-12  -0.987838  2014-05-12  streetinsider.com            RL
# 257  2014-08-06   0.197993  2014-08-06  streetinsider.com            RL
# ...

# %%
price_count_tick['RL_mod']=price_count_tick['RL'].abs()

# %%
price_count_tick.head()
# Out:
#          Date        RL        date       story_source entity_ticker  avg  \
# 0         NaN  0.000000  2013-07-13  streetinsider.com            RL  0.0
# 1  2013-07-31  0.000000  2013-07-13  streetinsider.com            RL  0.0
# 2  2013-08-01  2.707902  2013-07-13  streetinsider.com            RL  0.0
# 3  2013-08-02  0.556176  2013-07-13  streetinsider.com            RL  0.0
# 4  2013-08-05  0.143596  2013-07-13  streetinsider.com            RL  0.0
#
#    count    RL_mod
# 0    0.0  0.000000
# 1    0.0  0.000000
# 2    0.0  2.707902
# 3    0.0  0.556176
# 4    0.0  0.143596

# %%
price_count_tick['RL_mod'].corr(price_count_tick['count'])
# Out:
# 0.32854564878809767

# %%
ticker_list=article_count['entity_ticker'].unique().tolist()

# %%
#baseballnewssource
i=0
for ticker in ticker_list:
    #ticker_list=article_count['entity_ticker'].unique().tolist()
    try:
        #ticker=random.choice(ticker_list)
        tick_article=article_count[article_count['entity_ticker']==ticker]
        source_list=tick_article['story_source'].unique().tolist()
        story_source='baseballnewssource.com'#random.choice(source_list)
        tick_price=price[['Date',ticker]]
        price_count_tick=pd.merge(tick_price,tick_article[tick_article['story_source']==story_source],how='left',left_on='Date',right_on='date')
        price_count_tick[ticker]=price_count_tick[ticker].fillna(0.0)
        price_count_tick['date']=price_count_tick['date'].fillna('2013-07-13')
        price_count_tick['story_source']=price_count_tick['story_source'].fillna(story_source)
        price_count_tick['entity_ticker']=price_count_tick['entity_ticker'].fillna(ticker)
        price_count_tick['avg']=price_count_tick['avg'].fillna(0.0)
        price_count_tick['count']=price_count_tick['count'].fillna(0)
        price_count_tick['price_mod']=price_count_tick[ticker].abs()
        #price_count_tick['price_mod'].corr(price_count_tick['count'])
        print(ticker,story_source,price_count_tick['price_mod'].corr(price_count_tick['count']))
    except:
        print('failed_For '+ticker)
    i=i+1
# Out:
# GOOG baseballnewssource.com -0.0263351769858
# RL baseballnewssource.com -0.0250068825167
# FB baseballnewssource.com -0.0973891547945
# MSFT baseballnewssource.com -0.0430136124963
# INTC baseballnewssource.com -0.0140414610189
# AAL baseballnewssource.com -0.036241381198
# BA baseballnewssource.com -0.0238691808374
# EXPE baseballnewssource.com -0.0499429287118
# GE baseballnewssource.com -0.0640515810022
# NFLX baseballnewssource.com 0.0132606875536
# TRIP baseballnewssource.com 0.0175113908076
# AMD baseballnewssource.com 0.0812538423449
# AON baseballnewssource.com -0.0429361722631
# BMY baseballnewssource.com -0.0173274783469
# IBM baseballnewssource.com -0.0517850937728
# IT baseballnewssource.com -0.0449629298393
# JNJ baseballnewssource.com -0.042002937877
# NKE baseballnewssource.com 0.0240065011912
# PNR baseballnewssource.com -0.0343913181664
# REGN baseballnewssource.com -0.0530616402417
# ROK baseballnewssource.com -0.0721024599474
# ...

# %%
#baseballnewssource day shift 1
i=0
for ticker in ticker_list:
    #ticker_list=article_count['entity_ticker'].unique().tolist()
    try:
        #ticker=random.choice(ticker_list)
        tick_article=article_count[article_count['entity_ticker']==ticker]
        source_list=tick_article['story_source'].unique().tolist()
        story_source='baseballnewssource.com'#random.choice(source_list)
        tick_price=price[['Date',ticker]]
        tick_price['Date']=tick_price['Date'].shift(1)
        price_count_tick=pd.merge(tick_price,tick_article[tick_article['story_source']==story_source],how='left',left_on='Date',right_on='date')
        price_count_tick[ticker]=price_count_tick[ticker].fillna(0.0)
        price_count_tick['date']=price_count_tick['date'].fillna('2013-07-13')
        price_count_tick['story_source']=price_count_tick['story_source'].fillna(story_source)
        price_count_tick['entity_ticker']=price_count_tick['entity_ticker'].fillna(ticker)
        price_count_tick['avg']=price_count_tick['avg'].fillna(0.0)
        price_count_tick['count']=price_count_tick['count'].fillna(0)
        price_count_tick['price_mod']=price_count_tick[ticker].abs()
        #price_count_tick['price_mod'].corr(price_count_tick['count'])
        print(ticker,story_source,price_count_tick['price_mod'].corr(price_count_tick['count']))
    except:
        print('failed_For '+ticker)
    i=i+1
# Out:
# /home/ubuntu/.local/lib/python3.5/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
# GOOG baseballnewssource.com -0.0685221904176
# RL baseballnewssource.com -0.0181311134528
# FB baseballnewssource.com -0.126885924509
# MSFT baseballnewssource.com -0.0681557295813
# INTC baseballnewssource.com -0.0697756967524
# AAL baseballnewssource.com -0.0741120695124
# BA baseballnewssource.com -0.0541948839533
# EXPE baseballnewssource.com -0.0414382306918
# GE baseballnewssource.com -0.0253543560703
# NFLX baseballnewssource.com -0.0463928212059
# TRIP baseballnewssource.com 0.0507786530886
# AMD baseballnewssource.com 0.0935485655227
# ...

# %%
#baseballnewssource day shift -1
i=0
for ticker in ticker_list:
    #ticker_list=article_count['entity_ticker'].unique().tolist()
    try:
        #ticker=random.choice(ticker_list)
        tick_article=article_count[article_count['entity_ticker']==ticker]
        source_list=tick_article['story_source'].unique().tolist()
        story_source='baseballnewssource.com'#random.choice(source_list)
        tick_price=price[['Date',ticker]]
        tick_price['Date']=tick_price['Date'].shift(-1)
        price_count_tick=pd.merge(tick_price,tick_article[tick_article['story_source']==story_source],how='left',left_on='Date',right_on='date')
        price_count_tick[ticker]=price_count_tick[ticker].fillna(0.0)
        price_count_tick['date']=price_count_tick['date'].fillna('2013-07-13')
        price_count_tick['story_source']=price_count_tick['story_source'].fillna(story_source)
        price_count_tick['entity_ticker']=price_count_tick['entity_ticker'].fillna(ticker)
        price_count_tick['avg']=price_count_tick['avg'].fillna(0.0)
        price_count_tick['count']=price_count_tick['count'].fillna(0)
        price_count_tick['price_mod']=price_count_tick[ticker].abs()
        #price_count_tick['price_mod'].corr(price_count_tick['count'])
        print(ticker,story_source,price_count_tick['price_mod'].corr(price_count_tick['count']))
    except:
        print('failed_For '+ticker)
    i=i+1
# Out:
# /home/ubuntu/.local/lib/python3.5/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
# GOOG baseballnewssource.com -0.0511071915434
# RL baseballnewssource.com 0.0140698514774
# FB baseballnewssource.com -0.110069805674
# MSFT baseballnewssource.com -0.0387665554629
# INTC baseballnewssource.com -0.00669381908254
# AAL baseballnewssource.com -0.0616217848584
# BA baseballnewssource.com -0.0520808205072
# EXPE baseballnewssource.com -0.052552748626
# GE baseballnewssource.com -0.055163759084
# NFLX baseballnewssource.com 0.106331112974
# TRIP baseballnewssource.com 0.0193691299438
# AMD baseballnewssource.com 0.061502560383
# ...

# %%
df['shifted_time'] = df.groupby('entity_ticker')['day'].shift(-1)

# %%
#yahoo.com
i=0
for ticker in ticker_list:
    #ticker_list=article_count['entity_ticker'].unique().tolist()
    try:
        #ticker=random.choice(ticker_list)
        tick_article=article_count[article_count['entity_ticker']==ticker]
        source_list=tick_article['story_source'].unique().tolist()
        story_source='yahoo.com'#random.choice(source_list)
        tick_price=price[['Date',ticker]]
        price_count_tick=pd.merge(tick_price,tick_article[tick_article['story_source']==story_source],how='left',left_on='Date',right_on='date')
        price_count_tick[ticker]=price_count_tick[ticker].fillna(0.0)
        price_count_tick['date']=price_count_tick['date'].fillna('2013-07-13')
        price_count_tick['story_source']=price_count_tick['story_source'].fillna(story_source)
        price_count_tick['entity_ticker']=price_count_tick['entity_ticker'].fillna(ticker)
        price_count_tick['avg']=price_count_tick['avg'].fillna(0.0)
        price_count_tick['count']=price_count_tick['count'].fillna(0)
        price_count_tick['price_mod']=price_count_tick[ticker].abs()
        #price_count_tick['price_mod'].corr(price_count_tick['count'])
        print(ticker,story_source,price_count_tick['price_mod'].corr(price_count_tick['count']))
    except:
        print('failed_For '+ticker)
    i=i+1
# Out:
# GOOG yahoo.com 0.111317896393
# RL yahoo.com 0.365934660274
# FB yahoo.com 0.0891687783049
# MSFT yahoo.com 0.224862585077
# INTC yahoo.com 0.0978647547893
# AAL yahoo.com 0.0722968994499
# BA yahoo.com 0.18666889036
# EXPE yahoo.com 0.243945366933
# GE yahoo.com 0.158808763669
# NFLX yahoo.com 0.399596125304
# TRIP yahoo.com 0.0505605980552
# AMD yahoo.com 0.22744495914
# AON yahoo.com 0.0957731195412
# BMY yahoo.com 0.0857982559318
# IBM yahoo.com 0.338617837496
# IT yahoo.com -0.0142307736743
# JNJ yahoo.com 0.104794926141
# NKE yahoo.com 0.294822559931
# PNR yahoo.com 0.0283924296585
# REGN yahoo.com 0.0248201789839
# ROK yahoo.com 0.192158007358
# WM yahoo.com 0.0754760572067
# HOG yahoo.com 0.139187495335
# FDX yahoo.com 0.0200161470269
# HD yahoo.com 0.145496400733
# AXP yahoo.com 0.246323094267
# BBT yahoo.com 0.0780950586043
# failed_For CMCSA
# failed_For CMG
# failed_For COF
# failed_For COST
# DIS yahoo.com 0.0359770970363
# HRB yahoo.com 0.293958697055
# ...

# %%
i=0
for ticker in ticker_list:
    #ticker_list=article_count['entity_ticker'].unique().tolist()
    try:
        #ticker=random.choice(ticker_list)
        tick_article=article_count[article_count['entity_ticker']==ticker]
        source_list=tick_article['story_source'].unique().tolist()
        story_source='bloomberg.com'#random.choice(source_list)
        tick_price=price[['Date',ticker]]
        tick_price['Date']=tick_price['Date'].shift(1)
        price_count_tick=pd.merge(tick_price,tick_article[tick_article['story_source']==story_source],how='left',left_on='Date',right_on='date')
        price_count_tick[ticker]=price_count_tick[ticker].fillna(0.0)
        price_count_tick['date']=price_count_tick['date'].fillna('2013-07-13')
        price_count_tick['story_source']=price_count_tick['story_source'].fillna(story_source)
        price_count_tick['entity_ticker']=price_count_tick['entity_ticker'].fillna(ticker)
        price_count_tick['avg']=price_count_tick['avg'].fillna(0.0)
        price_count_tick['count']=price_count_tick['count'].fillna(0)
        price_count_tick['price_mod']=price_count_tick[ticker].abs()
        #price_count_tick['price_mod'].corr(price_count_tick['count'])
        print(ticker,story_source,price_count_tick['price_mod'].corr(price_count_tick['count']))
    except:
        print('failed_For '+ticker)
    i=i+1

# %%
#streetinsider day shift -1
i=0
for ticker in ticker_list:
    #ticker_list=article_count['entity_ticker'].unique().tolist()
    try:
        #ticker=random.choice(ticker_list)
        tick_article=article_count[article_count['entity_ticker']==ticker]
        source_list=tick_article['story_source'].unique().tolist()
        story_source='streetinsider.com'#random.choice(source_list)
        tick_price=price[['Date',ticker]]
        tick_price['Date']=tick_price['Date'].shift(-1)
        price_count_tick=pd.merge(tick_price,tick_article[tick_article['story_source']==story_source],how='left',left_on='Date',right_on='date')
        price_count_tick[ticker]=price_count_tick[ticker].fillna(0.0)
        price_count_tick['date']=price_count_tick['date'].fillna('2013-07-13')
        price_count_tick['story_source']=price_count_tick['story_source'].fillna(story_source)
        price_count_tick['entity_ticker']=price_count_tick['entity_ticker'].fillna(ticker)
        price_count_tick['avg']=price_count_tick['avg'].fillna(0.0)
        price_count_tick['count']=price_count_tick['count'].fillna(0)
        price_count_tick['price_mod']=price_count_tick[ticker].abs()
        #price_count_tick['price_mod'].corr(price_count_tick['count'])
        print(ticker,story_source,price_count_tick['price_mod'].corr(price_count_tick['count']))
    except:
        print('failed_For '+ticker)
    i=i+1
# Out:
# /home/ubuntu/.local/lib/python3.5/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
# GOOG streetinsider.com 0.0934080726015
# RL streetinsider.com 0.364793737566
# FB streetinsider.com 0.1095012305
# MSFT streetinsider.com 0.0927667235099
# INTC streetinsider.com 0.108652141331
# AAL streetinsider.com 0.104397455819
# BA streetinsider.com 0.15362686522
# EXPE streetinsider.com 0.0485592268985
# GE streetinsider.com 0.0933687566616
# NFLX streetinsider.com 0.0736479163229
# TRIP streetinsider.com 0.0782480864751
# AMD streetinsider.com 0.0621729442929
# AON streetinsider.com 0.0547714555726
# BMY streetinsider.com 0.0659416393751
# ...

# %%
#mideasttime.com
i=0
for ticker in ticker_list:
    #ticker_list=article_count['entity_ticker'].unique().tolist()
    try:
        #ticker=random.choice(ticker_list)
        tick_article=article_count[article_count['entity_ticker']==ticker]
        source_list=tick_article['story_source'].unique().tolist()
        story_source='mideasttime.com'#random.choice(source_list)
        tick_price=price[['Date',ticker]]
        price_count_tick=pd.merge(tick_price,tick_article[tick_article['story_source']==story_source],how='left',left_on='Date',right_on='date')
        price_count_tick[ticker]=price_count_tick[ticker].fillna(0.0)
        price_count_tick['date']=price_count_tick['date'].fillna('2013-07-13')
        price_count_tick['story_source']=price_count_tick['story_source'].fillna(story_source)
        price_count_tick['entity_ticker']=price_count_tick['entity_ticker'].fillna(ticker)
        price_count_tick['avg']=price_count_tick['avg'].fillna(0.0)
        price_count_tick['count']=price_count_tick['count'].fillna(0)
        price_count_tick['price_mod']=price_count_tick[ticker].abs()
        #price_count_tick['price_mod'].corr(price_count_tick['count'])
        price_count_tick=price_count_tick[price_count_tick['count']>0]
        print(ticker,story_source,price_count_tick['price_mod'].corr(price_count_tick['count']),len(price_count_tick))
    except:
        print('failed_For '+ticker)
    i=i+1
# Out:
# GOOG mideasttime.com 0.0677044197737 298
# RL mideasttime.com -0.0497239816557 135
# FB mideasttime.com 0.00470575541486 314
# MSFT mideasttime.com 0.192243726719 242
# INTC mideasttime.com -0.0772029979877 289
# AAL mideasttime.com -0.0198013353001 256
# BA mideasttime.com 0.0958736683291 259
# EXPE mideasttime.com 0.122074137938 140
# GE mideasttime.com -0.0771986258247 189
# NFLX mideasttime.com 0.127435556181 225
# TRIP mideasttime.com -0.00449870457844 119
# AMD mideasttime.com -0.0625900701966 125
# AON mideasttime.com 0.149529200782 84
# BMY mideasttime.com -0.0346128244544 205
# IBM mideasttime.com 0.129617010906 262
# IT mideasttime.com -0.0378368221284 192
# JNJ mideasttime.com 0.005698928071 201
# NKE mideasttime.com 0.104140682623 234
# PNR mideasttime.com 0.164437889188 103
# REGN mideasttime.com 0.00699495866804 178
# ROK mideasttime.com 0.103014024338 135
# WM mideasttime.com 0.0140239344454 131
# HOG mideasttime.com 0.00750743202463 144
# ...

# %%
from matplotlib.pyplot import hist

# %%
ticker='FB'
tick_article=article_count[article_count['entity_ticker']==ticker]
source_list=tick_article['story_source'].unique().tolist()
story_source='tickerreport.com'#random.choice(source_list)
tick_price=price[['Date',ticker]]
price_count_tick=pd.merge(tick_price,tick_article[tick_article['story_source']==story_source],how='left',left_on='Date',right_on='date')
price_count_tick[ticker]=price_count_tick[ticker].fillna(0.0)
price_count_tick['date']=price_count_tick['date'].fillna('2013-07-13')
price_count_tick['story_source']=price_count_tick['story_source'].fillna(story_source)
price_count_tick['entity_ticker']=price_count_tick['entity_ticker'].fillna(ticker)
price_count_tick['avg']=price_count_tick['avg'].fillna(0.0)
price_count_tick['count']=price_count_tick['count'].fillna(0)
price_count_tick['price_mod']=price_count_tick[ticker].abs()
#price_count_tick['price_mod'].corr(price_count_tick['count'])
price_count_tick=price_count_tick[price_count_tick['count']>0]
price_count_tick['price_mod']=price_count_tick['price_mod'].round(1)
price_count_tick.groupby(['price_mod'], as_index=False)['count'].mean()
#price_count_tick=price_count_tick.set_index('count')
#print(ticker,story_source,price_count_tick['price_mod'].corr(price_count_tick['count']),len(price_count_tick))
#price_count_tick.hist('price_mod')
# Out:
#     price_mod     count
# 0         0.0  1.916667
# 1         0.1  1.981132
# 2         0.2  1.571429
# 3         0.3  1.775000
# 4         0.4  2.034483
# 5         0.5  1.441176
# 6         0.6  2.333333
# 7         0.7  1.869565
# 8         0.8  1.862069
# 9         0.9  2.266667
# 10        1.0  1.592593
# 11        1.1  1.863636
# 12        1.2  1.470588
# 13        1.3  2.300000
# 14        1.4  1.384615
# 15        1.5  1.760000
# 16        1.6  2.615385
# 17        1.7  1.857143
# 18        1.8  2.923077
# 19        1.9  1.700000
# 20        2.0  2.857143
# 21        2.1  1.909091
# 22        2.2  1.166667
# 23        2.3  4.400000
# 24        2.4  3.166667
# 25        2.5  1.000000
# 26        2.6  2.400000
# 27        2.7  2.000000
# 28        2.8  3.800000
# 29        2.9  1.444444
# 30        3.0  1.250000
# 31        3.1  1.500000
# 32        3.2  3.000000
# 33        3.3  1.666667
# 34        3.4  1.000000
# 35        3.5  1.400000
# 36        3.6  1.000000
# ...

# %%
ticker='FB'
tick_article=article_count[article_count['entity_ticker']==ticker]
source_list=tick_article['story_source'].unique().tolist()
story_source='bloomberg.com'#random.choice(source_list)
tick_price=price[['Date',ticker]]
tick_article=tick_article.groupby(['date'], as_index=False)['avg'].mean()
price_count_tick=pd.merge(tick_price,tick_article,how='left',left_on='Date',right_on='date')
price_count_tick[ticker]=price_count_tick[ticker].fillna(0.0)
price_count_tick['date']=price_count_tick['date'].fillna('2013-07-13')
#price_count_tick['story_source']=price_count_tick['story_source'].fillna(story_source)
#price_count_tick['entity_ticker']=price_count_tick['entity_ticker'].fillna(ticker)
price_count_tick['avg']=price_count_tick['avg'].fillna(0.0)
#price_count_tick['count']=price_count_tick['count'].fillna(0)
price_count_tick['price_mod']=price_count_tick[ticker].abs()
#price_count_tick['price_mod'].corr(price_count_tick['count'])
#price_count_tick=price_count_tick[price_count_tick['count']>0]
price_count_tick[ticker]=price_count_tick[ticker].round(1)
price_count_tick.groupby([ticker], as_index=False)['avg'].mean()
#price_count_tick=price_count_tick.set_index('count')
#print(ticker,story_source,price_count_tick['price_mod'].corr(price_count_tick['count']),len(price_count_tick))
#price_count_tick.hist('price_mod')
#print(ticker,price_count_tick['price_mod'].corr(price_count_tick['count']),len(price_count_tick))
# Out:
#        FB          avg
# 0    -6.9  2385.511236
# 1    -6.7  2597.146985
# 2    -6.5   681.577314
# 3    -6.1  2359.343531
# 4    -5.8   196.388907
# 5    -5.6   780.025042
# 6    -5.2  1706.723386
# 7    -5.1  -549.393821
# 8    -5.0   891.273842
# 9    -4.9   177.415742
# 10   -4.7   622.559071
# 11   -4.6   915.302190
# 12   -4.5   931.527606
# 13   -4.4   791.194349
# 14   -4.2  1406.588845
# 15   -4.1   196.008881
# 16   -4.0   991.156586
# 17   -3.9   748.404025
# 18   -3.8   754.540285
# 19   -3.7   222.115479
# 20   -3.5   682.438611
# 21   -3.3   386.057338
# 22   -3.2  1089.006908
# 23   -3.1   504.539538
# 24   -3.0  1108.653549
# 25   -2.9   821.585946
# 26   -2.8   301.391815
# 27   -2.7  1410.551725
# 28   -2.6  1626.199255
# 29   -2.5   916.353584
# ..    ...          ...
# 78    2.4   478.284682
# 79    2.5   869.434559
# 80    2.6  -348.328121
# 81    2.7  1304.993694
# 82    2.8   961.687447
# 83    2.9  1058.460882
# 84    3.0   836.864644
# 85    3.1   992.988331
# ...

# %%
tick_price[tick_price['GOOG']>10]
# Out:
#            Date       GOOG
# 57   2013-10-18  13.796286
# 495  2015-07-17  16.052431

# %%
A=article_count[(article_count['date']=='2013-10-18')&(article_count['entity_ticker']==ticker)]

# %%
article_count.head()
# Out:
#          date        story_source entity_ticker     avg  count
# 0  2015-03-13  0024watchworld.com          GOOG  8750.0      1
# 1  2015-06-22  0024watchworld.com            RL     0.0      1
# 2  2014-03-28          002mag.com            FB  8060.0      1
# 3  2014-11-03          002mag.com            FB  8060.0      1
# 4  2014-12-02          002mag.com            FB  8060.0      1

# %%
A.sort_values(['avg'],ascending=[1])
# Out:
#                date             story_source entity_ticker      avg  count
# 2389456  2013-10-18     huffingtonpost.co.uk          GOOG -9380.00      1
# 755038   2013-10-18       borkenerzeitung.de          GOOG -9170.00      1
# 2677901  2013-10-18           ivz-aktuell.de          GOOG -9170.00      1
# 3266571  2013-10-18           mediatel.co.uk          GOOG -8760.92      1
# 3454564  2013-10-18        mobiletoday.co.uk          GOOG -8680.00      1
# 3981500  2013-10-18                pcmag.com          GOOG -8130.00      1
# 4679186  2013-10-18        solidwastemag.com          GOOG -7883.75      1
# 4658008  2013-10-18           smartbrief.com          GOOG -7630.02      1
# 174328   2013-10-18                  afr.com          GOOG -7500.00      1
# 3157497  2013-10-18       marketingtimes.com          GOOG -7500.00      1
# 1500243  2013-10-18              daniweb.com          GOOG -6804.14      1
# ...

# %%
len(A)
# Out:
# 781

# %%
len(A[A['avg']>0]['count'])
# Out:
# 507

# %%
ticker='JPM'
tick_article=article_count[article_count['entity_ticker']==ticker]
source_list=tick_article['story_source'].unique().tolist()
story_source='tickerreport.com'#random.choice(source_list)
tick_price=price[['Date',ticker]]
price_count_tick=pd.merge(tick_price,tick_article[tick_article['story_source']==story_source],how='left',left_on='Date',right_on='date')
price_count_tick[ticker]=price_count_tick[ticker].fillna(0.0)
price_count_tick['date']=price_count_tick['date'].fillna('2013-07-13')
price_count_tick['story_source']=price_count_tick['story_source'].fillna(story_source)
price_count_tick['entity_ticker']=price_count_tick['entity_ticker'].fillna(ticker)
price_count_tick['avg']=price_count_tick['avg'].fillna(0.0)
price_count_tick['count']=price_count_tick['count'].fillna(0)
price_count_tick['price_mod']=price_count_tick[ticker].abs()
#price_count_tick['price_mod'].corr(price_count_tick['count'])
print(ticker,story_source,price_count_tick['price_mod'].corr(price_count_tick['count']))
# Out:
# JPM tickerreport.com 0.0205537656346

# %%
#watchlistnews.com
i=0
for ticker in ticker_list:
    #ticker_list=article_count['entity_ticker'].unique().tolist()
    try:
        #ticker=random.choice(ticker_list)
        tick_article=article_count[article_count['entity_ticker']==ticker]
        source_list=tick_article['story_source'].unique().tolist()
        story_source='watchlistnews.com'#'mideasttime.com'#random.choice(source_list)
        tick_price=price[['Date',ticker]]
        price_count_tick=pd.merge(tick_price,tick_article[tick_article['story_source']==story_source],how='left',left_on='Date',right_on='date')
        price_count_tick[ticker]=price_count_tick[ticker].fillna(0.0)
        price_count_tick['date']=price_count_tick['date'].fillna('2013-07-13')
        price_count_tick['story_source']=price_count_tick['story_source'].fillna(story_source)
        price_count_tick['entity_ticker']=price_count_tick['entity_ticker'].fillna(ticker)
        price_count_tick['avg']=price_count_tick['avg'].fillna(0.0)
        price_count_tick['count']=price_count_tick['count'].fillna(0)
        price_count_tick['price_mod']=price_count_tick[ticker].abs()
        #price_count_tick['price_mod'].corr(price_count_tick['count'])
        price_count_tick=price_count_tick[price_count_tick['count']>0]
        print(ticker,story_source,price_count_tick['price_mod'].corr(price_count_tick['count']),len(price_count_tick))
    except:
        print('failed_For '+ticker)
    i=i+1
# Out:
# GOOG watchlistnews.com 0.156093735522 291
# RL watchlistnews.com 0.227334374803 106
# FB watchlistnews.com 0.049176542194 279
# MSFT watchlistnews.com 0.0654210058964 259
# INTC watchlistnews.com -0.0232835436899 246
# AAL watchlistnews.com 0.0843871463696 193
# BA watchlistnews.com -0.00269427426204 241
# EXPE watchlistnews.com 0.0908115837726 132
# GE watchlistnews.com 0.166026735646 185
# NFLX watchlistnews.com 0.197625080525 218
# TRIP watchlistnews.com -0.00594731250491 112
# AMD watchlistnews.com -0.0188158280558 117
# AON watchlistnews.com 0.0306509028066 86
# BMY watchlistnews.com 0.0225915586658 204
# IBM watchlistnews.com 0.0922997070236 243
# IT watchlistnews.com -0.046722686804 195
# JNJ watchlistnews.com 0.149138664429 215
# NKE watchlistnews.com 0.0511448541621 216
# PNR watchlistnews.com -0.0234346975115 112
# REGN watchlistnews.com 0.0528288605992 143
# ROK watchlistnews.com 0.0412863261006 134
# WM watchlistnews.com 0.0282350441906 152
# ...

# %%
#wkrb13.com
i=0
for ticker in ticker_list:
    #ticker_list=article_count['entity_ticker'].unique().tolist()
    try:
        #ticker=random.choice(ticker_list)
        tick_article=article_count[article_count['entity_ticker']==ticker]
        source_list=tick_article['story_source'].unique().tolist()
        story_source='wkrb13.com'#'mideasttime.com'#random.choice(source_list)
        tick_price=price[['Date',ticker]]
        price_count_tick=pd.merge(tick_price,tick_article[tick_article['story_source']==story_source],how='left',left_on='Date',right_on='date')
        price_count_tick[ticker]=price_count_tick[ticker].fillna(0.0)
        price_count_tick['date']=price_count_tick['date'].fillna('2013-07-13')
        price_count_tick['story_source']=price_count_tick['story_source'].fillna(story_source)
        price_count_tick['entity_ticker']=price_count_tick['entity_ticker'].fillna(ticker)
        price_count_tick['avg']=price_count_tick['avg'].fillna(0.0)
        price_count_tick['count']=price_count_tick['count'].fillna(0)
        price_count_tick['price_mod']=price_count_tick[ticker].abs()
        #price_count_tick['price_mod'].corr(price_count_tick['count'])
        price_count_tick=price_count_tick[price_count_tick['count']>0]
        print(ticker,story_source,price_count_tick['price_mod'].corr(price_count_tick['count']),len(price_count_tick))
    except:
        print('failed_For '+ticker)
    i=i+1
# Out:
# GOOG wkrb13.com 0.0139990878669 357
# RL wkrb13.com -0.0198149225391 160
# FB wkrb13.com 0.0742636500947 377
# MSFT wkrb13.com 0.113774864064 308
# INTC wkrb13.com 0.0991384601851 310
# AAL wkrb13.com -0.017158274733 329
# BA wkrb13.com 0.167083098562 314
# EXPE wkrb13.com 0.0965703021274 164
# GE wkrb13.com 0.0254170485152 210
# NFLX wkrb13.com 0.0976295457964 281
# TRIP wkrb13.com -0.0272424306518 127
# AMD wkrb13.com 0.152915259673 169
# AON wkrb13.com -0.00947395901594 109
# BMY wkrb13.com -0.0941351405056 222
# IBM wkrb13.com 0.0888121947319 283
# IT wkrb13.com 0.0419347121674 254
# JNJ wkrb13.com 0.127216046384 230
# NKE wkrb13.com 0.251919304163 287
# PNR wkrb13.com 0.0648872198741 131
# REGN wkrb13.com 0.115838915279 214
# ROK wkrb13.com -0.0135159762706 170
# WM wkrb13.com -0.0523066082376 148
# HOG wkrb13.com -0.0416602937318 147
# FDX wkrb13.com 0.153125800357 200
# HD wkrb13.com 0.0656906848663 221
# AXP wkrb13.com 0.000607162219984 223
# ...

# %%
i=0
source_list=['yahoo.com','zolmax.com','individual.com','tickerreport.com','mysmartrend.com']
df = pd.DataFrame(columns=['ticker','story_source','relevence','count'])
for story_source in source_list:
    for ticker in ticker_list:
        #ticker_list=article_count['entity_ticker'].unique().tolist()
        try:
            #ticker=random.choice(ticker_list)
            tick_article=article_count[article_count['entity_ticker']==ticker]
            source_list=tick_article['story_source'].unique().tolist()
            #story_source='wkrb13.com'#'mideasttime.com'#random.choice(source_list)
            tick_price=price[['Date',ticker]]
            price_count_tick=pd.merge(tick_price,tick_article[tick_article['story_source']==story_source],how='left',left_on='Date',right_on='date')
            price_count_tick[ticker]=price_count_tick[ticker].fillna(0.0)
            price_count_tick['date']=price_count_tick['date'].fillna('2013-07-13')
            price_count_tick['story_source']=price_count_tick['story_source'].fillna(story_source)
            price_count_tick['entity_ticker']=price_count_tick['entity_ticker'].fillna(ticker)
            price_count_tick['avg']=price_count_tick['avg'].fillna(0.0)
            price_count_tick['count']=price_count_tick['count'].fillna(0)
            price_count_tick['price_mod']=price_count_tick[ticker].abs()
            #price_count_tick['price_mod'].corr(price_count_tick['count'])
            price_count_tick=price_count_tick[price_count_tick['count']>0]
            print(ticker,story_source,price_count_tick['price_mod'].corr(price_count_tick['count']),len(price_count_tick))
            df=df.append({'ticker': ticker,'story_source':story_source,'relevence':price_count_tick['price_mod'].corr(price_count_tick['count']),'count':len(price_count_tick)}, ignore_index=True)
        except:
            print('failed_For '+ticker)
        i=i+1
df.to_csv('data_messed_up.csv')
# Out:
# GOOG yahoo.com 0.112198053561 1105
# RL yahoo.com 0.423075693215 108
# FB yahoo.com 0.0866739112305 1105
# MSFT yahoo.com 0.221888979109 1046
# INTC yahoo.com 0.141247940421 673
# AAL yahoo.com 0.0160244222132 439
# BA yahoo.com 0.19802488148 913
# EXPE yahoo.com 0.31807751959 177
# GE yahoo.com 0.156712096875 284
# NFLX yahoo.com 0.413106885634 911
# TRIP yahoo.com -0.194389094201 31
# AMD yahoo.com 0.214695220813 321
# AON yahoo.com 0.134069088441 87
# BMY yahoo.com -0.0123308989233 85
# IBM yahoo.com 0.413089969317 648
# IT yahoo.com -0.00203116047972 434
# JNJ yahoo.com 0.186134755394 224
# NKE yahoo.com 0.385498026697 420
# PNR yahoo.com nan 12
# REGN yahoo.com -0.223986825705 28
# ROK yahoo.com 0.580645395055 34
# WM yahoo.com 0.457464353054 96
# HOG yahoo.com 0.205803226028 125
# FDX yahoo.com 0.0214254430527 34
# HD yahoo.com 0.160801913865 253
# AXP yahoo.com 0.331887167905 218
# BBT yahoo.com -0.00938580039694 89
# failed_For CMCSA
# failed_For CMG
# failed_For COF
# ...

# %%
#bloomberg
i=0
for ticker in ticker_list:
    #ticker_list=article_count['entity_ticker'].unique().tolist()
    try:
        #ticker=random.choice(ticker_list)
        tick_article=article_count[article_count['entity_ticker']==ticker]
        source_list=tick_article['story_source'].unique().tolist()
        story_source='bloomberg.com'#random.choice(source_list)
        tick_price=price[['Date',ticker]]
        price_count_tick=pd.merge(tick_price,tick_article[tick_article['story_source']==story_source],how='left',left_on='Date',right_on='date')
        price_count_tick[ticker]=price_count_tick[ticker].fillna(0.0)
        price_count_tick['date']=price_count_tick['date'].fillna('2013-07-13')
        price_count_tick['story_source']=price_count_tick['story_source'].fillna(story_source)
        price_count_tick['entity_ticker']=price_count_tick['entity_ticker'].fillna(ticker)
        price_count_tick['avg']=price_count_tick['avg'].fillna(0.0)
        price_count_tick['count']=price_count_tick['count'].fillna(0)
        price_count_tick['price_mod']=price_count_tick[ticker].abs()
        #price_count_tick['price_mod'].corr(price_count_tick['count'])
        print(ticker,story_source,price_count_tick['price_mod'].corr(price_count_tick['count']))
    except:
        print('failed_For '+ticker)
    i=i+1
# Out:
# GOOG bloomberg.com 0.200265439656
# RL bloomberg.com 0.288408123252
# FB bloomberg.com 0.151545133061
# MSFT bloomberg.com 0.302265052105
# INTC bloomberg.com 0.129062501766
# AAL bloomberg.com 0.0648315271822
# BA bloomberg.com 0.12629845655
# EXPE bloomberg.com 0.323747665674
# GE bloomberg.com 0.0189780685539
# NFLX bloomberg.com 0.309991121221
# TRIP bloomberg.com nan
# AMD bloomberg.com 0.2227164655
# AON bloomberg.com -0.000683289008226
# BMY bloomberg.com -0.00870993532664
# IBM bloomberg.com 0.248758144812
# IT bloomberg.com 0.0137231477078
# JNJ bloomberg.com 0.0118480771547
# NKE bloomberg.com 0.196072590735
# PNR bloomberg.com -0.0117970781036
# REGN bloomberg.com 0.0105143875149
# ROK bloomberg.com 0.231123302095
# WM bloomberg.com 0.00102080884747
# HOG bloomberg.com 0.21308935164
# FDX bloomberg.com 0.000976573517744
# HD bloomberg.com 0.142494310077
# AXP bloomberg.com 0.143823373696
# BBT bloomberg.com 0.012564210043
# failed_For CMCSA
# failed_For CMG
# ...
