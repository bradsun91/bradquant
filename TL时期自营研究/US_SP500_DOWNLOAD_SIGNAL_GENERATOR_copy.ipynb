# %%
import pandas as pd, numpy as np
from datetime import datetime
import yfinance as yf
import os

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set(context='notebook', style='darkgrid', palette='deep', font='sans-serif', font_scale=1, color_codes=False, rc=None)

# %% [markdown]
# https://pypi.org/project/yfinance/

# %% [markdown]
# # Technical Indicators

# %% [markdown]
# # S&P500 List

# %%
def sp500():
    sp500_list = ['MMM', 'ABT', 'ABBV', 'ACN', 'ATVI', 'AYI', 'ADBE', 'AMD', 'HII', 'AAP', 'AES', 'AET', 'AMG', 'AFL', 'A', 'APD', 'AKAM', 'ALK', 'ALB', 'ARE', 'ALXN', 'ALGN', 'ALLE', 'AGN', 'ADS', 'LNT', 'ALL', 'GOOGL', 'GOOG', 'MO', 'AMZN', 'AEE', 'AAL', 'AEP', 'AXP', 'AIG', 'AMT', 'AWK', 'AMP', 'ABC', 'AME', 'AMGN', 'APH', 'APC', 'ADI', 'ANDV', 'ANSS', 'ANTM', 'AON', 'AOS', 'APA', 'AIV', 'AAPL', 'AMAT', 'APTV', 'ADM', 'ARNC', 'AJG', 'AIZ', 'T', 'ADSK', 'ADP', 'AZO', 'AVB', 'AVY', 'BHGE', 'BLL', 'BAC', 'BK', 'BAX', 'BBT', 'BDX', 'BRK.B', 'BBY', 'BIIB', 'BLK', 'HRB', 'BA', 'BWA', 'BXP', 'BSX', 'BHF', 'BMY', 'AVGO', 'BF.B', 'CHRW', 'CA', 'COG', 'CDNS', 'CPB', 'COF', 'CAH', 'CBOE', 'KMX', 'CCL', 'CAT', 'CBG', 'CBS', 'CELG', 'CNC', 'CNP', 'CTL', 'CERN', 'CF', 'SCHW', 'CHTR', 'CHK', 'CVX', 'CMG', 'CB', 'CHD', 'CI', 'XEC', 'CINF', 'CTAS', 'CSCO', 'C', 'CFG', 'CTXS', 'CLX', 'CME', 'CMS', 'KO', 'CTSH', 'CL', 'CMCSA', 'CMA', 'CAG', 'CXO', 'COP', 'ED', 'STZ', 'COO', 'GLW', 'COST', 'COTY', 'CCI', 'CSRA', 'CSX', 'CMI', 'CVS', 'DHI', 'DHR', 'DRI', 'DVA', 'DE', 'DAL', 'XRAY', 'DVN', 'DLR', 'DFS', 'DISCA', 'DISCK', 'DISH', 'DG', 'DLTR', 'D', 'DOV', 'DWDP', 'DPS', 'DTE', 'DRE', 'DUK', 'DXC', 'ETFC', 'EMN', 'ETN', 'EBAY', 'ECL', 'EIX', 'EW', 'EA', 'EMR', 'ETR', 'EVHC', 'EOG', 'EQT', 'EFX', 'EQIX', 'EQR', 'ESS', 'EL', 'ES', 'RE', 'EXC', 'EXPE', 'EXPD', 'ESRX', 'EXR', 'XOM', 'FFIV', 'FB', 'FAST', 'FRT', 'FDX', 'FIS', 'FITB', 'FE', 'FISV', 'FLIR', 'FLS', 'FLR', 'FMC', 'FL', 'F', 'FTV', 'FBHS', 'BEN', 'FCX', 'GPS', 'GRMN', 'IT', 'GD', 'GE', 'GGP', 'GIS', 'GM', 'GPC', 'GILD', 'GPN', 'GS', 'GT', 'GWW', 'HAL', 'HBI', 'HOG', 'HRS', 'HIG', 'HAS', 'HCA', 'HCP', 'HP', 'HSIC', 'HSY', 'HES', 'HPE', 'HLT', 'HOLX', 'HD', 'HON', 'HRL', 'HST', 'HPQ', 'HUM', 'HBAN', 'IDXX', 'INFO', 'ITW', 'ILMN', 'IR', 'INTC', 'ICE', 'IBM', 'INCY', 'IP', 'IPG', 'IFF', 'INTU', 'ISRG', 'IVZ', 'IQV', 'IRM', 'JEC', 'JBHT', 'SJM', 'JNJ', 'JCI', 'JPM', 'JNPR', 'KSU', 'K', 'KEY', 'KMB', 'KIM', 'KMI', 'KLAC', 'KSS', 'KHC', 'KR', 'LB', 'LLL', 'LH', 'LRCX', 'LEG', 'LEN', 'LUK', 'LLY', 'LNC', 'LKQ', 'LMT', 'L', 'LOW', 'LYB', 'MTB', 'MAC', 'M', 'MRO', 'MPC', 'MAR', 'MMC', 'MLM', 'MAS', 'MA', 'MAT', 'MKC', 'MCD', 'MCK', 'MDT', 'MRK', 'MET', 'MTD', 'MGM', 'KORS', 'MCHP', 'MU', 'MSFT', 'MAA', 'MHK', 'TAP', 'MDLZ', 'MON', 'MNST', 'MCO', 'MS', 'MOS', 'MSI', 'MYL', 'NDAQ', 'NOV', 'NAVI', 'NTAP', 'NFLX', 'NWL', 'NFX', 'NEM', 'NWSA', 'NWS', 'NEE', 'NLSN', 'NKE', 'NI', 'NBL', 'JWN', 'NSC', 'NTRS', 'NOC', 'NCLH', 'NRG', 'NUE', 'NVDA', 'ORLY', 'OXY', 'OMC', 'OKE', 'ORCL', 'PCAR', 'PKG', 'PH', 'PDCO', 'PAYX', 'PYPL', 'PNR', 'PBCT', 'PEP', 'PKI', 'PRGO', 'PFE', 'PCG', 'PM', 'PSX', 'PNW', 'PXD', 'PNC', 'RL', 'PPG', 'PPL', 'PX', 'PCLN', 'PFG', 'PG', 'PGR', 'PLD', 'PRU', 'PEG', 'PSA', 'PHM', 'PVH', 'QRVO', 'PWR', 'QCOM', 'DGX', 'RRC', 'RJF', 'RTN', 'O', 'RHT', 'REG', 'REGN', 'RF', 'RSG', 'RMD', 'RHI', 'ROK', 'COL', 'ROP', 'ROST', 'RCL', 'CRM', 'SBAC', 'SCG', 'SLB', 'SNI', 'STX', 'SEE', 'SRE', 'SHW', 'SIG', 'SPG', 'SWKS', 'SLG', 'SNA', 'SO', 'LUV', 'SPGI', 'SWK', 'SBUX', 'STT', 'SRCL', 'SYK', 'STI', 'SYMC', 'SYF', 'SNPS', 'SYY', 'TROW', 'TPR', 'TGT', 'TEL', 'FTI', 'TXN', 'TXT', 'TMO', 'TIF', 'TWX', 'TJX', 'TMK', 'TSS', 'TSCO', 'TDG', 'TRV', 'TRIP', 'FOXA', 'FOX', 'TSN', 'UDR', 'ULTA', 'USB', 'UA', 'UAA', 'UNP', 'UAL', 'UNH', 'UPS', 'URI', 'UTX', 'UHS', 'UNM', 'VFC', 'VLO', 'VAR', 'VTR', 'VRSN', 'VRSK', 'VZ', 'VRTX', 'VIAB', 'V', 'VNO', 'VMC', 'WMT', 'WBA', 'DIS', 'WM', 'WAT', 'WEC', 'WFC', 'HCN', 'WDC', 'WU', 'WRK', 'WY', 'WHR', 'WMB', 'WLTW', 'WYN', 'WYNN', 'XEL', 'XRX', 'XLNX', 'XL', 'XYL', 'YUM', 'ZBH', 'ZION', 'ZTS']
    return sp500_list

vti_weight = 0.3
tlt_weight= 0.40
ief_weight = 0.15
gld_weight = 0.075
dbc_weight = 0.075

def all_weather():
    all_weather_portfolio = ["VTI","TLT","IEF","GLD","DBC"]
    return all_weather_portfolio
all_weather = all_weather()

us_sectors = ["IYM","IYZ","FCL","FCD","IYE","IYG","IYH","IYJ","IYR","IYW","IDU"]
ticker_list = sp500()+["SPY","VXX","QQQ","YELP",'UBER']+all_weather+us_sectors+['TSLA']

# %%
# Version 2: add pre data.

# import requests
import eventlet
eventlet.monkey_patch()

us_db_path = "/Users/miaoyuesun/Code_Workspace/brad_public_workspace_mac/data/US_database/"
# ticker_list = sp500_list
# ticker_list = all_weather

# tickers that are left out:
# ticker_list = ["ANDV","XL","TSS","MAR","CSRA","BHGE"]
# ticker_list = ticker_list
ticker_list = ['QQQ']

today = str(datetime.now().date())
# start = "2010-01-01"
start = "2005-01-01"
end = today
# end = "2009-12-31"
for ticker in ticker_list:
#     print("testing")
    # Initial downloading:
    if not os.path.exists(us_db_path+ticker+".csv"):
        print("{} is new, start downloading now...".format(ticker))
        with eventlet.Timeout(60,False):
            try:
                data = yf.download(ticker, start=start, end=end)
                data.reset_index(inplace = True)
                data['Ticker'] = ticker
                data.to_csv(us_db_path+ticker+".csv", index = False)
                print("{} data file created: {}".format(ticker, end))
            except Exception as e:
                print(e)
                
#         print("Timed Out: Download Failed!")
    # Check for updates:
    else:
        print("Already have data csv for {}".format(ticker))
        hist_data = pd.read_csv(us_db_path+ticker+".csv")
        try:
            hist_data_first_date = hist_data['Date'].values[0]
            if start >= hist_data_first_date:
                hist_data_last_date = hist_data['Date'].values[-1]
                if today > hist_data_last_date:
                    print("Needs to update, start updating new data for {} now...".format(ticker))
                    update_start = hist_data_last_date
                    update_end = today
                    with eventlet.Timeout(60,False):
                        try:
                            new_data = yf.download(ticker, start=update_start, end=update_end)
                            new_data.reset_index(inplace = True)
                            new_data['Ticker'] = ticker
                            new_data.to_csv(us_db_path+ticker+".csv", mode='a', header=False, index = False)
                            updated_duplicated_df = pd.read_csv(us_db_path+ticker+".csv")
                            updated_df = updated_duplicated_df.drop_duplicates("Date")
                            updated_df.sort_values("Date", inplace = True)
                            updated_df.to_csv(us_db_path+ticker+".csv", index = False)
                            print("New data updated till today for {}!".format(ticker))
                        except Exception as e:
                            print(e)
        #             print("Timed Out: Update Failed!")
                else:
                    print("There's no new data to update for {}.".format(ticker))

            else:
                print("Setup start date earlier than existing data's, trying to pull data from before...")
                hist_data_last_date = hist_data['Date'].values[-1]
                if today > hist_data_last_date:
                    print("Needs to update, start updating new data for {} now...".format(ticker))
                    update_start = start
                    update_end = today
                    with eventlet.Timeout(60,False):
                        try:
                            new_data = yf.download(ticker, start=update_start, end=update_end)
                            new_data.reset_index(inplace = True)
                            new_date = new_data['Date'].values[0]
                            print("New data's first pulled date is {}".format(new_date))
                            new_data['Ticker'] = ticker
                            
                            new_data.to_csv(us_db_path+ticker+".csv", mode='a', header=False, index = False)
                            updated_duplicated_df = pd.read_csv(us_db_path+ticker+".csv")
                            updated_df = updated_duplicated_df.drop_duplicates("Date")
                            updated_df.sort_values("Date", inplace = True)
                            updated_df.to_csv(us_db_path+ticker+".csv", index = False)
                            print("New data updated till today for {}!".format(ticker))
                        except Exception as e:
                            print(e)
                else:
                    print("There's no new data to update for {}.".format(ticker))
        except Exception as e:
            print(e)

#     print("Data Download/Update for {} is Finished.".format(ticker))
    print("===============================================")
    
print("【Updated Finished for today!】")
# Out:
# Already have data csv for QQQ
# Needs to update, start updating new data for QQQ now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for QQQ!
# ===============================================
# 【Updated Finished for today!】
# /Users/miaoyuesun/anaconda3/lib/python3.5/site-packages/ipykernel_launcher.py:57: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
yf.download("TSLA", start="2019-01-01", end="2019-05-01")
# Out:
# Exception in thread Thread-9:
# Traceback (most recent call last):
#   File "/Users/miaoyuesun/anaconda3/lib/python3.5/site-packages/eventlet/support/greendns.py", line 425, in resolve
#     use_network=use_network)
#   File "/Users/miaoyuesun/anaconda3/lib/python3.5/site-packages/eventlet/support/greendns.py", line 380, in query
#     return end()
#   File "/Users/miaoyuesun/anaconda3/lib/python3.5/site-packages/eventlet/support/greendns.py", line 359, in end
#     raise result[1]
#   File "/Users/miaoyuesun/anaconda3/lib/python3.5/site-packages/eventlet/support/greendns.py", line 340, in step
#     a = fun(*args, **kwargs)
#   File "/Users/miaoyuesun/anaconda3/lib/python3.5/site-packages/dns/resolver.py", line 900, in query
#     timeout = self._compute_timeout(start, lifetime)
#   File "/Users/miaoyuesun/anaconda3/lib/python3.5/site-packages/dns/resolver.py", line 799, in _compute_timeout
#     raise Timeout(timeout=duration)
# dns.exception.Timeout: The DNS operation timed out after 132.74797296524048 seconds
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/miaoyuesun/anaconda3/lib/python3.5/site-packages/urllib3/connection.py", line 171, in _new_conn
#     (self._dns_host, self.port), self.timeout, **extra_kw)
#   File "/Users/miaoyuesun/anaconda3/lib/python3.5/site-packages/urllib3/util/connection.py", line 56, in create_connection
#     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#   File "/Users/miaoyuesun/anaconda3/lib/python3.5/site-packages/eventlet/support/greendns.py", line 517, in getaddrinfo
#     qname, addrs = _getaddrinfo_lookup(host, family, flags)
#   File "/Users/miaoyuesun/anaconda3/lib/python3.5/site-packages/eventlet/support/greendns.py", line 490, in _getaddrinfo_lookup
#     raise err
#   File "/Users/miaoyuesun/anaconda3/lib/python3.5/site-packages/eventlet/support/greendns.py", line 479, in _getaddrinfo_lookup
#     answer = resolve(host, qfamily, False, use_network=use_network)
#   File "/Users/miaoyuesun/anaconda3/lib/python3.5/site-packages/eventlet/support/greendns.py", line 432, in resolve
#     raise EAI_EAGAIN_ERROR
#   File "/Users/miaoyuesun/anaconda3/lib/python3.5/site-packages/eventlet/support/greendns.py", line 479, in _getaddrinfo_lookup
#     answer = resolve(host, qfamily, False, use_network=use_network)
#   File "/Users/miaoyuesun/anaconda3/lib/python3.5/site-packages/eventlet/support/greendns.py", line 432, in resolve
#     raise EAI_EAGAIN_ERROR
#   File "/Users/miaoyuesun/anaconda3/lib/python3.5/site-packages/urllib3/connection.py", line 171, in _new_conn
#     (self._dns_host, self.port), self.timeout, **extra_kw)
#   File "/Users/miaoyuesun/anaconda3/lib/python3.5/site-packages/urllib3/util/connection.py", line 56, in create_connection
#     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#   File "/Users/miaoyuesun/anaconda3/lib/python3.5/site-packages/eventlet/support/greendns.py", line 517, in getaddrinfo
#     qname, addrs = _getaddrinfo_lookup(host, family, flags)
#   File "/Users/miaoyuesun/anaconda3/lib/python3.5/site-packages/eventlet/support/greendns.py", line 490, in _getaddrinfo_lookup
#     raise err
#   File "/Users/miaoyuesun/anaconda3/lib/python3.5/site-packages/eventlet/support/greendns.py", line 479, in _getaddrinfo_lookup
#     answer = resolve(host, qfamily, False, use_network=use_network)
#   File "/Users/miaoyuesun/anaconda3/lib/python3.5/site-packages/eventlet/support/greendns.py", line 432, in resolve
#     raise EAI_EAGAIN_ERROR
#   File "/Users/miaoyuesun/anaconda3/lib/python3.5/site-packages/eventlet/support/greendns.py", line 479, in _getaddrinfo_lookup
#     answer = resolve(host, qfamily, False, use_network=use_network)
#   File "/Users/miaoyuesun/anaconda3/lib/python3.5/site-packages/eventlet/support/greendns.py", line 432, in resolve
#     raise EAI_EAGAIN_ERROR
#   File "/Users/miaoyuesun/anaconda3/lib/python3.5/site-packages/urllib3/connection.py", line 171, in _new_conn
#     (self._dns_host, self.port), self.timeout, **extra_kw)
#   File "/Users/miaoyuesun/anaconda3/lib/python3.5/site-packages/urllib3/util/connection.py", line 56, in create_connection
#     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#   File "/Users/miaoyuesun/anaconda3/lib/python3.5/site-packages/eventlet/support/greendns.py", line 517, in getaddrinfo
#     qname, addrs = _getaddrinfo_lookup(host, family, flags)
#   File "/Users/miaoyuesun/anaconda3/lib/python3.5/site-packages/eventlet/support/greendns.py", line 490, in _getaddrinfo_lookup
#     raise err
#   File "/Users/miaoyuesun/anaconda3/lib/python3.5/site-packages/eventlet/support/greendns.py", line 479, in _getaddrinfo_lookup
#     answer = resolve(host, qfamily, False, use_network=use_network)
#   File "/Users/miaoyuesun/anaconda3/lib/python3.5/site-packages/eventlet/support/greendns.py", line 432, in resolve
#     raise EAI_EAGAIN_ERROR
#   File "/Users/miaoyuesun/anaconda3/lib/python3.5/site-packages/eventlet/support/greendns.py", line 479, in _getaddrinfo_lookup
#     answer = resolve(host, qfamily, False, use_network=use_network)
#   File "/Users/miaoyuesun/anaconda3/lib/python3.5/site-packages/eventlet/support/greendns.py", line 432, in resolve
#     raise EAI_EAGAIN_ERROR
#   File "/Users/miaoyuesun/anaconda3/lib/python3.5/site-packages/urllib3/connection.py", line 171, in _new_conn
#     (self._dns_host, self.port), self.timeout, **extra_kw)
#   File "/Users/miaoyuesun/anaconda3/lib/python3.5/site-packages/urllib3/util/connection.py", line 56, in create_connection
#     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#   File "/Users/miaoyuesun/anaconda3/lib/python3.5/site-packages/eventlet/support/greendns.py", line 517, in getaddrinfo
#     qname, addrs = _getaddrinfo_lookup(host, family, flags)
#   File "/Users/miaoyuesun/anaconda3/lib/python3.5/site-packages/eventlet/support/greendns.py", line 490, in _getaddrinfo_lookup
#     raise err
#   File "/Users/miaoyuesun/anaconda3/lib/python3.5/site-packages/eventlet/support/greendns.py", line 479, in _getaddrinfo_lookup
#     answer = resolve(host, qfamily, False, use_network=use_network)
#   File "/Users/miaoyuesun/anaconda3/lib/python3.5/site-packages/eventlet/support/greendns.py", line 432, in resolve
#     raise EAI_EAGAIN_ERROR
#   File "/Users/miaoyuesun/anaconda3/lib/python3.5/site-packages/eventlet/support/greendns.py", line 479, in _getaddrinfo_lookup
#     answer = resolve(host, qfamily, False, use_network=use_network)
#   File "/Users/miaoyuesun/anaconda3/lib/python3.5/site-packages/eventlet/support/greendns.py", line 432, in resolve
#     raise EAI_EAGAIN_ERROR
#   File "/Users/miaoyuesun/anaconda3/lib/python3.5/site-packages/urllib3/connection.py", line 171, in _new_conn
#     (self._dns_host, self.port), self.timeout, **extra_kw)
#   File "/Users/miaoyuesun/anaconda3/lib/python3.5/site-packages/urllib3/util/connection.py", line 56, in create_connection
#     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#   File "/Users/miaoyuesun/anaconda3/lib/python3.5/site-packages/eventlet/support/greendns.py", line 517, in getaddrinfo
#     qname, addrs = _getaddrinfo_lookup(host, family, flags)
#   File "/Users/miaoyuesun/anaconda3/lib/python3.5/site-packages/eventlet/support/greendns.py", line 490, in _getaddrinfo_lookup
#     raise err
#   File "/Users/miaoyuesun/anaconda3/lib/python3.5/site-packages/eventlet/support/greendns.py", line 479, in _getaddrinfo_lookup
#     answer = resolve(host, qfamily, False, use_network=use_network)
#   File "/Users/miaoyuesun/anaconda3/lib/python3.5/site-packages/eventlet/support/greendns.py", line 432, in resolve
#     raise EAI_EAGAIN_ERROR
#   File "/Users/miaoyuesun/anaconda3/lib/python3.5/site-packages/eventlet/support/greendns.py", line 479, in _getaddrinfo_lookup
#     answer = resolve(host, qfamily, False, use_network=use_network)
#   File "/Users/miaoyuesun/anaconda3/lib/python3.5/site-packages/eventlet/support/greendns.py", line 432, in resolve
#     raise EAI_EAGAIN_ERROR
#   File "/Users/miaoyuesun/anaconda3/lib/python3.5/site-packages/urllib3/connection.py", line 171, in _new_conn
#     (self._dns_host, self.port), self.timeout, **extra_kw)
#   File "/Users/miaoyuesun/anaconda3/lib/python3.5/site-packages/urllib3/util/connection.py", line 56, in create_connection
#     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#   File "/Users/miaoyuesun/anaconda3/lib/python3.5/site-packages/eventlet/support/greendns.py", line 517, in getaddrinfo
#     qname, addrs = _getaddrinfo_lookup(host, family, flags)
#   File "/Users/miaoyuesun/anaconda3/lib/python3.5/site-packages/eventlet/support/greendns.py", line 490, in _getaddrinfo_lookup
#     raise err
#   File "/Users/miaoyuesun/anaconda3/lib/python3.5/site-packages/eventlet/support/greendns.py", line 479, in _getaddrinfo_lookup
#     answer = resolve(host, qfamily, False, use_network=use_network)
#   File "/Users/miaoyuesun/anaconda3/lib/python3.5/site-packages/eventlet/support/greendns.py", line 432, in resolve
#     raise EAI_EAGAIN_ERROR
#   File "/Users/miaoyuesun/anaconda3/lib/python3.5/site-packages/eventlet/support/greendns.py", line 479, in _getaddrinfo_lookup
#     answer = resolve(host, qfamily, False, use_network=use_network)
#   File "/Users/miaoyuesun/anaconda3/lib/python3.5/site-packages/eventlet/support/greendns.py", line 432, in resolve
#     raise EAI_EAGAIN_ERROR
# socket.gaierror: [Errno 2] Lookup timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/miaoyuesun/anaconda3/lib/python3.5/site-packages/urllib3/connectionpool.py", line 600, in urlopen
#     chunked=chunked)
#   File "/Users/miaoyuesun/anaconda3/lib/python3.5/site-packages/urllib3/connectionpool.py", line 343, in _make_request
#     self._validate_conn(conn)
#   File "/Users/miaoyuesun/anaconda3/lib/python3.5/site-packages/urllib3/connectionpool.py", line 849, in _validate_conn
#     conn.connect()
#   File "/Users/miaoyuesun/anaconda3/lib/python3.5/site-packages/urllib3/connection.py", line 314, in connect
#     conn = self._new_conn()
#   File "/Users/miaoyuesun/anaconda3/lib/python3.5/site-packages/urllib3/connection.py", line 180, in _new_conn
#     self, "Failed to establish a new connection: %s" % e)
# urllib3.exceptions.NewConnectionError: <urllib3.connection.VerifiedHTTPSConnection object at 0x1a191bc940>: Failed to establish a new connection: [Errno 2] Lookup timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/miaoyuesun/anaconda3/lib/python3.5/site-packages/requests/adapters.py", line 449, in send
#     timeout=timeout
#   File "/Users/miaoyuesun/anaconda3/lib/python3.5/site-packages/urllib3/connectionpool.py", line 638, in urlopen
#     _stacktrace=sys.exc_info()[2])
#   File "/Users/miaoyuesun/anaconda3/lib/python3.5/site-packages/urllib3/util/retry.py", line 398, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='query1.finance.yahoo.com', port=443): Max retries exceeded with url: /v8/finance/chart/AYI?period1=1577116800&includePrePost=False&period2=1577289600&events=div%2Csplits&interval=1d (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x1a191bc940>: Failed to establish a new connection: [Errno 2] Lookup timed out',))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/miaoyuesun/anaconda3/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/Users/miaoyuesun/anaconda3/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/miaoyuesun/anaconda3/lib/python3.5/site-packages/multitasking/__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "/Users/miaoyuesun/anaconda3/lib/python3.5/site-packages/yfinance/multi.py", line 167, in _download_one_threaded
#     actions, period, interval, prepost, proxy, rounding)
#   File "/Users/miaoyuesun/anaconda3/lib/python3.5/site-packages/yfinance/multi.py", line 182, in _download_one
#     rounding=rounding, many=True)
#   File "/Users/miaoyuesun/anaconda3/lib/python3.5/site-packages/yfinance/base.py", line 144, in history
#     data = _requests.get(url=url, params=params, proxies=proxy)
#   File "/Users/miaoyuesun/anaconda3/lib/python3.5/site-packages/requests/api.py", line 75, in get
#     return request('get', url, params=params, **kwargs)
#   File "/Users/miaoyuesun/anaconda3/lib/python3.5/site-packages/requests/api.py", line 60, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "/Users/miaoyuesun/anaconda3/lib/python3.5/site-packages/requests/sessions.py", line 533, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/Users/miaoyuesun/anaconda3/lib/python3.5/site-packages/requests/sessions.py", line 646, in send
#     r = adapter.send(request, **kwargs)
#   File "/Users/miaoyuesun/anaconda3/lib/python3.5/site-packages/requests/adapters.py", line 516, in send
#     raise ConnectionError(e, request=request)
# requests.exceptions.ConnectionError: HTTPSConnectionPool(host='query1.finance.yahoo.com', port=443): Max retries exceeded with url: /v8/finance/chart/AYI?period1=1577116800&includePrePost=False&period2=1577289600&events=div%2Csplits&interval=1d (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x1a191bc940>: Failed to establish a new connection: [Errno 2] Lookup timed out',))
# KeyboardInterrupt

# %%
us_db_path = "C:/Users/Administrator/Documents/GitHub/mac_win_since_20191006/research_mac_win/US_database/"
stock = pd.read_csv(us_db_path+"AAPL.csv", encoding = "ANSI")

# %%
def MACD(df, n_fast, n_slow, n_macd): # n_fast = 12, n_slow = 26
    """
    
    http://stockcharts.com/docs/doku.php?id=scans:indicators

    """
    """
    MACD, MACD Signal and MACD difference, rationale CHECKED, code CHECKED, updated
    # Conventional look-back window for calculating MACDsign is 9
    """
    EMAfast = df['Adj Close'].ewm(span = n_fast, min_periods = n_fast - 1).mean()
    EMAslow = df['Adj Close'].ewm(span = n_slow, min_periods = n_slow - 1).mean()
    MACD = pd.Series(EMAfast - EMAslow, name = 'MACD_' + str(n_fast) + '_' + str(n_slow))
    MACDsign = MACD.ewm(span = n_macd, min_periods = n_macd-1).mean().rename('MACDsign_' + str(n_fast) + '_' + str(n_slow))
    MACDdiff = pd.Series(MACD - MACDsign, name = 'MACDdiff_' + str(n_fast) + '_' + str(n_slow))
    df['MACD_Diff'] = MACD
    df['MACD_Diff_EMA'] = MACDsign
    df['MACD'] = MACDdiff
    df['MACD_signal'] = df['MACD'].apply(lambda x: "多头信号" if x>0 else ("空头信号" if x<0 else "空仓信号"))
#     return MACD, MACDsign, MACDdiff
    return df

# %%
# analysis_tickers = ['AAPL',"GOOG","TSLA"]
analysis_tickers = sp500()

# %%
ticker_df_list = []
for ticker in analysis_tickers:
    print("Reading: ", ticker)
    ticker_df = pd.read_csv(us_db_path+ticker+".csv", encoding = "ANSI")
    ticker_df_list.append(ticker_df)
# Out:
# Reading:  MMM
# Reading:  ABT
# Reading:  ABBV
# Reading:  ACN
# Reading:  ATVI
# Reading:  AYI
# Reading:  ADBE
# Reading:  AMD
# Reading:  HII
# Reading:  AAP
# Reading:  AES
# Reading:  AET
# Reading:  AMG
# Reading:  AFL
# Reading:  A
# Reading:  APD
# Reading:  AKAM
# Reading:  ALK
# Reading:  ALB
# Reading:  ARE
# Reading:  ALXN
# Reading:  ALGN
# Reading:  ALLE
# Reading:  AGN
# Reading:  ADS
# Reading:  LNT
# Reading:  ALL
# Reading:  GOOGL
# Reading:  GOOG
# Reading:  MO
# Reading:  AMZN
# Reading:  AEE
# Reading:  AAL
# Reading:  AEP
# Reading:  AXP
# Reading:  AIG
# Reading:  AMT
# Reading:  AWK
# Reading:  AMP
# Reading:  ABC
# Reading:  AME
# Reading:  AMGN
# Reading:  APH
# Reading:  APC
# Reading:  ADI
# Reading:  ANDV
# Reading:  ANSS
# Reading:  ANTM
# Reading:  AON
# Reading:  AOS
# Reading:  APA
# Reading:  AIV
# Reading:  AAPL
# Reading:  AMAT
# Reading:  APTV
# Reading:  ADM
# Reading:  ARNC
# Reading:  AJG
# Reading:  AIZ
# Reading:  T
# Reading:  ADSK
# Reading:  ADP
# Reading:  AZO
# Reading:  AVB
# Reading:  AVY
# Reading:  BHGE
# Reading:  BLL
# Reading:  BAC
# Reading:  BK
# Reading:  BAX
# Reading:  BBT
# Reading:  BDX
# Reading:  BRK.B
# Reading:  BBY
# Reading:  BIIB
# Reading:  BLK
# Reading:  HRB
# Reading:  BA
# Reading:  BWA
# Reading:  BXP
# Reading:  BSX
# Reading:  BHF
# Reading:  BMY
# Reading:  AVGO
# Reading:  BF.B
# Reading:  CHRW
# Reading:  CA
# Reading:  COG
# Reading:  CDNS
# Reading:  CPB
# Reading:  COF
# Reading:  CAH
# Reading:  CBOE
# Reading:  KMX
# Reading:  CCL
# Reading:  CAT
# Reading:  CBG
# Reading:  CBS
# Reading:  CELG
# Reading:  CNC
# Reading:  CNP
# Reading:  CTL
# Reading:  CERN
# Reading:  CF
# Reading:  SCHW
# Reading:  CHTR
# Reading:  CHK
# Reading:  CVX
# Reading:  CMG
# Reading:  CB
# Reading:  CHD
# Reading:  CI
# Reading:  XEC
# Reading:  CINF
# Reading:  CTAS
# Reading:  CSCO
# Reading:  C
# Reading:  CFG
# Reading:  CTXS
# Reading:  CLX
# Reading:  CME
# Reading:  CMS
# Reading:  KO
# Reading:  CTSH
# Reading:  CL
# Reading:  CMCSA
# Reading:  CMA
# Reading:  CAG
# Reading:  CXO
# Reading:  COP
# Reading:  ED
# Reading:  STZ
# Reading:  COO
# Reading:  GLW
# Reading:  COST
# Reading:  COTY
# Reading:  CCI
# Reading:  CSRA
# Reading:  CSX
# Reading:  CMI
# Reading:  CVS
# Reading:  DHI
# Reading:  DHR
# Reading:  DRI
# Reading:  DVA
# Reading:  DE
# Reading:  DAL
# Reading:  XRAY
# Reading:  DVN
# Reading:  DLR
# Reading:  DFS
# Reading:  DISCA
# Reading:  DISCK
# Reading:  DISH
# Reading:  DG
# Reading:  DLTR
# Reading:  D
# Reading:  DOV
# Reading:  DWDP
# Reading:  DPS
# Reading:  DTE
# Reading:  DRE
# Reading:  DUK
# Reading:  DXC
# Reading:  ETFC
# Reading:  EMN
# Reading:  ETN
# Reading:  EBAY
# Reading:  ECL
# Reading:  EIX
# Reading:  EW
# Reading:  EA
# Reading:  EMR
# Reading:  ETR
# Reading:  EVHC
# Reading:  EOG
# Reading:  EQT
# Reading:  EFX
# Reading:  EQIX
# Reading:  EQR
# Reading:  ESS
# Reading:  EL
# Reading:  ES
# Reading:  RE
# Reading:  EXC
# Reading:  EXPE
# Reading:  EXPD
# Reading:  ESRX
# Reading:  EXR
# Reading:  XOM
# Reading:  FFIV
# Reading:  FB
# Reading:  FAST
# Reading:  FRT
# Reading:  FDX
# Reading:  FIS
# Reading:  FITB
# Reading:  FE
# Reading:  FISV
# Reading:  FLIR
# Reading:  FLS
# Reading:  FLR
# Reading:  FMC
# Reading:  FL
# Reading:  F
# Reading:  FTV
# Reading:  FBHS
# Reading:  BEN
# Reading:  FCX
# Reading:  GPS
# Reading:  GRMN
# Reading:  IT
# Reading:  GD
# Reading:  GE
# Reading:  GGP
# Reading:  GIS
# Reading:  GM
# Reading:  GPC
# Reading:  GILD
# Reading:  GPN
# Reading:  GS
# Reading:  GT
# Reading:  GWW
# Reading:  HAL
# Reading:  HBI
# Reading:  HOG
# Reading:  HRS
# Reading:  HIG
# Reading:  HAS
# Reading:  HCA
# Reading:  HCP
# Reading:  HP
# Reading:  HSIC
# Reading:  HSY
# Reading:  HES
# Reading:  HPE
# Reading:  HLT
# Reading:  HOLX
# Reading:  HD
# Reading:  HON
# Reading:  HRL
# Reading:  HST
# Reading:  HPQ
# Reading:  HUM
# Reading:  HBAN
# Reading:  IDXX
# Reading:  INFO
# Reading:  ITW
# Reading:  ILMN
# Reading:  IR
# Reading:  INTC
# Reading:  ICE
# Reading:  IBM
# Reading:  INCY
# Reading:  IP
# Reading:  IPG
# Reading:  IFF
# Reading:  INTU
# Reading:  ISRG
# Reading:  IVZ
# Reading:  IQV
# Reading:  IRM
# Reading:  JEC
# Reading:  JBHT
# Reading:  SJM
# Reading:  JNJ
# Reading:  JCI
# Reading:  JPM
# Reading:  JNPR
# Reading:  KSU
# Reading:  K
# Reading:  KEY
# Reading:  KMB
# Reading:  KIM
# Reading:  KMI
# Reading:  KLAC
# Reading:  KSS
# Reading:  KHC
# Reading:  KR
# Reading:  LB
# Reading:  LLL
# Reading:  LH
# Reading:  LRCX
# Reading:  LEG
# Reading:  LEN
# Reading:  LUK
# Reading:  LLY
# Reading:  LNC
# Reading:  LKQ
# Reading:  LMT
# Reading:  L
# Reading:  LOW
# Reading:  LYB
# Reading:  MTB
# Reading:  MAC
# Reading:  M
# Reading:  MRO
# Reading:  MPC
# Reading:  MAR
# Reading:  MMC
# Reading:  MLM
# Reading:  MAS
# Reading:  MA
# Reading:  MAT
# Reading:  MKC
# Reading:  MCD
# Reading:  MCK
# Reading:  MDT
# Reading:  MRK
# Reading:  MET
# Reading:  MTD
# Reading:  MGM
# Reading:  KORS
# Reading:  MCHP
# Reading:  MU
# Reading:  MSFT
# Reading:  MAA
# Reading:  MHK
# Reading:  TAP
# Reading:  MDLZ
# Reading:  MON
# Reading:  MNST
# Reading:  MCO
# Reading:  MS
# Reading:  MOS
# Reading:  MSI
# Reading:  MYL
# Reading:  NDAQ
# Reading:  NOV
# Reading:  NAVI
# Reading:  NTAP
# Reading:  NFLX
# Reading:  NWL
# Reading:  NFX
# Reading:  NEM
# Reading:  NWSA
# Reading:  NWS
# Reading:  NEE
# Reading:  NLSN
# Reading:  NKE
# Reading:  NI
# Reading:  NBL
# Reading:  JWN
# Reading:  NSC
# Reading:  NTRS
# Reading:  NOC
# Reading:  NCLH
# Reading:  NRG
# Reading:  NUE
# Reading:  NVDA
# Reading:  ORLY
# Reading:  OXY
# Reading:  OMC
# Reading:  OKE
# Reading:  ORCL
# Reading:  PCAR
# Reading:  PKG
# Reading:  PH
# Reading:  PDCO
# Reading:  PAYX
# Reading:  PYPL
# Reading:  PNR
# Reading:  PBCT
# Reading:  PEP
# Reading:  PKI
# Reading:  PRGO
# Reading:  PFE
# Reading:  PCG
# Reading:  PM
# Reading:  PSX
# Reading:  PNW
# Reading:  PXD
# Reading:  PNC
# Reading:  RL
# Reading:  PPG
# Reading:  PPL
# Reading:  PX
# Reading:  PCLN
# Reading:  PFG
# Reading:  PG
# Reading:  PGR
# Reading:  PLD
# Reading:  PRU
# Reading:  PEG
# Reading:  PSA
# Reading:  PHM
# Reading:  PVH
# Reading:  QRVO
# Reading:  PWR
# Reading:  QCOM
# Reading:  DGX
# Reading:  RRC
# Reading:  RJF
# Reading:  RTN
# Reading:  O
# Reading:  RHT
# Reading:  REG
# Reading:  REGN
# Reading:  RF
# Reading:  RSG
# Reading:  RMD
# Reading:  RHI
# Reading:  ROK
# Reading:  COL
# Reading:  ROP
# Reading:  ROST
# Reading:  RCL
# Reading:  CRM
# Reading:  SBAC
# Reading:  SCG
# Reading:  SLB
# Reading:  SNI
# Reading:  STX
# Reading:  SEE
# Reading:  SRE
# Reading:  SHW
# Reading:  SIG
# Reading:  SPG
# Reading:  SWKS
# Reading:  SLG
# Reading:  SNA
# Reading:  SO
# Reading:  LUV
# Reading:  SPGI
# Reading:  SWK
# Reading:  SBUX
# Reading:  STT
# Reading:  SRCL
# Reading:  SYK
# Reading:  STI
# Reading:  SYMC
# Reading:  SYF
# Reading:  SNPS
# Reading:  SYY
# Reading:  TROW
# Reading:  TPR
# Reading:  TGT
# Reading:  TEL
# Reading:  FTI
# Reading:  TXN
# Reading:  TXT
# Reading:  TMO
# Reading:  TIF
# Reading:  TWX
# Reading:  TJX
# Reading:  TMK
# Reading:  TSS
# Reading:  TSCO
# Reading:  TDG
# Reading:  TRV
# Reading:  TRIP
# Reading:  FOXA
# Reading:  FOX
# Reading:  TSN
# Reading:  UDR
# Reading:  ULTA
# Reading:  USB
# Reading:  UA
# Reading:  UAA
# Reading:  UNP
# Reading:  UAL
# Reading:  UNH
# Reading:  UPS
# Reading:  URI
# Reading:  UTX
# Reading:  UHS
# Reading:  UNM
# Reading:  VFC
# Reading:  VLO
# Reading:  VAR
# Reading:  VTR
# Reading:  VRSN
# Reading:  VRSK
# Reading:  VZ
# Reading:  VRTX
# Reading:  VIAB
# Reading:  V
# Reading:  VNO
# Reading:  VMC
# Reading:  WMT
# Reading:  WBA
# Reading:  DIS
# Reading:  WM
# Reading:  WAT
# Reading:  WEC
# Reading:  WFC
# Reading:  HCN
# Reading:  WDC
# Reading:  WU
# Reading:  WRK
# Reading:  WY
# Reading:  WHR
# Reading:  WMB
# Reading:  WLTW
# Reading:  WYN
# Reading:  WYNN
# Reading:  XEL
# Reading:  XRX
# Reading:  XLNX
# Reading:  XL
# Reading:  XYL
# Reading:  YUM
# Reading:  ZBH
# Reading:  ZION
# Reading:  ZTS

# %%
tickers = pd.concat(ticker_df_list)

# %%
signal_record = []
for ticker in analysis_tickers:
    print("Calculating Signal for: ", ticker)
    try:
        single_ticker_df = tickers[tickers['Ticker']==ticker]
        signal_df = MACD(single_ticker_df, 12, 26, 9)
        last_signal = signal_df[['Ticker','MACD_signal']].values[-1]
        signal_record.append(last_signal)
    except:
        pass
# Out:
# Calculating Signal for:  MMM
# Calculating Signal for:  ABT
# Calculating Signal for:  ABBV
# Calculating Signal for:  ACN
# Calculating Signal for:  ATVI
# Calculating Signal for:  AYI
# Calculating Signal for:  ADBE
# Calculating Signal for:  AMD
# Calculating Signal for:  HII
# Calculating Signal for:  AAP
# Calculating Signal for:  AES
# Calculating Signal for:  AET
# Calculating Signal for:  AMG
# Calculating Signal for:  AFL
# Calculating Signal for:  A
# Calculating Signal for:  APD
# Calculating Signal for:  AKAM
# Calculating Signal for:  ALK
# Calculating Signal for:  ALB
# Calculating Signal for:  ARE
# Calculating Signal for:  ALXN
# Calculating Signal for:  ALGN
# Calculating Signal for:  ALLE
# Calculating Signal for:  AGN
# Calculating Signal for:  ADS
# Calculating Signal for:  LNT
# Calculating Signal for:  ALL
# Calculating Signal for:  GOOGL
# Calculating Signal for:  GOOG
# Calculating Signal for:  MO
# Calculating Signal for:  AMZN
# Calculating Signal for:  AEE
# Calculating Signal for:  AAL
# Calculating Signal for:  AEP
# Calculating Signal for:  AXP
# Calculating Signal for:  AIG
# Calculating Signal for:  AMT
# Calculating Signal for:  AWK
# Calculating Signal for:  AMP
# Calculating Signal for:  ABC
# Calculating Signal for:  AME
# Calculating Signal for:  AMGN
# Calculating Signal for:  APH
# Calculating Signal for:  APC
# Calculating Signal for:  ADI
# Calculating Signal for:  ANDV
# Calculating Signal for:  ANSS
# Calculating Signal for:  ANTM
# Calculating Signal for:  AON
# Calculating Signal for:  AOS
# Calculating Signal for:  APA
# Calculating Signal for:  AIV
# Calculating Signal for:  AAPL
# Calculating Signal for:  AMAT
# Calculating Signal for:  APTV
# Calculating Signal for:  ADM
# Calculating Signal for:  ARNC
# Calculating Signal for:  AJG
# Calculating Signal for:  AIZ
# Calculating Signal for:  T
# Calculating Signal for:  ADSK
# Calculating Signal for:  ADP
# Calculating Signal for:  AZO
# Calculating Signal for:  AVB
# Calculating Signal for:  AVY
# Calculating Signal for:  BHGE
# Calculating Signal for:  BLL
# Calculating Signal for:  BAC
# Calculating Signal for:  BK
# Calculating Signal for:  BAX
# Calculating Signal for:  BBT
# Calculating Signal for:  BDX
# Calculating Signal for:  BRK.B
# Calculating Signal for:  BBY
# Calculating Signal for:  BIIB
# Calculating Signal for:  BLK
# Calculating Signal for:  HRB
# Calculating Signal for:  BA
# Calculating Signal for:  BWA
# Calculating Signal for:  BXP
# Calculating Signal for:  BSX
# Calculating Signal for:  BHF
# Calculating Signal for:  BMY
# Calculating Signal for:  AVGO
# Calculating Signal for:  BF.B
# Calculating Signal for:  CHRW
# Calculating Signal for:  CA
# Calculating Signal for:  COG
# Calculating Signal for:  CDNS
# Calculating Signal for:  CPB
# Calculating Signal for:  COF
# Calculating Signal for:  CAH
# Calculating Signal for:  CBOE
# Calculating Signal for:  KMX
# Calculating Signal for:  CCL
# Calculating Signal for:  CAT
# Calculating Signal for:  CBG
# Calculating Signal for:  CBS
# Calculating Signal for:  CELG
# Calculating Signal for:  CNC
# Calculating Signal for:  CNP
# Calculating Signal for:  CTL
# Calculating Signal for:  CERN
# Calculating Signal for:  CF
# Calculating Signal for:  SCHW
# Calculating Signal for:  CHTR
# Calculating Signal for:  CHK
# Calculating Signal for:  CVX
# Calculating Signal for:  CMG
# Calculating Signal for:  CB
# Calculating Signal for:  CHD
# Calculating Signal for:  CI
# Calculating Signal for:  XEC
# Calculating Signal for:  CINF
# Calculating Signal for:  CTAS
# Calculating Signal for:  CSCO
# Calculating Signal for:  C
# Calculating Signal for:  CFG
# Calculating Signal for:  CTXS
# Calculating Signal for:  CLX
# Calculating Signal for:  CME
# Calculating Signal for:  CMS
# Calculating Signal for:  KO
# Calculating Signal for:  CTSH
# Calculating Signal for:  CL
# Calculating Signal for:  CMCSA
# Calculating Signal for:  CMA
# Calculating Signal for:  CAG
# Calculating Signal for:  CXO
# Calculating Signal for:  COP
# Calculating Signal for:  ED
# Calculating Signal for:  STZ
# Calculating Signal for:  COO
# Calculating Signal for:  GLW
# Calculating Signal for:  COST
# Calculating Signal for:  COTY
# Calculating Signal for:  CCI
# Calculating Signal for:  CSRA
# Calculating Signal for:  CSX
# Calculating Signal for:  CMI
# Calculating Signal for:  CVS
# Calculating Signal for:  DHI
# Calculating Signal for:  DHR
# Calculating Signal for:  DRI
# Calculating Signal for:  DVA
# Calculating Signal for:  DE
# Calculating Signal for:  DAL
# Calculating Signal for:  XRAY
# Calculating Signal for:  DVN
# Calculating Signal for:  DLR
# Calculating Signal for:  DFS
# Calculating Signal for:  DISCA
# Calculating Signal for:  DISCK
# Calculating Signal for:  DISH
# Calculating Signal for:  DG
# Calculating Signal for:  DLTR
# Calculating Signal for:  D
# Calculating Signal for:  DOV
# Calculating Signal for:  DWDP
# Calculating Signal for:  DPS
# Calculating Signal for:  DTE
# Calculating Signal for:  DRE
# Calculating Signal for:  DUK
# Calculating Signal for:  DXC
# Calculating Signal for:  ETFC
# Calculating Signal for:  EMN
# Calculating Signal for:  ETN
# Calculating Signal for:  EBAY
# Calculating Signal for:  ECL
# Calculating Signal for:  EIX
# Calculating Signal for:  EW
# Calculating Signal for:  EA
# Calculating Signal for:  EMR
# Calculating Signal for:  ETR
# Calculating Signal for:  EVHC
# Calculating Signal for:  EOG
# Calculating Signal for:  EQT
# Calculating Signal for:  EFX
# Calculating Signal for:  EQIX
# Calculating Signal for:  EQR
# Calculating Signal for:  ESS
# Calculating Signal for:  EL
# Calculating Signal for:  ES
# Calculating Signal for:  RE
# Calculating Signal for:  EXC
# Calculating Signal for:  EXPE
# Calculating Signal for:  EXPD
# Calculating Signal for:  ESRX
# Calculating Signal for:  EXR
# Calculating Signal for:  XOM
# Calculating Signal for:  FFIV
# Calculating Signal for:  FB
# Calculating Signal for:  FAST
# Calculating Signal for:  FRT
# Calculating Signal for:  FDX
# Calculating Signal for:  FIS
# Calculating Signal for:  FITB
# Calculating Signal for:  FE
# Calculating Signal for:  FISV
# Calculating Signal for:  FLIR
# Calculating Signal for:  FLS
# Calculating Signal for:  FLR
# Calculating Signal for:  FMC
# Calculating Signal for:  FL
# Calculating Signal for:  F
# Calculating Signal for:  FTV
# Calculating Signal for:  FBHS
# Calculating Signal for:  BEN
# Calculating Signal for:  FCX
# Calculating Signal for:  GPS
# Calculating Signal for:  GRMN
# Calculating Signal for:  IT
# Calculating Signal for:  GD
# Calculating Signal for:  GE
# Calculating Signal for:  GGP
# Calculating Signal for:  GIS
# Calculating Signal for:  GM
# Calculating Signal for:  GPC
# Calculating Signal for:  GILD
# Calculating Signal for:  GPN
# Calculating Signal for:  GS
# Calculating Signal for:  GT
# Calculating Signal for:  GWW
# Calculating Signal for:  HAL
# Calculating Signal for:  HBI
# Calculating Signal for:  HOG
# Calculating Signal for:  HRS
# Calculating Signal for:  HIG
# Calculating Signal for:  HAS
# Calculating Signal for:  HCA
# Calculating Signal for:  HCP
# Calculating Signal for:  HP
# Calculating Signal for:  HSIC
# Calculating Signal for:  HSY
# Calculating Signal for:  HES
# Calculating Signal for:  HPE
# Calculating Signal for:  HLT
# Calculating Signal for:  HOLX
# Calculating Signal for:  HD
# Calculating Signal for:  HON
# Calculating Signal for:  HRL
# Calculating Signal for:  HST
# Calculating Signal for:  HPQ
# Calculating Signal for:  HUM
# Calculating Signal for:  HBAN
# Calculating Signal for:  IDXX
# Calculating Signal for:  INFO
# Calculating Signal for:  ITW
# Calculating Signal for:  ILMN
# Calculating Signal for:  IR
# Calculating Signal for:  INTC
# Calculating Signal for:  ICE
# Calculating Signal for:  IBM
# Calculating Signal for:  INCY
# Calculating Signal for:  IP
# Calculating Signal for:  IPG
# Calculating Signal for:  IFF
# Calculating Signal for:  INTU
# Calculating Signal for:  ISRG
# Calculating Signal for:  IVZ
# Calculating Signal for:  IQV
# Calculating Signal for:  IRM
# Calculating Signal for:  JEC
# Calculating Signal for:  JBHT
# Calculating Signal for:  SJM
# Calculating Signal for:  JNJ
# Calculating Signal for:  JCI
# Calculating Signal for:  JPM
# Calculating Signal for:  JNPR
# Calculating Signal for:  KSU
# Calculating Signal for:  K
# Calculating Signal for:  KEY
# Calculating Signal for:  KMB
# Calculating Signal for:  KIM
# Calculating Signal for:  KMI
# Calculating Signal for:  KLAC
# Calculating Signal for:  KSS
# Calculating Signal for:  KHC
# Calculating Signal for:  KR
# Calculating Signal for:  LB
# Calculating Signal for:  LLL
# Calculating Signal for:  LH
# Calculating Signal for:  LRCX
# Calculating Signal for:  LEG
# Calculating Signal for:  LEN
# Calculating Signal for:  LUK
# Calculating Signal for:  LLY
# Calculating Signal for:  LNC
# Calculating Signal for:  LKQ
# Calculating Signal for:  LMT
# Calculating Signal for:  L
# Calculating Signal for:  LOW
# Calculating Signal for:  LYB
# Calculating Signal for:  MTB
# Calculating Signal for:  MAC
# Calculating Signal for:  M
# Calculating Signal for:  MRO
# Calculating Signal for:  MPC
# Calculating Signal for:  MAR
# Calculating Signal for:  MMC
# Calculating Signal for:  MLM
# Calculating Signal for:  MAS
# Calculating Signal for:  MA
# Calculating Signal for:  MAT
# Calculating Signal for:  MKC
# Calculating Signal for:  MCD
# Calculating Signal for:  MCK
# Calculating Signal for:  MDT
# Calculating Signal for:  MRK
# Calculating Signal for:  MET
# Calculating Signal for:  MTD
# Calculating Signal for:  MGM
# Calculating Signal for:  KORS
# Calculating Signal for:  MCHP
# Calculating Signal for:  MU
# Calculating Signal for:  MSFT
# Calculating Signal for:  MAA
# Calculating Signal for:  MHK
# Calculating Signal for:  TAP
# Calculating Signal for:  MDLZ
# Calculating Signal for:  MON
# Calculating Signal for:  MNST
# Calculating Signal for:  MCO
# Calculating Signal for:  MS
# Calculating Signal for:  MOS
# Calculating Signal for:  MSI
# Calculating Signal for:  MYL
# Calculating Signal for:  NDAQ
# Calculating Signal for:  NOV
# Calculating Signal for:  NAVI
# Calculating Signal for:  NTAP
# Calculating Signal for:  NFLX
# Calculating Signal for:  NWL
# Calculating Signal for:  NFX
# Calculating Signal for:  NEM
# Calculating Signal for:  NWSA
# Calculating Signal for:  NWS
# Calculating Signal for:  NEE
# Calculating Signal for:  NLSN
# Calculating Signal for:  NKE
# Calculating Signal for:  NI
# Calculating Signal for:  NBL
# Calculating Signal for:  JWN
# Calculating Signal for:  NSC
# Calculating Signal for:  NTRS
# Calculating Signal for:  NOC
# Calculating Signal for:  NCLH
# Calculating Signal for:  NRG
# Calculating Signal for:  NUE
# Calculating Signal for:  NVDA
# Calculating Signal for:  ORLY
# Calculating Signal for:  OXY
# Calculating Signal for:  OMC
# Calculating Signal for:  OKE
# Calculating Signal for:  ORCL
# Calculating Signal for:  PCAR
# Calculating Signal for:  PKG
# Calculating Signal for:  PH
# Calculating Signal for:  PDCO
# Calculating Signal for:  PAYX
# Calculating Signal for:  PYPL
# Calculating Signal for:  PNR
# Calculating Signal for:  PBCT
# Calculating Signal for:  PEP
# Calculating Signal for:  PKI
# Calculating Signal for:  PRGO
# Calculating Signal for:  PFE
# Calculating Signal for:  PCG
# Calculating Signal for:  PM
# Calculating Signal for:  PSX
# Calculating Signal for:  PNW
# Calculating Signal for:  PXD
# Calculating Signal for:  PNC
# Calculating Signal for:  RL
# Calculating Signal for:  PPG
# Calculating Signal for:  PPL
# Calculating Signal for:  PX
# Calculating Signal for:  PCLN
# Calculating Signal for:  PFG
# Calculating Signal for:  PG
# Calculating Signal for:  PGR
# Calculating Signal for:  PLD
# Calculating Signal for:  PRU
# Calculating Signal for:  PEG
# Calculating Signal for:  PSA
# Calculating Signal for:  PHM
# Calculating Signal for:  PVH
# Calculating Signal for:  QRVO
# Calculating Signal for:  PWR
# Calculating Signal for:  QCOM
# Calculating Signal for:  DGX
# Calculating Signal for:  RRC
# Calculating Signal for:  RJF
# Calculating Signal for:  RTN
# Calculating Signal for:  O
# Calculating Signal for:  RHT
# Calculating Signal for:  REG
# Calculating Signal for:  REGN
# Calculating Signal for:  RF
# Calculating Signal for:  RSG
# Calculating Signal for:  RMD
# Calculating Signal for:  RHI
# Calculating Signal for:  ROK
# Calculating Signal for:  COL
# Calculating Signal for:  ROP
# Calculating Signal for:  ROST
# Calculating Signal for:  RCL
# Calculating Signal for:  CRM
# Calculating Signal for:  SBAC
# Calculating Signal for:  SCG
# Calculating Signal for:  SLB
# Calculating Signal for:  SNI
# Calculating Signal for:  STX
# Calculating Signal for:  SEE
# Calculating Signal for:  SRE
# Calculating Signal for:  SHW
# Calculating Signal for:  SIG
# Calculating Signal for:  SPG
# Calculating Signal for:  SWKS
# Calculating Signal for:  SLG
# Calculating Signal for:  SNA
# Calculating Signal for:  SO
# Calculating Signal for:  LUV
# Calculating Signal for:  SPGI
# Calculating Signal for:  SWK
# Calculating Signal for:  SBUX
# Calculating Signal for:  STT
# Calculating Signal for:  SRCL
# Calculating Signal for:  SYK
# Calculating Signal for:  STI
# Calculating Signal for:  SYMC
# Calculating Signal for:  SYF
# Calculating Signal for:  SNPS
# Calculating Signal for:  SYY
# Calculating Signal for:  TROW
# Calculating Signal for:  TPR
# Calculating Signal for:  TGT
# Calculating Signal for:  TEL
# Calculating Signal for:  FTI
# Calculating Signal for:  TXN
# Calculating Signal for:  TXT
# Calculating Signal for:  TMO
# Calculating Signal for:  TIF
# Calculating Signal for:  TWX
# Calculating Signal for:  TJX
# Calculating Signal for:  TMK
# Calculating Signal for:  TSS
# Calculating Signal for:  TSCO
# Calculating Signal for:  TDG
# Calculating Signal for:  TRV
# Calculating Signal for:  TRIP
# Calculating Signal for:  FOXA
# Calculating Signal for:  FOX
# Calculating Signal for:  TSN
# Calculating Signal for:  UDR
# Calculating Signal for:  ULTA
# Calculating Signal for:  USB
# Calculating Signal for:  UA
# Calculating Signal for:  UAA
# Calculating Signal for:  UNP
# Calculating Signal for:  UAL
# Calculating Signal for:  UNH
# Calculating Signal for:  UPS
# Calculating Signal for:  URI
# Calculating Signal for:  UTX
# Calculating Signal for:  UHS
# Calculating Signal for:  UNM
# Calculating Signal for:  VFC
# Calculating Signal for:  VLO
# Calculating Signal for:  VAR
# Calculating Signal for:  VTR
# Calculating Signal for:  VRSN
# Calculating Signal for:  VRSK
# Calculating Signal for:  VZ
# Calculating Signal for:  VRTX
# Calculating Signal for:  VIAB
# Calculating Signal for:  V
# Calculating Signal for:  VNO
# Calculating Signal for:  VMC
# Calculating Signal for:  WMT
# Calculating Signal for:  WBA
# Calculating Signal for:  DIS
# Calculating Signal for:  WM
# Calculating Signal for:  WAT
# Calculating Signal for:  WEC
# Calculating Signal for:  WFC
# Calculating Signal for:  HCN
# Calculating Signal for:  WDC
# Calculating Signal for:  WU
# Calculating Signal for:  WRK
# Calculating Signal for:  WY
# Calculating Signal for:  WHR
# Calculating Signal for:  WMB
# Calculating Signal for:  WLTW
# Calculating Signal for:  WYN
# Calculating Signal for:  WYNN
# Calculating Signal for:  XEL
# Calculating Signal for:  XRX
# Calculating Signal for:  XLNX
# Calculating Signal for:  XL
# Calculating Signal for:  XYL
# Calculating Signal for:  YUM
# Calculating Signal for:  ZBH
# Calculating Signal for:  ZION
# Calculating Signal for:  ZTS
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
signal_record
# Out:
# [array(['MMM', '空头信号'], dtype=object),
#  array(['ABT', '多头信号'], dtype=object),
#  array(['ABBV', '多头信号'], dtype=object),
#  array(['ACN', '多头信号'], dtype=object),
#  array(['ATVI', '空头信号'], dtype=object),
#  array(['AYI', '空头信号'], dtype=object),
#  array(['ADBE', '多头信号'], dtype=object),
#  array(['AMD', '多头信号'], dtype=object),
#  array(['HII', '多头信号'], dtype=object),
#  array(['AAP', '空头信号'], dtype=object),
#  array(['AES', '多头信号'], dtype=object),
#  array(['AMG', '多头信号'], dtype=object),
#  array(['AFL', '多头信号'], dtype=object),
#  array(['A', '多头信号'], dtype=object),
#  array(['APD', '多头信号'], dtype=object),
#  array(['AKAM', '空头信号'], dtype=object),
#  array(['ALK', '空头信号'], dtype=object),
#  array(['ALB', '多头信号'], dtype=object),
#  array(['ARE', '空头信号'], dtype=object),
#  array(['ALXN', '空头信号'], dtype=object),
#  array(['ALGN', '空头信号'], dtype=object),
#  array(['ALLE', '空头信号'], dtype=object),
#  array(['AGN', '多头信号'], dtype=object),
#  array(['ADS', '多头信号'], dtype=object),
#  array(['LNT', '多头信号'], dtype=object),
#  array(['ALL', '多头信号'], dtype=object),
#  array(['GOOGL', '多头信号'], dtype=object),
#  array(['GOOG', '多头信号'], dtype=object),
#  array(['MO', '空头信号'], dtype=object),
#  array(['AMZN', '空头信号'], dtype=object),
#  array(['AEE', '空头信号'], dtype=object),
#  array(['AAL', '空头信号'], dtype=object),
#  array(['AEP', '空头信号'], dtype=object),
#  array(['AXP', '多头信号'], dtype=object),
#  array(['AIG', '多头信号'], dtype=object),
#  array(['AMT', '空头信号'], dtype=object),
#  array(['AWK', '空头信号'], dtype=object),
#  array(['AMP', '多头信号'], dtype=object),
#  array(['ABC', '空头信号'], dtype=object),
#  array(['AME', '多头信号'], dtype=object),
#  array(['AMGN', '多头信号'], dtype=object),
#  array(['APH', '空头信号'], dtype=object),
#  array(['ADI', '多头信号'], dtype=object),
#  array(['ANDV', '空头信号'], dtype=object),
#  array(['ANSS', '多头信号'], dtype=object),
#  array(['ANTM', '多头信号'], dtype=object),
#  array(['AON', '多头信号'], dtype=object),
#  array(['AOS', '空头信号'], dtype=object),
#  array(['APA', '多头信号'], dtype=object),
#  array(['AIV', '空头信号'], dtype=object),
#  array(['AAPL', '多头信号'], dtype=object),
#  array(['AMAT', '多头信号'], dtype=object),
#  array(['APTV', '空头信号'], dtype=object),
#  array(['ADM', '多头信号'], dtype=object),
#  array(['ARNC', '多头信号'], dtype=object),
#  array(['AJG', '多头信号'], dtype=object),
#  array(['AIZ', '多头信号'], dtype=object),
#  array(['T', '空头信号'], dtype=object),
#  array(['ADSK', '多头信号'], dtype=object),
#  array(['ADP', '多头信号'], dtype=object),
#  array(['AZO', '多头信号'], dtype=object),
#  array(['AVB', '空头信号'], dtype=object),
#  array(['AVY', '空头信号'], dtype=object),
#  array(['BHGE', '多头信号'], dtype=object),
#  array(['BLL', '空头信号'], dtype=object),
#  array(['BAC', '空头信号'], dtype=object),
#  array(['BK', '多头信号'], dtype=object),
#  array(['BAX', '多头信号'], dtype=object),
#  array(['BBT', '空头信号'], dtype=object),
#  array(['BDX', '空头信号'], dtype=object),
#  array(['BBY', '空头信号'], dtype=object),
#  array(['BIIB', '空头信号'], dtype=object),
#  array(['BLK', '多头信号'], dtype=object),
#  array(['HRB', '空头信号'], dtype=object),
#  array(['BA', '多头信号'], dtype=object),
#  array(['BWA', '多头信号'], dtype=object),
#  array(['BXP', '空头信号'], dtype=object),
#  array(['BSX', '多头信号'], dtype=object),
#  array(['BHF', '多头信号'], dtype=object),
#  array(['BMY', '多头信号'], dtype=object),
#  array(['AVGO', '多头信号'], dtype=object),
#  array(['CHRW', '空头信号'], dtype=object),
#  array(['CA', '多头信号'], dtype=object),
#  array(['COG', '空头信号'], dtype=object),
#  array(['CDNS', '多头信号'], dtype=object),
#  array(['CPB', '空头信号'], dtype=object),
#  array(['COF', '多头信号'], dtype=object),
#  array(['CAH', '多头信号'], dtype=object),
#  array(['CBOE', '多头信号'], dtype=object),
#  array(['KMX', '空头信号'], dtype=object),
#  array(['CCL', '多头信号'], dtype=object),
#  array(['CAT', '空头信号'], dtype=object),
#  array(['CBS', '多头信号'], dtype=object),
#  array(['CELG', '多头信号'], dtype=object),
#  array(['CNC', '多头信号'], dtype=object),
#  array(['CNP', '空头信号'], dtype=object),
#  array(['CTL', '多头信号'], dtype=object),
#  array(['CERN', '空头信号'], dtype=object),
#  array(['CF', '多头信号'], dtype=object),
#  array(['SCHW', '多头信号'], dtype=object),
#  array(['CHTR', '多头信号'], dtype=object),
#  array(['CHK', '空头信号'], dtype=object),
#  array(['CVX', '多头信号'], dtype=object),
#  array(['CMG', '空头信号'], dtype=object),
#  array(['CB', '多头信号'], dtype=object),
#  array(['CHD', '空头信号'], dtype=object),
#  array(['CI', '多头信号'], dtype=object),
#  array(['XEC', '多头信号'], dtype=object),
#  array(['CINF', '空头信号'], dtype=object),
#  array(['CTAS', '空头信号'], dtype=object),
#  array(['CSCO', '空头信号'], dtype=object),
#  array(['C', '空头信号'], dtype=object),
#  array(['CFG', '多头信号'], dtype=object),
#  array(['CTXS', '空头信号'], dtype=object),
#  array(['CLX', '空头信号'], dtype=object),
#  array(['CME', '多头信号'], dtype=object),
#  array(['CMS', '空头信号'], dtype=object),
#  array(['KO', '空头信号'], dtype=object),
#  array(['CTSH', '多头信号'], dtype=object),
#  array(['CL', '多头信号'], dtype=object),
#  array(['CMCSA', '多头信号'], dtype=object),
#  array(['CMA', '多头信号'], dtype=object),
#  array(['CAG', '多头信号'], dtype=object),
#  array(['CXO', '多头信号'], dtype=object),
#  array(['COP', '多头信号'], dtype=object),
#  array(['ED', '空头信号'], dtype=object),
#  array(['STZ', '空头信号'], dtype=object),
#  array(['COO', '多头信号'], dtype=object),
#  array(['GLW', '空头信号'], dtype=object),
#  array(['COST', '多头信号'], dtype=object),
#  array(['COTY', '空头信号'], dtype=object),
#  array(['CCI', '空头信号'], dtype=object),
#  array(['CSRA', '空仓信号'], dtype=object),
#  array(['CSX', '空头信号'], dtype=object),
#  array(['CMI', '空头信号'], dtype=object),
#  array(['CVS', '多头信号'], dtype=object),
#  array(['DHI', '多头信号'], dtype=object),
#  array(['DHR', '多头信号'], dtype=object),
#  array(['DRI', '多头信号'], dtype=object),
#  array(['DVA', '多头信号'], dtype=object),
#  array(['DE', '空头信号'], dtype=object),
#  array(['DAL', '多头信号'], dtype=object),
#  array(['XRAY', '多头信号'], dtype=object),
#  array(['DVN', '多头信号'], dtype=object),
#  array(['DLR', '空头信号'], dtype=object),
#  array(['DFS', '多头信号'], dtype=object),
#  array(['DISCA', '多头信号'], dtype=object),
#  array(['DISCK', '多头信号'], dtype=object),
#  array(['DISH', '多头信号'], dtype=object),
#  array(['DG', '空头信号'], dtype=object),
#  array(['DLTR', '空头信号'], dtype=object),
#  array(['D', '空头信号'], dtype=object),
#  array(['DOV', '多头信号'], dtype=object),
#  array(['DTE', '空头信号'], dtype=object),
#  array(['DRE', '空头信号'], dtype=object),
#  array(['DUK', '空头信号'], dtype=object),
#  array(['DXC', '多头信号'], dtype=object),
#  array(['ETFC', '多头信号'], dtype=object),
#  array(['EMN', '空头信号'], dtype=object),
#  array(['ETN', '多头信号'], dtype=object),
#  array(['EBAY', '空头信号'], dtype=object),
#  array(['ECL', '多头信号'], dtype=object),
#  array(['EIX', '多头信号'], dtype=object),
#  array(['EW', '多头信号'], dtype=object),
#  array(['EA', '空头信号'], dtype=object),
#  array(['EMR', '空头信号'], dtype=object),
#  array(['ETR', '空头信号'], dtype=object),
#  array(['EVHC', '空头信号'], dtype=object),
#  array(['EOG', '多头信号'], dtype=object),
#  array(['EQT', '多头信号'], dtype=object),
#  array(['EFX', '多头信号'], dtype=object),
#  array(['EQIX', '空头信号'], dtype=object),
#  array(['EQR', '空头信号'], dtype=object),
#  array(['ESS', '空头信号'], dtype=object),
#  array(['EL', '多头信号'], dtype=object),
#  array(['ES', '空头信号'], dtype=object),
#  array(['RE', '多头信号'], dtype=object),
#  array(['EXC', '空头信号'], dtype=object),
#  array(['EXPE', '空头信号'], dtype=object),
#  array(['EXPD', '多头信号'], dtype=object),
#  array(['EXR', '空头信号'], dtype=object),
#  array(['XOM', '空头信号'], dtype=object),
#  array(['FFIV', '空头信号'], dtype=object),
#  array(['FB', '多头信号'], dtype=object),
#  array(['FAST', '空头信号'], dtype=object),
#  array(['FRT', '空头信号'], dtype=object),
#  array(['FDX', '空头信号'], dtype=object),
#  array(['FIS', '多头信号'], dtype=object),
#  array(['FITB', '空头信号'], dtype=object),
#  array(['FE', '空头信号'], dtype=object),
#  array(['FISV', '多头信号'], dtype=object),
#  array(['FLIR', '空头信号'], dtype=object),
#  array(['FLS', '空头信号'], dtype=object),
#  array(['FLR', '空头信号'], dtype=object),
#  array(['FMC', '多头信号'], dtype=object),
#  array(['FL', '空头信号'], dtype=object),
#  array(['F', '多头信号'], dtype=object),
#  array(['FTV', '空头信号'], dtype=object),
#  array(['FBHS', '空头信号'], dtype=object),
#  array(['BEN', '空头信号'], dtype=object),
#  array(['FCX', '多头信号'], dtype=object),
#  array(['GPS', '空头信号'], dtype=object),
#  array(['GRMN', '多头信号'], dtype=object),
#  array(['IT', '多头信号'], dtype=object),
#  array(['GD', '多头信号'], dtype=object),
#  array(['GE', '多头信号'], dtype=object),
#  array(['GIS', '多头信号'], dtype=object),
#  array(['GM', '空头信号'], dtype=object),
#  array(['GPC', '空头信号'], dtype=object),
#  array(['GILD', '空头信号'], dtype=object),
#  array(['GPN', '多头信号'], dtype=object),
#  array(['GS', '多头信号'], dtype=object),
#  array(['GT', '空头信号'], dtype=object),
#  array(['GWW', '空头信号'], dtype=object),
#  array(['HAL', '多头信号'], dtype=object),
#  array(['HBI', '空头信号'], dtype=object),
#  array(['HOG', '空头信号'], dtype=object),
#  array(['HIG', '多头信号'], dtype=object),
#  array(['HAS', '多头信号'], dtype=object),
#  array(['HCA', '空头信号'], dtype=object),
#  array(['HCP', '空头信号'], dtype=object),
#  array(['HP', '多头信号'], dtype=object),
#  array(['HSIC', '多头信号'], dtype=object),
#  array(['HSY', '多头信号'], dtype=object),
#  array(['HES', '空头信号'], dtype=object),
#  array(['HPE', '多头信号'], dtype=object),
#  array(['HLT', '多头信号'], dtype=object),
#  array(['HOLX', '空头信号'], dtype=object),
#  array(['HD', '空头信号'], dtype=object),
#  array(['HON', '多头信号'], dtype=object),
#  array(['HRL', '多头信号'], dtype=object),
#  array(['HST', '多头信号'], dtype=object),
#  array(['HPQ', '多头信号'], dtype=object),
#  array(['HUM', '多头信号'], dtype=object),
#  array(['HBAN', '空头信号'], dtype=object),
#  array(['IDXX', '空头信号'], dtype=object),
#  array(['INFO', '多头信号'], dtype=object),
#  array(['ITW', '空头信号'], dtype=object),
#  array(['ILMN', '空头信号'], dtype=object),
#  array(['IR', '空头信号'], dtype=object),
#  array(['INTC', '多头信号'], dtype=object),
#  array(['ICE', '多头信号'], dtype=object),
#  array(['IBM', '多头信号'], dtype=object),
#  array(['INCY', '多头信号'], dtype=object),
#  array(['IP', '多头信号'], dtype=object),
#  array(['IPG', '空头信号'], dtype=object),
#  array(['IFF', '多头信号'], dtype=object),
#  array(['INTU', '多头信号'], dtype=object),
#  array(['ISRG', '空头信号'], dtype=object),
#  array(['IVZ', '多头信号'], dtype=object),
#  array(['IQV', '多头信号'], dtype=object),
#  array(['IRM', '空头信号'], dtype=object),
#  array(['JEC', '空头信号'], dtype=object),
#  array(['JBHT', '空头信号'], dtype=object),
#  array(['SJM', '空头信号'], dtype=object),
#  array(['JNJ', '多头信号'], dtype=object),
#  array(['JCI', '空头信号'], dtype=object),
#  array(['JPM', '空头信号'], dtype=object),
#  array(['JNPR', '多头信号'], dtype=object),
#  array(['KSU', '多头信号'], dtype=object),
#  array(['K', '多头信号'], dtype=object),
#  array(['KEY', '多头信号'], dtype=object),
#  array(['KMB', '多头信号'], dtype=object),
#  array(['KIM', '空头信号'], dtype=object),
#  array(['KMI', '多头信号'], dtype=object),
#  array(['KLAC', '多头信号'], dtype=object),
#  array(['KSS', '多头信号'], dtype=object),
#  array(['KHC', '多头信号'], dtype=object),
#  array(['KR', '多头信号'], dtype=object),
#  array(['LB', '多头信号'], dtype=object),
#  array(['LH', '多头信号'], dtype=object),
#  array(['LRCX', '空头信号'], dtype=object),
#  array(['LEG', '空头信号'], dtype=object),
#  array(['LEN', '空头信号'], dtype=object),
#  array(['LLY', '多头信号'], dtype=object),
#  array(['LNC', '空头信号'], dtype=object),
#  array(['LKQ', '多头信号'], dtype=object),
#  array(['LMT', '多头信号'], dtype=object),
#  array(['L', '多头信号'], dtype=object),
#  array(['LOW', '多头信号'], dtype=object),
#  array(['LYB', '多头信号'], dtype=object),
#  array(['MTB', '多头信号'], dtype=object),
#  array(['MAC', '多头信号'], dtype=object),
#  array(['M', '多头信号'], dtype=object),
#  array(['MRO', '空头信号'], dtype=object),
#  array(['MPC', '空头信号'], dtype=object),
#  array(['MAR', '多头信号'], dtype=object),
#  array(['MMC', '多头信号'], dtype=object),
#  array(['MLM', '空头信号'], dtype=object),
#  array(['MAS', '空头信号'], dtype=object),
#  array(['MA', '多头信号'], dtype=object),
#  array(['MAT', '多头信号'], dtype=object),
#  array(['MKC', '多头信号'], dtype=object),
#  array(['MCD', '多头信号'], dtype=object),
#  array(['MCK', '多头信号'], dtype=object),
#  array(['MDT', '多头信号'], dtype=object),
#  array(['MRK', '多头信号'], dtype=object),
#  array(['MET', '多头信号'], dtype=object),
#  array(['MTD', '多头信号'], dtype=object),
#  array(['MGM', '多头信号'], dtype=object),
#  array(['MCHP', '空头信号'], dtype=object),
#  array(['MU', '空头信号'], dtype=object),
#  array(['MSFT', '多头信号'], dtype=object),
#  array(['MAA', '空头信号'], dtype=object),
#  array(['MHK', '空头信号'], dtype=object),
#  array(['TAP', '空头信号'], dtype=object),
#  array(['MDLZ', '多头信号'], dtype=object),
#  array(['MNST', '多头信号'], dtype=object),
#  array(['MCO', '空头信号'], dtype=object),
#  array(['MS', '多头信号'], dtype=object),
#  array(['MOS', '空头信号'], dtype=object),
#  array(['MSI', '空头信号'], dtype=object),
#  array(['MYL', '空头信号'], dtype=object),
#  array(['NDAQ', '多头信号'], dtype=object),
#  array(['NOV', '空头信号'], dtype=object),
#  array(['NAVI', '多头信号'], dtype=object),
#  array(['NTAP', '多头信号'], dtype=object),
#  array(['NFLX', '多头信号'], dtype=object),
#  array(['NWL', '空头信号'], dtype=object),
#  array(['NEM', '空头信号'], dtype=object),
#  array(['NWSA', '空头信号'], dtype=object),
#  array(['NWS', '空头信号'], dtype=object),
#  array(['NEE', '空头信号'], dtype=object),
#  array(['NLSN', '多头信号'], dtype=object),
#  array(['NKE', '空头信号'], dtype=object),
#  array(['NI', '空头信号'], dtype=object),
#  array(['NBL', '多头信号'], dtype=object),
#  array(['JWN', '空头信号'], dtype=object),
#  array(['NSC', '空头信号'], dtype=object),
#  array(['NTRS', '多头信号'], dtype=object),
#  array(['NOC', '多头信号'], dtype=object),
#  array(['NCLH', '多头信号'], dtype=object),
#  array(['NRG', '空头信号'], dtype=object),
#  array(['NUE', '空头信号'], dtype=object),
#  array(['NVDA', '空头信号'], dtype=object),
#  array(['ORLY', '空头信号'], dtype=object),
#  array(['OXY', '空头信号'], dtype=object),
#  array(['OMC', '多头信号'], dtype=object),
#  array(['OKE', '多头信号'], dtype=object),
#  array(['ORCL', '多头信号'], dtype=object),
#  array(['PCAR', '空头信号'], dtype=object),
#  array(['PKG', '空头信号'], dtype=object),
#  array(['PH', '空头信号'], dtype=object),
#  array(['PDCO', '多头信号'], dtype=object),
#  array(['PAYX', '空头信号'], dtype=object),
#  array(['PYPL', '多头信号'], dtype=object),
#  array(['PNR', '空头信号'], dtype=object),
#  array(['PBCT', '空头信号'], dtype=object),
#  array(['PEP', '空头信号'], dtype=object),
#  array(['PKI', '多头信号'], dtype=object),
#  array(['PRGO', '空头信号'], dtype=object),
#  array(['PFE', '空头信号'], dtype=object),
#  array(['PCG', '多头信号'], dtype=object),
#  array(['PM', '空头信号'], dtype=object),
#  array(['PSX', '空头信号'], dtype=object),
#  array(['PNW', '空头信号'], dtype=object),
#  array(['PXD', '多头信号'], dtype=object),
#  array(['PNC', '空头信号'], dtype=object),
#  array(['RL', '多头信号'], dtype=object),
#  array(['PPG', '多头信号'], dtype=object),
#  array(['PPL', '空头信号'], dtype=object),
#  array(['PX', '多头信号'], dtype=object),
#  array(['PFG', '空头信号'], dtype=object),
#  array(['PG', '空头信号'], dtype=object),
#  array(['PGR', '多头信号'], dtype=object),
#  array(['PLD', '空头信号'], dtype=object),
#  array(['PRU', '空头信号'], dtype=object),
#  array(['PEG', '空头信号'], dtype=object),
#  array(['PSA', '空头信号'], dtype=object),
#  array(['PHM', '空头信号'], dtype=object),
#  array(['PVH', '多头信号'], dtype=object),
#  array(['QRVO', '多头信号'], dtype=object),
#  array(['PWR', '空头信号'], dtype=object),
#  array(['QCOM', '多头信号'], dtype=object),
#  array(['DGX', '多头信号'], dtype=object),
#  array(['RRC', '空头信号'], dtype=object),
#  array(['RJF', '多头信号'], dtype=object),
#  array(['RTN', '空头信号'], dtype=object),
#  array(['O', '空头信号'], dtype=object),
#  array(['REG', '空头信号'], dtype=object),
#  array(['REGN', '多头信号'], dtype=object),
#  array(['RF', '空头信号'], dtype=object),
#  array(['RSG', '多头信号'], dtype=object),
#  array(['RMD', '多头信号'], dtype=object),
#  array(['RHI', '空头信号'], dtype=object),
#  array(['ROK', '多头信号'], dtype=object),
#  array(['COL', '空头信号'], dtype=object),
#  array(['ROP', '多头信号'], dtype=object),
#  array(['ROST', '多头信号'], dtype=object),
#  array(['RCL', '多头信号'], dtype=object),
#  array(['CRM', '多头信号'], dtype=object),
#  array(['SBAC', '空头信号'], dtype=object),
#  array(['SCG', '多头信号'], dtype=object),
#  array(['SLB', '多头信号'], dtype=object),
#  array(['SNI', '空仓信号'], dtype=object),
#  array(['STX', '空头信号'], dtype=object),
#  array(['SEE', '空头信号'], dtype=object),
#  array(['SRE', '多头信号'], dtype=object),
#  array(['SHW', '多头信号'], dtype=object),
#  array(['SIG', '空头信号'], dtype=object),
#  array(['SPG', '空头信号'], dtype=object),
#  array(['SWKS', '多头信号'], dtype=object),
#  array(['SLG', '多头信号'], dtype=object),
#  array(['SNA', '空头信号'], dtype=object),
#  array(['SO', '空头信号'], dtype=object),
#  array(['LUV', '多头信号'], dtype=object),
#  array(['SPGI', '多头信号'], dtype=object),
#  array(['SWK', '空头信号'], dtype=object),
#  array(['SBUX', '多头信号'], dtype=object),
#  array(['STT', '多头信号'], dtype=object),
#  array(['SRCL', '多头信号'], dtype=object),
#  array(['SYK', '空头信号'], dtype=object),
#  array(['STI', '空头信号'], dtype=object),
#  array(['SYMC', '多头信号'], dtype=object),
#  array(['SYF', '多头信号'], dtype=object),
#  array(['SNPS', '多头信号'], dtype=object),
#  array(['SYY', '多头信号'], dtype=object),
#  array(['TROW', '多头信号'], dtype=object),
#  array(['TPR', '空头信号'], dtype=object),
#  array(['TGT', '空头信号'], dtype=object),
#  array(['TEL', '空头信号'], dtype=object),
#  array(['FTI', '空头信号'], dtype=object),
#  array(['TXN', '空头信号'], dtype=object),
#  array(['TXT', '空头信号'], dtype=object),
#  array(['TMO', '多头信号'], dtype=object),
#  array(['TIF', '空头信号'], dtype=object),
#  array(['TWX', '多头信号'], dtype=object),
#  array(['TJX', '空头信号'], dtype=object),
#  array(['TSS', '空头信号'], dtype=object),
#  array(['TSCO', '多头信号'], dtype=object),
#  array(['TDG', '多头信号'], dtype=object),
#  array(['TRV', '多头信号'], dtype=object),
#  array(['TRIP', '空头信号'], dtype=object),
#  array(['FOXA', '多头信号'], dtype=object),
#  array(['FOX', '多头信号'], dtype=object),
#  array(['TSN', '多头信号'], dtype=object),
#  array(['UDR', '空头信号'], dtype=object),
#  array(['ULTA', '多头信号'], dtype=object),
#  array(['USB', '多头信号'], dtype=object),
#  array(['UA', '空头信号'], dtype=object),
#  array(['UAA', '空头信号'], dtype=object),
#  array(['UNP', '多头信号'], dtype=object),
#  array(['UAL', '空头信号'], dtype=object),
#  array(['UNH', '空头信号'], dtype=object),
#  array(['UPS', '多头信号'], dtype=object),
#  array(['URI', '多头信号'], dtype=object),
#  array(['UTX', '多头信号'], dtype=object),
#  array(['UHS', '多头信号'], dtype=object),
#  array(['UNM', '多头信号'], dtype=object),
#  array(['VFC', '多头信号'], dtype=object),
#  array(['VLO', '空头信号'], dtype=object),
#  array(['VAR', '多头信号'], dtype=object),
#  array(['VTR', '空头信号'], dtype=object),
#  array(['VRSN', '多头信号'], dtype=object),
#  array(['VRSK', '空头信号'], dtype=object),
#  array(['VZ', '空头信号'], dtype=object),
#  array(['VRTX', '多头信号'], dtype=object),
#  array(['VIAB', '多头信号'], dtype=object),
#  array(['V', '多头信号'], dtype=object),
#  array(['VNO', '空头信号'], dtype=object),
#  array(['VMC', '空头信号'], dtype=object),
#  array(['WMT', '多头信号'], dtype=object),
#  array(['WBA', '多头信号'], dtype=object),
#  array(['DIS', '多头信号'], dtype=object),
#  array(['WM', '多头信号'], dtype=object),
#  array(['WAT', '多头信号'], dtype=object),
#  array(['WEC', '空头信号'], dtype=object),
#  array(['WFC', '多头信号'], dtype=object),
#  array(['WDC', '空头信号'], dtype=object),
#  array(['WU', '空头信号'], dtype=object),
#  array(['WRK', '多头信号'], dtype=object),
#  array(['WY', '空头信号'], dtype=object),
#  array(['WHR', '空头信号'], dtype=object),
#  array(['WMB', '空头信号'], dtype=object),
#  array(['WLTW', '多头信号'], dtype=object),
#  array(['WYNN', '空头信号'], dtype=object),
#  array(['XEL', '空头信号'], dtype=object),
#  array(['XRX', '多头信号'], dtype=object),
#  array(['XLNX', '多头信号'], dtype=object),
#  array(['XL', '多头信号'], dtype=object),
#  array(['XYL', '空头信号'], dtype=object),
#  array(['YUM', '空头信号'], dtype=object),
#  array(['ZBH', '多头信号'], dtype=object),
#  array(['ZION', '空头信号'], dtype=object),
#  array(['ZTS', '空头信号'], dtype=object)]

# %%
aapl.tail(200)[['MACD_Diff','MACD_Diff_EMA','MACD','MACD_signal']].plot(figsize = (16,8))

# %%
aapl
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     1990-01-02    1.258929    1.339286    1.250000    1.330357    1.081430
# 1     1990-01-03    1.357143    1.357143    1.339286    1.339286    1.088688
# 2     1990-01-04    1.366071    1.383929    1.330357    1.343750    1.092317
# 3     1990-01-05    1.348214    1.366071    1.321429    1.348214    1.095946
# 4     1990-01-08    1.339286    1.357143    1.321429    1.357143    1.103203
# 5     1990-01-09    1.357143    1.357143    1.321429    1.343750    1.092317
# 6     1990-01-10    1.343750    1.343750    1.276786    1.285714    1.045140
# 7     1990-01-11    1.294643    1.294643    1.232143    1.232143    1.001593
# 8     1990-01-12    1.223214    1.241071    1.205357    1.232143    1.001593
# 9     1990-01-15    1.232143    1.276786    1.223214    1.223214    0.994335
# 10    1990-01-16    1.196429    1.250000    1.169643    1.245536    1.012479
# 11    1990-01-17    1.241071    1.241071    1.178571    1.187500    0.965303
# 12    1990-01-18    1.178571    1.196429    1.151786    1.156250    0.939900
# 13    1990-01-19    1.205357    1.232143    1.196429    1.223214    0.994335
# 14    1990-01-22    1.214286    1.232143    1.187500    1.187500    0.965303
# 15    1990-01-23    1.205357    1.223214    1.178571    1.205357    0.979819
# 16    1990-01-24    1.160714    1.223214    1.151786    1.214286    0.987077
# 17    1990-01-25    1.223214    1.241071    1.214286    1.218750    0.990705
# 18    1990-01-26    1.214286    1.214286    1.151786    1.169643    0.950787
# 19    1990-01-29    1.178571    1.196429    1.147321    1.187500    0.965303
# 20    1990-01-30    1.187500    1.232143    1.178571    1.214286    0.987077
# 21    1990-01-31    1.232143    1.241071    1.178571    1.214286    0.987077
# 22    1990-02-01    1.232143    1.236607    1.196429    1.200893    0.976190
# 23    1990-02-02    1.187500    1.241071    1.187500    1.223214    0.994335
# 24    1990-02-05    1.223214    1.258929    1.214286    1.250000    1.016108
# 25    1990-02-06    1.241071    1.250000    1.214286    1.241071    1.008851
# 26    1990-02-07    1.178571    1.214286    1.160714    1.187500    0.965303
# 27    1990-02-08    1.187500    1.196429    1.151786    1.178571    0.958045
# 28    1990-02-09    1.196429    1.232143    1.187500    1.223214    0.994335
# 29    1990-02-12    1.223214    1.232143    1.205357    1.214286    0.987077
# ...          ...         ...         ...         ...         ...         ...
# 7498  2019-10-04  225.639999  227.490005  223.889999  227.009995  226.330490
# 7499  2019-10-07  226.270004  229.929993  225.839996  227.059998  226.380341
# 7500  2019-10-08  225.820007  228.059998  224.330002  224.399994  223.728302
# 7501  2019-10-09  227.029999  227.789993  225.639999  227.029999  226.350433
# 7502  2019-10-10  227.929993  230.440002  227.300003  230.089996  229.401276
# 7503  2019-10-11  232.949997  237.639999  232.309998  236.210007  235.502960
# 7504  2019-10-14  234.899994  238.130005  234.669998  235.869995  235.163971
# 7505  2019-10-15  236.389999  237.649994  234.880005  235.320007  234.615631
# 7506  2019-10-16  233.369995  235.240005  233.199997  234.369995  233.668457
# 7507  2019-10-17  235.089996  236.149994  233.520004  235.279999  234.575745
# 7508  2019-10-18  234.589996  237.580002  234.289993  236.410004  235.702362
# 7509  2019-10-21  237.520004  240.990005  237.320007  240.509995  239.790085
# 7510  2019-10-22  241.160004  242.199997  239.619995  239.960007  239.241745
# 7511  2019-10-23  242.100006  243.240005  241.220001  243.179993  242.452087
# 7512  2019-10-24  244.509995  244.800003  241.809998  243.580002  242.850891
# 7513  2019-10-25  243.160004  246.729996  242.880005  246.580002  245.841919
# 7514  2019-10-28  247.419998  249.250000  246.720001  249.050003  248.304520
# 7515  2019-10-29  248.970001  249.750000  242.570007  243.289993  242.561752
# 7516  2019-10-30  244.759995  245.300003  241.210007  243.259995  242.531845
# 7517  2019-10-31  247.240005  249.169998  237.259995  248.759995  248.015381
# 7518  2019-11-01  249.539993  255.929993  249.160004  255.820007  255.054260
# 7519  2019-11-04  257.329987  257.850006  255.380005  257.500000  256.729218
# 7520  2019-11-05  257.049988  258.190002  256.320007  257.130005  256.360352
# 7521  2019-11-06  256.769989  257.489990  255.369995  257.239990  256.470001
# 7522  2019-11-07  258.739990  260.350006  258.109985  259.429993  259.429993
# 7523  2019-11-08  258.690002  260.440002  256.850006  260.140015  260.140015
# 7524  2019-11-11  258.299988  260.713287  258.279999  260.387085  260.387085
# 7525  2019-11-12  261.549988  262.679993  260.924988  262.220001  262.220001
# 7526  2019-11-13  261.130005  264.779999  261.070007  264.470001  264.470001
# 7527  2019-11-14  263.750000  264.880005  262.100006  262.640015  262.640015
#
#         Volume Ticker  MACD_Diff  MACD_Diff_EMA      MACD  MACD_signal
# 0     45799600   AAPL        NaN            NaN       NaN            0
# 1     51998800   AAPL        NaN            NaN       NaN            0
# 2     55378400   AAPL        NaN            NaN       NaN            0
# 3     30828000   AAPL        NaN            NaN       NaN            0
# 4     25393200   AAPL        NaN            NaN       NaN            0
# 5     21534800   AAPL        NaN            NaN       NaN            0
# 6     49929600   AAPL        NaN            NaN       NaN            0
# 7     52763200   AAPL        NaN            NaN       NaN            0
# 8     42974400   AAPL        NaN            NaN       NaN            0
# 9     40434800   AAPL        NaN            NaN       NaN            0
# 10    53561200   AAPL        NaN            NaN       NaN            0
# 11    49324800   AAPL        NaN            NaN       NaN            0
# 12    68322800   AAPL        NaN            NaN       NaN            0
# 13    66284400   AAPL        NaN            NaN       NaN            0
# 14    36402800   AAPL        NaN            NaN       NaN            0
# 15    35218400   AAPL        NaN            NaN       NaN            0
# 16    42448000   AAPL        NaN            NaN       NaN            0
# 17    27885200   AAPL        NaN            NaN       NaN            0
# 18    45312400   AAPL        NaN            NaN       NaN            0
# 19    29982400   AAPL        NaN            NaN       NaN            0
# 20    29111600   AAPL        NaN            NaN       NaN            0
# 21    35985600   AAPL        NaN            NaN       NaN            0
# 22    29268400   AAPL        NaN            NaN       NaN            0
# 23    29618400   AAPL        NaN            NaN       NaN            0
# 24    25438000   AAPL  -0.008150            NaN       NaN            0
# 25    18480000   AAPL  -0.005820            NaN       NaN            0
# 26    78111600   AAPL  -0.007734            NaN       NaN            0
# 27    46659200   AAPL  -0.009774            NaN       NaN            0
# 28    42019600   AAPL  -0.008035            NaN       NaN            0
# 29    18729200   AAPL  -0.007232            NaN       NaN            0
# ...        ...    ...        ...            ...       ...          ...
# 7498  34619700   AAPL   3.202221       3.230394 -0.028172           -1
# 7499  30576500   AAPL   3.427900       3.269895  0.158005            1
# 7500  27955000   AAPL   3.353455       3.286607  0.066848            1
# 7501  18692600   AAPL   3.466714       3.322628  0.144086            1
# 7502  28253400   AAPL   3.760046       3.410112  0.349934            1
# 7503  41698900   AAPL   4.435220       3.615134  0.820087            1
# 7504  24106900   AAPL   4.886536       3.869414  1.017122            1
# 7505  21840000   AAPL   5.140570       4.123645  1.016925            1
# 7506  18475800   AAPL   5.205233       4.339963  0.865271            1
# 7507  16896300   AAPL   5.269170       4.525804  0.743365            1
# 7508  24358400   AAPL   5.349357       4.690515  0.658842            1
# 7509  21811800   AAPL   5.678286       4.888069  0.790217            1
# 7510  20573400   AAPL   5.827410       5.075937  0.751473            1
# 7511  18957200   AAPL   6.134701       5.287690  0.847011            1
# 7512  17318800   AAPL   6.337454       5.497643  0.839811            1
# 7513  18369300   AAPL   6.663401       5.730794  0.932607            1
# 7514  24143200   AAPL   7.039873       5.992610  1.047263            1
# 7515  35709900   AAPL   6.795116       6.153111  0.642005            1
# 7516  31130500   AAPL   6.523524       6.227194  0.296330            1
# 7517  34790500   AAPL   6.675143       6.316784  0.358359            1
# 7518  37781300   AAPL   7.281054       6.509638  0.771417            1
# 7519  25818000   AAPL   7.806813       6.769073  1.037740            1
# 7520  19974400   AAPL   8.100250       7.035308  1.064942            1
# 7521  18966100   AAPL   8.246614       7.277570  0.969045            1
# 7522  23735100   AAPL   8.442010       7.510458  0.931552            1
# 7523  17496600   AAPL   8.555532       7.719472  0.836059            1
# 7524   8745916   AAPL   8.566684       7.888915  0.677769            1
# 7525  11623393   AAPL   8.624011       8.035934  0.588077            1
# 7526  25683600   AAPL   8.750133       8.178774  0.571359            1
# 7527  22295700   AAPL   8.603249       8.263669  0.339580            1
#
# [7528 rows x 12 columns]

# %%
MACD(stock, 12, 26, 9)['MACD_signal'].tail(100).plot()

# %%
stock
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     1990-01-02    1.258929    1.339286    1.250000    1.330357    1.081430
# 1     1990-01-03    1.357143    1.357143    1.339286    1.339286    1.088688
# 2     1990-01-04    1.366071    1.383929    1.330357    1.343750    1.092317
# 3     1990-01-05    1.348214    1.366071    1.321429    1.348214    1.095946
# 4     1990-01-08    1.339286    1.357143    1.321429    1.357143    1.103203
# 5     1990-01-09    1.357143    1.357143    1.321429    1.343750    1.092317
# 6     1990-01-10    1.343750    1.343750    1.276786    1.285714    1.045140
# 7     1990-01-11    1.294643    1.294643    1.232143    1.232143    1.001593
# 8     1990-01-12    1.223214    1.241071    1.205357    1.232143    1.001593
# 9     1990-01-15    1.232143    1.276786    1.223214    1.223214    0.994335
# 10    1990-01-16    1.196429    1.250000    1.169643    1.245536    1.012479
# 11    1990-01-17    1.241071    1.241071    1.178571    1.187500    0.965303
# 12    1990-01-18    1.178571    1.196429    1.151786    1.156250    0.939900
# 13    1990-01-19    1.205357    1.232143    1.196429    1.223214    0.994335
# 14    1990-01-22    1.214286    1.232143    1.187500    1.187500    0.965303
# 15    1990-01-23    1.205357    1.223214    1.178571    1.205357    0.979819
# 16    1990-01-24    1.160714    1.223214    1.151786    1.214286    0.987077
# 17    1990-01-25    1.223214    1.241071    1.214286    1.218750    0.990705
# 18    1990-01-26    1.214286    1.214286    1.151786    1.169643    0.950787
# 19    1990-01-29    1.178571    1.196429    1.147321    1.187500    0.965303
# 20    1990-01-30    1.187500    1.232143    1.178571    1.214286    0.987077
# 21    1990-01-31    1.232143    1.241071    1.178571    1.214286    0.987077
# 22    1990-02-01    1.232143    1.236607    1.196429    1.200893    0.976190
# 23    1990-02-02    1.187500    1.241071    1.187500    1.223214    0.994335
# 24    1990-02-05    1.223214    1.258929    1.214286    1.250000    1.016108
# 25    1990-02-06    1.241071    1.250000    1.214286    1.241071    1.008851
# 26    1990-02-07    1.178571    1.214286    1.160714    1.187500    0.965303
# 27    1990-02-08    1.187500    1.196429    1.151786    1.178571    0.958045
# 28    1990-02-09    1.196429    1.232143    1.187500    1.223214    0.994335
# 29    1990-02-12    1.223214    1.232143    1.205357    1.214286    0.987077
# ...          ...         ...         ...         ...         ...         ...
# 7498  2019-10-04  225.639999  227.490005  223.889999  227.009995  226.330490
# 7499  2019-10-07  226.270004  229.929993  225.839996  227.059998  226.380341
# 7500  2019-10-08  225.820007  228.059998  224.330002  224.399994  223.728302
# 7501  2019-10-09  227.029999  227.789993  225.639999  227.029999  226.350433
# 7502  2019-10-10  227.929993  230.440002  227.300003  230.089996  229.401276
# 7503  2019-10-11  232.949997  237.639999  232.309998  236.210007  235.502960
# 7504  2019-10-14  234.899994  238.130005  234.669998  235.869995  235.163971
# 7505  2019-10-15  236.389999  237.649994  234.880005  235.320007  234.615631
# 7506  2019-10-16  233.369995  235.240005  233.199997  234.369995  233.668457
# 7507  2019-10-17  235.089996  236.149994  233.520004  235.279999  234.575745
# 7508  2019-10-18  234.589996  237.580002  234.289993  236.410004  235.702362
# 7509  2019-10-21  237.520004  240.990005  237.320007  240.509995  239.790085
# 7510  2019-10-22  241.160004  242.199997  239.619995  239.960007  239.241745
# 7511  2019-10-23  242.100006  243.240005  241.220001  243.179993  242.452087
# 7512  2019-10-24  244.509995  244.800003  241.809998  243.580002  242.850891
# 7513  2019-10-25  243.160004  246.729996  242.880005  246.580002  245.841919
# 7514  2019-10-28  247.419998  249.250000  246.720001  249.050003  248.304520
# 7515  2019-10-29  248.970001  249.750000  242.570007  243.289993  242.561752
# 7516  2019-10-30  244.759995  245.300003  241.210007  243.259995  242.531845
# 7517  2019-10-31  247.240005  249.169998  237.259995  248.759995  248.015381
# 7518  2019-11-01  249.539993  255.929993  249.160004  255.820007  255.054260
# 7519  2019-11-04  257.329987  257.850006  255.380005  257.500000  256.729218
# 7520  2019-11-05  257.049988  258.190002  256.320007  257.130005  256.360352
# 7521  2019-11-06  256.769989  257.489990  255.369995  257.239990  256.470001
# 7522  2019-11-07  258.739990  260.350006  258.109985  259.429993  259.429993
# 7523  2019-11-08  258.690002  260.440002  256.850006  260.140015  260.140015
# 7524  2019-11-11  258.299988  260.713287  258.279999  260.387085  260.387085
# 7525  2019-11-12  261.549988  262.679993  260.924988  262.220001  262.220001
# 7526  2019-11-13  261.130005  264.779999  261.070007  264.470001  264.470001
# 7527  2019-11-14  263.750000  264.880005  262.100006  262.640015  262.640015
#
#         Volume Ticker
# 0     45799600   AAPL
# 1     51998800   AAPL
# 2     55378400   AAPL
# 3     30828000   AAPL
# 4     25393200   AAPL
# 5     21534800   AAPL
# 6     49929600   AAPL
# 7     52763200   AAPL
# 8     42974400   AAPL
# 9     40434800   AAPL
# 10    53561200   AAPL
# 11    49324800   AAPL
# 12    68322800   AAPL
# 13    66284400   AAPL
# 14    36402800   AAPL
# 15    35218400   AAPL
# 16    42448000   AAPL
# 17    27885200   AAPL
# 18    45312400   AAPL
# 19    29982400   AAPL
# 20    29111600   AAPL
# 21    35985600   AAPL
# 22    29268400   AAPL
# 23    29618400   AAPL
# 24    25438000   AAPL
# 25    18480000   AAPL
# 26    78111600   AAPL
# 27    46659200   AAPL
# 28    42019600   AAPL
# 29    18729200   AAPL
# ...        ...    ...
# 7498  34619700   AAPL
# 7499  30576500   AAPL
# 7500  27955000   AAPL
# 7501  18692600   AAPL
# 7502  28253400   AAPL
# 7503  41698900   AAPL
# 7504  24106900   AAPL
# 7505  21840000   AAPL
# 7506  18475800   AAPL
# 7507  16896300   AAPL
# 7508  24358400   AAPL
# 7509  21811800   AAPL
# 7510  20573400   AAPL
# 7511  18957200   AAPL
# 7512  17318800   AAPL
# 7513  18369300   AAPL
# 7514  24143200   AAPL
# 7515  35709900   AAPL
# 7516  31130500   AAPL
# 7517  34790500   AAPL
# 7518  37781300   AAPL
# 7519  25818000   AAPL
# 7520  19974400   AAPL
# 7521  18966100   AAPL
# 7522  23735100   AAPL
# 7523  17496600   AAPL
# 7524   8745916   AAPL
# 7525  11623393   AAPL
# 7526  25683600   AAPL
# 7527  22295700   AAPL
#
# [7528 rows x 8 columns]
