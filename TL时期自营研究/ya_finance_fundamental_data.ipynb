# %%
from yahoofinancials import YahooFinancials

# %% [markdown]
# https://pypi.org/project/yahoofinancials/

# %%
tech_stocks = ['AAPL', 'MSFT', 'INTC']
bank_stocks = ['WFC', 'BAC', 'C']
commodity_futures = ['GC=F', 'SI=F', 'CL=F']
cryptocurrencies = ['BTC-USD', 'ETH-USD', 'XRP-USD']
currencies = ['EURUSD=X', 'JPY=X', 'GBPUSD=X']
mutual_funds = ['PRLAX', 'QASGX', 'HISFX']
us_treasuries = ['^TNX', '^IRX', '^TYX']

yahoo_financials_tech = YahooFinancials(tech_stocks)
yahoo_financials_banks = YahooFinancials(bank_stocks)
yahoo_financials_commodities = YahooFinancials(commodity_futures)
yahoo_financials_cryptocurrencies = YahooFinancials(cryptocurrencies)
yahoo_financials_currencies = YahooFinancials(currencies)
yahoo_financials_mutualfunds = YahooFinancials(mutual_funds)
yahoo_financials_treasuries = YahooFinancials(us_treasuries)

tech_cash_flow_data_an = yahoo_financials_tech.get_financial_stmts('annual', 'cash')
bank_cash_flow_data_an = yahoo_financials_banks.get_financial_stmts('annual', 'cash')

banks_net_ebit = yahoo_financials_banks.get_ebit()
tech_stock_price_data = yahoo_financials_tech.get_stock_price_data()
daily_bank_stock_prices = yahoo_financials_banks.get_historical_price_data('2008-09-15', '2018-09-15', 'daily')
daily_commodity_prices = yahoo_financials_commodities.get_historical_price_data('2008-09-15', '2018-09-15', 'daily')
daily_crypto_prices = yahoo_financials_cryptocurrencies.get_historical_price_data('2008-09-15', '2018-09-15', 'daily')
daily_currency_prices = yahoo_financials_currencies.get_historical_price_data('2008-09-15', '2018-09-15', 'daily')
daily_mutualfund_prices = yahoo_financials_mutualfunds.get_historical_price_data('2008-09-15', '2018-09-15', 'daily')
daily_treasury_prices = yahoo_financials_treasuries.get_historical_price_data('2008-09-15', '2018-09-15', 'daily')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-4487971ea7d3> in <module>()
#      23 daily_commodity_prices = yahoo_financials_commodities.get_historical_price_data('2008-09-15', '2018-09-15', 'daily')
#      24 daily_crypto_prices = yahoo_financials_cryptocurrencies.get_historical_price_data('2008-09-15', '2018-09-15', 'daily')
# ---> 25 daily_currency_prices = yahoo_financials_currencies.get_historical_price_data('2008-09-15', '2018-09-15', 'daily')
#      26 daily_mutualfund_prices = yahoo_financials_mutualfunds.get_historical_price_data('2008-09-15', '2018-09-15', 'daily')
#      27 daily_treasury_prices = yahoo_financials_treasuries.get_historical_price_data('2008-09-15', '2018-09-15', 'daily')
#
# ~/anaconda3/lib/python3.5/site-packages/yahoofinancials/__init__.py in get_historical_price_data(self, start_date, end_date, time_interval)
#     642         end = self.format_date(end_date)
#     643         hist_obj = {'start': start, 'end': end, 'interval': interval_code}
# --> 644         return self.get_stock_data('history', hist_obj=hist_obj)
#     645
#     646     # Private Method for Functions needing stock_price_data
#
# ~/anaconda3/lib/python3.5/site-packages/yahoofinancials/__init__.py in get_stock_data(self, statement_type, tech_type, report_name, hist_obj)
#     476             for tick in self.ticker:
#     477                 try:
# --> 478                     dict_ent = self._create_dict_ent(tick, statement_type, tech_type, report_name, hist_obj)
#     479                     data.update(dict_ent)
#     480                 except ManagedException:
#
# ~/anaconda3/lib/python3.5/site-packages/yahoofinancials/__init__.py in _create_dict_ent(self, up_ticker, statement_type, tech_type, report_name, hist_obj)
#     411             YAHOO_URL = self._build_historical_url(up_ticker, hist_obj)
#     412             try:
# --> 413                 cleaned_re_data = self._recursive_api_request(hist_obj, up_ticker)
#     414             except KeyError:
#     415                 try:
#
# ~/anaconda3/lib/python3.5/site-packages/yahoofinancials/__init__.py in _recursive_api_request(self, hist_obj, up_ticker, i)
#     380     def _recursive_api_request(self, hist_obj, up_ticker, i=0):
#     381         api_url = self._build_api_url(hist_obj, up_ticker)
# --> 382         re_data = self._clean_api_data(api_url)
#     383         cleaned_re_data = self._clean_historical_data(re_data)
#     384         if cleaned_re_data is not None:
#
# ~/anaconda3/lib/python3.5/site-packages/yahoofinancials/__init__.py in _clean_api_data(self, api_url)
#     338     # Private Method to clean API data
#     339     def _clean_api_data(self, api_url):
# --> 340         raw_data = self._get_api_data(api_url)
#     341         ret_obj = {}
#     342         ret_obj.update({'eventsData': []})
#
# ~/anaconda3/lib/python3.5/site-packages/yahoofinancials/__init__.py in _get_api_data(self, api_url, tries)
#     323         response = urlopener.open(api_url)
#     324         if response.getcode() == 200:
# --> 325             res_content = response.read()
#     326             response.close()
#     327             if sys.version_info < (3, 0):
#
# ~/anaconda3/lib/python3.5/tempfile.py in func_wrapper(*args, **kwargs)
#     481             @_functools.wraps(func)
#     482             def func_wrapper(*args, **kwargs):
# --> 483                 return func(*args, **kwargs)
#     484             # Avoid closing the file as long as the wrapper is alive,
#     485             # see issue #18879.
#
# ~/anaconda3/lib/python3.5/http/client.py in read(self, amt)
#     453
#     454             if self.chunked:
# --> 455                 return self._readall_chunked()
#     456
#     457             if self.length is None:
#
# ~/anaconda3/lib/python3.5/http/client.py in _readall_chunked(self)
#     559                 if chunk_left is None:
#     560                     break
# --> 561                 value.append(self._safe_read(chunk_left))
#     562                 self.chunk_left = 0
#     563             return b''.join(value)
#
# ~/anaconda3/lib/python3.5/http/client.py in _safe_read(self, amt)
#     605         s = []
#     606         while amt > 0:
# --> 607             chunk = self.fp.read(min(amt, MAXAMOUNT))
#     608             if not chunk:
#     609                 raise IncompleteRead(b''.join(s), amt)
#
# ~/anaconda3/lib/python3.5/socket.py in readinto(self, b)
#     574         while True:
#     575             try:
# --> 576                 return self._sock.recv_into(b)
#     577             except timeout:
#     578                 self._timeout_occurred = True
#
# ~/anaconda3/lib/python3.5/ssl.py in recv_into(self, buffer, nbytes, flags)
#     935                   "non-zero flags not allowed in calls to recv_into() on %s" %
#     936                   self.__class__)
# --> 937             return self.read(nbytes, buffer)
#     938         else:
#     939             return socket.recv_into(self, buffer, nbytes, flags)
#
# ~/anaconda3/lib/python3.5/ssl.py in read(self, len, buffer)
#     797             raise ValueError("Read on closed or unwrapped SSL socket.")
#     798         try:
# --> 799             return self._sslobj.read(len, buffer)
#     800         except SSLError as x:
#     801             if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# ~/anaconda3/lib/python3.5/ssl.py in read(self, len, buffer)
#     581         """
#     582         if buffer is not None:
# --> 583             v = self._sslobj.read(len, buffer)
#     584         else:
#     585             v = self._sslobj.read(len)
#
# KeyboardInterrupt:
