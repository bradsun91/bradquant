# %%
import pandas as pd, numpy as np
from datetime import datetime
# import yfinance as yf
import tushare as ts
import time, urllib
ts.set_token('2f31c3932ead9fcc3830879132cc3ec8df3566550f711889d4a30f67')
import glob
import os

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set(context='notebook', style='darkgrid', palette='deep', font='sans-serif', font_scale=1, color_codes=False, rc=None)

# %%
ch_etfs_df = pd.read_csv("/Users/miaoyuesun/Code_Workspace/brad_public_workspace_mac/data/"+"CH_ETFs.csv")
ch_etfs_df.dropna(inplace = True)
ch_etfs_df['基金规模\n[单位] 元'] = ch_etfs_df['基金规模\n[单位] 元'].apply(lambda x: float(x.replace(",","")))
ch_etfs_df['机构投资者持有份额\n[报告期] 2019中报\n[单位] 份'] = ch_etfs_df['机构投资者持有份额\n[报告期] 2019中报\n[单位] 份'].apply(lambda x: float(x.replace(",","")))
ch_etfs_df.sort_values("基金规模\n[单位] 元", ascending=False, inplace =True)

# %%
ch_etfs_df.head(3)
# Out:
#           证券代码          证券简称 投资类型(一级分类) 投资类型(二级分类)  基金规模\n[单位] 元  \
# 152  510500.OF    南方中证500ETF      股票型基金    被动指数型基金  4.349555e+10
# 180  510050.OF     华夏上证50ETF      股票型基金    被动指数型基金  4.166154e+10
# 162  510300.OF  华泰柏瑞沪深300ETF      股票型基金    被动指数型基金  3.451196e+10
#
#      机构投资者持有份额\n[报告期] 2019中报\n[单位] 份  机构投资者持有比例\n[报告期] 2019中报\n[单位] %  \
# 152                     6.869517e+09                            76.03
# 180                     1.220778e+10                            73.10
# 162                     6.917064e+09                            73.10
#
#      管理费率\n[单位] %  托管费率\n[单位] %  \
# 152           0.5           0.1
# 180           0.5           0.1
# 162           0.5           0.1
#
#                                        认购费率\n[收费类型] 前端
# 152  500万份以上 1000元/笔\n100万份以下 1%\n100~300万份 0.6%\n3...
# 180       100万份以下 1%\n100~1000万份 0.8%\n1000万份以上 0.5%\n
# 162        100万份以上 1000元/笔\n50万份以下 1%\n50~100万份 0.5%\n

# %%
ch_etfs = ch_etfs_df.copy()
ch_etfs['code'] =ch_etfs['证券代码'].apply(lambda x: str(x)[:6])
ch_etfs_ticker = list(ch_etfs['code'].unique())
# Add the sp500 etf
etf_tickers = ['513500']+ch_etfs_ticker

# %%
def GetHistoryData(Code, BeginTime, EndTime):
    df = ts.get_k_data(Code, index = False,  start = BeginTime, end = EndTime)
    return df

# %%
etf_tickers[:5]
# Out:
# ['513500', '510500', '510050', '510300', '510330']

# %%
import eventlet
eventlet.monkey_patch()

ch_db_path = "/Users/miaoyuesun/Code_Workspace/brad_public_workspace_mac/data/CH_database/"
ticker_list = etf_tickers
# ticker_list = ['511020']
# ticker_list = ['513500',#标普500
#                '501021',#香港中小
#                # 目前黄金ETF基金主要有四只，易方达黄金ETF(159934)、博时黄金159937、国泰黄金ETF（518800）、华安黄金ETF（518880）。
#                '159934','159937','518800','518880'
#                # 300ETF（510300）、创业板ETF（159915）、500ETF（510500）都是指数ETF基金。
#                # 除了这些宽基指数基金外，还有跟踪行业指数的指数ETF，比如金融ETF(510230)、银行ETF（512800）、
#                # 军工ETF（512660）、广发医药（159938）等。
#                '510300','159915','510500','510230','512800','512660','159938']
today = str(datetime.now().date())
start = '2010-01-01'
end = today
count = 1
for ticker in ticker_list:
    if count%200==0:
        print("=======================Sleeping======================")
        time.sleep(60)
    else:
        if not os.path.exists(ch_db_path+ticker+".csv"):
            print("{} is new, start downloading now...".format(ticker))
            try:
                ############ replace get_data with other customized functions #############
                data = GetHistoryData(ticker, start, today)
                ############ replace get_data with other customized functions #############
#                 print(data)
                data['date'] = data['date'].astype(str)
#                 data['date'] = data['date'].apply(lambda x:x[:4]+"-"+x[4:6]+"-"+x[6:] if len(x)!=10 else x)
                data.sort_values("date", inplace = True)
                data.to_csv(ch_db_path+ticker+".csv", index = False)
                print("{} data file created: {}".format(ticker, end))
            except Exception as e:
                print(e)

        else:
            print("Already have data csv for {}".format(ticker))
            hist_data = pd.read_csv(ch_db_path+ticker+".csv")   
            hist_data['date'] = hist_data['date'].astype(str)
#             hist_data['date'] = hist_data['date'].apply(lambda x:x[:4]+"-"+x[4:6]+"-"+x[6:] if len(x)!=10 else x)
            hist_data.to_csv(ch_db_path+ticker+".csv", index = False)
            hist_data = pd.read_csv(ch_db_path+ticker+".csv")
            try:
                hist_data_last_date = hist_data['date'].values[-1]        
                if today > hist_data_last_date:
                    print("Needs to update, start updating new data for {} now...".format(ticker))
                    update_start = hist_data_last_date
                    update_end = today
                    with eventlet.Timeout(60,False):
                        try:
                            ############ replace get_data with other customized functions #############
                            new_data = GetHistoryData(ticker, update_start, update_end)
                            ############ replace get_data with other customized functions #############
                            
                            new_data['date'] = new_data['date'].astype(str)
                            new_data['date'] = new_data['date'].apply(lambda x:x[:4]+"-"+x[4:6]+"-"+x[6:])
                            new_data.to_csv(ch_db_path+ticker+".csv", mode='a', header=False, index = False)
                            updated_duplicated_df = pd.read_csv(ch_db_path+ticker+".csv")
                            updated_df = updated_duplicated_df.drop_duplicates("date")
                            updated_df.sort_values("date", inplace = True)
                            updated_df.to_csv(ch_db_path+ticker+".csv", index = False)
                            print("New data updated till today for {}!".format(ticker))
                        except Exception as e:
                            print(e)
        #             print("Timed Out: Update Failed!")
                else:
                    print("There's no new data to update for {}.".format(ticker))
            except Exception as e:
                print(e)

    #     print("Data Download/Update for {} is Finished.".format(ticker))
        print("=======================Executed: {}=======================".format(count))
    count+=1
print("【Updated Finished for today!】")
# Out:
# Already have data csv for 513500
# Needs to update, start updating new data for 513500 now...
# New data updated till today for 513500!
# =======================Executed: 1=======================
# Already have data csv for 510500
# Needs to update, start updating new data for 510500 now...
# /Users/miaoyuesun/anaconda3/lib/python3.5/site-packages/ipykernel_launcher.py:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# New data updated till today for 510500!
# =======================Executed: 2=======================
# Already have data csv for 510050
# Needs to update, start updating new data for 510050 now...
# New data updated till today for 510050!
# =======================Executed: 3=======================
# Already have data csv for 510300
# Needs to update, start updating new data for 510300 now...
# New data updated till today for 510300!
# =======================Executed: 4=======================
# Already have data csv for 510330
# Needs to update, start updating new data for 510330 now...
# New data updated till today for 510330!
# =======================Executed: 5=======================
# Already have data csv for 159919
# Needs to update, start updating new data for 159919 now...
# New data updated till today for 159919!
# =======================Executed: 6=======================
# Already have data csv for 510180
# Needs to update, start updating new data for 510180 now...
# New data updated till today for 510180!
# =======================Executed: 7=======================
# Already have data csv for 159915
# Needs to update, start updating new data for 159915 now...
# New data updated till today for 159915!
# =======================Executed: 8=======================
# Already have data csv for 512960
# Needs to update, start updating new data for 512960 now...
# New data updated till today for 512960!
# =======================Executed: 9=======================
# Already have data csv for 512950
# Needs to update, start updating new data for 512950 now...
# New data updated till today for 512950!
# =======================Executed: 10=======================
# Already have data csv for 510810
# Needs to update, start updating new data for 510810 now...
# New data updated till today for 510810!
# =======================Executed: 11=======================
# Already have data csv for 512880
# Needs to update, start updating new data for 512880 now...
# New data updated till today for 512880!
# =======================Executed: 12=======================
# Already have data csv for 510900
# Needs to update, start updating new data for 510900 now...
# New data updated till today for 510900!
# =======================Executed: 13=======================
# Already have data csv for 518880
# Needs to update, start updating new data for 518880 now...
# New data updated till today for 518880!
# =======================Executed: 14=======================
# Already have data csv for 510310
# Needs to update, start updating new data for 510310 now...
# New data updated till today for 510310!
# =======================Executed: 15=======================
# Already have data csv for 159901
# Needs to update, start updating new data for 159901 now...
# New data updated till today for 159901!
# =======================Executed: 16=======================
# Already have data csv for 512500
# Needs to update, start updating new data for 512500 now...
# New data updated till today for 512500!
# =======================Executed: 17=======================
# Already have data csv for 159920
# Needs to update, start updating new data for 159920 now...
# New data updated till today for 159920!
# =======================Executed: 18=======================
# Already have data csv for 159949
# Needs to update, start updating new data for 159949 now...
# New data updated till today for 159949!
# =======================Executed: 19=======================
# Already have data csv for 510230
# Needs to update, start updating new data for 510230 now...
# New data updated till today for 510230!
# =======================Executed: 20=======================
# Already have data csv for 510850
# Needs to update, start updating new data for 510850 now...
# New data updated till today for 510850!
# =======================Executed: 21=======================
# Already have data csv for 159959
# Needs to update, start updating new data for 159959 now...
# New data updated till today for 159959!
# =======================Executed: 22=======================
# Already have data csv for 511030
# Needs to update, start updating new data for 511030 now...
# New data updated till today for 511030!
# =======================Executed: 23=======================
# Already have data csv for 510390
# Needs to update, start updating new data for 510390 now...
# New data updated till today for 510390!
# =======================Executed: 24=======================
# Already have data csv for 510510
# Needs to update, start updating new data for 510510 now...
# New data updated till today for 510510!
# =======================Executed: 25=======================
# Already have data csv for 510380
# Needs to update, start updating new data for 510380 now...
# New data updated till today for 510380!
# =======================Executed: 26=======================
# Already have data csv for 512000
# Needs to update, start updating new data for 512000 now...
# New data updated till today for 512000!
# =======================Executed: 27=======================
# Already have data csv for 159962
# Needs to update, start updating new data for 159962 now...
# New data updated till today for 159962!
# =======================Executed: 28=======================
# Already have data csv for 510360
# Needs to update, start updating new data for 510360 now...
# New data updated till today for 510360!
# =======================Executed: 29=======================
# Already have data csv for 159928
# Needs to update, start updating new data for 159928 now...
# New data updated till today for 159928!
# =======================Executed: 30=======================
# Already have data csv for 159922
# Needs to update, start updating new data for 159922 now...
# New data updated till today for 159922!
# =======================Executed: 31=======================
# Already have data csv for 510880
# Needs to update, start updating new data for 510880 now...
# New data updated till today for 510880!
# =======================Executed: 32=======================
# Already have data csv for 159938
# Needs to update, start updating new data for 159938 now...
# New data updated till today for 159938!
# =======================Executed: 33=======================
# Already have data csv for 510590
# Needs to update, start updating new data for 510590 now...
# New data updated till today for 510590!
# =======================Executed: 34=======================
# Already have data csv for 159902
# Needs to update, start updating new data for 159902 now...
# New data updated till today for 159902!
# =======================Executed: 35=======================
# Already have data csv for 512660
# Needs to update, start updating new data for 512660 now...
# New data updated till today for 512660!
# =======================Executed: 36=======================
# Already have data csv for 512070
# Needs to update, start updating new data for 512070 now...
# New data updated till today for 512070!
# =======================Executed: 37=======================
# Already have data csv for 159939
# Needs to update, start updating new data for 159939 now...
# New data updated till today for 159939!
# =======================Executed: 38=======================
# Already have data csv for 511220
# Needs to update, start updating new data for 511220 now...
# New data updated till today for 511220!
# =======================Executed: 39=======================
# Already have data csv for 512900
# Needs to update, start updating new data for 512900 now...
# New data updated till today for 512900!
# =======================Executed: 40=======================
# Already have data csv for 512380
# Needs to update, start updating new data for 512380 now...
# New data updated till today for 512380!
# =======================Executed: 41=======================
# Already have data csv for 512800
# Needs to update, start updating new data for 512800 now...
# New data updated till today for 512800!
# =======================Executed: 42=======================
# Already have data csv for 512580
# Needs to update, start updating new data for 512580 now...
# New data updated till today for 512580!
# =======================Executed: 43=======================
# Already have data csv for 159905
# Needs to update, start updating new data for 159905 now...
# New data updated till today for 159905!
# =======================Executed: 44=======================
# Already have data csv for 159952
# Needs to update, start updating new data for 159952 now...
# New data updated till today for 159952!
# =======================Executed: 45=======================
# Already have data csv for 159910
# Needs to update, start updating new data for 159910 now...
# New data updated till today for 159910!
# =======================Executed: 46=======================
# Already have data csv for 511270
# Needs to update, start updating new data for 511270 now...
# New data updated till today for 511270!
# =======================Executed: 47=======================
# Already have data csv for 513050
# Needs to update, start updating new data for 513050 now...
# New data updated till today for 513050!
# =======================Executed: 48=======================
# Already have data csv for 159948
# Needs to update, start updating new data for 159948 now...
# New data updated till today for 159948!
# =======================Executed: 49=======================
# Already have data csv for 512980
# Needs to update, start updating new data for 512980 now...
# New data updated till today for 512980!
# =======================Executed: 50=======================
# Already have data csv for 511020
# Needs to update, start updating new data for 511020 now...
# New data updated till today for 511020!
# =======================Executed: 51=======================
# Already have data csv for 513500
# Needs to update, start updating new data for 513500 now...
# New data updated till today for 513500!
# =======================Executed: 52=======================
# Already have data csv for 510580
# Needs to update, start updating new data for 510580 now...
# New data updated till today for 510580!
# =======================Executed: 53=======================
# Already have data csv for 513660
# Needs to update, start updating new data for 513660 now...
# New data updated till today for 513660!
# =======================Executed: 54=======================
# Already have data csv for 512330
# Needs to update, start updating new data for 512330 now...
# New data updated till today for 512330!
# =======================Executed: 55=======================
# Already have data csv for 512010
# Needs to update, start updating new data for 512010 now...
# New data updated till today for 512010!
# =======================Executed: 56=======================
# Already have data csv for 159916
# Needs to update, start updating new data for 159916 now...
# New data updated till today for 159916!
# =======================Executed: 57=======================
# Already have data csv for 512160
# Needs to update, start updating new data for 512160 now...
# New data updated till today for 512160!
# =======================Executed: 58=======================
# Already have data csv for 510560
# Needs to update, start updating new data for 510560 now...
# New data updated till today for 510560!
# =======================Executed: 59=======================
# Already have data csv for 512510
# Needs to update, start updating new data for 512510 now...
# New data updated till today for 512510!
# =======================Executed: 60=======================
# Already have data csv for 513100
# Needs to update, start updating new data for 513100 now...
# New data updated till today for 513100!
# =======================Executed: 61=======================
# Already have data csv for 512090
# Needs to update, start updating new data for 512090 now...
# New data updated till today for 512090!
# =======================Executed: 62=======================
# Already have data csv for 159961
# Needs to update, start updating new data for 159961 now...
# New data updated till today for 159961!
# =======================Executed: 63=======================
# Already have data csv for 512040
# Needs to update, start updating new data for 512040 now...
# New data updated till today for 512040!
# =======================Executed: 64=======================
# Already have data csv for 512990
# Needs to update, start updating new data for 512990 now...
# New data updated till today for 512990!
# =======================Executed: 65=======================
# Already have data csv for 510160
# Needs to update, start updating new data for 510160 now...
# New data updated till today for 510160!
# =======================Executed: 66=======================
# Already have data csv for 510710
# Needs to update, start updating new data for 510710 now...
# New data updated till today for 510710!
# =======================Executed: 67=======================
# Already have data csv for 512180
# Needs to update, start updating new data for 512180 now...
# New data updated till today for 512180!
# =======================Executed: 68=======================
# Already have data csv for 159960
# Needs to update, start updating new data for 159960 now...
# New data updated till today for 159960!
# =======================Executed: 69=======================
# Already have data csv for 513030
# Needs to update, start updating new data for 513030 now...
# New data updated till today for 513030!
# =======================Executed: 70=======================
# Already have data csv for 511010
# Needs to update, start updating new data for 511010 now...
# New data updated till today for 511010!
# =======================Executed: 71=======================
# Already have data csv for 159940
# Needs to update, start updating new data for 159940 now...
# New data updated till today for 159940!
# =======================Executed: 72=======================
# Already have data csv for 512680
# Needs to update, start updating new data for 512680 now...
# New data updated till today for 512680!
# =======================Executed: 73=======================
# Already have data csv for 512520
# Needs to update, start updating new data for 512520 now...
# New data updated till today for 512520!
# =======================Executed: 74=======================
# Already have data csv for 512280
# Needs to update, start updating new data for 512280 now...
# New data updated till today for 512280!
# =======================Executed: 75=======================
# Already have data csv for 159903
# Needs to update, start updating new data for 159903 now...
# New data updated till today for 159903!
# =======================Executed: 76=======================
# Already have data csv for 512290
# Needs to update, start updating new data for 512290 now...
# New data updated till today for 512290!
# =======================Executed: 77=======================
# Already have data csv for 159933
# Needs to update, start updating new data for 159933 now...
# New data updated till today for 159933!
# =======================Executed: 78=======================
# Already have data csv for 510800
# Needs to update, start updating new data for 510800 now...
# New data updated till today for 510800!
# =======================Executed: 79=======================
# Already have data csv for 510010
# Needs to update, start updating new data for 510010 now...
# New data updated till today for 510010!
# =======================Executed: 80=======================
# Already have data csv for 159929
# Needs to update, start updating new data for 159929 now...
# New data updated till today for 159929!
# =======================Executed: 81=======================
# Already have data csv for 512220
# Needs to update, start updating new data for 512220 now...
# New data updated till today for 512220!
# =======================Executed: 82=======================
# Already have data csv for 512400
# Needs to update, start updating new data for 512400 now...
# New data updated till today for 512400!
# =======================Executed: 83=======================
# Already have data csv for 159935
# Needs to update, start updating new data for 159935 now...
# New data updated till today for 159935!
# =======================Executed: 84=======================
# Already have data csv for 159936
# Needs to update, start updating new data for 159936 now...
# New data updated till today for 159936!
# =======================Executed: 85=======================
# Already have data csv for 512890
# Needs to update, start updating new data for 512890 now...
# New data updated till today for 512890!
# =======================Executed: 86=======================
# Already have data csv for 159909
# Needs to update, start updating new data for 159909 now...
# New data updated till today for 159909!
# =======================Executed: 87=======================
# Already have data csv for 510210
# Needs to update, start updating new data for 510210 now...
# New data updated till today for 510210!
# =======================Executed: 88=======================
# Already have data csv for 512770
# Needs to update, start updating new data for 512770 now...
# New data updated till today for 512770!
# =======================Executed: 89=======================
# Already have data csv for 512700
# Needs to update, start updating new data for 512700 now...
# New data updated till today for 512700!
# =======================Executed: 90=======================
# Already have data csv for 159958
# Needs to update, start updating new data for 159958 now...
# New data updated till today for 159958!
# =======================Executed: 91=======================
# Already have data csv for 159965
# Needs to update, start updating new data for 159965 now...
# New data updated till today for 159965!
# =======================Executed: 92=======================
# Already have data csv for 510130
# Needs to update, start updating new data for 510130 now...
# New data updated till today for 510130!
# =======================Executed: 93=======================
# Already have data csv for 512920
# Needs to update, start updating new data for 512920 now...
# New data updated till today for 512920!
# =======================Executed: 94=======================
# Already have data csv for 159943
# Needs to update, start updating new data for 159943 now...
# New data updated till today for 159943!
# =======================Executed: 95=======================
# Already have data csv for 510630
# Needs to update, start updating new data for 510630 now...
# New data updated till today for 510630!
# =======================Executed: 96=======================
# Already have data csv for 510150
# Needs to update, start updating new data for 510150 now...
# New data updated till today for 510150!
# =======================Executed: 97=======================
# Already have data csv for 512260
# Needs to update, start updating new data for 512260 now...
# New data updated till today for 512260!
# =======================Executed: 98=======================
# Already have data csv for 512390
# Needs to update, start updating new data for 512390 now...
# New data updated till today for 512390!
# =======================Executed: 99=======================
# Already have data csv for 512820
# Needs to update, start updating new data for 512820 now...
# New data updated till today for 512820!
# =======================Executed: 100=======================
# Already have data csv for 159907
# Needs to update, start updating new data for 159907 now...
# New data updated till today for 159907!
# =======================Executed: 101=======================
# Already have data csv for 512360
# Needs to update, start updating new data for 512360 now...
# New data updated till today for 512360!
# =======================Executed: 102=======================
# Already have data csv for 510290
# Needs to update, start updating new data for 510290 now...
# New data updated till today for 510290!
# =======================Executed: 103=======================
# Already have data csv for 512100
# Needs to update, start updating new data for 512100 now...
# New data updated till today for 512100!
# =======================Executed: 104=======================
# Already have data csv for 510020
# Needs to update, start updating new data for 510020 now...
# New data updated till today for 510020!
# =======================Executed: 105=======================
# Already have data csv for 159957
# Needs to update, start updating new data for 159957 now...
# New data updated till today for 159957!
# =======================Executed: 106=======================
# Already have data csv for 512150
# Needs to update, start updating new data for 512150 now...
# New data updated till today for 512150!
# =======================Executed: 107=======================
# Already have data csv for 512550
# Needs to update, start updating new data for 512550 now...
# New data updated till today for 512550!
# =======================Executed: 108=======================
# Already have data csv for 510030
# Needs to update, start updating new data for 510030 now...
# New data updated till today for 510030!
# =======================Executed: 109=======================
# Already have data csv for 510550
# Needs to update, start updating new data for 510550 now...
# New data updated till today for 510550!
# =======================Executed: 110=======================
# Already have data csv for 510680
# Needs to update, start updating new data for 510680 now...
# New data updated till today for 510680!
# =======================Executed: 111=======================
# Already have data csv for 510060
# Needs to update, start updating new data for 510060 now...
# New data updated till today for 510060!
# =======================Executed: 112=======================
# Already have data csv for 512690
# Needs to update, start updating new data for 512690 now...
# New data updated till today for 512690!
# =======================Executed: 113=======================
# Already have data csv for 510220
# Needs to update, start updating new data for 510220 now...
# New data updated till today for 510220!
# =======================Executed: 114=======================
# Already have data csv for 159954
# Needs to update, start updating new data for 159954 now...
# New data updated till today for 159954!
# =======================Executed: 115=======================
# Already have data csv for 159906
# Needs to update, start updating new data for 159906 now...
# New data updated till today for 159906!
# =======================Executed: 116=======================
# Already have data csv for 159918
# Needs to update, start updating new data for 159918 now...
# New data updated till today for 159918!
# =======================Executed: 117=======================
# Already have data csv for 159912
# Needs to update, start updating new data for 159912 now...
# New data updated till today for 159912!
# =======================Executed: 118=======================
# Already have data csv for 510090
# Needs to update, start updating new data for 510090 now...
# New data updated till today for 510090!
# =======================Executed: 119=======================
# Already have data csv for 510170
# Needs to update, start updating new data for 510170 now...
# New data updated till today for 510170!
# =======================Executed: 120=======================
# Already have data csv for 159908
# Needs to update, start updating new data for 159908 now...
# New data updated till today for 159908!
# =======================Executed: 121=======================
# Already have data csv for 512870
# Needs to update, start updating new data for 512870 now...
# New data updated till today for 512870!
# =======================Executed: 122=======================
# Already have data csv for 512270
# Needs to update, start updating new data for 512270 now...
# New data updated till today for 512270!
# =======================Executed: 123=======================
# Already have data csv for 510190
# Needs to update, start updating new data for 510190 now...
# New data updated till today for 510190!
# =======================Executed: 124=======================
# Already have data csv for 510410
# Needs to update, start updating new data for 510410 now...
# New data updated till today for 510410!
# =======================Executed: 125=======================
# Already have data csv for 510430
# Needs to update, start updating new data for 510430 now...
# New data updated till today for 510430!
# =======================Executed: 126=======================
# Already have data csv for 512120
# Needs to update, start updating new data for 512120 now...
# New data updated till today for 512120!
# =======================Executed: 127=======================
# Already have data csv for 510660
# Needs to update, start updating new data for 510660 now...
# New data updated till today for 510660!
# =======================Executed: 128=======================
# Already have data csv for 510600
# Needs to update, start updating new data for 510600 now...
# New data updated till today for 510600!
# =======================Executed: 129=======================
# Already have data csv for 513600
# Needs to update, start updating new data for 513600 now...
# New data updated till today for 513600!
# =======================Executed: 130=======================
# Already have data csv for 159963
# Needs to update, start updating new data for 159963 now...
# New data updated till today for 159963!
# =======================Executed: 131=======================
# Already have data csv for 510070
# Needs to update, start updating new data for 510070 now...
# New data updated till today for 510070!
# =======================Executed: 132=======================
# Already have data csv for 159913
# Needs to update, start updating new data for 159913 now...
# New data updated till today for 159913!
# =======================Executed: 133=======================
# Already have data csv for 512200
# Needs to update, start updating new data for 512200 now...
# New data updated till today for 512200!
# =======================Executed: 134=======================
# Already have data csv for 512780
# Needs to update, start updating new data for 512780 now...
# New data updated till today for 512780!
# =======================Executed: 135=======================
# Already have data csv for 159956
# Needs to update, start updating new data for 159956 now...
# New data updated till today for 159956!
# =======================Executed: 136=======================
# Already have data csv for 512810
# Needs to update, start updating new data for 512810 now...
# New data updated till today for 512810!
# =======================Executed: 137=======================
# Already have data csv for 512640
# Needs to update, start updating new data for 512640 now...
# New data updated till today for 512640!
# =======================Executed: 138=======================
# Already have data csv for 159964
# Needs to update, start updating new data for 159964 now...
# New data updated till today for 159964!
# =======================Executed: 139=======================
# Already have data csv for 159911
# Needs to update, start updating new data for 159911 now...
# New data updated till today for 159911!
# =======================Executed: 140=======================
# Already have data csv for 512310
# Needs to update, start updating new data for 512310 now...
# New data updated till today for 512310!
# =======================Executed: 141=======================
# Already have data csv for 511280
# Needs to update, start updating new data for 511280 now...
# New data updated till today for 511280!
# =======================Executed: 142=======================
# Already have data csv for 512300
# Needs to update, start updating new data for 512300 now...
# New data updated till today for 512300!
# =======================Executed: 143=======================
# Already have data csv for 513900
# Needs to update, start updating new data for 513900 now...
# New data updated till today for 513900!
# =======================Executed: 144=======================
# Already have data csv for 512340
# Needs to update, start updating new data for 512340 now...
# New data updated till today for 512340!
# =======================Executed: 145=======================
# Already have data csv for 510650
# Needs to update, start updating new data for 510650 now...
# New data updated till today for 510650!
# =======================Executed: 146=======================
# Already have data csv for 511310
# Needs to update, start updating new data for 511310 now...
# New data updated till today for 511310!
# =======================Executed: 147=======================
# Already have data csv for 510110
# Needs to update, start updating new data for 510110 now...
# New data updated till today for 510110!
# =======================Executed: 148=======================
# Already have data csv for 512860
# Needs to update, start updating new data for 512860 now...
# New data updated till today for 512860!
# =======================Executed: 149=======================
# Already have data csv for 510440
# Needs to update, start updating new data for 510440 now...
# New data updated till today for 510440!
# =======================Executed: 150=======================
# Already have data csv for 159923
# Needs to update, start updating new data for 159923 now...
# New data updated till today for 159923!
# =======================Executed: 151=======================
# Already have data csv for 159931
# Needs to update, start updating new data for 159931 now...
# New data updated till today for 159931!
# =======================Executed: 152=======================
# Already have data csv for 159932
# Needs to update, start updating new data for 159932 now...
# New data updated till today for 159932!
# =======================Executed: 153=======================
# Already have data csv for 159945
# Needs to update, start updating new data for 159945 now...
# New data updated till today for 159945!
# =======================Executed: 154=======================
# Already have data csv for 511290
# Needs to update, start updating new data for 511290 now...
# New data updated till today for 511290!
# =======================Executed: 155=======================
# Already have data csv for 159955
# Needs to update, start updating new data for 159955 now...
# New data updated till today for 159955!
# =======================Executed: 156=======================
# Already have data csv for 512850
# Needs to update, start updating new data for 512850 now...
# New data updated till today for 512850!
# =======================Executed: 157=======================
# Already have data csv for 512560
# Needs to update, start updating new data for 512560 now...
# New data updated till today for 512560!
# =======================Executed: 158=======================
# Already have data csv for 510120
# Needs to update, start updating new data for 510120 now...
# New data updated till today for 510120!
# =======================Executed: 159=======================
# Already have data csv for 512590
# Needs to update, start updating new data for 512590 now...
# New data updated till today for 512590!
# =======================Executed: 160=======================
# Already have data csv for 159944
# Needs to update, start updating new data for 159944 now...
# New data updated till today for 159944!
# =======================Executed: 161=======================
# Already have data csv for 159953
# Needs to update, start updating new data for 159953 now...
# New data updated till today for 159953!
# =======================Executed: 162=======================
# Already have data csv for 159941
# Needs to update, start updating new data for 159941 now...
# New data updated till today for 159941!
# =======================Executed: 163=======================
# Already have data csv for 159930
# Needs to update, start updating new data for 159930 now...
# New data updated till today for 159930!
# =======================Executed: 164=======================
# Already have data csv for 512600
# Needs to update, start updating new data for 512600 now...
# New data updated till today for 512600!
# =======================Executed: 165=======================
# Already have data csv for 510270
# Needs to update, start updating new data for 510270 now...
# New data updated till today for 510270!
# =======================Executed: 166=======================
# Already have data csv for 512610
# Needs to update, start updating new data for 512610 now...
# New data updated till today for 512610!
# =======================Executed: 167=======================
# Already have data csv for 159951
# Needs to update, start updating new data for 159951 now...
# New data updated till today for 159951!
# =======================Executed: 168=======================
# Already have data csv for 159926
# Needs to update, start updating new data for 159926 now...
# New data updated till today for 159926!
# =======================Executed: 169=======================
# Already have data csv for 513680
# Needs to update, start updating new data for 513680 now...
# New data updated till today for 513680!
# =======================Executed: 170=======================
# 【Updated Finished for today!】
