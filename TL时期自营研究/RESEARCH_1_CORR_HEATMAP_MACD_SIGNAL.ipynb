# %%
import pandas as pd, numpy as np
import glob
import os
import csv
# 一次性merge多个pct_chg
from functools import reduce

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set(context='notebook', style='darkgrid', palette='deep', font='sans-serif', font_scale=1, color_codes=False, rc=None)

# %% [markdown]
# # Prepare Tickers and Functions

# %%
def sp500():
    sp500_list = ['MMM', 'ABT', 'ABBV', 'ACN', 'ATVI', 'AYI', 'ADBE', 'AMD', 'HII', 'AAP', 'AES', 'AET', 'AMG', 'AFL', 'A', 'APD', 'AKAM', 'ALK', 'ALB', 'ARE', 'ALXN', 'ALGN', 'ALLE', 'AGN', 'ADS', 'LNT', 'ALL', 'GOOGL', 'GOOG', 'MO', 'AMZN', 'AEE', 'AAL', 'AEP', 'AXP', 'AIG', 'AMT', 'AWK', 'AMP', 'ABC', 'AME', 'AMGN', 'APH', 'APC', 'ADI', 'ANDV', 'ANSS', 'ANTM', 'AON', 'AOS', 'APA', 'AIV', 'AAPL', 'AMAT', 'APTV', 'ADM', 'ARNC', 'AJG', 'AIZ', 'T', 'ADSK', 'ADP', 'AZO', 'AVB', 'AVY', 'BHGE', 'BLL', 'BAC', 'BK', 'BAX', 'BBT', 'BDX', 'BRK.B', 'BBY', 'BIIB', 'BLK', 'HRB', 'BA', 'BWA', 'BXP', 'BSX', 'BHF', 'BMY', 'AVGO', 'BF.B', 'CHRW', 'CA', 'COG', 'CDNS', 'CPB', 'COF', 'CAH', 'CBOE', 'KMX', 'CCL', 'CAT', 'CBG', 'CBS', 'CELG', 'CNC', 'CNP', 'CTL', 'CERN', 'CF', 'SCHW', 'CHTR', 'CHK', 'CVX', 'CMG', 'CB', 'CHD', 'CI', 'XEC', 'CINF', 'CTAS', 'CSCO', 'C', 'CFG', 'CTXS', 'CLX', 'CME', 'CMS', 'KO', 'CTSH', 'CL', 'CMCSA', 'CMA', 'CAG', 'CXO', 'COP', 'ED', 'STZ', 'COO', 'GLW', 'COST', 'COTY', 'CCI', 'CSRA', 'CSX', 'CMI', 'CVS', 'DHI', 'DHR', 'DRI', 'DVA', 'DE', 'DAL', 'XRAY', 'DVN', 'DLR', 'DFS', 'DISCA', 'DISCK', 'DISH', 'DG', 'DLTR', 'D', 'DOV', 'DWDP', 'DPS', 'DTE', 'DRE', 'DUK', 'DXC', 'ETFC', 'EMN', 'ETN', 'EBAY', 'ECL', 'EIX', 'EW', 'EA', 'EMR', 'ETR', 'EVHC', 'EOG', 'EQT', 'EFX', 'EQIX', 'EQR', 'ESS', 'EL', 'ES', 'RE', 'EXC', 'EXPE', 'EXPD', 'ESRX', 'EXR', 'XOM', 'FFIV', 'FB', 'FAST', 'FRT', 'FDX', 'FIS', 'FITB', 'FE', 'FISV', 'FLIR', 'FLS', 'FLR', 'FMC', 'FL', 'F', 'FTV', 'FBHS', 'BEN', 'FCX', 'GPS', 'GRMN', 'IT', 'GD', 'GE', 'GGP', 'GIS', 'GM', 'GPC', 'GILD', 'GPN', 'GS', 'GT', 'GWW', 'HAL', 'HBI', 'HOG', 'HRS', 'HIG', 'HAS', 'HCA', 'HCP', 'HP', 'HSIC', 'HSY', 'HES', 'HPE', 'HLT', 'HOLX', 'HD', 'HON', 'HRL', 'HST', 'HPQ', 'HUM', 'HBAN', 'IDXX', 'INFO', 'ITW', 'ILMN', 'IR', 'INTC', 'ICE', 'IBM', 'INCY', 'IP', 'IPG', 'IFF', 'INTU', 'ISRG', 'IVZ', 'IQV', 'IRM', 'JEC', 'JBHT', 'SJM', 'JNJ', 'JCI', 'JPM', 'JNPR', 'KSU', 'K', 'KEY', 'KMB', 'KIM', 'KMI', 'KLAC', 'KSS', 'KHC', 'KR', 'LB', 'LLL', 'LH', 'LRCX', 'LEG', 'LEN', 'LUK', 'LLY', 'LNC', 'LKQ', 'LMT', 'L', 'LOW', 'LYB', 'MTB', 'MAC', 'M', 'MRO', 'MPC', 'MAR', 'MMC', 'MLM', 'MAS', 'MA', 'MAT', 'MKC', 'MCD', 'MCK', 'MDT', 'MRK', 'MET', 'MTD', 'MGM', 'KORS', 'MCHP', 'MU', 'MSFT', 'MAA', 'MHK', 'TAP', 'MDLZ', 'MON', 'MNST', 'MCO', 'MS', 'MOS', 'MSI', 'MYL', 'NDAQ', 'NOV', 'NAVI', 'NTAP', 'NFLX', 'NWL', 'NFX', 'NEM', 'NWSA', 'NWS', 'NEE', 'NLSN', 'NKE', 'NI', 'NBL', 'JWN', 'NSC', 'NTRS', 'NOC', 'NCLH', 'NRG', 'NUE', 'NVDA', 'ORLY', 'OXY', 'OMC', 'OKE', 'ORCL', 'PCAR', 'PKG', 'PH', 'PDCO', 'PAYX', 'PYPL', 'PNR', 'PBCT', 'PEP', 'PKI', 'PRGO', 'PFE', 'PCG', 'PM', 'PSX', 'PNW', 'PXD', 'PNC', 'RL', 'PPG', 'PPL', 'PX', 'PCLN', 'PFG', 'PG', 'PGR', 'PLD', 'PRU', 'PEG', 'PSA', 'PHM', 'PVH', 'QRVO', 'PWR', 'QCOM', 'DGX', 'RRC', 'RJF', 'RTN', 'O', 'RHT', 'REG', 'REGN', 'RF', 'RSG', 'RMD', 'RHI', 'ROK', 'COL', 'ROP', 'ROST', 'RCL', 'CRM', 'SBAC', 'SCG', 'SLB', 'SNI', 'STX', 'SEE', 'SRE', 'SHW', 'SIG', 'SPG', 'SWKS', 'SLG', 'SNA', 'SO', 'LUV', 'SPGI', 'SWK', 'SBUX', 'STT', 'SRCL', 'SYK', 'STI', 'SYMC', 'SYF', 'SNPS', 'SYY', 'TROW', 'TPR', 'TGT', 'TEL', 'FTI', 'TXN', 'TXT', 'TMO', 'TIF', 'TWX', 'TJX', 'TMK', 'TSS', 'TSCO', 'TDG', 'TRV', 'TRIP', 'FOXA', 'FOX', 'TSN', 'UDR', 'ULTA', 'USB', 'UA', 'UAA', 'UNP', 'UAL', 'UNH', 'UPS', 'URI', 'UTX', 'UHS', 'UNM', 'VFC', 'VLO', 'VAR', 'VTR', 'VRSN', 'VRSK', 'VZ', 'VRTX', 'VIAB', 'V', 'VNO', 'VMC', 'WMT', 'WBA', 'DIS', 'WM', 'WAT', 'WEC', 'WFC', 'HCN', 'WDC', 'WU', 'WRK', 'WY', 'WHR', 'WMB', 'WLTW', 'WYN', 'WYNN', 'XEL', 'XRX', 'XLNX', 'XL', 'XYL', 'YUM', 'ZBH', 'ZION', 'ZTS']
    return sp500_list

def all_weather():
    all_weather_portfolio = ["VTI","TLT","IEF","GLD","DBC"]
    return all_weather_portfolio

def us_sectors_etf():
    us_sectors = ["IYM","IYZ","FCL","FCD","IYE","IYG","IYH","IYJ","IYR","IYW","IDU"]
    return us_sectors

def get_code():
    codes = pro.stock_basic(list_status='L').ts_code.values
    return codes

# For processing ETFs:
def generate_ch_etfs_ticker_list(etf_info_path_file):
    ch_etfs_df = pd.read_csv(etf_info_path_file)
    ch_etfs_df.dropna(inplace = True)
    ch_etfs_df['基金规模\n[单位] 元'] = ch_etfs_df['基金规模\n[单位] 元'].apply(lambda x: float(x.replace(",","")))
    ch_etfs_df['机构投资者持有份额\n[报告期] 2019中报\n[单位] 份'] = ch_etfs_df['机构投资者持有份额\n[报告期] 2019中报\n[单位] 份'].apply(lambda x: float(x.replace(",","")))
    ch_etfs_df.sort_values("基金规模\n[单位] 元", ascending=False, inplace =True)
    ch_etfs_df = ch_etfs_df
    ch_etfs = ch_etfs_df.copy()
    ch_etfs['code'] =ch_etfs['证券代码'].apply(lambda x: str(x)[:6])
    ch_etfs_ticker_list = list(ch_etfs['code'].unique())
    return ch_etfs_ticker_list


def get_df_date_price_code(path, ticker_list, date_col, price_col, code_col):
    # for etf data cols are 'date', 'close', 'code'
    ticker_df_list = []
    for ticker in ticker_list:
        print("Reading Assets: ", ticker)
        try:
            ticker_df = pd.read_csv(path+ticker+".csv")
            ticker_df = ticker_df.sort_values(date_col)
            ticker_df = ticker_df[[date_col, price_col, code_col]]
            ticker_df['pct_chg'] = ticker_df[price_col].pct_change()
            ticker_df = ticker_df[[date_col, 'pct_chg']].dropna()
            ticker_df.columns = [date_col,ticker]
            ticker_df[date_col] = pd.to_datetime(ticker_df[date_col])
            ticker_df_list.append(ticker_df)
        except:
            pass
    return ticker_df_list

# 先为之后使用reduce铺路：创造一个merge的函数，这里的目的是为了将多资产数据基于date_col进行merge：
def merge_df(df1, df2, date_col="date"):
    # By default the etf's date_col goes by 'date'
    merged = df1.merge(df2, on = date_col, how = 'outer')
    merged.sort_values(date_col, inplace = True)
    return merged

def merge_df_for_corr(ticker_df_list, date_col):
    # Here below merge_df is a function instead of a variable
    merged_all = reduce(merge_df, ticker_df_list)
    # For etf data the date col is 'date'
    merged_all.set_index(date_col, inplace=True)
    merged_all.dropna(how="all", axis = 1, inplace = True)
    return merged_all

def select_N_lowest_corr_assets(merged_all, asset_category, n):
    # asset_category be default for etf is 'etf'
    # Create ETFs' correlation matrix dataframe
    merged_all_corr = merged_all.corr()
    merged_all_corr_abs = abs(merged_all_corr)
    corr_mean_dict = {}
    for row in merged_all_corr_abs.iterrows():
        row_list = list(row)
        print(row_list[0])
        print(np.mean(row_list[1]))
        corr_mean_dict[row_list[0]] = np.mean(row_list[1])
        print("========")
    corr_mean_df = pd.DataFrame()
    corr_mean_df[asset_category] = corr_mean_dict.keys()
    corr_mean_df['abs_corr_mean'] = corr_mean_dict.values()
    corr_mean_df_assets = corr_mean_df.sort_values("abs_corr_mean", ascending=True)
    lowest_corr_assets_list = list(corr_mean_df_assets[asset_category])[:n]
    return lowest_corr_assets_list, corr_mean_df_assets

def select_df_from_db_by_tickers(path, ticker_list):
    # e.g. ch_db_path = "/Users/miaoyuesun/Code_Workspace/brad_public_workspace_mac/data/CH_database/"
    csv_path = path+"*.csv"
    files = glob.glob(csv_path)
    
    tickers_data = []
    if len(ticker_list)!=1:
        for ticker in ticker_list:
            print("Reading: ", ticker)
            df = pd.read_csv(path+ticker+".csv")
            tickers_data.append(df)
        tickers_data_concated = pd.concat(tickers_data)
        tickers_data_concated.reset_index(inplace=True)
        del tickers_data_concated['index']
    else:
        df = pd.read_csv(path+ticker_list[0]+".csv")
        tickers_data_concated = df
    return tickers_data_concated

def MACD(df, n_fast, n_slow, n_macd, price_col): # n_fast = 12, n_slow = 26
    """
    http://stockcharts.com/docs/doku.php?id=scans:indicators
    MACD, MACD Signal and MACD difference, rationale CHECKED, code CHECKED, updated
    # Conventional look-back window for calculating MACDsign is 9
    """
    EMAfast = df[price_col].ewm(span = n_fast, min_periods = n_fast - 1).mean()
    EMAslow = df[price_col].ewm(span = n_slow, min_periods = n_slow - 1).mean()
    MACD = pd.Series(EMAfast - EMAslow, name = 'MACD_' + str(n_fast) + '_' + str(n_slow))
    MACDsign = MACD.ewm(span = n_macd, min_periods = n_macd-1).mean().rename('MACDsign_' + str(n_fast) + '_' + str(n_slow))
    MACDdiff = pd.Series(MACD - MACDsign, name = 'MACDdiff_' + str(n_fast) + '_' + str(n_slow))
    df['MACD_Diff'] = MACD
    df['MACD_Diff_EMA'] = MACDsign
    df['MACD'] = MACDdiff
    df['SIGNAL_STATUS'] = df['MACD'].apply(lambda x: "多头状态" if x>0 else ("空头状态" if x<0 else "无信号状态"))
    return df

def calc_macd_signals(tickers_data_concated, ticker_list, code_col, ticker_type, price_col):
    signal_record = []
    signal_data = []
    if len(ticker_list)!=1:
        for ticker in ticker_list:
            print("Calculating Signal for: ", ticker)
            try:
                if ticker_type == "float":
                # Be aware of types of ticker values here, whether it's float or strings, depends.
                    single_ticker_df = tickers_data_concated[tickers_data_concated[code_col]==float(ticker)]
                elif ticker_type == "string":
                    single_ticker_df = tickers_data_concated[tickers_data_concated[code_col]==ticker]
                signal_df = MACD(single_ticker_df, 12, 26, 9, price_col)
#                 last_signal = signal_df[[code_col,'SIGNAL_STATUS']].values[-1]
                signal_data.append(signal_df)
#                 signal_record.append(last_signal)
            except:
                pass
        signal_data_df = pd.concat(signal_data)
    else:
        print("Calculating Signal for: ", ticker_list[0])
        try:                
            print("getting thru")
            signal_df = MACD(tickers_data_concated, 12, 26, 9, price_col)
#             last_signal = signal_df[[code_col,'SIGNAL_STATUS']].values[-1]
#             signal_data.append(signal_df)
#             signal_record.append(last_signal)
        except:
            pass
        signal_data_df = signal_df
    return signal_data_df
    
    
def make_numeric_signals(series):
    for item in series:
#         print(item)
        if item =="多":
            return 1
        elif item =="空":
            return -1
        else:
            return 0
        
def generate_most_recent_signal_data_v1(signal_data_df, date_col, code_col):
    # v1 is the version of generating the og macd signals
    signal_data_df['SIGNAL_DIRECTION'] = signal_data_df['SIGNAL_STATUS'].apply(lambda x: make_numeric_signals(x))
    signal_data_df['SIGNAL_DIRECTION_DIFF'] = signal_data_df.groupby([code_col])['SIGNAL_DIRECTION'].diff()
    signal_data_df['SIGNAL_ACTION'] = signal_data_df['SIGNAL_DIRECTION_DIFF'].apply(lambda x: "LONG" if x==2 else("SHORT" if x==-2 else "NO CHANGE"))
    most_recent_signals = signal_data_df.groupby([code_col])[[date_col,code_col,'SIGNAL_STATUS','SIGNAL_ACTION']].tail(1)
    return most_recent_signals

def check_macd_signal_plot(signal_data_df, ticker, cols_list_to_plot, code_col, N_tails, date_col):
    signal_data_df_copy = signal_data_df.copy()
    signal_data_df_copy.set_index(date_col, inplace = True)
    df_to_plot = signal_data_df_copy[signal_data_df_copy[code_col]==ticker][cols_list_to_plot].tail(N_tails)
    df_to_plot.plot(figsize = (18, 6))
    plt.title("{}".format(ticker))

# %%
ch_db_path = "/Users/miaoyuesun/Code_Workspace/brad_public_workspace_mac/data/CH_database/"
us_db_path = "/Users/miaoyuesun/Code_Workspace/brad_public_workspace_mac/data/US_database/"
etf_info_path_file = "/Users/miaoyuesun/Code_Workspace/brad_public_workspace_mac/data/CH_ETFs.csv"

# %% [markdown]
# # On ETFs

# %%
# On etfs:
# ch_etfs_ticker_list = ['603867.SH','603868.SH']
# 20200211 删除low-quality tickers
low_quality_tickers = ['511290','159926','510120','518880','511310','511280','510440','513900','513680','159944','510430','510560','159953','510380','510020']
ch_etfs_ticker_list = generate_ch_etfs_ticker_list(etf_info_path_file)
ch_etfs_ticker_list = list(set(ch_etfs_ticker_list)-set(low_quality_tickers))

# etf_ticker_df_list = get_df_date_price_code(ch_db_path, ch_etfs_ticker_list, 'trade_date', 'close', 'ts_code')
etf_ticker_df_list = get_df_date_price_code(ch_db_path, ch_etfs_ticker_list, 'date', 'close', 'code')
# merged_etfs = merge_df_for_corr(etf_ticker_df_list, 'trade_date')
merged_etfs = merge_df_for_corr(etf_ticker_df_list, 'date')
# lowest_corr_etf_list = select_N_lowest_corr_assets(merged_etfs, "stocks", 20)
lowest_corr_etf_list,corr_mean_df_assets = select_N_lowest_corr_assets(merged_etfs, "etf", 40)

lowest_corr_etf_df = select_df_from_db_by_tickers(ch_db_path, lowest_corr_etf_list)
# lowest_corr_etf_macd_signals = calc_macd_signals(lowest_corr_etf_df, lowest_corr_etf_list, 'ts_code', 'float','close')
lowest_corr_etf_macd_signals = calc_macd_signals(lowest_corr_etf_df, lowest_corr_etf_list, 'code', 'float','close')
# most_recent_etf_macd_signals = generate_most_recent_signal_data_v1(lowest_corr_etf_macd_signals, 'trade_date','ts_code')
most_recent_etf_macd_signals = generate_most_recent_signal_data_v1(lowest_corr_etf_macd_signals, 'date','code')
# Out:
# Reading Assets:  510270
# Reading Assets:  512000
# Reading Assets:  512640
# Reading Assets:  510110
# Reading Assets:  510900
# Reading Assets:  512560
# Reading Assets:  512040
# Reading Assets:  159958
# Reading Assets:  159909
# /Users/miaoyuesun/anaconda3/lib/python3.5/site-packages/pandas/compat/_optional.py:106: UserWarning: Pandas requires version '2.6.2' or newer of 'numexpr' (version '2.6.1' currently installed).
#   warnings.warn(msg, UserWarning)
# Reading Assets:  512200
# Reading Assets:  159960
# Reading Assets:  511220
# Reading Assets:  513050
# Reading Assets:  159954
# Reading Assets:  510880
# Reading Assets:  159955
# Reading Assets:  512280
# Reading Assets:  510220
# Reading Assets:  512160
# Reading Assets:  510330
# Reading Assets:  159964
# Reading Assets:  510600
# Reading Assets:  510660
# Reading Assets:  513500
# Reading Assets:  510410
# Reading Assets:  510590
# Reading Assets:  512610
# Reading Assets:  159939
# Reading Assets:  512990
# Reading Assets:  510180
# Reading Assets:  510070
# Reading Assets:  510060
# Reading Assets:  510300
# Reading Assets:  159962
# Reading Assets:  512100
# Reading Assets:  512880
# Reading Assets:  512800
# Reading Assets:  512010
# Reading Assets:  159938
# Reading Assets:  510360
# Reading Assets:  510030
# Reading Assets:  159948
# Reading Assets:  510550
# Reading Assets:  512340
# Reading Assets:  510290
# Reading Assets:  159935
# Reading Assets:  159916
# Reading Assets:  159923
# Reading Assets:  512500
# Reading Assets:  513100
# Reading Assets:  159919
# Reading Assets:  512820
# Reading Assets:  159901
# Reading Assets:  512070
# Reading Assets:  159918
# Reading Assets:  512360
# Reading Assets:  512330
# Reading Assets:  512860
# Reading Assets:  510510
# Reading Assets:  510190
# Reading Assets:  159922
# Reading Assets:  512550
# Reading Assets:  159936
# Reading Assets:  159965
# Reading Assets:  512150
# Reading Assets:  512380
# Reading Assets:  512220
# Reading Assets:  512600
# Reading Assets:  159902
# Reading Assets:  512920
# Reading Assets:  159961
# Reading Assets:  513600
# Reading Assets:  159945
# Reading Assets:  510050
# Reading Assets:  511270
# Reading Assets:  510160
# Reading Assets:  159933
# Reading Assets:  512300
# Reading Assets:  159910
# Reading Assets:  159908
# Reading Assets:  512590
# Reading Assets:  512850
# Reading Assets:  510150
# Reading Assets:  159957
# Reading Assets:  159956
# Reading Assets:  510090
# Reading Assets:  512390
# Reading Assets:  512700
# Reading Assets:  159903
# Reading Assets:  510650
# Reading Assets:  510210
# Reading Assets:  512270
# Reading Assets:  159959
# Reading Assets:  159941
# Reading Assets:  512120
# Reading Assets:  512520
# Reading Assets:  512580
# Reading Assets:  159940
# Reading Assets:  510850
# Reading Assets:  512680
# Reading Assets:  512260
# Reading Assets:  510310
# Reading Assets:  510170
# Reading Assets:  159963
# Reading Assets:  159952
# Reading Assets:  510710
# Reading Assets:  512180
# Reading Assets:  159907
# Reading Assets:  512290
# Reading Assets:  512660
# Reading Assets:  511010
# Reading Assets:  159906
# Reading Assets:  159905
# Reading Assets:  512950
# Reading Assets:  511020
# Reading Assets:  159912
# Reading Assets:  512310
# Reading Assets:  159931
# Reading Assets:  512510
# Reading Assets:  513030
# Reading Assets:  511030
# Reading Assets:  512980
# Reading Assets:  510230
# Reading Assets:  513660
# Reading Assets:  512090
# Reading Assets:  512810
# Reading Assets:  159951
# Reading Assets:  159932
# Reading Assets:  510500
# Reading Assets:  512870
# Reading Assets:  512960
# Reading Assets:  510010
# Reading Assets:  510680
# Reading Assets:  159913
# Reading Assets:  510810
# Reading Assets:  512690
# Reading Assets:  510390
# Reading Assets:  512900
# Reading Assets:  159929
# Reading Assets:  159920
# Reading Assets:  159949
# Reading Assets:  510580
# Reading Assets:  512780
# Reading Assets:  510130
# Reading Assets:  159915
# Reading Assets:  512400
# Reading Assets:  159928
# Reading Assets:  510800
# Reading Assets:  159943
# Reading Assets:  159911
# Reading Assets:  510630
# Reading Assets:  159930
# Reading Assets:  512770
# Reading Assets:  512890
# 510270
# 0.5065000324647785
# ========
# 512000
# 0.6057611250496521
# ========
# 512640
# 0.5164549419435496
# ========
# 510110
# 0.4237121404198496
# ========
# 510900
# 0.5301411961933795
# ========
# 512560
# 0.4587403177615428
# ========
# 512040
# 0.7818193257155042
# ========
# 159958
# 0.6911008576492669
# ========
# 159909
# 0.5541766785371544
# ========
# 512200
# 0.6102216418868004
# ========
# 159960
# 0.4821821488391238
# ========
# 511220
# 0.04357961277360838
# ========
# 513050
# 0.4721142930811029
# ========
# 159954
# 0.6075220900139703
# ========
# 510880
# 0.6811735900253151
# ========
# 159955
# 0.6754623188238953
# ========
# 512280
# 0.7626376820966787
# ========
# 510220
# 0.5519873017840085
# ========
# 512160
# 0.7612207199753529
# ========
# 510330
# 0.7150468191606328
# ========
# 159964
# 0.7219155564004631
# ========
# 510600
# 0.7177662923744849
# ========
# 510660
# 0.5852935762434038
# ========
# 513500
# 0.25169237104125974
# ========
# 510410
# 0.5881026587077093
# ========
# 510590
# 0.7423225187079748
# ========
# 512610
# 0.5579563439999405
# ========
# 159939
# 0.6152504993455806
# ========
# 512990
# 0.7436074416360773
# ========
# 510180
# 0.5271561744350094
# ========
# 510070
# 0.5580944412538025
# ========
# 510060
# 0.6269081233366528
# ========
# 510300
# 0.721790178249415
# ========
# 159962
# 0.6530993644442198
# ========
# 512100
# 0.6546570456613999
# ========
# 512880
# 0.6071579888002409
# ========
# 512800
# 0.5819380688644209
# ========
# 512010
# 0.5804339979322239
# ========
# 159938
# 0.6291398964627553
# ========
# 510360
# 0.7206172281699216
# ========
# 510030
# 0.5785253901464354
# ========
# 159948
# 0.656553231689527
# ========
# 510550
# 0.7313559286062326
# ========
# 512340
# 0.6787828899945365
# ========
# 510290
# 0.6899578419489758
# ========
# 159935
# 0.4418760256046205
# ========
# 159916
# 0.4963521283676478
# ========
# 159923
# 0.5503629166702242
# ========
# 512500
# 0.7213717444153285
# ========
# 513100
# 0.2945223913731557
# ========
# 159919
# 0.6084346556536165
# ========
# 512820
# 0.597510504059606
# ========
# 159901
# 0.5044338461176155
# ========
# 512070
# 0.6511361902733599
# ========
# 159918
# 0.4722764581651466
# ========
# 512360
# 0.7590367233962618
# ========
# 512330
# 0.6202038261321725
# ========
# 512860
# 0.7653997885773638
# ========
# 510510
# 0.7060391918200738
# ========
# 510190
# 0.5593905083772773
# ========
# 159922
# 0.6826236505437467
# ========
# 512550
# 0.6761868310148559
# ========
# 159936
# 0.5532295165639035
# ========
# 159965
# 0.7532200599664612
# ========
# 512150
# 0.7054924599195889
# ========
# 512380
# 0.7864033130724093
# ========
# 512220
# 0.5173917582426768
# ========
# 512600
# 0.4722910391607745
# ========
# 159902
# 0.7049918983388134
# ========
# 512920
# 0.6061311497082602
# ========
# 159961
# 0.7543317151801128
# ========
# 513600
# 0.45576757949233443
# ========
# 159945
# 0.5131791443545972
# ========
# 510050
# 0.6544578669437291
# ========
# 511270
# 0.3303372075333283
# ========
# 510160
# 0.6844867494973697
# ========
# 159933
# 0.4552256494962528
# ========
# 512300
# 0.6063653530255566
# ========
# 159910
# 0.6149639106184075
# ========
# 159908
# 0.4532763377647424
# ========
# 512590
# 0.7459290567698174
# ========
# 512850
# 0.718092786623623
# ========
# 510150
# 0.5443643864211601
# ========
# 159957
# 0.6718631811747954
# ========
# 159956
# 0.638000114799811
# ========
# 510090
# 0.3646427547778619
# ========
# 512390
# 0.7133294332754528
# ========
# 512700
# 0.5760577271877689
# ========
# 159903
# 0.6853094687280329
# ========
# 510650
# 0.5433570806147684
# ========
# 510210
# 0.5356277114902012
# ========
# 512270
# 0.7751147929534075
# ========
# 159959
# 0.7648485157050585
# ========
# 159941
# 0.3183799533902503
# ========
# 512120
# 0.5225113565973889
# ========
# 512520
# 0.7618427695835887
# ========
# 512580
# 0.6654839217384514
# ========
# 159940
# 0.6435829604276039
# ========
# 510850
# 0.7425447741547043
# ========
# 512680
# 0.5575194349382777
# ========
# 512260
# 0.7487605613188837
# ========
# 510310
# 0.7253854123665204
# ========
# 510170
# 0.4629957727061665
# ========
# 159963
# 0.6138208908673237
# ========
# 159952
# 0.670512984006276
# ========
# 510710
# 0.6761906177593574
# ========
# 512180
# 0.7596355689802358
# ========
# 159907
# 0.6712669155029644
# ========
# 512290
# 0.5371118946872327
# ========
# 512660
# 0.5615423664629033
# ========
# 511010
# 0.19569058443212273
# ========
# 159906
# 0.5118673047987232
# ========
# 159905
# 0.6737749810813197
# ========
# 512950
# 0.7817139808604726
# ========
# 511020
# 0.4101524576015904
# ========
# 159912
# 0.6235221945637295
# ========
# 512310
# 0.7032941111585642
# ========
# 159931
# 0.5198156113801834
# ========
# 512510
# 0.7282581131099137
# ========
# 513030
# 0.3625666683371087
# ========
# 511030
# 0.05978031797872168
# ========
# 512980
# 0.6733152548479053
# ========
# 510230
# 0.6013947826665537
# ========
# 513660
# 0.49354698817576087
# ========
# 512090
# 0.763847499366777
# ========
# 512810
# 0.5550277910267565
# ========
# 159951
# 0.48534652383998733
# ========
# 159932
# 0.46168655235635
# ========
# 510500
# 0.4863156081095694
# ========
# 512870
# 0.7747252150045757
# ========
# 512960
# 0.7775722179505685
# ========
# 510010
# 0.5698057122406404
# ========
# 510680
# 0.3196019243140075
# ========
# 159913
# 0.4670925470928331
# ========
# 510810
# 0.6572689191745357
# ========
# 512690
# 0.5951554302311068
# ========
# 510390
# 0.7472953983171395
# ========
# 512900
# 0.6146237674537209
# ========
# 159929
# 0.6127197913882572
# ========
# 159920
# 0.4791827987585127
# ========
# 159949
# 0.6452068301150516
# ========
# 510580
# 0.44070459554537245
# ========
# 512780
# 0.6746991564167116
# ========
# 510130
# 0.5866840133769246
# ========
# 159915
# 0.6471993537848469
# ========
# 512400
# 0.5868370115494383
# ========
# 159928
# 0.6053405250475564
# ========
# 510800
# 0.6923808603263322
# ========
# 159943
# 0.6935301315294408
# ========
# 159911
# 0.5529270038177848
# ========
# 510630
# 0.5980846633964043
# ========
# 159930
# 0.5365170364063393
# ========
# 512770
# 0.7089396758633495
# ========
# 512890
# 0.7532575998538921
# ========
# Reading:  511220
# Reading:  511030
# Reading:  511010
# Reading:  513500
# Reading:  513100
# Reading:  159941
# Reading:  510680
# Reading:  511270
# Reading:  513030
# Reading:  510090
# Reading:  511020
# Reading:  510110
# Reading:  510580
# Reading:  159935
# Reading:  159908
# Reading:  159933
# Reading:  513600
# Reading:  512560
# Reading:  159932
# Reading:  510170
# Reading:  159913
# Reading:  513050
# Reading:  159918
# Reading:  512600
# Reading:  159920
# Reading:  159960
# Reading:  159951
# Reading:  510500
# Reading:  513660
# Reading:  159916
# Reading:  159901
# Reading:  510270
# Reading:  159906
# Reading:  159945
# Reading:  512640
# Reading:  512220
# Reading:  159931
# Reading:  512120
# Reading:  510180
# Reading:  510900
# Calculating Signal for:  511220
# Calculating Signal for:  511030
# Calculating Signal for:  511010
# Calculating Signal for:  513500
# Calculating Signal for:  513100
# Calculating Signal for:  159941
# Calculating Signal for:  510680
# Calculating Signal for:  511270
# Calculating Signal for:  513030
# Calculating Signal for:  510090
# Calculating Signal for:  511020
# /Users/miaoyuesun/anaconda3/lib/python3.5/site-packages/ipykernel_launcher.py:113: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/miaoyuesun/anaconda3/lib/python3.5/site-packages/ipykernel_launcher.py:114: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/miaoyuesun/anaconda3/lib/python3.5/site-packages/ipykernel_launcher.py:115: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/miaoyuesun/anaconda3/lib/python3.5/site-packages/ipykernel_launcher.py:116: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Calculating Signal for:  510110
# Calculating Signal for:  510580
# Calculating Signal for:  159935
# Calculating Signal for:  159908
# Calculating Signal for:  159933
# Calculating Signal for:  513600
# Calculating Signal for:  512560
# Calculating Signal for:  159932
# Calculating Signal for:  510170
# Calculating Signal for:  159913
# Calculating Signal for:  513050
# Calculating Signal for:  159918
# Calculating Signal for:  512600
# Calculating Signal for:  159920
# Calculating Signal for:  159960
# Calculating Signal for:  159951
# Calculating Signal for:  510500
# Calculating Signal for:  513660
# Calculating Signal for:  159916
# Calculating Signal for:  159901
# Calculating Signal for:  510270
# Calculating Signal for:  159906
# Calculating Signal for:  159945
# Calculating Signal for:  512640
# Calculating Signal for:  512220
# Calculating Signal for:  159931
# Calculating Signal for:  512120
# Calculating Signal for:  510180
# Calculating Signal for:  510900

# %%
corr_mean_df_assets.head(40)
# Out:
#         etf  abs_corr_mean
# 26   511220       0.043580
# 85   511030       0.059780
# 60   511010       0.195691
# 44   513500       0.251692
# 93   513100       0.294522
# 29   159941       0.318380
# 130  510680       0.319602
# 146  511270       0.330337
# 77   513030       0.362567
# 56   510090       0.364643
# 65   511020       0.410152
# 3    510110       0.423712
# 119  510580       0.440705
# 84   159935       0.441876
# 51   159908       0.453276
# 149  159933       0.455226
# 141  513600       0.455768
# 11   512560       0.458740
# 97   159932       0.461687
# 116  510170       0.462996
# 106  159913       0.467093
# 27   513050       0.472114
# 104  159918       0.472276
# 136  512600       0.472291
# 114  159920       0.479183
# 25   159960       0.482182
# 91   159951       0.485347
# 101  510500       0.486316
# 117  513660       0.493547
# 87   159916       0.496352
# 98   159901       0.504434
# 0    510270       0.506500
# 66   159906       0.511867
# 142  159945       0.513179
# 2    512640       0.516455
# 70   512220       0.517392
# 102  159931       0.519816
# 33   512120       0.522511
# 58   510180       0.527156
# 6    510900       0.530141

# %%
most_recent_etf_macd_signals
# Out:
#              date    code SIGNAL_STATUS SIGNAL_ACTION
# 1254   2020-02-25  511220          多头状态     NO CHANGE
# 1467   2020-02-25  511030          多头状态     NO CHANGE
# 3151   2020-02-25  511010          空头状态     NO CHANGE
# 4639   2020-02-25  513500          空头状态     NO CHANGE
# 6291   2020-02-25  513100          空头状态     NO CHANGE
# 7416   2020-02-25  159941          空头状态     NO CHANGE
# 8709   2020-02-25  510680          多头状态     NO CHANGE
# 9011   2020-02-25  511270          空头状态     NO CHANGE
# 10341  2020-02-25  513030          空头状态     NO CHANGE
# 12436  2020-02-25  510090          多头状态     NO CHANGE
# 12658  2020-02-25  511020          空头状态     NO CHANGE
# 14736  2020-02-25  510110          多头状态     NO CHANGE
# 15779  2020-02-25  510580          多头状态     NO CHANGE
# 17156  2020-02-25  159935          多头状态     NO CHANGE
# 19152  2020-02-25  159908          多头状态     NO CHANGE
# 20621  2020-02-25  159933          多头状态     NO CHANGE
# 21857  2020-02-25  513600          空头状态     NO CHANGE
# 22481  2020-02-25  512560          多头状态     NO CHANGE
# 23986  2020-02-25  159932          多头状态     NO CHANGE
# 26154  2020-02-25  510170          多头状态     NO CHANGE
# 28090  2020-02-25  159913          多头状态     NO CHANGE
# 28843  2020-02-25  513050          空头状态     NO CHANGE
# 30693  2020-02-25  159918          多头状态     NO CHANGE
# 32010  2020-02-25  512600          多头状态     NO CHANGE
# 33796  2020-02-25  159920          空头状态     NO CHANGE
# 34119  2020-02-25  159960          空头状态         SHORT
# 34742  2020-02-25  159951          多头状态     NO CHANGE
# 36430  2020-02-25  510500          多头状态     NO CHANGE
# 37664  2020-02-25  513660          空头状态     NO CHANGE
# 39529  2020-02-25  159916          多头状态     NO CHANGE
# 41991  2020-02-25  159901          多头状态     NO CHANGE
# 44037  2020-02-25  510270          多头状态     NO CHANGE
# 46185  2020-02-25  159906          多头状态     NO CHANGE
# 47312  2020-02-25  159945          多头状态     NO CHANGE
# 48409  2020-02-25  512640          多头状态     NO CHANGE
# 49674  2020-02-25  512220          多头状态     NO CHANGE
# 51237  2020-02-25  159931          多头状态     NO CHANGE
# 52705  2020-02-25  512120          空头状态     NO CHANGE
# 55167  2020-02-25  510180          多头状态     NO CHANGE
# 56952  2020-02-25  510900          空头状态         SHORT

# %%
# most_recent_etf_macd_signals.to_csv("selected_ETF_pool.csv")

# %%
etf_to_check = 510090
check_macd_signal_plot(lowest_corr_etf_macd_signals, etf_to_check, ['MACD_Diff','MACD_Diff_EMA','MACD'], 'code', 200, 'date')

# %%
check_macd_signal_plot(lowest_corr_etf_macd_signals, etf_to_check, ['close'], 'code', 200, 'date')

# %% [markdown]
# # On stocks

# %%
MACD(stock_df, 12, 26, 9, 'Adj Close')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-d470db3ec9b3> in <module>()
# ----> 1 MACD(stock_df, 12, 26, 9, 'Adj Close')
#
# NameError: name 'stock_df' is not defined

# %%
# On etfs:
us_stocks_ticker_list = ['TSLA','QQQ']
# us_stock_ticker_df_list = get_df_date_price_code(us_db_path, us_stocks_ticker_list, 'Date', 'Adj Close', 'Ticker')
# merged_us_stocks = merge_df_for_corr(us_stock_ticker_df_list, 'Date')
# lowest_corr_etf_list = select_N_lowest_corr_assets(merged_etfs, "etf", 20)
stock_df = select_df_from_db_by_tickers(us_db_path, us_stocks_ticker_list)
macd_signals = calc_macd_signals(stock_df, us_stocks_ticker_list, 'Ticker','string', 'Adj Close')
most_recent_us_stock_macd_signals = generate_most_recent_signal_data_v1(macd_signals, 'Date','Ticker')

# %%
most_recent_us_stock_macd_signals

# %%
stock_to_check = 'TSLA'
check_macd_signal_plot(macd_signals, stock_to_check, ['MACD_Diff','MACD_Diff_EMA','MACD'], 'Ticker', 80, 'Date')
