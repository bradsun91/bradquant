# %%
import pandas as pd, numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set(style="darkgrid")

# %%
# 1. backtest.py

#!/usr/bin/python
# -*- coding: utf-8 -*-


from __future__ import print_function

import datetime
import pprint
try:
    import Queue as queue
except ImportError:
    import queue
import time

print("Executing backtest.py")
class Backtest(object):
    """
    Enscapsulates the settings and components for carrying out
    an event-driven backtest.
    """

    def __init__(
        self, csv_dir, symbol_list, initial_capital,
        heartbeat, start_date, data_handler, 
        execution_handler, portfolio, strategy
    ):
        """
        Initialises the backtest.
        Parameters:
        csv_dir - The hard root to the CSV data directory.
        symbol_list - The list of symbol strings.
        intial_capital - The starting capital for the portfolio.
        heartbeat - Backtest "heartbeat" in seconds
        start_date - The start datetime of the strategy.
        data_handler - (Class) Handles the market data feed.
        execution_handler - (Class) Handles the orders/fills for trades.
        portfolio - (Class) Keeps track of portfolio current and prior positions.
        strategy - (Class) Generates signals based on market data.
        """
        self.csv_dir = csv_dir
        self.symbol_list = symbol_list
        self.initial_capital = initial_capital
        self.heartbeat = heartbeat
        self.start_date = start_date

        self.data_handler_cls = data_handler
        self.execution_handler_cls = execution_handler
        self.portfolio_cls = portfolio
        self.strategy_cls = strategy

        # Added by Brad on 20191006
        # self.plots_cls = plots

        self.events = queue.Queue()
        
        self.signals = 0
        self.orders = 0
        self.fills = 0
        self.num_strats = 1
       
        self._generate_trading_instances()

    def _generate_trading_instances(self):
        # function1: call0 classes of 1)DataHandler, 2)strategy, 3)portfolion, 4)ExecutionHandler
        """
        Generates the trading instance objects from 
        their class types.
        """
        print(
            "Creating DataHandler, Strategy, Portfolio and ExecutionHandler"
        )
        self.data_handler = self.data_handler_cls(self.events, self.csv_dir, self.symbol_list)
        self.strategy = self.strategy_cls(self.data_handler, self.events)
        self.portfolio = self.portfolio_cls(self.data_handler, self.events, self.start_date, 
                                            self.initial_capital)
        self.execution_handler = self.execution_handler_cls(self.events)

    def _run_backtest(self): # 
        # function1: update market bars
        # function2: identify the current event, including 1)market, 2)signal, 3)order, 4)
        """
        Executes the backtest.
        """
        print("Running Backtest...")
        i = 0
        while True:
            i += 1
            # print(i)

            # Update the market bars
            if self.data_handler.continue_backtest == True:
                self.data_handler.update_bars()
            else:
                break

            # Handle the events
            while True:
                try:
                    event = self.events.get(False)
                except queue.Empty:
                    break
                else:
                    if event is not None:
                        if event.type == 'MARKET':
                            self.strategy.calculate_signals(event)
                            self.portfolio.update_timeindex(event)

                        elif event.type == 'SIGNAL':
                            self.signals += 1                            
                            self.portfolio.update_signal(event)

                        elif event.type == 'ORDER':
                            self.orders += 1
                            self.execution_handler.execute_order(event)

                        elif event.type == 'FILL':
                            self.fills += 1
                            self.portfolio.update_fill(event)

            time.sleep(self.heartbeat)

	# OG version
    # def _output_performance(self):
    #     """
    #     Outputs the strategy performance from the backtest.
    #     """
    #     self.portfolio.create_equity_curve_dataframe()
        
    #     print("Creating summary stats...")
    #     stats = self.portfolio.output_summary_stats()
        
    #     print("Creating equity curve...")
    #     print(self.portfolio.equity_curve.tail(10))
    #     pprint.pprint(stats)

    #     print("Signals: %s" % self.signals)
    #     print("Orders: %s" % self.orders)
    #     print("Fills: %s" % self.fills)


    def _output_performance(self):
        """
        Outputs the strategy performance from the backtest.
        """
        self.portfolio.create_equity_curve_dataframe()
        
        print("Creating summary stats...")
        stats = self.portfolio.output_summary_stats()
        
        print("Creating equity curve...")
        print(self.portfolio.equity_curve.tail(10))
        pprint.pprint(stats)

        print("Signals: %s" % self.signals)
        print("Orders: %s" % self.orders)
        print("Fills: %s" % self.fills)

    def simulate_trading(self):
        # function 1: call 1)_run _backtest, 2__output_formance
        """
        Simulates the backtest and outputs portfolio performance.
        """
        self._run_backtest()
        self._output_performance()
# Out:
# Executing backtest.py

# %%
# 2. event.py

#!/usr/bin/python
# -*- coding: utf-8 -*-

from __future__ import print_function

print("Executing event.py")
class Event(object):
    """
    Event is base class providing an interface for all subsequent 
    (inherited) events, that will trigger further events in the 
    trading infrastructure.   
    """
    pass


class MarketEvent(Event):
    """
    Handles the event of receiving a new market update with 
    corresponding bars.
    """

    def __init__(self):
        """
        Initialises the MarketEvent.
        """
        self.type = 'MARKET'


class SignalEvent(Event):
    """
    Handles the event of sending a Signal from a Strategy object.
    This is received by a Portfolio object and acted upon.
    """
    
    def __init__(self, strategy_id, symbol, datetime, signal_type, strength):
        """
        Initialises the SignalEvent.
        Parameters:
        strategy_id - The unique ID of the strategy sending the signal.
        symbol - The ticker symbol, e.g. 'GOOG'.
        datetime - The timestamp at which the signal was generated.
        signal_type - 'LONG' or 'SHORT'.
        strength - An adjustment factor "suggestion" used to scale 
            quantity at the portfolio level. Useful for pairs strategies.
        """
        self.strategy_id = strategy_id
        self.type = 'SIGNAL'
        self.symbol = symbol
        self.datetime = datetime
        self.signal_type = signal_type
        self.strength = strength


class OrderEvent(Event):
    """
    Handles the event of sending an Order to an execution system.
    The order contains a symbol (e.g. GOOG), a type (market or limit),
    quantity and a direction.
    """

    def __init__(self, symbol, order_type, quantity, direction):
        """
        Initialises the order type, setting whether it is
        a Market order ('MKT') or Limit order ('LMT'), has
        a quantity (integral) and its direction ('BUY' or
        'SELL').
        TODO: Must handle error checking here to obtain 
        rational orders (i.e. no negative quantities etc).
        Parameters:
        symbol - The instrument to trade.
        order_type - 'MKT' or 'LMT' for Market or Limit.
        quantity - Non-negative integer for quantity.
        direction - 'BUY' or 'SELL' for long or short.
        """
        self.type = 'ORDER'
        self.symbol = symbol
        self.order_type = order_type
        self.quantity = quantity
        self.direction = direction

    def print_order(self):
        """
        Outputs the values within the Order.
        """
        print(
            "Order: Symbol=%s, Type=%s, Quantity=%s, Direction=%s" % 
            (self.symbol, self.order_type, self.quantity, self.direction)
        )


class FillEvent(Event):
    """
    Encapsulates the notion of a Filled Order, as returned
    from a brokerage. Stores the quantity of an instrument
    actually filled and at what price. In addition, stores
    the commission of the trade from the brokerage.
    
    TODO: Currently does not support filling positions at
    different prices. This will be simulated by averaging
    the cost.
    """

    def __init__(self, timeindex, symbol, exchange, quantity, 
                 direction, fill_cost, commission=None):
        """
        Initialises the FillEvent object. Sets the symbol, exchange,
        quantity, direction, cost of fill and an optional 
        commission.
        If commission is not provided, the Fill object will
        calculate it based on the trade size and Interactive
        Brokers fees.
        Parameters:
        timeindex - The bar-resolution when the order was filled.
        symbol - The instrument which was filled.
        exchange - The exchange where the order was filled.
        quantity - The filled quantity.
        direction - The direction of fill ('BUY' or 'SELL')
        fill_cost - The holdings value in dollars.
        commission - An optional commission sent from IB.
        """
        self.type = 'FILL'
        self.timeindex = timeindex
        self.symbol = symbol
        self.exchange = exchange
        self.quantity = quantity
        self.direction = direction
        self.fill_cost = fill_cost

        # Calculate commission
        if commission is None:
            self.commission = self.calculate_ib_commission()
        else:
            self.commission = commission

    def calculate_ib_commission(self):
        """
        Calculates the fees of trading based on an Interactive
        Brokers fee structure for API, in USD.
        This does not include exchange or ECN fees.
        Based on "US API Directed Orders":
        https://www.interactivebrokers.com/en/index.php?f=commission&p=stocks2
        """
#         full_cost = 1.3
#         if self.quantity <= 500:
#             full_cost = max(1.3, 0.013 * self.quantity)
#         else: # Greater than 500
#             full_cost = max(1.3, 0.008 * self.quantity)
        full_cost = 0
        return full_cost
# Out:
# Executing event.py

# %%
# 3. data.py
#!/usr/bin/python
# -*- coding: utf-8 -*-

from __future__ import print_function

from abc import ABCMeta, abstractmethod
import datetime
import os, os.path

import numpy as np
import pandas as pd

# from event import MarketEvent

print("Executing data.py")
class DataHandler(object):
    """
    DataHandler is an abstract base class providing an interface for
    all subsequent (inherited) data handlers (both live and historic).
    The goal of a (derived) DataHandler object is to output a generated
    set of bars (OHLCVI) for each symbol requested. 
    This will replicate how a live strategy would function as current
    market data would be sent "down the pipe". Thus a historic and live
    system will be treated identically by the rest of the backtesting suite.
    """

    __metaclass__ = ABCMeta

    @abstractmethod
    def get_latest_bar(self, symbol):
        """
        Returns the last bar updated.
        """
        raise NotImplementedError("Should implement get_latest_bar()")

    @abstractmethod
    def get_latest_bars(self, symbol, N=1):
        """
        Returns the last N bars updated.
        """
        raise NotImplementedError("Should implement get_latest_bars()")

    @abstractmethod
    def get_latest_bar_datetime(self, symbol):
        """
        Returns a Python datetime object for the last bar.
        """
        raise NotImplementedError("Should implement get_latest_bar_datetime()")

    @abstractmethod
    def get_latest_bar_value(self, symbol, val_type):
        """
        Returns one of the Open, High, Low, Close, Volume or OI
        from the last bar.
        """
        raise NotImplementedError("Should implement get_latest_bar_value()")

    @abstractmethod
    def get_latest_bars_values(self, symbol, val_type, N=1):
        """
        Returns the last N bar values from the 
        latest_symbol list, or N-k if less available.
        """
        raise NotImplementedError("Should implement get_latest_bars_values()")

    @abstractmethod
    def update_bars(self):
        """
        Pushes the latest bars to the bars_queue for each symbol
        in a tuple OHLCVI format: (datetime, open, high, low, 
        close, volume, open interest).
        """
        raise NotImplementedError("Should implement update_bars()")


class HistoricCSVDataHandler(DataHandler):
    """
    HistoricCSVDataHandler is designed to read CSV files for
    each requested symbol from disk and provide an interface
    to obtain the "latest" bar in a manner identical to a live
    trading interface. 
    """

    def __init__(self, events, csv_dir, symbol_list):
        """
        Initialises the historic data handler by requesting
        the location of the CSV files and a list of symbols.
        It will be assumed that all files are of the form
        'symbol.csv', where symbol is a string in the list.
        Parameters:
        events - The Event Queue.
        csv_dir - Absolute directory path to the CSV files.
        symbol_list - A list of symbol strings.
        """
        self.events = events
        self.csv_dir = csv_dir
        self.symbol_list = symbol_list

        self.symbol_data = {}
        self.latest_symbol_data = {}
        self.continue_backtest = True       
        self.bar_index = 0

        self._open_convert_csv_files()

    def _open_convert_csv_files(self):
        """
        Opens the CSV files from the data directory, converting
        them into pandas DataFrames within a symbol dictionary.
        For this handler it will be assumed that the data is
        taken from Yahoo. Thus its format will be respected.
        """
        comb_index = None

        for s in self.symbol_list:
            # Load the CSV file with no header information, indexed on date
            self.symbol_data[s] = pd.io.parsers.read_csv(
                os.path.join(self.csv_dir, '%s.csv' % s),
                header=0, index_col=0, parse_dates=True,
                names=['Date', 'Open', 'High','Low', 'Close', 'Adj Close', 'Volume','Ticker'
                ]
            )
            # ).sort_values('date')

            # Combine the index to pad forward values
            if comb_index is None:
                comb_index = self.symbol_data[s].index
            else:
                comb_index.union(self.symbol_data[s].index)

            # Set the latest symbol_data to None
            self.latest_symbol_data[s] = []

        # Reindex the dataframes
        for s in self.symbol_list:
            self.symbol_data[s] = self.symbol_data[s].\
                reindex(index=comb_index, method='pad').iterrows()

    def _get_new_bar(self, symbol):
        """
        Returns the latest bar from the data feed.
        """
        for b in self.symbol_data[symbol]:
            yield b

    def get_latest_bar(self, symbol):
        """
        Returns the last bar from the latest_symbol list.
        """
        try:
            bars_list = self.latest_symbol_data[symbol]
        except KeyError:
            print("That symbol is not available in the historical data set.")
            raise
        else:
            return bars_list[-1]

    def get_latest_bars(self, symbol, N=1):
        """
        Returns the last N bars from the latest_symbol list,
        or N-k if less available.
        """
        try:
            bars_list = self.latest_symbol_data[symbol]
        except KeyError:
            print("That symbol is not available in the historical data set.")
            raise
        else:
            return bars_list[-N:]

    def get_latest_bar_datetime(self, symbol):
        """
        Returns a Python datetime object for the last bar.
        """
        try:
            bars_list = self.latest_symbol_data[symbol]
        except KeyError:
            print("That symbol is not available in the historical data set.")
            raise
        else:
            return bars_list[-1][0]

    def get_latest_bar_value(self, symbol, val_type):
        """
        Returns one of the Open, High, Low, Close, Volume or OI
        values from the pandas Bar series object.
        """
        try:
            bars_list = self.latest_symbol_data[symbol]
        except KeyError:
            print("That symbol is not available in the historical data set.")
            raise
        else:
            return getattr(bars_list[-1][1], val_type)

    def get_latest_bars_values(self, symbol, val_type, N=1):
        """
        Returns the last N bar values from the 
        latest_symbol list, or N-k if less available.
        """
        try:
            bars_list = self.get_latest_bars(symbol, N)
        except KeyError:
            print("That symbol is not available in the historical data set.")
            raise
        else:
            return np.array([getattr(b[1], val_type) for b in bars_list])

    def update_bars(self):
        """
        Pushes the latest bar to the latest_symbol_data structure
        for all symbols in the symbol list.
        """
        for s in self.symbol_list:
            try:
                bar = next(self._get_new_bar(s))
            except StopIteration:
                self.continue_backtest = False
            else:
                if bar is not None:
                    self.latest_symbol_data[s].append(bar)
        self.events.put(MarketEvent())
# Out:
# Executing data.py

# %%
# 4. execution.py

#!/usr/bin/python
# -*- coding: utf-8 -*-

from __future__ import print_function

from abc import ABCMeta, abstractmethod
import datetime
try:
    import Queue as queue
except ImportError:
    import queue

# from event import FillEvent, OrderEvent

print("Executing execution.py")
class ExecutionHandler(object):
    """
    The ExecutionHandler abstract class handles the interaction
    between a set of order objects generated by a Portfolio and
    the ultimate set of Fill objects that actually occur in the
    market. 
    The handlers can be used to subclass simulated brokerages
    or live brokerages, with identical interfaces. This allows
    strategies to be backtested in a very similar manner to the
    live trading engine.
    """

    __metaclass__ = ABCMeta

    @abstractmethod
    def execute_order(self, event):
        """
        Takes an Order event and executes it, producing
        a Fill event that gets placed onto the Events queue.
        Parameters:
        event - Contains an Event object with order information.
        """
        raise NotImplementedError("Should implement execute_order()")


class SimulatedExecutionHandler(ExecutionHandler):
    """
    The simulated execution handler simply converts all order
    objects into their equivalent fill objects automatically
    without latency, slippage or fill-ratio issues.
    This allows a straightforward "first go" test of any strategy,
    before implementation with a more sophisticated execution
    handler.
    """
    
    def __init__(self, events):
        """
        Initialises the handler, setting the event queues
        up internally.
        Parameters:
        events - The Queue of Event objects.
        """
        self.events = events

    def execute_order(self, event):
        """
        Simply converts Order objects into Fill objects naively,
        i.e. without any latency, slippage or fill ratio problems.
        Parameters:
        event - Contains an Event object with order information.
        """
        if event.type == 'ORDER':
            fill_event = FillEvent(
                datetime.datetime.utcnow(), event.symbol,
                'ARCA', event.quantity, event.direction, None
            )
            self.events.put(fill_event)
# Out:
# Executing execution.py

# %%
# 5. strategy.py

#!/usr/bin/python
# -*- coding: utf-8 -*-

from __future__ import print_function

from abc import ABCMeta, abstractmethod
import datetime
try:
    import Queue as queue
except ImportError:
    import queue

import numpy as np
import pandas as pd

# from event import SignalEvent

print("Executing strategy.py")
class Strategy(object):
    """
    Strategy is an abstract base class providing an interface for
    all subsequent (inherited) strategy handling objects.
    The goal of a (derived) Strategy object is to generate Signal
    objects for particular symbols based on the inputs of Bars 
    (OHLCV) generated by a DataHandler object.
    This is designed to work both with historic and live data as
    the Strategy object is agnostic to where the data came from,
    since it obtains the bar tuples from a queue object.
    """

    __metaclass__ = ABCMeta

    @abstractmethod
    def calculate_signals(self):
        """
        Provides the mechanisms to calculate the list of signals.
        """
        raise NotImplementedError("Should implement calculate_signals()")
# Out:
# Executing strategy.py

# %%
# 6. portfolio.py

#!/usr/bin/python
# -*- coding: utf-8 -*-


from __future__ import print_function

import datetime
from math import floor
try:
    import Queue as queue
except ImportError:
    import queue

import numpy as np
import pandas as pd

# from event import FillEvent, OrderEvent
# from performance import create_sharpe_ratio, create_drawdowns


print("Executing portfolio.py")
class Portfolio(object):
    """
    The Portfolio class handles the positions and market
    value of all instruments at a resolution of a "bar",
    i.e. secondly, minutely, 5-min, 30-min, 60 min or EOD.
    The positions DataFrame stores a time-index of the 
    quantity of positions held. 
    The holdings DataFrame stores the cash and total market
    holdings value of each symbol for a particular 
    time-index, as well as the percentage change in 
    portfolio total across bars.
    """

    def __init__(self, bars, events, start_date, initial_capital=100000.0):
        """
        Initialises the portfolio with bars and an event queue. 
        Also includes a starting datetime index and initial capital 
        (USD unless otherwise stated).
        Parameters:
        bars - The DataHandler object with current market data.
        events - The Event Queue object.
        start_date - The start date (bar) of the portfolio.
        initial_capital - The starting capital in USD.
        """
        self.bars = bars
        self.events = events
        self.symbol_list = self.bars.symbol_list
        self.start_date = start_date
        self.initial_capital = initial_capital
        
        self.all_positions = self.construct_all_positions()
        self.current_positions = dict( (k,v) for k, v in [(s, 0) for s in self.symbol_list] )
        self.all_holdings = self.construct_all_holdings()
        self.current_holdings = self.construct_current_holdings()
        
        # Brad's add on 20191117
#         fill.direction = "None"
#         self.fill_cost = self.update_holdings_from_fill(self, fill)
        
        # =============brad's added on 20191117:===============
        self.len_symbol_list = len(symbol_list)
        print("Number of assets in the portfolio： ",self.len_symbol_list)
        print("Position Value for each asset: ", self.initial_capital/self.len_symbol_list)

        
    def construct_all_positions(self):
        """
        Constructs the positions list using the start_date
        to determine when the time index will begin.
        """
        d = dict( (k,v) for k, v in [(s, 0) for s in self.symbol_list] )
        d['datetime'] = self.start_date
        return [d]

    def construct_all_holdings(self):
        """
        Constructs the holdings list using the start_date
        to determine when the time index will begin.
        """
        d = dict( (k,v) for k, v in [(s, 0.0) for s in self.symbol_list] )
        d['datetime'] = self.start_date
        d['cash'] = self.initial_capital
        d['commission'] = 0.0
        d['total'] = self.initial_capital
        return [d]

    def construct_current_holdings(self):
        """
        This constructs the dictionary which will hold the instantaneous
        value of the portfolio across all symbols.
        """
        d = dict( (k,v) for k, v in [(s, 0.0) for s in self.symbol_list] )
        d['cash'] = self.initial_capital
        d['commission'] = 0.0
        d['total'] = self.initial_capital
        return d

    def update_timeindex(self, event):
        """
        Adds a new record to the positions matrix for the current 
        market data bar. This reflects the PREVIOUS bar, i.e. all
        current market data at this stage is known (OHLCV).
        Makes use of a MarketEvent from the events queue.
        """
        latest_datetime = self.bars.get_latest_bar_datetime(self.symbol_list[0])

        # Update positions
        # ================
        dp = dict( (k,v) for k, v in [(s, 0) for s in self.symbol_list] )
        dp['datetime'] = latest_datetime

        for s in self.symbol_list:
            dp[s] = self.current_positions[s]

        # Append the current positions
        self.all_positions.append(dp)

        # Update holdings
        # ===============
        dh = dict( (k,v) for k, v in [(s, 0) for s in self.symbol_list] )
        dh['datetime'] = latest_datetime
        dh['cash'] = self.current_holdings['cash']
        dh['commission'] = self.current_holdings['commission']
        dh['total'] = self.current_holdings['cash']

        for s in self.symbol_list:
            # Approximation to the real value
            market_value = self.current_positions[s] * \
                self.bars.get_latest_bar_value(s, "Adj Close")
            dh[s] = market_value
            dh['total'] += market_value

        # Append the current holdings
        self.all_holdings.append(dh)

    # ======================
    # FILL/POSITION HANDLING
    # ======================

    def update_positions_from_fill(self, fill):
        """
        Takes a Fill object and updates the position matrix to
        reflect the new position.
        Parameters:
        fill - The Fill object to update the positions with.
        """
        # Check whether the fill is a buy or sell
        fill_dir = 0
        if fill.direction == 'BUY':
            fill_dir = 1
        if fill.direction == 'SELL':
            fill_dir = -1

        # Update positions list with new quantities
        self.current_positions[fill.symbol] += fill_dir*fill.quantity

    def update_holdings_from_fill(self, fill):
        """
        Takes a Fill object and updates the holdings matrix to
        reflect the holdings value.
        Parameters:
        fill - The Fill object to update the holdings with.
        """
        # Check whether the fill is a buy or sell
        fill_dir = 0
        if fill.direction == 'BUY':
            fill_dir = 1
        if fill.direction == 'SELL':
            fill_dir = -1

        # Update holdings list with new quantities
        fill_cost = self.bars.get_latest_bar_value(
            fill.symbol, "Adj Close"
        )
        cost = fill_dir * fill_cost * fill.quantity
        self.current_holdings[fill.symbol] += cost
        self.current_holdings['commission'] += fill.commission
        self.current_holdings['cash'] -= (cost + fill.commission)
        self.current_holdings['total'] -= (cost + fill.commission)
        # Brad's add on 20191117
        return fill_cost

    def update_fill(self, event):
        """
        Updates the portfolio current positions and holdings 
        from a FillEvent.
        """
        if event.type == 'FILL':
            self.update_positions_from_fill(event)
            self.update_holdings_from_fill(event)

    def generate_naive_order(self, signal):
        """
        Simply files an Order object as a constant quantity
        sizing of the signal object, without risk management or
        position sizing considerations.
        Parameters:
        signal - The tuple containing Signal information.
        """
        order = None

        symbol = signal.symbol
        direction = signal.signal_type
        strength = signal.strength
        # ================ Brad's change on 20191117 =================
#         mkt_quantity = 100
        symbol_value = self.bars.get_latest_bar_value(symbol, "Adj Close")
        mkt_quantity = int(self.initial_capital/self.len_symbol_list/symbol_value)
        print("Asset: ", symbol, "symbol_value: ",symbol_value,  "mkt_quantity: ", mkt_quantity)
        cur_quantity = self.current_positions[symbol]
        order_type = 'MKT'

        if direction == 'LONG' and cur_quantity == 0:
            order = OrderEvent(symbol, order_type, mkt_quantity, 'BUY')
        if direction == 'SHORT' and cur_quantity == 0:
            order = OrderEvent(symbol, order_type, mkt_quantity, 'SELL')   
    
        if direction == 'EXIT' and cur_quantity > 0:
            order = OrderEvent(symbol, order_type, abs(cur_quantity), 'SELL')
        if direction == 'EXIT' and cur_quantity < 0:
            order = OrderEvent(symbol, order_type, abs(cur_quantity), 'BUY')
        return order

    def update_signal(self, event):
        """
        Acts on a SignalEvent to generate new orders 
        based on the portfolio logic.
        """
        if event.type == 'SIGNAL':
            order_event = self.generate_naive_order(event)
            self.events.put(order_event)

    # ========================
    # POST-BACKTEST STATISTICS
    # ========================

    def create_equity_curve_dataframe(self):
        """
        Creates a pandas DataFrame from the all_holdings
        list of dictionaries.
        """
        curve = pd.DataFrame(self.all_holdings)
        curve.set_index('datetime', inplace=True)
        curve['returns'] = curve['total'].pct_change()
        curve['equity_curve'] = (1.0+curve['returns']).cumprod()
        self.equity_curve = curve

    def output_summary_stats(self):
        """
        Creates a list of summary statistics for the portfolio.
        """
        total_return = self.equity_curve['equity_curve'][-1]
        returns = self.equity_curve['returns']
        pnl = self.equity_curve['equity_curve']

        sharpe_ratio = create_sharpe_ratio(returns, periods=252*60*6.5)
        drawdown, max_dd, dd_duration = create_drawdowns(pnl)
        self.equity_curve['drawdown'] = drawdown

        stats = [("Total Return", "%0.2f%%" % ((total_return - 1.0) * 100.0)),
                 ("Sharpe Ratio", "%0.2f" % sharpe_ratio),
                 ("Max Drawdown", "%0.2f%%" % (max_dd * 100.0)),
                 ("Drawdown Duration", "%d" % dd_duration)]

        self.equity_curve.to_csv('equity.csv')
        return stats

    # Added by Brad on 20191007:
    def draw_summary_plots(self):
        print("Testing draw_summary_plots")
        self.equity_curve['equity_curve'].plot(figsize = (18,6))
# Out:
# Executing portfolio.py

# %%
# 7. performance.py

#!/usr/bin/python
# -*- coding: utf-8 -*-

from __future__ import print_function

import numpy as np
import pandas as pd

print("Executing performance.py")
def create_sharpe_ratio(returns, periods=252):
    """
    Create the Sharpe ratio for the strategy, based on a 
    benchmark of zero (i.e. no risk-free rate information).
    Parameters:
    returns - A pandas Series representing period percentage returns.
    periods - Daily (252), Hourly (252*6.5), Minutely(252*6.5*60) etc.
    """
    return np.sqrt(periods) * (np.mean(returns)) / np.std(returns)


def create_drawdowns(pnl):
    """
    Calculate the largest peak-to-trough drawdown of the PnL curve
    as well as the duration of the drawdown. Requires that the 
    pnl_returns is a pandas Series.
    Parameters:
    pnl - A pandas Series representing period percentage returns.
    Returns:
    drawdown, duration - Highest peak-to-trough drawdown and duration.
    """

    # Calculate the cumulative returns curve 
    # and set up the High Water Mark
    hwm = [0]

    # Create the drawdown and duration series
    idx = pnl.index
    drawdown = pd.Series(index = idx)
    duration = pd.Series(index = idx)

    # Loop over the index range
    for t in range(1, len(idx)):
        hwm.append(max(hwm[t-1], pnl[t]))
        drawdown[t]= (hwm[t]-pnl[t])
        duration[t]= (0 if drawdown[t] == 0 else duration[t-1]+1)
    return drawdown, drawdown.max(), duration.max()
# Out:
# Executing performance.py

# %%
# mac.py
print("Executing mac.py")
class MovingAverageCrossStrategy(Strategy):
    """
    Carries out a basic Moving Average Crossover strategy with a
    short/long simple weighted moving average. Default short/long
    windows are 12/26 periods respectively.
    """

    def __init__(self, bars, events, short_window=12, long_window=26):
        """
        Initialises the buy and hold strategy.

        Parameters:
        bars - The DataHandler object that provides bar information
        events - The Event Queue object.
        short_window - The short moving average lookback.
        long_window - The long moving average lookback.
        """
        self.bars = bars
        self.symbol_list = self.bars.symbol_list
        self.events = events
        self.short_window = short_window
        self.long_window = long_window

        # Set to True if a symbol is in the market
        self.bought = self._calculate_initial_bought()

    def _calculate_initial_bought(self):
        """
        Adds keys to the bought dictionary for all symbols
        and sets them to 'OUT'.
        """
        bought = {}
        for s in self.symbol_list:
            bought[s] = 'OUT'
        return bought

    def calculate_signals(self, event):
        """
        Generates a new set of signals based on the MAC
        SMA with the short window crossing the long window
        meaning a long entry and vice versa for a short entry.    

        Parameters
        event - A MarketEvent object. 
        """
        if event.type == 'MARKET':
            for symbol in self.symbol_list:
                bars = self.bars.get_latest_bars_values(symbol, "Adj Close", N=self.long_window)

                if bars is not None and bars != []:
                    short_sma = np.mean(bars[-self.short_window:])
                    long_sma = np.mean(bars[-self.long_window:])

                    dt = self.bars.get_latest_bar_datetime(symbol)
                    sig_dir = ""
                    strength = 1.0
                    strategy_id = 1

                    if short_sma > long_sma and self.bought[symbol] == "OUT":
                        sig_dir = 'LONG'
                        signal = SignalEvent(strategy_id, symbol, dt, sig_dir, strength)
                        self.events.put(signal)
                        self.bought[symbol] = 'LONG'

                    elif short_sma < long_sma and self.bought[symbol] == "LONG":
                        sig_dir = 'EXIT'
                        signal = SignalEvent(strategy_id, symbol, dt, sig_dir, strength)
                        self.events.put(signal)
                        self.bought[symbol] = 'OUT'


class movingAverageConvergenceDivergence(Strategy):
    def __init__(self, bars, events, short_window=12, long_window=26):
        self.bars = bars
        self.symbol_list = self.bars.symbol_list
        self.events = events
        self.short_window = short_window
        self.long_window = long_window

        # Set to True if a symbol is in the market
        self.bought = self._calculate_initial_bought()

    def _calculate_initial_bought(self):
        """
        Adds keys to the bought dictionary for all symbols
        and sets them to 'OUT'.
        """
        bought = {}
        for s in self.symbol_list:
            bought[s] = 'OUT'
        return bought

    def calculate_signals(self, event):
        """
        Generates a new set of signals based on the MAC
        SMA with the short window crossing the long window
        meaning a long entry and vice versa for a short entry.
        Parameters
        event - A MarketEvent object.
        """
        if event.type == 'MARKET':
            for symbol in self.symbol_list:
                bars = self.bars.get_latest_bars_values(symbol, "Close", N=self.long_window)

                if bars is not None and bars != []:
#                     print('-------', bars)
                    exp1 = pd.Series(bars[-self.short_window:]).ewm(span=12, adjust=False).mean().iloc[-1]
                    exp2 = pd.Series(bars[-self.long_window:]).ewm(span=26, adjust=False).mean().iloc[-1]
                    macd = exp1 - exp2
                    exp3 = pd.Series(bars[-self.long_window:]).ewm(span=9, adjust=False).mean().iloc[-1]
                    dt = self.bars.get_latest_bar_datetime(symbol)
                    sig_dir = ""
                    strength = 1.0
                    strategy_id = 2

                    if macd < exp3 and self.bought[symbol] == "OUT":
                        sig_dir = 'LONG'
                        signal = SignalEvent(strategy_id, symbol, dt, sig_dir, strength)
                        self.events.put(signal)
                        self.bought[symbol] = 'LONG'

                    elif macd > exp3 and self.bought[symbol] == "LONG":
                        sig_dir = 'EXIT'
                        signal = SignalEvent(strategy_id, symbol, dt, sig_dir, strength)
                        self.events.put(signal)
                        self.bought[symbol] = 'OUT'
                        
                        
                        
                        
if __name__ == "__main__":
    # csv_dir = REPLACE_WITH_YOUR_CSV_DIR_HERE
    csv_dir = "/Users/miaoyuesun/Code_Workspace/brad_public_workspace_mac/data/US_database"
#     symbol_list = ["IYM","IYZ","FCL","FCD","IYE","IYG","IYH","IYJ","IYR","IYW","IDU"]
#     symbol_list = ['TSLA','AMZN','AAPL']
#     symbol_list = ['SPY']
#     symbol_list = ["VTI","TLT","IEF","GLD","DBC"]
#     symbol_list = ['jd000d']
    symbol_list = ['QQQ', 'SPY', 'TSLA',  'YELP']
    initial_capital = 100000.0
    start_date = datetime.datetime(2010,4,1,0,0,0)
    start_date_str = str(start_date)
    heartbeat = 0.0

    backtest = Backtest(csv_dir, 
                        symbol_list, 
                        initial_capital, 
                        heartbeat,
                        start_date,
                        HistoricCSVDataHandler, 
                        SimulatedExecutionHandler, 
                        Portfolio, 
                        MovingAverageCrossStrategy,
#                         movingAverageConvergenceDivergence
                       )
    
    backtest.simulate_trading()
# Out:
# Executing mac.py
# Creating DataHandler, Strategy, Portfolio and ExecutionHandler
# Number of assets in the portfolio：  4
# Position Value for each asset:  25000.0
# Running Backtest...
# Asset:  QQQ symbol_value:  45.39594650268555 mkt_quantity:  550
# Asset:  SPY symbol_value:  88.08079528808594 mkt_quantity:  283
# Asset:  SPY symbol_value:  89.85780334472656 mkt_quantity:  278
# Asset:  SPY symbol_value:  89.3868179321289 mkt_quantity:  279
# Asset:  SPY symbol_value:  87.95235443115234 mkt_quantity:  284
# Asset:  SPY symbol_value:  92.38421630859376 mkt_quantity:  270
# Asset:  QQQ symbol_value:  46.82140350341797 mkt_quantity:  533
# Asset:  QQQ symbol_value:  47.53414916992188 mkt_quantity:  525
# Asset:  QQQ symbol_value:  48.65808486938477 mkt_quantity:  513
# /Users/miaoyuesun/anaconda3/lib/python3.5/site-packages/ipykernel_launcher.py:52: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
# /Users/miaoyuesun/anaconda3/lib/python3.5/site-packages/ipykernel_launcher.py:52: DeprecationWarning: elementwise comparison failed; this will raise an error in the future.
# Asset:  QQQ symbol_value:  47.6917724609375 mkt_quantity:  524
# Asset:  QQQ symbol_value:  43.7237434387207 mkt_quantity:  571
# Asset:  SPY symbol_value:  88.38053894042969 mkt_quantity:  282
# Asset:  QQQ symbol_value:  48.30171203613281 mkt_quantity:  517
# Asset:  SPY symbol_value:  92.5127410888672 mkt_quantity:  270
# Asset:  SPY symbol_value:  91.22430419921876 mkt_quantity:  274
# Asset:  QQQ symbol_value:  49.50787734985352 mkt_quantity:  504
# Asset:  QQQ symbol_value:  52.8248519897461 mkt_quantity:  473
# Asset:  SPY symbol_value:  93.9515609741211 mkt_quantity:  266
# Asset:  SPY symbol_value:  91.02027130126952 mkt_quantity:  274
# Asset:  QQQ symbol_value:  52.81800842285156 mkt_quantity:  473
# Asset:  QQQ symbol_value:  53.78431701660156 mkt_quantity:  464
# Asset:  QQQ symbol_value:  53.86655044555664 mkt_quantity:  464
# Asset:  QQQ symbol_value:  57.37540817260742 mkt_quantity:  435
# Asset:  SPY symbol_value:  92.75178527832031 mkt_quantity:  269
# Asset:  SPY symbol_value:  101.54991912841795 mkt_quantity:  246
# Asset:  SPY symbol_value:  99.77969360351562 mkt_quantity:  250
# Asset:  SPY symbol_value:  96.8869171142578 mkt_quantity:  258
# Asset:  SPY symbol_value:  96.58465576171876 mkt_quantity:  258
# Asset:  QQQ symbol_value:  89.91464233398438 mkt_quantity:  278
# Asset:  SPY symbol_value:  100.05493927001952 mkt_quantity:  249
# Asset:  SPY symbol_value:  102.14344024658205 mkt_quantity:  244
# Asset:  QQQ symbol_value:  82.23902893066406 mkt_quantity:  303
# Asset:  SPY symbol_value:  101.17996978759766 mkt_quantity:  247
# Asset:  QQQ symbol_value:  82.88320922851562 mkt_quantity:  301
# Asset:  QQQ symbol_value:  86.40580749511719 mkt_quantity:  289
# Asset:  SPY symbol_value:  103.97847747802734 mkt_quantity:  240
# Asset:  QQQ symbol_value:  77.414306640625 mkt_quantity:  322
# Asset:  SPY symbol_value:  99.87831115722656 mkt_quantity:  250
# Asset:  SPY symbol_value:  104.26041412353516 mkt_quantity:  239
# Asset:  QQQ symbol_value:  83.77415466308594 mkt_quantity:  298
# Asset:  QQQ symbol_value:  78.83977508544922 mkt_quantity:  317
# Asset:  SPY symbol_value:  100.67295837402344 mkt_quantity:  248
# Asset:  SPY symbol_value:  99.3680419921875 mkt_quantity:  251
# Asset:  SPY symbol_value:  94.21368408203124 mkt_quantity:  265
# Asset:  QQQ symbol_value:  58.17039489746094 mkt_quantity:  429
# Asset:  SPY symbol_value:  93.55368041992188 mkt_quantity:  267
# Asset:  QQQ symbol_value:  50.07148361206055 mkt_quantity:  499
# Asset:  SPY symbol_value:  93.0820541381836 mkt_quantity:  268
# Asset:  SPY symbol_value:  86.79510498046875 mkt_quantity:  288
# Asset:  QQQ symbol_value:  42.45724868774414 mkt_quantity:  588
# Asset:  QQQ symbol_value:  41.53618621826172 mkt_quantity:  601
# Asset:  SPY symbol_value:  88.2649917602539 mkt_quantity:  283
# Asset:  SPY symbol_value:  83.44795227050781 mkt_quantity:  299
# Asset:  QQQ symbol_value:  35.33427047729492 mkt_quantity:  707
# Asset:  QQQ symbol_value:  34.29913711547852 mkt_quantity:  728
# Asset:  SPY symbol_value:  82.99871826171875 mkt_quantity:  301
# Asset:  SPY symbol_value:  77.15204620361328 mkt_quantity:  324
# Asset:  QQQ symbol_value:  30.17624092102051 mkt_quantity:  828
# Asset:  SPY symbol_value:  81.27062225341797 mkt_quantity:  307
# Asset:  QQQ symbol_value:  35.097400665283196 mkt_quantity:  712
# Asset:  SPY symbol_value:  81.68067932128906 mkt_quantity:  306
# Asset:  QQQ symbol_value:  35.053550720214844 mkt_quantity:  713
# Asset:  QQQ symbol_value:  33.71141815185547 mkt_quantity:  741
# Asset:  SPY symbol_value:  80.05458068847656 mkt_quantity:  312
# Asset:  SPY symbol_value:  81.83621215820312 mkt_quantity:  305
# Asset:  QQQ symbol_value:  33.79912567138672 mkt_quantity:  739
# Asset:  QQQ symbol_value:  30.781509399414066 mkt_quantity:  812
# Asset:  SPY symbol_value:  79.88684844970703 mkt_quantity:  312
# Asset:  QQQ symbol_value:  28.097225189208984 mkt_quantity:  889
# Asset:  SPY symbol_value:  78.06462097167969 mkt_quantity:  320
# Asset:  QQQ symbol_value:  25.75506019592285 mkt_quantity:  970
# Asset:  SPY symbol_value:  74.88105010986328 mkt_quantity:  333
# Asset:  SPY symbol_value:  63.30351638793945 mkt_quantity:  394
# Asset:  QQQ symbol_value:  22.58831024169922 mkt_quantity:  1106
# Asset:  QQQ symbol_value:  20.746156692504886 mkt_quantity:  1205
# Asset:  SPY symbol_value:  64.84039306640625 mkt_quantity:  385
# Asset:  QQQ symbol_value:  20.886510848999023 mkt_quantity:  1196
# Asset:  SPY symbol_value:  63.98038864135742 mkt_quantity:  390
# Asset:  QQQ symbol_value:  22.67603874206543 mkt_quantity:  1102
# Asset:  SPY symbol_value:  64.93096160888672 mkt_quantity:  385
# Asset:  SPY symbol_value:  66.65771484375 mkt_quantity:  375
# Asset:  QQQ symbol_value:  23.63220596313477 mkt_quantity:  1057
# Asset:  SPY symbol_value:  61.64457321166992 mkt_quantity:  405
# Asset:  QQQ symbol_value:  22.06197929382324 mkt_quantity:  1133
# Asset:  QQQ symbol_value:  21.728639602661133 mkt_quantity:  1150
# Asset:  SPY symbol_value:  63.31085205078125 mkt_quantity:  394
# Asset:  QQQ symbol_value:  22.83393478393555 mkt_quantity:  1094
# Asset:  QQQ symbol_value:  24.237476348876953 mkt_quantity:  1031
# Asset:  SPY symbol_value:  72.87840270996094 mkt_quantity:  343
# Asset:  SPY symbol_value:  72.90009307861328 mkt_quantity:  342
# Asset:  SPY symbol_value:  71.93030548095703 mkt_quantity:  347
# Asset:  QQQ symbol_value:  26.50069808959961 mkt_quantity:  943
# Asset:  SPY symbol_value:  72.92906951904297 mkt_quantity:  342
# Asset:  QQQ symbol_value:  28.45689392089844 mkt_quantity:  878
# Asset:  QQQ symbol_value:  29.176197052001953 mkt_quantity:  856
# Asset:  SPY symbol_value:  74.42951965332031 mkt_quantity:  335
# Asset:  SPY symbol_value:  76.20943450927734 mkt_quantity:  328
# Asset:  QQQ symbol_value:  30.992042541503906 mkt_quantity:  806
# Asset:  QQQ symbol_value:  30.027099609375 mkt_quantity:  832
# Asset:  QQQ symbol_value:  30.202547073364247 mkt_quantity:  827
# Asset:  QQQ symbol_value:  32.00457763671875 mkt_quantity:  781
# Asset:  SPY symbol_value:  81.10970306396484 mkt_quantity:  308
# Asset:  QQQ symbol_value:  32.452136993408196 mkt_quantity:  770
# Asset:  SPY symbol_value:  83.77462005615234 mkt_quantity:  298
# Asset:  QQQ symbol_value:  30.51272201538086 mkt_quantity:  819
# Asset:  SPY symbol_value:  81.27685546875 mkt_quantity:  307
# Asset:  QQQ symbol_value:  31.96068954467773 mkt_quantity:  782
# Asset:  SPY symbol_value:  82.10456085205078 mkt_quantity:  304
# Asset:  SPY symbol_value:  82.13958740234375 mkt_quantity:  304
# Asset:  QQQ symbol_value:  31.19721603393555 mkt_quantity:  801
# Asset:  SPY symbol_value:  81.67642974853516 mkt_quantity:  306
# Asset:  QQQ symbol_value:  29.85455894470215 mkt_quantity:  837
# Asset:  SPY symbol_value:  82.11978912353516 mkt_quantity:  304
# Asset:  SPY symbol_value:  86.03970336914062 mkt_quantity:  290
# Asset:  QQQ symbol_value:  34.145057678222656 mkt_quantity:  732
# Asset:  SPY symbol_value:  88.20503234863281 mkt_quantity:  283
# Asset:  SPY symbol_value:  89.425048828125 mkt_quantity:  279
# Asset:  QQQ symbol_value:  33.64890670776367 mkt_quantity:  742
# Asset:  QQQ symbol_value:  33.24135589599609 mkt_quantity:  752
# Asset:  QQQ symbol_value:  32.9312744140625 mkt_quantity:  759
# Asset:  QQQ symbol_value:  32.816104888916016 mkt_quantity:  761
# Asset:  SPY symbol_value:  87.30430603027344 mkt_quantity:  286
# Asset:  SPY symbol_value:  86.59481811523438 mkt_quantity:  288
# Asset:  QQQ symbol_value:  32.10732650756836 mkt_quantity:  778
# Asset:  QQQ symbol_value:  33.529258728027344 mkt_quantity:  745
# Asset:  SPY symbol_value:  89.94367980957031 mkt_quantity:  277
# Asset:  SPY symbol_value:  91.80329132080078 mkt_quantity:  272
# Asset:  QQQ symbol_value:  34.48697280883789 mkt_quantity:  724
# Asset:  QQQ symbol_value:  34.44264602661133 mkt_quantity:  725
# Asset:  SPY symbol_value:  91.6233367919922 mkt_quantity:  272
# Asset:  SPY symbol_value:  93.24298095703124 mkt_quantity:  268
# Asset:  QQQ symbol_value:  35.143203735351555 mkt_quantity:  711
# Asset:  QQQ symbol_value:  34.300769805908196 mkt_quantity:  728
# Asset:  SPY symbol_value:  92.36725616455078 mkt_quantity:  270
# Asset:  QQQ symbol_value:  34.44264602661133 mkt_quantity:  725
# Asset:  SPY symbol_value:  92.07360076904295 mkt_quantity:  271
# Asset:  QQQ symbol_value:  36.80137252807617 mkt_quantity:  679
# Asset:  QQQ symbol_value:  38.11697387695313 mkt_quantity:  655
# Asset:  QQQ symbol_value:  37.46807861328125 mkt_quantity:  667
# Asset:  SPY symbol_value:  95.58981323242188 mkt_quantity:  261
# Asset:  SPY symbol_value:  97.86087799072266 mkt_quantity:  255
# Asset:  QQQ symbol_value:  36.84582138061523 mkt_quantity:  678
# Asset:  QQQ symbol_value:  36.96061325073242 mkt_quantity:  676
# Asset:  QQQ symbol_value:  36.74712371826172 mkt_quantity:  680
# Asset:  SPY symbol_value:  97.7863998413086 mkt_quantity:  255
# Asset:  SPY symbol_value:  99.58769989013672 mkt_quantity:  251
# Asset:  QQQ symbol_value:  36.96061325073242 mkt_quantity:  676
# Asset:  SPY symbol_value:  95.92431640625 mkt_quantity:  260
# Asset:  SPY symbol_value:  97.28729248046876 mkt_quantity:  256
# Asset:  SPY symbol_value:  94.62301635742188 mkt_quantity:  264
# Asset:  SPY symbol_value:  97.7758560180664 mkt_quantity:  255
# Asset:  QQQ symbol_value:  32.7484130859375 mkt_quantity:  763
# Asset:  QQQ symbol_value:  39.10286712646485 mkt_quantity:  639
# Asset:  QQQ symbol_value:  40.40481948852539 mkt_quantity:  618
# Asset:  QQQ symbol_value:  39.37932586669922 mkt_quantity:  634
# Asset:  QQQ symbol_value:  39.86978530883789 mkt_quantity:  627
# Asset:  SPY symbol_value:  106.9181900024414 mkt_quantity:  233
# Asset:  QQQ symbol_value:  38.21113967895508 mkt_quantity:  654
# Asset:  QQQ symbol_value:  38.83304977416992 mkt_quantity:  643
# Asset:  SPY symbol_value:  109.7806625366211 mkt_quantity:  227
# Asset:  SPY symbol_value:  117.4993667602539 mkt_quantity:  212
# Asset:  SPY symbol_value:  120.02597045898438 mkt_quantity:  208
# Asset:  SPY symbol_value:  113.28575897216795 mkt_quantity:  220
# Asset:  QQQ symbol_value:  42.34611892700195 mkt_quantity:  590
# Asset:  SPY symbol_value:  114.73950958251952 mkt_quantity:  217
# Asset:  QQQ symbol_value:  44.36431121826172 mkt_quantity:  563
# Asset:  SPY symbol_value:  118.60360717773438 mkt_quantity:  210
# Asset:  QQQ symbol_value:  43.53857803344727 mkt_quantity:  574
# Asset:  SPY symbol_value:  118.79100036621094 mkt_quantity:  210
# Asset:  QQQ symbol_value:  45.8526611328125 mkt_quantity:  545
# Asset:  QQQ symbol_value:  45.0865478515625 mkt_quantity:  554
# Asset:  SPY symbol_value:  113.8069076538086 mkt_quantity:  219
# Asset:  SPY symbol_value:  107.83895111083984 mkt_quantity:  231
# Asset:  SPY symbol_value:  102.91542053222656 mkt_quantity:  242
# Asset:  QQQ symbol_value:  39.1246452331543 mkt_quantity:  638
# Asset:  SPY symbol_value:  107.87569427490234 mkt_quantity:  231
# Asset:  SPY symbol_value:  108.9726104736328 mkt_quantity:  229
# Asset:  QQQ symbol_value:  43.6806755065918 mkt_quantity:  572
# Asset:  QQQ symbol_value:  40.19993591308594 mkt_quantity:  621
# Asset:  SPY symbol_value:  100.0561294555664 mkt_quantity:  249
# Asset:  QQQ symbol_value:  39.79685974121094 mkt_quantity:  628
# Asset:  QQQ symbol_value:  41.14043426513672 mkt_quantity:  607
# Asset:  SPY symbol_value:  101.42024230957031 mkt_quantity:  246
# Asset:  QQQ symbol_value:  39.107154846191406 mkt_quantity:  639
# Asset:  SPY symbol_value:  68.45686340332031 mkt_quantity:  365
# Asset:  SPY symbol_value:  68.17769622802734 mkt_quantity:  366
# Asset:  SPY symbol_value:  70.14795684814453 mkt_quantity:  356
# Asset:  QQQ symbol_value:  26.60290336608887 mkt_quantity:  939
# Asset:  SPY symbol_value:  67.58925628662111 mkt_quantity:  369
# Asset:  QQQ symbol_value:  25.815711975097656 mkt_quantity:  968
# Asset:  QQQ symbol_value:  28.27519989013672 mkt_quantity:  884
# Asset:  QQQ symbol_value:  24.94500541687012 mkt_quantity:  1002
# Asset:  QQQ symbol_value:  27.782489776611328 mkt_quantity:  899
# Asset:  SPY symbol_value:  66.59088134765625 mkt_quantity:  375
# Asset:  QQQ symbol_value:  31.064245223999023 mkt_quantity:  804
# Asset:  QQQ symbol_value:  32.71860122680664 mkt_quantity:  764
# Asset:  SPY symbol_value:  74.99783325195312 mkt_quantity:  333
# Asset:  QQQ symbol_value:  32.81285858154297 mkt_quantity:  761
# Asset:  QQQ symbol_value:  34.37022018432617 mkt_quantity:  727
# Asset:  SPY symbol_value:  77.8241195678711 mkt_quantity:  321
# Asset:  QQQ symbol_value:  38.54848098754883 mkt_quantity:  648
# Asset:  QQQ symbol_value:  38.93595504760742 mkt_quantity:  642
# Asset:  QQQ symbol_value:  37.241920471191406 mkt_quantity:  671
# Asset:  SPY symbol_value:  85.8628921508789 mkt_quantity:  291
# Asset:  QQQ symbol_value:  40.188472747802734 mkt_quantity:  622
# Asset:  SPY symbol_value:  91.11676788330078 mkt_quantity:  274
# Asset:  QQQ symbol_value:  40.34579086303711 mkt_quantity:  619
# Asset:  SPY symbol_value:  90.36495208740234 mkt_quantity:  276
# Asset:  QQQ symbol_value:  40.25553512573242 mkt_quantity:  621
# Asset:  SPY symbol_value:  91.05607604980469 mkt_quantity:  274
# Asset:  SPY symbol_value:  93.3064422607422 mkt_quantity:  267
# Asset:  QQQ symbol_value:  41.03038024902344 mkt_quantity:  609
# Asset:  QQQ symbol_value:  42.18539047241211 mkt_quantity:  592
# Asset:  SPY symbol_value:  90.95294952392578 mkt_quantity:  274
# Asset:  QQQ symbol_value:  38.522254943847656 mkt_quantity:  648
# Asset:  SPY symbol_value:  84.83519744873047 mkt_quantity:  294
# Asset:  QQQ symbol_value:  41.51550674438477 mkt_quantity:  602
# Asset:  SPY symbol_value:  90.86166381835938 mkt_quantity:  275
# Asset:  TSLA symbol_value:  21.26000022888184 mkt_quantity:  1175
# Asset:  TSLA symbol_value:  18.31999969482422 mkt_quantity:  1364
# Asset:  QQQ symbol_value:  40.74452209472656 mkt_quantity:  613
# Asset:  SPY symbol_value:  89.25959777832031 mkt_quantity:  280
# Asset:  TSLA symbol_value:  21.059999465942386 mkt_quantity:  1187
# Asset:  QQQ symbol_value:  42.8579330444336 mkt_quantity:  583
# Asset:  SPY symbol_value:  93.50965881347656 mkt_quantity:  267
# Asset:  TSLA symbol_value:  20.459999084472656 mkt_quantity:  1221
# Asset:  TSLA symbol_value:  20.239999771118164 mkt_quantity:  1235
# Asset:  TSLA symbol_value:  20.540000915527344 mkt_quantity:  1217
# Asset:  TSLA symbol_value:  21.0 mkt_quantity:  1190
# Asset:  QQQ symbol_value:  47.9769287109375 mkt_quantity:  521
# Asset:  SPY symbol_value:  99.4430923461914 mkt_quantity:  251
# Asset:  QQQ symbol_value:  48.95883560180664 mkt_quantity:  510
# Asset:  SPY symbol_value:  102.50582122802734 mkt_quantity:  243
# Asset:  TSLA symbol_value:  30.809999465942386 mkt_quantity:  811
# Asset:  QQQ symbol_value:  52.09854125976562 mkt_quantity:  479
# Asset:  TSLA symbol_value:  24.65999984741211 mkt_quantity:  1013
# Asset:  SPY symbol_value:  111.06497192382812 mkt_quantity:  225
# Asset:  TSLA symbol_value:  22.209999084472656 mkt_quantity:  1125
# Asset:  SPY symbol_value:  112.18783569335938 mkt_quantity:  222
# Asset:  QQQ symbol_value:  52.108192443847656 mkt_quantity:  479
# Asset:  TSLA symbol_value:  26.70000076293945 mkt_quantity:  936
# Asset:  QQQ symbol_value:  51.925743103027344 mkt_quantity:  481
# Asset:  SPY symbol_value:  111.26942443847656 mkt_quantity:  224
# Asset:  TSLA symbol_value:  26.01000022888184 mkt_quantity:  961
# Asset:  SPY symbol_value:  113.30284881591795 mkt_quantity:  220
# Asset:  QQQ symbol_value:  53.386207580566406 mkt_quantity:  468
# Asset:  TSLA symbol_value:  29.729999542236328 mkt_quantity:  840
# Asset:  TSLA symbol_value:  27.63999938964844 mkt_quantity:  904
# Asset:  SPY symbol_value:  106.25798034667969 mkt_quantity:  235
# Asset:  QQQ symbol_value:  49.21697616577149 mkt_quantity:  507
# Asset:  QQQ symbol_value:  49.95756912231445 mkt_quantity:  500
# Asset:  SPY symbol_value:  101.85488891601562 mkt_quantity:  245
# Asset:  TSLA symbol_value:  26.01000022888184 mkt_quantity:  961
# Asset:  SPY symbol_value:  98.934814453125 mkt_quantity:  252
# Asset:  QQQ symbol_value:  47.80602264404297 mkt_quantity:  522
# Asset:  QQQ symbol_value:  53.11883163452149 mkt_quantity:  470
# Asset:  SPY symbol_value:  104.33094024658205 mkt_quantity:  239
# Asset:  QQQ symbol_value:  52.3676986694336 mkt_quantity:  477
# Asset:  SPY symbol_value:  101.44562530517578 mkt_quantity:  246
# Asset:  SPY symbol_value:  105.71824645996094 mkt_quantity:  236
# Asset:  QQQ symbol_value:  51.076148986816406 mkt_quantity:  489
# Asset:  TSLA symbol_value:  29.45000076293945 mkt_quantity:  848
# Asset:  QQQ symbol_value:  51.11529159545898 mkt_quantity:  489
# Asset:  QQQ symbol_value:  52.97269821166992 mkt_quantity:  471
# Asset:  TSLA symbol_value:  29.57999992370605 mkt_quantity:  845
# Asset:  YELP symbol_value:  25.21999931335449 mkt_quantity:  991
# Asset:  SPY symbol_value:  117.97835540771484 mkt_quantity:  211
# Asset:  TSLA symbol_value:  33.59000015258789 mkt_quantity:  744
# Asset:  QQQ symbol_value:  61.352210998535156 mkt_quantity:  407
# Asset:  YELP symbol_value:  22.270000457763672 mkt_quantity:  1122
# Asset:  SPY symbol_value:  117.94396209716795 mkt_quantity:  211
# Asset:  SPY symbol_value:  115.3717269897461 mkt_quantity:  216
# Asset:  QQQ symbol_value:  59.30528259277344 mkt_quantity:  421
# Asset:  SPY symbol_value:  117.34444427490234 mkt_quantity:  213
# Asset:  YELP symbol_value:  21.38999938964844 mkt_quantity:  1168
# Asset:  TSLA symbol_value:  33.779998779296875 mkt_quantity:  740
# Asset:  QQQ symbol_value:  58.12360382080078 mkt_quantity:  430
# Asset:  YELP symbol_value:  21.5 mkt_quantity:  1162
# Asset:  TSLA symbol_value:  28.1299991607666 mkt_quantity:  888
# Asset:  QQQ symbol_value:  59.88688659667969 mkt_quantity:  417
# Asset:  YELP symbol_value:  23.8700008392334 mkt_quantity:  1047
# Asset:  TSLA symbol_value:  29.11000061035156 mkt_quantity:  858
# Asset:  YELP symbol_value:  18.190000534057614 mkt_quantity:  1374
# Asset:  TSLA symbol_value:  28.54999923706055 mkt_quantity:  875
# Asset:  YELP symbol_value:  26.20000076293945 mkt_quantity:  954
# Asset:  TSLA symbol_value:  31.04999923706055 mkt_quantity:  805
# Asset:  QQQ symbol_value:  63.279502868652344 mkt_quantity:  395
# Asset:  TSLA symbol_value:  29.25 mkt_quantity:  854
# Asset:  SPY symbol_value:  124.63009643554688 mkt_quantity:  200
# Asset:  YELP symbol_value:  24.61000061035156 mkt_quantity:  1015
# Asset:  TSLA symbol_value:  31.540000915527344 mkt_quantity:  792
# Asset:  QQQ symbol_value:  60.7983283996582 mkt_quantity:  411
# Asset:  SPY symbol_value:  122.7957763671875 mkt_quantity:  203
# Asset:  YELP symbol_value:  18.09000015258789 mkt_quantity:  1381
# Asset:  YELP symbol_value:  18.440000534057614 mkt_quantity:  1355
# Asset:  TSLA symbol_value:  34.34000015258789 mkt_quantity:  728
# Asset:  YELP symbol_value:  21.07999992370605 mkt_quantity:  1185
# Asset:  TSLA symbol_value:  36.9900016784668 mkt_quantity:  675
# Asset:  TSLA symbol_value:  34.43000030517578 mkt_quantity:  726
# Asset:  QQQ symbol_value:  63.008201599121094 mkt_quantity:  396
# Asset:  QQQ symbol_value:  64.20915222167969 mkt_quantity:  389
# Asset:  TSLA symbol_value:  35.150001525878906 mkt_quantity:  711
# Asset:  YELP symbol_value:  23.670000076293945 mkt_quantity:  1056
# Asset:  YELP symbol_value:  26.959999084472656 mkt_quantity:  927
# Asset:  YELP symbol_value:  27.459999084472656 mkt_quantity:  910
# Asset:  SPY symbol_value:  144.92678833007812 mkt_quantity:  172
# Asset:  QQQ symbol_value:  67.82898712158203 mkt_quantity:  368
# Asset:  YELP symbol_value:  31.0 mkt_quantity:  806
# Asset:  QQQ symbol_value:  70.17784118652344 mkt_quantity:  356
# Asset:  SPY symbol_value:  148.02761840820312 mkt_quantity:  168
# Asset:  SPY symbol_value:  145.6671600341797 mkt_quantity:  171
# Asset:  QQQ symbol_value:  70.60842895507812 mkt_quantity:  354
# Asset:  QQQ symbol_value:  72.85501861572266 mkt_quantity:  343
# Asset:  SPY symbol_value:  150.56483459472656 mkt_quantity:  166
# Asset:  SPY symbol_value:  147.11451721191406 mkt_quantity:  169
# Asset:  TSLA symbol_value:  182.8000030517578 mkt_quantity:  136
# Asset:  SPY symbol_value:  154.93218994140625 mkt_quantity:  161
# Asset:  YELP symbol_value:  69.41000366210939 mkt_quantity:  360
# Asset:  YELP symbol_value:  68.0 mkt_quantity:  367
# Asset:  YELP symbol_value:  71.12999725341797 mkt_quantity:  351
# Asset:  TSLA symbol_value:  147.47000122070312 mkt_quantity:  169
# Asset:  SPY symbol_value:  161.41732788085938 mkt_quantity:  154
# Asset:  YELP symbol_value:  65.79000091552734 mkt_quantity:  379
# Asset:  SPY symbol_value:  162.16856384277344 mkt_quantity:  154
# Asset:  SPY symbol_value:  159.94459533691406 mkt_quantity:  156
# Asset:  QQQ symbol_value:  79.39039611816406 mkt_quantity:  314
# Asset:  QQQ symbol_value:  85.00394439697266 mkt_quantity:  294
# Asset:  SPY symbol_value:  164.24974060058594 mkt_quantity:  152
# Asset:  YELP symbol_value:  87.81999969482422 mkt_quantity:  284
# Asset:  QQQ symbol_value:  83.6276626586914 mkt_quantity:  298
# Asset:  TSLA symbol_value:  220.44000244140625 mkt_quantity:  113
# Asset:  SPY symbol_value:  166.4101104736328 mkt_quantity:  150
# Asset:  SPY symbol_value:  167.77374267578125 mkt_quantity:  149
# Asset:  SPY symbol_value:  166.0602264404297 mkt_quantity:  150
# Asset:  SPY symbol_value:  167.84552001953125 mkt_quantity:  148
# Asset:  SPY symbol_value:  164.31976318359375 mkt_quantity:  152
# Asset:  SPY symbol_value:  168.94004821777344 mkt_quantity:  147
# Asset:  QQQ symbol_value:  82.9356689453125 mkt_quantity:  301
# Asset:  YELP symbol_value:  68.55999755859375 mkt_quantity:  364
# Asset:  TSLA symbol_value:  207.7700042724609 mkt_quantity:  120
# Asset:  YELP symbol_value:  68.06999969482422 mkt_quantity:  367
# Asset:  TSLA symbol_value:  215.3999938964844 mkt_quantity:  116
# Asset:  SPY symbol_value:  173.5265655517578 mkt_quantity:  144
# Asset:  TSLA symbol_value:  238.4900054931641 mkt_quantity:  104
# Asset:  QQQ symbol_value:  90.73395538330078 mkt_quantity:  275
# Asset:  YELP symbol_value:  74.45999908447266 mkt_quantity:  335
# Asset:  QQQ symbol_value:  93.81356811523438 mkt_quantity:  266
# Asset:  SPY symbol_value:  180.46762084960938 mkt_quantity:  138
# Asset:  YELP symbol_value:  75.88999938964844 mkt_quantity:  329
# Asset:  TSLA symbol_value:  252.13999938964844 mkt_quantity:  99
# Asset:  SPY symbol_value:  177.81539916992188 mkt_quantity:  140
# Asset:  QQQ symbol_value:  94.11297607421876 mkt_quantity:  265
# Asset:  QQQ symbol_value:  96.60916137695312 mkt_quantity:  258
# Asset:  SPY symbol_value:  182.6334686279297 mkt_quantity:  136
# Asset:  TSLA symbol_value:  251.0800018310547 mkt_quantity:  99
# Asset:  TSLA symbol_value:  228.27999877929688 mkt_quantity:  109
# Asset:  SPY symbol_value:  179.23724365234375 mkt_quantity:  139
# Asset:  QQQ symbol_value:  96.99027252197266 mkt_quantity:  257
# Asset:  SPY symbol_value:  187.17477416992188 mkt_quantity:  133
# Asset:  QQQ symbol_value:  95.697265625 mkt_quantity:  261
# Asset:  TSLA symbol_value:  211.27999877929688 mkt_quantity:  118
# Asset:  YELP symbol_value:  52.43999862670898 mkt_quantity:  476
# Asset:  QQQ symbol_value:  96.93090057373048 mkt_quantity:  257
# Asset:  SPY symbol_value:  182.91293334960938 mkt_quantity:  136
# Asset:  TSLA symbol_value:  192.69000244140625 mkt_quantity:  129
# Asset:  YELP symbol_value:  51.40999984741211 mkt_quantity:  486
# Asset:  YELP symbol_value:  55.18999862670898 mkt_quantity:  452
# Asset:  YELP symbol_value:  53.0 mkt_quantity:  471
# Asset:  YELP symbol_value:  55.77999877929688 mkt_quantity:  448
# Asset:  QQQ symbol_value:  98.37492370605469 mkt_quantity:  254
# Asset:  SPY symbol_value:  187.70294189453125 mkt_quantity:  133
# Asset:  TSLA symbol_value:  220.9900054931641 mkt_quantity:  113
# Asset:  YELP symbol_value:  42.16999816894531 mkt_quantity:  592
# Asset:  TSLA symbol_value:  207.19000244140625 mkt_quantity:  120
# Asset:  SPY symbol_value:  187.4388427734375 mkt_quantity:  133
# Asset:  YELP symbol_value:  46.709999084472656 mkt_quantity:  535
# Asset:  QQQ symbol_value:  103.2042465209961 mkt_quantity:  242
# Asset:  YELP symbol_value:  46.81999969482422 mkt_quantity:  533
# Asset:  YELP symbol_value:  47.43000030517578 mkt_quantity:  527
# Asset:  TSLA symbol_value:  210.08999633789062 mkt_quantity:  118
# Asset:  SPY symbol_value:  191.2575225830078 mkt_quantity:  130
# Asset:  QQQ symbol_value:  103.36490631103516 mkt_quantity:  241
# Asset:  YELP symbol_value:  39.61000061035156 mkt_quantity:  631
# Asset:  QQQ symbol_value:  105.03271484375 mkt_quantity:  238
# Asset:  QQQ symbol_value:  105.49278259277344 mkt_quantity:  236
# Asset:  QQQ symbol_value:  105.4448699951172 mkt_quantity:  237
# Asset:  QQQ symbol_value:  105.9912109375 mkt_quantity:  235
# Asset:  YELP symbol_value:  46.47999954223633 mkt_quantity:  537
# Asset:  SPY symbol_value:  190.67210388183602 mkt_quantity:  131
# Asset:  YELP symbol_value:  44.040000915527344 mkt_quantity:  567
# Asset:  QQQ symbol_value:  103.71956634521484 mkt_quantity:  241
# Asset:  SPY symbol_value:  192.89561462402344 mkt_quantity:  129
# Asset:  SPY symbol_value:  188.8145446777344 mkt_quantity:  132
# Asset:  QQQ symbol_value:  103.46813201904295 mkt_quantity:  241
# Asset:  QQQ symbol_value:  103.7275390625 mkt_quantity:  241
# Asset:  QQQ symbol_value:  109.50139617919922 mkt_quantity:  228
# Asset:  SPY symbol_value:  194.6328125 mkt_quantity:  128
# Asset:  TSLA symbol_value:  267.8699951171875 mkt_quantity:  93
# Asset:  TSLA symbol_value:  264.82000732421875 mkt_quantity:  94
# Asset:  TSLA symbol_value:  266.27999877929693 mkt_quantity:  93
# Asset:  SPY symbol_value:  193.54820251464844 mkt_quantity:  129
# Asset:  SPY symbol_value:  192.0315399169922 mkt_quantity:  130
# Asset:  SPY symbol_value:  191.7926025390625 mkt_quantity:  130
# Asset:  QQQ symbol_value:  106.16773223876952 mkt_quantity:  235
# Asset:  TSLA symbol_value:  250.2400054931641 mkt_quantity:  99
# Asset:  YELP symbol_value:  25.1299991607666 mkt_quantity:  994
# Asset:  QQQ symbol_value:  101.77452850341795 mkt_quantity:  245
# Asset:  SPY symbol_value:  178.22837829589844 mkt_quantity:  140
# Asset:  YELP symbol_value:  21.3799991607666 mkt_quantity:  1169
# Asset:  SPY symbol_value:  177.05494689941406 mkt_quantity:  141
# Asset:  QQQ symbol_value:  98.4424057006836 mkt_quantity:  253
# Asset:  TSLA symbol_value:  231.9600067138672 mkt_quantity:  107
# Asset:  SPY symbol_value:  186.19273376464844 mkt_quantity:  134
# Asset:  QQQ symbol_value:  103.69098663330078 mkt_quantity:  241
# Asset:  YELP symbol_value:  22.520000457763672 mkt_quantity:  1110
# Asset:  TSLA symbol_value:  212.94000244140625 mkt_quantity:  117
# Asset:  SPY symbol_value:  193.42721557617188 mkt_quantity:  129
# Asset:  QQQ symbol_value:  109.9315414428711 mkt_quantity:  227
# Asset:  QQQ symbol_value:  110.2204360961914 mkt_quantity:  226
# Asset:  SPY symbol_value:  192.66958618164062 mkt_quantity:  129
# Asset:  SPY symbol_value:  186.5253753662109 mkt_quantity:  134
# Asset:  QQQ symbol_value:  108.1691436767578 mkt_quantity:  231
# Asset:  YELP symbol_value:  26.25 mkt_quantity:  952
# Asset:  TSLA symbol_value:  211.0 mkt_quantity:  118
# Asset:  SPY symbol_value:  181.7427978515625 mkt_quantity:  137
# Asset:  QQQ symbol_value:  99.01353454589844 mkt_quantity:  252
# Asset:  TSLA symbol_value:  186.3500061035156 mkt_quantity:  134
# Asset:  YELP symbol_value:  21.200000762939453 mkt_quantity:  1179
# Asset:  YELP symbol_value:  18.96999931335449 mkt_quantity:  1317
# Asset:  YELP symbol_value:  20.780000686645508 mkt_quantity:  1203
# Asset:  QQQ symbol_value:  103.39578247070312 mkt_quantity:  241
# Asset:  TSLA symbol_value:  222.55999755859366 mkt_quantity:  112
# Asset:  SPY symbol_value:  194.74114990234366 mkt_quantity:  128
# Asset:  QQQ symbol_value:  106.69957733154295 mkt_quantity:  234
# Asset:  SPY symbol_value:  196.4414825439453 mkt_quantity:  127
# Asset:  TSLA symbol_value:  218.9900054931641 mkt_quantity:  114
# Asset:  QQQ symbol_value:  104.17633819580078 mkt_quantity:  239
# Asset:  TSLA symbol_value:  196.3999938964844 mkt_quantity:  127
# Asset:  SPY symbol_value:  190.86119079589844 mkt_quantity:  130
# Asset:  QQQ symbol_value:  108.0426254272461 mkt_quantity:  231
# Asset:  SPY symbol_value:  201.82981872558602 mkt_quantity:  123
# Asset:  TSLA symbol_value:  221.52999877929688 mkt_quantity:  112
# Asset:  TSLA symbol_value:  223.2400054931641 mkt_quantity:  111
# Asset:  QQQ symbol_value:  111.01522064208984 mkt_quantity:  225
# Asset:  SPY symbol_value:  200.2896881103516 mkt_quantity:  124
# Asset:  YELP symbol_value:  38.459999084472656 mkt_quantity:  650
# Asset:  QQQ symbol_value:  114.27336883544922 mkt_quantity:  218
# Asset:  YELP symbol_value:  41.66999816894531 mkt_quantity:  599
# Asset:  TSLA symbol_value:  204.02999877929688 mkt_quantity:  122
# Asset:  SPY symbol_value:  203.5194549560547 mkt_quantity:  122
# Asset:  TSLA symbol_value:  196.50999450683602 mkt_quantity:  127
# Asset:  SPY symbol_value:  201.7072906494141 mkt_quantity:  123
# Asset:  YELP symbol_value:  35.080001831054695 mkt_quantity:  712
# Asset:  QQQ symbol_value:  114.63371276855469 mkt_quantity:  218
# Asset:  YELP symbol_value:  36.61999893188477 mkt_quantity:  682
# Asset:  SPY symbol_value:  205.6336212158203 mkt_quantity:  121
# Asset:  QQQ symbol_value:  115.32515716552734 mkt_quantity:  216
# Asset:  TSLA symbol_value:  193.1499938964844 mkt_quantity:  129
# Asset:  YELP symbol_value:  36.09000015258789 mkt_quantity:  692
# Asset:  YELP symbol_value:  38.68000030517578 mkt_quantity:  646
# Asset:  YELP symbol_value:  35.540000915527344 mkt_quantity:  703
# Asset:  TSLA symbol_value:  251.2100067138672 mkt_quantity:  99
# Asset:  SPY symbol_value:  222.9924774169922 mkt_quantity:  112
# Asset:  TSLA symbol_value:  270.22000122070307 mkt_quantity:  92
# Asset:  YELP symbol_value:  33.889999389648445 mkt_quantity:  737
# Asset:  SPY symbol_value:  227.32151794433602 mkt_quantity:  109
# Asset:  YELP symbol_value:  29.01000022888184 mkt_quantity:  861
# Asset:  YELP symbol_value:  30.71999931335449 mkt_quantity:  813
# Asset:  QQQ symbol_value:  138.61909484863278 mkt_quantity:  180
# Asset:  SPY symbol_value:  230.49012756347656 mkt_quantity:  108
# Asset:  YELP symbol_value:  29.32999992370605 mkt_quantity:  852
# Asset:  TSLA symbol_value:  313.2200012207031 mkt_quantity:  79
# Asset:  YELP symbol_value:  31.489999771118164 mkt_quantity:  793
# Asset:  SPY symbol_value:  235.38644409179688 mkt_quantity:  106
# Asset:  QQQ symbol_value:  141.3082275390625 mkt_quantity:  176
# Asset:  TSLA symbol_value:  356.9100036621094 mkt_quantity:  70
# Asset:  QQQ symbol_value:  138.70744323730472 mkt_quantity:  180
# Asset:  SPY symbol_value:  232.92393493652344 mkt_quantity:  107
# Asset:  TSLA symbol_value:  355.3999938964844 mkt_quantity:  70
# Asset:  QQQ symbol_value:  142.43690490722656 mkt_quantity:  175
# Asset:  SPY symbol_value:  236.2679748535156 mkt_quantity:  105
# Asset:  TSLA symbol_value:  377.6400146484375 mkt_quantity:  66
# Asset:  QQQ symbol_value:  143.4961700439453 mkt_quantity:  174
# Asset:  TSLA symbol_value:  348.1400146484375 mkt_quantity:  71
# Asset:  QQQ symbol_value:  145.06991577148438 mkt_quantity:  172
# Asset:  YELP symbol_value:  44.02000045776367 mkt_quantity:  567
# Asset:  YELP symbol_value:  47.1500015258789 mkt_quantity:  530
# Asset:  TSLA symbol_value:  306.5299987792969 mkt_quantity:  81
# Asset:  YELP symbol_value:  42.900001525878906 mkt_quantity:  582
# Asset:  QQQ symbol_value:  153.32228088378906 mkt_quantity:  163
# Asset:  QQQ symbol_value:  155.06321716308594 mkt_quantity:  161
# Asset:  TSLA symbol_value:  316.5799865722656 mkt_quantity:  78
# Asset:  YELP symbol_value:  43.16999816894531 mkt_quantity:  579
# Asset:  TSLA symbol_value:  344.57000732421875 mkt_quantity:  72
# Asset:  SPY symbol_value:  249.3489990234375 mkt_quantity:  100
# Asset:  QQQ symbol_value:  153.85975646972656 mkt_quantity:  162
# Asset:  TSLA symbol_value:  310.4200134277344 mkt_quantity:  80
# Asset:  YELP symbol_value:  38.290000915527344 mkt_quantity:  652
# Asset:  QQQ symbol_value:  164.81031799316406 mkt_quantity:  151
# Asset:  TSLA symbol_value:  330.92999267578125 mkt_quantity:  75
# Asset:  YELP symbol_value:  44.11000061035156 mkt_quantity:  566
# Asset:  SPY symbol_value:  264.1088256835937 mkt_quantity:  94
# Asset:  TSLA symbol_value:  325.6000061035156 mkt_quantity:  76
# Asset:  SPY symbol_value:  257.61624145507807 mkt_quantity:  97
# Asset:  QQQ symbol_value:  157.05136108398438 mkt_quantity:  159
# Asset:  YELP symbol_value:  41.27999877929688 mkt_quantity:  605
# Asset:  YELP symbol_value:  44.650001525878906 mkt_quantity:  559
# Asset:  SPY symbol_value:  259.07382202148443 mkt_quantity:  96
# Asset:  TSLA symbol_value:  290.239990234375 mkt_quantity:  86
# Asset:  QQQ symbol_value:  156.4392852783203 mkt_quantity:  159
# Asset:  SPY symbol_value:  259.37509155273443 mkt_quantity:  96
# Asset:  TSLA symbol_value:  301.9700012207031 mkt_quantity:  82
# Asset:  SPY symbol_value:  264.33087158203125 mkt_quantity:  94
# Asset:  TSLA symbol_value:  305.0199890136719 mkt_quantity:  81
# Asset:  TSLA symbol_value:  279.07000732421875 mkt_quantity:  89
# Asset:  YELP symbol_value:  43.40999984741211 mkt_quantity:  575
# Asset:  TSLA symbol_value:  317.6600036621094 mkt_quantity:  78
# Asset:  SPY symbol_value:  265.3616943359375 mkt_quantity:  94
# Asset:  QQQ symbol_value:  168.98280334472656 mkt_quantity:  147
# Asset:  TSLA symbol_value:  318.510009765625 mkt_quantity:  78
# Asset:  QQQ symbol_value:  177.2736358642578 mkt_quantity:  141
# Asset:  SPY symbol_value:  272.66287231445307 mkt_quantity:  91
# Asset:  TSLA symbol_value:  379.5700073242188 mkt_quantity:  65
# Asset:  YELP symbol_value:  49.349998474121094 mkt_quantity:  506
# Asset:  TSLA symbol_value:  311.8599853515625 mkt_quantity:  80
# Asset:  YELP symbol_value:  46.04999923706055 mkt_quantity:  542
# Asset:  YELP symbol_value:  48.77000045776367 mkt_quantity:  512
# Asset:  QQQ symbol_value:  181.75547790527344 mkt_quantity:  137
# Asset:  QQQ symbol_value:  182.50872802734366 mkt_quantity:  136
# Asset:  TSLA symbol_value:  310.70001220703125 mkt_quantity:  80
# Asset:  TSLA symbol_value:  262.79998779296875 mkt_quantity:  95
# Asset:  QQQ symbol_value:  170.2086639404297 mkt_quantity:  146
# Asset:  SPY symbol_value:  266.86691284179693 mkt_quantity:  93
# Asset:  YELP symbol_value:  41.75 mkt_quantity:  598
# Asset:  TSLA symbol_value:  334.8500061035156 mkt_quantity:  74
# Asset:  SPY symbol_value:  264.93527221679693 mkt_quantity:  94
# Asset:  SPY symbol_value:  262.287841796875 mkt_quantity:  95
# Asset:  YELP symbol_value:  35.2400016784668 mkt_quantity:  709
# Asset:  TSLA symbol_value:  295.3900146484375 mkt_quantity:  84
# Asset:  YELP symbol_value:  33.639999389648445 mkt_quantity:  743
# Asset:  YELP symbol_value:  34.5 mkt_quantity:  724
# Asset:  QQQ symbol_value:  161.40196228027344 mkt_quantity:  154
# Asset:  SPY symbol_value:  256.76788330078125 mkt_quantity:  97
# Asset:  TSLA symbol_value:  298.9200134277344 mkt_quantity:  83
# Asset:  TSLA symbol_value:  296.3800048828125 mkt_quantity:  84
# Asset:  YELP symbol_value:  34.799999237060554 mkt_quantity:  718
# Asset:  YELP symbol_value:  35.5 mkt_quantity:  704
# Asset:  TSLA symbol_value:  276.0599975585937 mkt_quantity:  90
# Asset:  TSLA symbol_value:  271.23001098632807 mkt_quantity:  92
# Asset:  QQQ symbol_value:  179.77915954589844 mkt_quantity:  139
# Asset:  SPY symbol_value:  280.7318725585937 mkt_quantity:  89
# Asset:  YELP symbol_value:  32.84999847412109 mkt_quantity:  761
# Asset:  SPY symbol_value:  286.5367431640625 mkt_quantity:  87
# Asset:  QQQ symbol_value:  185.6244354248047 mkt_quantity:  134
# Asset:  TSLA symbol_value:  224.7400054931641 mkt_quantity:  111
# Asset:  YELP symbol_value:  32.81999969482422 mkt_quantity:  761
# Asset:  YELP symbol_value:  34.93000030517578 mkt_quantity:  715
# Asset:  SPY symbol_value:  282.5153503417969 mkt_quantity:  88
# Asset:  QQQ symbol_value:  182.89117431640625 mkt_quantity:  136
# Asset:  TSLA symbol_value:  230.75 mkt_quantity:  108
# Asset:  QQQ symbol_value:  187.9509735107422 mkt_quantity:  133
# Asset:  SPY symbol_value:  296.45098876953125 mkt_quantity:  84
# Asset:  TSLA symbol_value:  245.8699951171875 mkt_quantity:  101
# Asset:  YELP symbol_value:  36.52000045776367 mkt_quantity:  684
# Asset:  QQQ symbol_value:  186.07000732421875 mkt_quantity:  134
# Asset:  SPY symbol_value:  294.3500061035156 mkt_quantity:  84
# Asset:  YELP symbol_value:  33.400001525878906 mkt_quantity:  748
# Asset:  TSLA symbol_value:  240.0500030517578 mkt_quantity:  104
# Asset:  TSLA symbol_value:  244.7400054931641 mkt_quantity:  102
# Asset:  QQQ symbol_value:  191.69000244140625 mkt_quantity:  130
# Asset:  SPY symbol_value:  299.8800048828125 mkt_quantity:  83
# Asset:  YELP symbol_value:  34.84999847412109 mkt_quantity:  717
# Asset:  TSLA symbol_value:  336.5899963378906 mkt_quantity:  74
# Asset:  YELP symbol_value:  33.200000762939446 mkt_quantity:  753
# Asset:  TSLA symbol_value:  378.989990234375 mkt_quantity:  65
# Asset:  YELP symbol_value:  35.0 mkt_quantity:  714
# Asset:  YELP symbol_value:  34.380001068115234 mkt_quantity:  727
# Creating summary stats...
# Creating equity curve...
#                      QQQ           SPY          TSLA          YELP  \
# datetime
# 2020-01-31  29058.899841  27141.000000  41600.000000  24654.419128
# 2020-02-03  28618.199921  26838.050507  43789.850159  23347.800545
# 2020-02-04  29304.599762  27229.810608  57392.401428  23919.000000
# 2020-02-05  29927.300873  27578.409088  53511.900635  24547.320763
# 2020-02-06  29742.699127  27714.530304  45494.798889      0.000000
# 2020-02-07  29790.800476  27624.060608  47485.749207      0.000000
# 2020-02-10  29697.200317  27492.090912  52000.000000      0.000000
# 2020-02-11  30322.500000  27901.280304  49971.348572      0.000000
# 2020-02-12  30339.400635  27956.888885  50561.549683      0.000000
# 2020-02-12  30339.400635  27956.888885  50561.549683      0.000000
#
#                      cash  commission          total   returns  equity_curve  \
# datetime
# 2020-01-31  207004.003492         0.0  329458.322462  0.002395      3.294583
# 2020-02-03  207004.003492         0.0  329597.904623  0.000424      3.295979
# 2020-02-04  207004.003492         0.0  344849.815290  0.046274      3.448498
# 2020-02-05  207004.003492         0.0  342568.934851 -0.006614      3.425689
# 2020-02-06  231551.324255         0.0  334503.352575 -0.023544      3.345034
# 2020-02-07  231551.324255         0.0  336451.934546  0.005825      3.364519
# 2020-02-10  231551.324255         0.0  340740.615484  0.012747      3.407406
# 2020-02-11  231551.324255         0.0  339746.453131 -0.002918      3.397465
# 2020-02-12  231551.324255         0.0  340409.163458  0.001951      3.404092
# 2020-02-12  231551.324255         0.0  340409.163458  0.000000      3.404092
#
#             drawdown
# datetime
# 2020-01-31  0.017373
# 2020-02-03  0.015977
# 2020-02-04  0.000000
# 2020-02-05  0.022809
# 2020-02-06  0.103465
# 2020-02-07  0.083979
# 2020-02-10  0.041092
# 2020-02-11  0.051034
# 2020-02-12  0.044407
# 2020-02-12  0.044407
# [('Total Return', '240.41%'),
#  ('Sharpe Ratio', '11.65'),
#  ('Max Drawdown', '35.20%'),
#  ('Drawdown Duration', '503')]
# Signals: 577
# Orders: 577
# Fills: 577

# %%
53.57/9
# Out:
# 5.952222222222222

# %% [markdown]
# https://www.xuebuyuan.com/3244260.html
#
#
# - VOX	Vanguard Telecommunication Services ETF
# - ======================
# - IYM	iShares Dow Jones U.S. Basic Materials Sector Index Fund
# - IYZ	iShares Dow Jones U.S. Telecommunications Sector Index Fund
# - FCL	Focus Morningstar Consumer Cyclical Index ETF
# - FCD	Focus Morningstar Consumer Defensive Index ETF
# - IYE	iShares Dow Jones U.S. Energy Sector Index Fund
# - IYG	iShares Dow Jones U.S. Financial Services Index Fund
# - IYH	iShares Dow Jones U.S. Healthcare Sector Index Fund
# - IYJ	iShares Dow Jones U.S. Industrial Sector Index Fund
# - IYR	iShares Dow Jones U.S. Real Estate Index Fund
# - IYW	iShares Dow Jones U.S. Technology Sector Index Fund
# - IDU	iShares Dow Jones U.S. Utilities Sector Index Fund

# %%
df_equity = pd.read_csv("equity.csv")
df_equity.drop_duplicates("datetime", inplace = True)
df_equity =df_equity[df_equity['datetime']>start_date_str]
df_equity.index = df_equity['datetime']
df_equity = df_equity[df_equity['total'].map(lambda x: str(x)!="nan")]
del df_equity['datetime']
df_equity['equity_curve'].plot(figsize = (16, 7))

# %%
df_equity
# Out:
#                       QQQ           SPY           TSLA          YELP  \
# datetime
# 2012-03-02   33104.812946  32930.575867   35605.840958      0.000000
# 2012-03-05   32762.885742  32796.275330   35323.420479  21346.829767
# 2012-03-06   32441.389103  32316.623230   34633.060638  20848.500000
# 2012-03-07   32691.440163  32542.051086   34643.518883  20594.250000
# 2012-03-08   33043.567829  32865.813904   34591.219681  20340.000000
# ...                   ...           ...            ...           ...
# 2020-01-28  121900.199661  91016.799316  594640.529785  36266.219845
# 2020-01-29  123587.395935  91946.401367  602171.742554  36276.388138
# 2020-01-30  122305.347290  90820.795898  661511.302124  35595.000000
# 2020-01-31  124059.149323  91560.000000  669440.000000  35117.008759
# 2020-02-03  122177.699661  90538.001709  704679.742554  33255.900776
#
#                     cash  commission          total   returns  equity_curve  \
# datetime
# 2012-03-02  25031.669769         0.0  126672.899540  0.266729      1.266729
# 2012-03-05     33.809847         0.0  122263.221165 -0.034812      1.222632
# 2012-03-06     33.809847         0.0  120273.382818 -0.016275      1.202734
# 2012-03-07     33.809847         0.0  120505.069979  0.001926      1.205051
# 2012-03-08     33.809847         0.0  120874.411261  0.003065      1.208744
# ...                  ...         ...            ...       ...           ...
# 2020-01-28     33.809847         0.0  843857.558455  0.036539      8.438576
# 2020-01-29     33.809847         0.0  854015.737841  0.012038      8.540157
# 2020-01-30     33.809847         0.0  910266.255159  0.065866      9.102663
# 2020-01-31     33.809847         0.0  920209.967928  0.010924      9.202100
# 2020-02-03     33.809847         0.0  950685.154547  0.033118      9.506852
#
#             drawdown
# datetime
# 2012-03-02  0.000000
# 2012-03-05  0.044097
# 2012-03-06  0.063995
# 2012-03-07  0.061678
# 2012-03-08  0.057985
# ...              ...
# 2020-01-28  0.081125
# 2020-01-29  0.000000
# 2020-01-30  0.000000
# 2020-01-31  0.000000
# 2020-02-03  0.000000
#
# [1993 rows x 10 columns]
