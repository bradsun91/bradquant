# %%
from pandas.tseries.offsets import BDay
import pandas as pd, numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os, glob
import alphalens
import csv

# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
results_folder_path = '/Users/brad_sun/Dropbox/ACCERN/json_backtest_record/results/'
configs_folder_path = '/Users/brad_sun/Dropbox/ACCERN/json_backtest_record/configs/'
result_file_path = '/Users/brad_sun/Dropbox/ACCERN/json_backtest_record/results/*.csv'
config_file_path = '/Users/brad_sun/Dropbox/ACCERN/json_backtest_record/configs/*.csv'

# %%
# The only thing to change as a file variable for later saving pictures
save_pic_name = '3_21_vipul_multi_data_3_sp500_ctc_daily_results'

# %% [markdown]
# # Preprocessing Mode

# %%
result_file = glob.glob(result_file_path)
config_file = glob.glob(config_file_path)
result_csv = result_file[0]
config_csv = config_file[0]
result = pd.read_csv(result_csv)
config = pd.read_csv(config_csv)

# %%
result.columns = ['algo_id', 'algo_name', 'backtest_id', 'alpha', 'beta', 'sharpe', 'sortino',
       'total_returns', 'benchmark_returns', 'volatility', 'max_drawdown',
       'backtest_url']

# %%
merged = result.merge(config, on = 'algo_name')

# %%
title_to_convert_to_float = ['alpha', 'beta', 'sharpe', 'sortino', 'volatility']
title_to_strip_pct = ['total_returns', 'benchmark_returns', 'max_drawdown']

for col in title_to_convert_to_float:
    merged[col] = merged[col].apply(lambda x: float(x))
for col in title_to_strip_pct:
    merged[col] = merged[col].apply(lambda x: x.strip('%'))
    merged[col] = merged[col].apply(lambda x: float(x))
    merged[col] = merged[col]/100

# %%
# Add one more performance metric: annualized return:
merged['annualized_returns'] = (1+merged['total_returns'])**(1/4.25) - 1

# %%
merged.head()
# Out:
#                     algo_id                              algo_name  \
# 0  5ab2ad341274a90a283a605c  3_21_vipul_multi_data_3_ctc_100mil_23
# 1  5ab2a8181274a96da63a608b    3_21_vipul_multi_data_3_ctc_1mil_21
# 2  5ab2a3e01274a900153a6262     3_21_vipul_multi_data_3_ctc_1mil_2
# 3  5ab2ad041274a9000f3a62f0  3_21_vipul_multi_data_3_ctc_100mil_22
# 4  5ab2a9f4ce20ea07dbd504e1   3_21_vipul_multi_data_3_ctc_100mil_7
#
#                 backtest_id  alpha  beta  sharpe  sortino  total_returns  \
# 0  5ab2ad471311344338806fc9   0.06 -0.08    1.53     2.31         0.2300
# 1  5ab2a8260ddace414b0dcb9e   0.07  1.08    1.50     2.16         1.3518
# 2  5ab2a3f21311344338806e11   0.11  0.53    2.04     3.15         1.1435
# 3  5ab2ad16fe98ee41037abd7a   0.06  0.38    2.00     3.02         0.5994
# 4  5ab2aa0673168242ea8c84db   0.07  0.34    1.99     3.01         0.6118
#
#    benchmark_returns  volatility         ...          \
# 0              0.711        0.03         ...
# 1              0.711        0.14         ...
# 2              0.711        0.09         ...
# 3              0.711        0.05         ...
# 4              0.711        0.06         ...
#
#                                         backtest_url  \
# 0  https://www.quantopian.com/algorithms/5ab2ad34...
# 1  https://www.quantopian.com/algorithms/5ab2a818...
# 2  https://www.quantopian.com/algorithms/5ab2a3e0...
# 3  https://www.quantopian.com/algorithms/5ab2ad04...
# 4  https://www.quantopian.com/algorithms/5ab2a9f4...
#
#                                   algo_file  \
# 0  3_21_run_vipul_multi_data_3_sp500_CTC.py
# 1  3_21_run_vipul_multi_data_3_sp500_CTC.py
# 2  3_21_run_vipul_multi_data_3_sp500_CTC.py
# 3  3_21_run_vipul_multi_data_3_sp500_CTC.py
# 4  3_21_run_vipul_multi_data_3_sp500_CTC.py
#
#                                            data_file start_date  end_date  \
# 0  https://dl.dropboxusercontent.com/s/i2owo338rz...     8/1/13  11/30/17
# 1  https://dl.dropboxusercontent.com/s/i2owo338rz...     8/1/13  11/30/17
# 2  https://dl.dropboxusercontent.com/s/i2owo338rz...     8/1/13  11/30/17
# 3  https://dl.dropboxusercontent.com/s/i2owo338rz...     8/1/13  11/30/17
# 4  https://dl.dropboxusercontent.com/s/i2owo338rz...     8/1/13  11/30/17
#
#      capital  num_stocks_to_trade  long_half  short_half  annualized_returns
# 0  100000000                   50       0.50        0.50            0.049915
# 1    1000000                   50       1.00        0.00            0.222893
# 2    1000000                   10       0.75        0.25            0.196496
# 3  100000000                   50       0.75        0.25            0.116837
# 4  100000000                   20       0.75        0.25            0.118869
#
# [5 rows x 21 columns]

# %% [markdown]
# # Research Mode:

# %%
research = merged.copy()

# Construct a heatmap analysis graph for all strats:
df = pd.DataFrame(index = research.index)
df['sharpe'] = research.sharpe
df['long_exposure'] = research.long_half
df['num_stocks'] = research.num_stocks_to_trade
df['capital_capacity'] = research.capital
df['alpha'] = research.alpha
df['beta'] = research.beta
df['total_returns'] = research.total_returns
df['volatility'] = research.volatility
df['max_drawdown'] = research.max_drawdown
df['annualized_returns'] = research.annualized_returns
df_reset_index = df.reset_index()

# %%
research
# Out:
#                      algo_id                              algo_name  \
# 0   5ab2ad341274a90a283a605c  3_21_vipul_multi_data_3_ctc_100mil_23
# 1   5ab2a8181274a96da63a608b    3_21_vipul_multi_data_3_ctc_1mil_21
# 2   5ab2a3e01274a900153a6262     3_21_vipul_multi_data_3_ctc_1mil_2
# 3   5ab2ad041274a9000f3a62f0  3_21_vipul_multi_data_3_ctc_100mil_22
# 4   5ab2a9f4ce20ea07dbd504e1   3_21_vipul_multi_data_3_ctc_100mil_7
# 5   5ab2a4e9e89f310012dd44ec     3_21_vipul_multi_data_3_ctc_1mil_7
# 6   5ab2a3b6e89f3157a6dd435b     3_21_vipul_multi_data_3_ctc_1mil_1
# 7   5ab2a8371274a979db3a6038    3_21_vipul_multi_data_3_ctc_1mil_22
# 8   5ab2a5631274a96da63a6055     3_21_vipul_multi_data_3_ctc_1mil_8
# 9   5ab2ac35e89f31180add454e  3_21_vipul_multi_data_3_ctc_100mil_17
# 10  5ab2a4c3ce20ea001bd50717     3_21_vipul_multi_data_3_ctc_1mil_6
# 11  5ab2a6a2ce20ea27b0d50688    3_21_vipul_multi_data_3_ctc_1mil_12
# 12  5ab2a8d2ce20ea27b0d506af   3_21_vipul_multi_data_3_ctc_100mil_2
# 13  5ab2ab16e89f315927dd440f  3_21_vipul_multi_data_3_ctc_100mil_12
# 14  5ab2a8561274a90a283a600a    3_21_vipul_multi_data_3_ctc_1mil_23
# 15  5ab2a795ce20ea27b0d5069f    3_21_vipul_multi_data_3_ctc_1mil_17
# 16  5ab2a8b3ce20ea5c74d505a6   3_21_vipul_multi_data_3_ctc_100mil_1
# 17  5ab2a67de89f31180add4503    3_21_vipul_multi_data_3_ctc_1mil_11
# 18  5ab2aa1dce20ea0012d5079e   3_21_vipul_multi_data_3_ctc_100mil_8
# 19  5ab2a9cace20ea0012d5079a   3_21_vipul_multi_data_3_ctc_100mil_6
# 20  5ab2a4041274a96da63a6039     3_21_vipul_multi_data_3_ctc_1mil_3
# 21  5ab2aaecce20ea001bd5078b  3_21_vipul_multi_data_3_ctc_100mil_11
# 22  5ab2acdd1274a97d743a607f  3_21_vipul_multi_data_3_ctc_100mil_21
# 23  5ab2a777e89f315927dd43d6    3_21_vipul_multi_data_3_ctc_1mil_16
# 24  5ab2ac0ce89f310012dd456e  3_21_vipul_multi_data_3_ctc_100mil_16
# 25  5ab2a7b5e89f313bb2dd4446    3_21_vipul_multi_data_3_ctc_1mil_18
# 26  5ab2a6c2ce20ea001bd50741    3_21_vipul_multi_data_3_ctc_1mil_13
# 27  5ab2ac5f1274a979db3a6075  3_21_vipul_multi_data_3_ctc_100mil_18
# 28  5ab2a8f61274a979db3a603e   3_21_vipul_multi_data_3_ctc_100mil_3
# 29  5ab2ab45e89f310ff5dd42e7  3_21_vipul_multi_data_3_ctc_100mil_13
# 30  5ab2aa411274a90a283a6023   3_21_vipul_multi_data_3_ctc_100mil_9
# 31  5ab2a971e89f310012dd453e   3_21_vipul_multi_data_3_ctc_100mil_4
# 32  5ab2a5e1ce20ea0012d50750     3_21_vipul_multi_data_3_ctc_1mil_9
# 33  5ab2a473e89f310012dd44e4     3_21_vipul_multi_data_3_ctc_1mil_4
# 34  5ab2ad5ee89f310ff5dd42ff  3_21_vipul_multi_data_3_ctc_100mil_24
# 35  5ab2a8751274a96da63a6092    3_21_vipul_multi_data_3_ctc_1mil_24
# 36  5ab2a7d4e89f313bb2dd444a    3_21_vipul_multi_data_3_ctc_1mil_19
# 37  5ab2ac8a1274a97d743a607b  3_21_vipul_multi_data_3_ctc_100mil_19
# 38  5ab2ab701274a96da63a60b6  3_21_vipul_multi_data_3_ctc_100mil_14
# 39  5ab2a6e7ce20ea0012d50767    3_21_vipul_multi_data_3_ctc_1mil_14
# 40  5ab2aac11274a96da63a60a7  3_21_vipul_multi_data_3_ctc_100mil_10
# 41  5ab2a65d1274a9000f3a628c    3_21_vipul_multi_data_3_ctc_1mil_10
# 42  5ab2a99ece20ea001bd50775   3_21_vipul_multi_data_3_ctc_100mil_5
# 43  5ab2a49fce20ea0015d506ed     3_21_vipul_multi_data_3_ctc_1mil_5
# 44  5ab2a7061274a900153a62a5    3_21_vipul_multi_data_3_ctc_1mil_15
# 45  5ab2ab94ce20ea0012d507af  3_21_vipul_multi_data_3_ctc_100mil_15
# 46  5ab2a7f4e89f31180add4511    3_21_vipul_multi_data_3_ctc_1mil_20
# 47  5ab2a8941274a97d743a6040    3_21_vipul_multi_data_3_ctc_1mil_25
# 48  5ab2acae1274a90a283a6055  3_21_vipul_multi_data_3_ctc_100mil_20
# 49  5ab2ad83ce20ea27b0d506f5  3_21_vipul_multi_data_3_ctc_100mil_25
#
#                  backtest_id  alpha  beta  sharpe  sortino  total_returns  \
# 0   5ab2ad471311344338806fc9   0.06 -0.08    1.53     2.31         0.2300
# 1   5ab2a8260ddace414b0dcb9e   0.07  1.08    1.50     2.16         1.3518
# 2   5ab2a3f21311344338806e11   0.11  0.53    2.04     3.15         1.1435
# 3   5ab2ad16fe98ee41037abd7a   0.06  0.38    2.00     3.02         0.5994
# 4   5ab2aa0673168242ea8c84db   0.07  0.34    1.99     3.01         0.6118
# 5   5ab2a4f6934aec4234008b03   0.08  0.53    1.97     2.92         0.9251
# 6   5ab2a3c9c60f8042dc00ee00   0.14  1.08    1.87     2.79         2.1871
# 7   5ab2a8441f002840cf20b8f8   0.06  0.49    1.83     2.72         0.6946
# 8   5ab2a5751f002840cf20b82f   0.08  0.00    1.82     2.87         0.3858
# 9   5ab2ac48934aec4234008ba3   0.05  0.40    1.72     2.52         0.5210
# 10  5ab2a4d71a74f74267764d5b   0.09  1.06    1.69     2.46         1.6423
# 11  5ab2a6b0bd339240a0d70760   0.05  0.53    1.63     2.37         0.6727
# 12  5ab2a8dfbd339240a0d7077e   0.06  0.22    1.62     2.55         0.4384
# 13  5ab2ab2973168242ea8c84ef   0.04  0.40    1.60     2.36         0.4963
# 14  5ab2a864fe98ee41037abd03   0.06 -0.06    1.60     2.43         0.2516
# 15  5ab2a7a390a53b41996a73e9   0.05  0.52    1.59     2.29         0.6143
# 16  5ab2a8c01f002840cf20b908   0.05  0.51    1.58     2.41         0.6688
# 17  5ab2a69073168242ea8c8476   0.08  1.07    1.58     2.29         1.4620
# 18  5ab2aa30fe98ee41037abd3b   0.06 -0.04    1.53     2.39         0.2882
# 19  5ab2a9dc1311344338806f12   0.05  0.69    1.52     2.23         0.8149
# 20  5ab2a4121f002840cf20b7f8   0.09  0.00    1.52     2.38         0.4406
# 21  5ab2aaff0ddace414b0dcbc2   0.05  0.79    1.49     2.18         0.9000
# 22  5ab2aced90a53b41996a7468   0.05  0.85    1.45     2.11         0.9290
# 23  5ab2a78490a53b41996a73e4   0.06  1.09    1.45     2.07         1.2842
# 24  5ab2ac1e1a74f74267764e8a   0.04  0.84    1.42     2.06         0.8940
# 25  5ab2a7c2c60f8042dc00ee53   0.05 -0.03    1.28     1.94         0.1956
# 26  5ab2a6cf90a53b41996a73c2   0.05 -0.01    1.22     1.88         0.2101
# 27  5ab2ac711f002840cf20b9ee   0.04 -0.05    1.21     1.81         0.1787
# 28  5ab2a90990a53b41996a740e   0.06 -0.02    1.14     1.77         0.2486
# 29  5ab2ab581f002840cf20b98f   0.04 -0.03    1.09     1.66         0.1723
# 30  5ab2aa5490a53b41996a7434   0.06 -0.44    0.08     0.11         0.0130
# 31  5ab2a98390a53b41996a7415   0.04 -0.30    0.06     0.08         0.0067
# 32  5ab2a5f4c60f8042dc00ee3b   0.07 -0.53   -0.03    -0.04        -0.0227
# 33  5ab2a4861311344338806e25   0.06 -0.52   -0.10    -0.14        -0.0551
# 34  5ab2ad710ddace414b0dcbeb   0.06 -0.55   -0.22    -0.31        -0.0811
# 35  5ab2a8821311344338806ef5   0.06 -0.60   -0.24    -0.34        -0.0949
# 36  5ab2a7e10ddace414b0dcb89   0.04 -0.57   -0.38    -0.54        -0.1332
# 37  5ab2ac9cfe98ee41037abd67   0.04 -0.52   -0.39    -0.55        -0.1262
# 38  5ab2ab83c60f8042dc00ef16   0.03 -0.49   -0.42    -0.60        -0.1289
# 39  5ab2a6f51a74f74267764daa   0.04 -0.54   -0.42    -0.60        -0.1416
# 40  5ab2aad50ddace414b0dcbbf   0.06 -0.88   -0.50    -0.72        -0.2491
# 41  5ab2a672fe98ee41037abcba   0.06 -1.06   -0.56    -0.79        -0.3171
# 42  5ab2a9c1934aec4234008b7e   0.02 -0.64   -0.64    -0.89        -0.2425
# 43  5ab2a4b11a74f74267764d43   0.04 -1.03   -0.66    -0.93        -0.3768
# 44  5ab2a7191a74f74267764db8   0.04 -1.06   -0.70    -0.99        -0.3695
# 45  5ab2aba2c60f8042dc00ef1e   0.04 -0.97   -0.71    -1.01        -0.3424
# 46  5ab2a8061f002840cf20b8ea   0.04 -1.07   -0.73    -1.03        -0.3816
# 47  5ab2a8a11311344338806efb   0.03 -1.07   -0.76    -1.07        -0.3907
# 48  5ab2acc01311344338806fab   0.03 -1.00   -0.77    -1.09        -0.3723
# 49  5ab2ad95934aec4234008bc0   0.03 -1.00   -0.78    -1.09        -0.3730
#
#     benchmark_returns  volatility         ...          \
# 0               0.711        0.03         ...
# 1               0.711        0.14         ...
# 2               0.711        0.09         ...
# 3               0.711        0.05         ...
# 4               0.711        0.06         ...
# 5               0.711        0.08         ...
# 6               0.711        0.15         ...
# 7               0.711        0.07         ...
# 8               0.711        0.04         ...
# 9               0.711        0.06         ...
# 10              0.711        0.14         ...
# 11              0.711        0.07         ...
# 12              0.711        0.05         ...
# 13              0.711        0.06         ...
# 14              0.711        0.03         ...
# 15              0.711        0.07         ...
# 16              0.711        0.08         ...
# 17              0.711        0.14         ...
# 18              0.711        0.04         ...
# 19              0.711        0.09         ...
# 20              0.711        0.06         ...
# 21              0.711        0.10         ...
# 22              0.711        0.11         ...
# 23              0.711        0.14         ...
# 24              0.711        0.11         ...
# 25              0.711        0.03         ...
# 26              0.711        0.04         ...
# 27              0.711        0.03         ...
# 28              0.711        0.05         ...
# 29              0.711        0.03         ...
# 30              0.711        0.07         ...
# 31              0.711        0.06         ...
# 32              0.711        0.08         ...
# 33              0.711        0.09         ...
# 34              0.711        0.08         ...
# 35              0.711        0.08         ...
# 36              0.711        0.08         ...
# 37              0.711        0.07         ...
# 38              0.711        0.07         ...
# 39              0.711        0.08         ...
# 40              0.711        0.12         ...
# 41              0.711        0.14         ...
# 42              0.711        0.09         ...
# 43              0.711        0.15         ...
# 44              0.711        0.14         ...
# 45              0.711        0.13         ...
# 46              0.711        0.14         ...
# 47              0.711        0.14         ...
# 48              0.711        0.13         ...
# 49              0.711        0.13         ...
#
#                                          backtest_url  \
# 0   https://www.quantopian.com/algorithms/5ab2ad34...
# 1   https://www.quantopian.com/algorithms/5ab2a818...
# 2   https://www.quantopian.com/algorithms/5ab2a3e0...
# 3   https://www.quantopian.com/algorithms/5ab2ad04...
# 4   https://www.quantopian.com/algorithms/5ab2a9f4...
# 5   https://www.quantopian.com/algorithms/5ab2a4e9...
# 6   https://www.quantopian.com/algorithms/5ab2a3b6...
# 7   https://www.quantopian.com/algorithms/5ab2a837...
# 8   https://www.quantopian.com/algorithms/5ab2a563...
# 9   https://www.quantopian.com/algorithms/5ab2ac35...
# 10  https://www.quantopian.com/algorithms/5ab2a4c3...
# 11  https://www.quantopian.com/algorithms/5ab2a6a2...
# 12  https://www.quantopian.com/algorithms/5ab2a8d2...
# 13  https://www.quantopian.com/algorithms/5ab2ab16...
# 14  https://www.quantopian.com/algorithms/5ab2a856...
# 15  https://www.quantopian.com/algorithms/5ab2a795...
# 16  https://www.quantopian.com/algorithms/5ab2a8b3...
# 17  https://www.quantopian.com/algorithms/5ab2a67d...
# 18  https://www.quantopian.com/algorithms/5ab2aa1d...
# 19  https://www.quantopian.com/algorithms/5ab2a9ca...
# 20  https://www.quantopian.com/algorithms/5ab2a404...
# 21  https://www.quantopian.com/algorithms/5ab2aaec...
# 22  https://www.quantopian.com/algorithms/5ab2acdd...
# 23  https://www.quantopian.com/algorithms/5ab2a777...
# 24  https://www.quantopian.com/algorithms/5ab2ac0c...
# 25  https://www.quantopian.com/algorithms/5ab2a7b5...
# 26  https://www.quantopian.com/algorithms/5ab2a6c2...
# 27  https://www.quantopian.com/algorithms/5ab2ac5f...
# 28  https://www.quantopian.com/algorithms/5ab2a8f6...
# 29  https://www.quantopian.com/algorithms/5ab2ab45...
# 30  https://www.quantopian.com/algorithms/5ab2aa41...
# 31  https://www.quantopian.com/algorithms/5ab2a971...
# 32  https://www.quantopian.com/algorithms/5ab2a5e1...
# 33  https://www.quantopian.com/algorithms/5ab2a473...
# 34  https://www.quantopian.com/algorithms/5ab2ad5e...
# 35  https://www.quantopian.com/algorithms/5ab2a875...
# 36  https://www.quantopian.com/algorithms/5ab2a7d4...
# 37  https://www.quantopian.com/algorithms/5ab2ac8a...
# 38  https://www.quantopian.com/algorithms/5ab2ab70...
# 39  https://www.quantopian.com/algorithms/5ab2a6e7...
# 40  https://www.quantopian.com/algorithms/5ab2aac1...
# 41  https://www.quantopian.com/algorithms/5ab2a65d...
# 42  https://www.quantopian.com/algorithms/5ab2a99e...
# 43  https://www.quantopian.com/algorithms/5ab2a49f...
# 44  https://www.quantopian.com/algorithms/5ab2a706...
# 45  https://www.quantopian.com/algorithms/5ab2ab94...
# 46  https://www.quantopian.com/algorithms/5ab2a7f4...
# 47  https://www.quantopian.com/algorithms/5ab2a894...
# 48  https://www.quantopian.com/algorithms/5ab2acae...
# 49  https://www.quantopian.com/algorithms/5ab2ad83...
#
#                                    algo_file  \
# 0   3_21_run_vipul_multi_data_3_sp500_CTC.py
# 1   3_21_run_vipul_multi_data_3_sp500_CTC.py
# 2   3_21_run_vipul_multi_data_3_sp500_CTC.py
# 3   3_21_run_vipul_multi_data_3_sp500_CTC.py
# 4   3_21_run_vipul_multi_data_3_sp500_CTC.py
# 5   3_21_run_vipul_multi_data_3_sp500_CTC.py
# 6   3_21_run_vipul_multi_data_3_sp500_CTC.py
# 7   3_21_run_vipul_multi_data_3_sp500_CTC.py
# 8   3_21_run_vipul_multi_data_3_sp500_CTC.py
# 9   3_21_run_vipul_multi_data_3_sp500_CTC.py
# 10  3_21_run_vipul_multi_data_3_sp500_CTC.py
# 11  3_21_run_vipul_multi_data_3_sp500_CTC.py
# 12  3_21_run_vipul_multi_data_3_sp500_CTC.py
# 13  3_21_run_vipul_multi_data_3_sp500_CTC.py
# 14  3_21_run_vipul_multi_data_3_sp500_CTC.py
# 15  3_21_run_vipul_multi_data_3_sp500_CTC.py
# 16  3_21_run_vipul_multi_data_3_sp500_CTC.py
# 17  3_21_run_vipul_multi_data_3_sp500_CTC.py
# 18  3_21_run_vipul_multi_data_3_sp500_CTC.py
# 19  3_21_run_vipul_multi_data_3_sp500_CTC.py
# 20  3_21_run_vipul_multi_data_3_sp500_CTC.py
# 21  3_21_run_vipul_multi_data_3_sp500_CTC.py
# 22  3_21_run_vipul_multi_data_3_sp500_CTC.py
# 23  3_21_run_vipul_multi_data_3_sp500_CTC.py
# 24  3_21_run_vipul_multi_data_3_sp500_CTC.py
# 25  3_21_run_vipul_multi_data_3_sp500_CTC.py
# 26  3_21_run_vipul_multi_data_3_sp500_CTC.py
# 27  3_21_run_vipul_multi_data_3_sp500_CTC.py
# 28  3_21_run_vipul_multi_data_3_sp500_CTC.py
# 29  3_21_run_vipul_multi_data_3_sp500_CTC.py
# 30  3_21_run_vipul_multi_data_3_sp500_CTC.py
# 31  3_21_run_vipul_multi_data_3_sp500_CTC.py
# 32  3_21_run_vipul_multi_data_3_sp500_CTC.py
# 33  3_21_run_vipul_multi_data_3_sp500_CTC.py
# 34  3_21_run_vipul_multi_data_3_sp500_CTC.py
# 35  3_21_run_vipul_multi_data_3_sp500_CTC.py
# 36  3_21_run_vipul_multi_data_3_sp500_CTC.py
# 37  3_21_run_vipul_multi_data_3_sp500_CTC.py
# 38  3_21_run_vipul_multi_data_3_sp500_CTC.py
# 39  3_21_run_vipul_multi_data_3_sp500_CTC.py
# 40  3_21_run_vipul_multi_data_3_sp500_CTC.py
# 41  3_21_run_vipul_multi_data_3_sp500_CTC.py
# 42  3_21_run_vipul_multi_data_3_sp500_CTC.py
# 43  3_21_run_vipul_multi_data_3_sp500_CTC.py
# 44  3_21_run_vipul_multi_data_3_sp500_CTC.py
# 45  3_21_run_vipul_multi_data_3_sp500_CTC.py
# 46  3_21_run_vipul_multi_data_3_sp500_CTC.py
# 47  3_21_run_vipul_multi_data_3_sp500_CTC.py
# 48  3_21_run_vipul_multi_data_3_sp500_CTC.py
# 49  3_21_run_vipul_multi_data_3_sp500_CTC.py
#
#                                             data_file start_date  end_date  \
# 0   https://dl.dropboxusercontent.com/s/i2owo338rz...     8/1/13  11/30/17
# 1   https://dl.dropboxusercontent.com/s/i2owo338rz...     8/1/13  11/30/17
# 2   https://dl.dropboxusercontent.com/s/i2owo338rz...     8/1/13  11/30/17
# 3   https://dl.dropboxusercontent.com/s/i2owo338rz...     8/1/13  11/30/17
# 4   https://dl.dropboxusercontent.com/s/i2owo338rz...     8/1/13  11/30/17
# 5   https://dl.dropboxusercontent.com/s/i2owo338rz...     8/1/13  11/30/17
# 6   https://dl.dropboxusercontent.com/s/i2owo338rz...     8/1/13  11/30/17
# 7   https://dl.dropboxusercontent.com/s/i2owo338rz...     8/1/13  11/30/17
# 8   https://dl.dropboxusercontent.com/s/i2owo338rz...     8/1/13  11/30/17
# 9   https://dl.dropboxusercontent.com/s/i2owo338rz...     8/1/13  11/30/17
# 10  https://dl.dropboxusercontent.com/s/i2owo338rz...     8/1/13  11/30/17
# 11  https://dl.dropboxusercontent.com/s/i2owo338rz...     8/1/13  11/30/17
# 12  https://dl.dropboxusercontent.com/s/i2owo338rz...     8/1/13  11/30/17
# 13  https://dl.dropboxusercontent.com/s/i2owo338rz...     8/1/13  11/30/17
# 14  https://dl.dropboxusercontent.com/s/i2owo338rz...     8/1/13  11/30/17
# 15  https://dl.dropboxusercontent.com/s/i2owo338rz...     8/1/13  11/30/17
# 16  https://dl.dropboxusercontent.com/s/i2owo338rz...     8/1/13  11/30/17
# 17  https://dl.dropboxusercontent.com/s/i2owo338rz...     8/1/13  11/30/17
# 18  https://dl.dropboxusercontent.com/s/i2owo338rz...     8/1/13  11/30/17
# 19  https://dl.dropboxusercontent.com/s/i2owo338rz...     8/1/13  11/30/17
# 20  https://dl.dropboxusercontent.com/s/i2owo338rz...     8/1/13  11/30/17
# 21  https://dl.dropboxusercontent.com/s/i2owo338rz...     8/1/13  11/30/17
# 22  https://dl.dropboxusercontent.com/s/i2owo338rz...     8/1/13  11/30/17
# 23  https://dl.dropboxusercontent.com/s/i2owo338rz...     8/1/13  11/30/17
# 24  https://dl.dropboxusercontent.com/s/i2owo338rz...     8/1/13  11/30/17
# 25  https://dl.dropboxusercontent.com/s/i2owo338rz...     8/1/13  11/30/17
# 26  https://dl.dropboxusercontent.com/s/i2owo338rz...     8/1/13  11/30/17
# 27  https://dl.dropboxusercontent.com/s/i2owo338rz...     8/1/13  11/30/17
# 28  https://dl.dropboxusercontent.com/s/i2owo338rz...     8/1/13  11/30/17
# 29  https://dl.dropboxusercontent.com/s/i2owo338rz...     8/1/13  11/30/17
# 30  https://dl.dropboxusercontent.com/s/i2owo338rz...     8/1/13  11/30/17
# 31  https://dl.dropboxusercontent.com/s/i2owo338rz...     8/1/13  11/30/17
# 32  https://dl.dropboxusercontent.com/s/i2owo338rz...     8/1/13  11/30/17
# 33  https://dl.dropboxusercontent.com/s/i2owo338rz...     8/1/13  11/30/17
# 34  https://dl.dropboxusercontent.com/s/i2owo338rz...     8/1/13  11/30/17
# 35  https://dl.dropboxusercontent.com/s/i2owo338rz...     8/1/13  11/30/17
# 36  https://dl.dropboxusercontent.com/s/i2owo338rz...     8/1/13  11/30/17
# 37  https://dl.dropboxusercontent.com/s/i2owo338rz...     8/1/13  11/30/17
# 38  https://dl.dropboxusercontent.com/s/i2owo338rz...     8/1/13  11/30/17
# 39  https://dl.dropboxusercontent.com/s/i2owo338rz...     8/1/13  11/30/17
# 40  https://dl.dropboxusercontent.com/s/i2owo338rz...     8/1/13  11/30/17
# 41  https://dl.dropboxusercontent.com/s/i2owo338rz...     8/1/13  11/30/17
# 42  https://dl.dropboxusercontent.com/s/i2owo338rz...     8/1/13  11/30/17
# 43  https://dl.dropboxusercontent.com/s/i2owo338rz...     8/1/13  11/30/17
# 44  https://dl.dropboxusercontent.com/s/i2owo338rz...     8/1/13  11/30/17
# 45  https://dl.dropboxusercontent.com/s/i2owo338rz...     8/1/13  11/30/17
# 46  https://dl.dropboxusercontent.com/s/i2owo338rz...     8/1/13  11/30/17
# 47  https://dl.dropboxusercontent.com/s/i2owo338rz...     8/1/13  11/30/17
# 48  https://dl.dropboxusercontent.com/s/i2owo338rz...     8/1/13  11/30/17
# 49  https://dl.dropboxusercontent.com/s/i2owo338rz...     8/1/13  11/30/17
#
#       capital  num_stocks_to_trade  long_half  short_half  annualized_returns
# 0   100000000                   50       0.50        0.50            0.049915
# 1     1000000                   50       1.00        0.00            0.222893
# 2     1000000                   10       0.75        0.25            0.196496
# 3   100000000                   50       0.75        0.25            0.116837
# 4   100000000                   20       0.75        0.25            0.118869
# 5     1000000                   20       0.75        0.25            0.166622
# 6     1000000                   10       1.00        0.00            0.313548
# 7     1000000                   50       0.75        0.25            0.132135
# 8     1000000                   20       0.50        0.50            0.079795
# 9   100000000                   40       0.75        0.25            0.103707
# 10    1000000                   20       1.00        0.00            0.256869
# 11    1000000                   30       0.75        0.25            0.128675
# 12  100000000                   10       0.75        0.25            0.089302
# 13  100000000                   30       0.75        0.25            0.099464
# 14    1000000                   50       0.50        0.50            0.054224
# 15    1000000                   40       0.75        0.25            0.119277
# 16  100000000                   10       1.00        0.00            0.128055
# 17    1000000                   30       1.00        0.00            0.236140
# 18  100000000                   20       0.50        0.50            0.061398
# 19  100000000                   20       1.00        0.00            0.150553
# 20    1000000                   10       0.50        0.50            0.089693
# 21  100000000                   30       1.00        0.00            0.163025
# 22  100000000                   50       1.00        0.00            0.167178
# 23    1000000                   40       1.00        0.00            0.214529
# 24  100000000                   40       1.00        0.00            0.162160
# 25    1000000                   40       0.50        0.50            0.042931
# 26    1000000                   30       0.50        0.50            0.045893
# 27  100000000                   40       0.50        0.50            0.039443
# 28  100000000                   10       0.50        0.50            0.053629
# 29  100000000                   30       0.50        0.50            0.038112
# 30  100000000                   20       0.25        0.75            0.003044
# 31  100000000                   10       0.25        0.75            0.001572
# 32    1000000                   20       0.25        0.75           -0.005388
# 33    1000000                   10       0.25        0.75           -0.013247
# 34  100000000                   50       0.25        0.75           -0.019704
# 35    1000000                   50       0.25        0.75           -0.023188
# 36    1000000                   40       0.25        0.75           -0.033075
# 37  100000000                   40       0.25        0.75           -0.031244
# 38  100000000                   30       0.25        0.75           -0.031949
# 39    1000000                   30       0.25        0.75           -0.035288
# 40  100000000                   20       0.00        1.00           -0.065186
# 41    1000000                   20       0.00        1.00           -0.085834
# 42  100000000                   10       0.00        1.00           -0.063259
# 43    1000000                   10       0.00        1.00           -0.105301
# 44    1000000                   30       0.00        1.00           -0.102846
# 45  100000000                   30       0.00        1.00           -0.093918
# 46    1000000                   40       0.00        1.00           -0.106927
# 47    1000000                   50       0.00        1.00           -0.110037
# 48  100000000                   40       0.00        1.00           -0.103785
# 49  100000000                   50       0.00        1.00           -0.104020
#
# [50 rows x 21 columns]

# %%
df_1_mil = df_reset_index[df_reset_index.capital_capacity == 1000000]
df_100_mil = df_reset_index[df_reset_index.capital_capacity == 100000000]

sharpe_1_mil = pd.pivot_table(df_1_mil, index = 'num_stocks', columns=['long_exposure'], values='sharpe')
alpha_1_mil = pd.pivot_table(df_1_mil, index = 'num_stocks', columns=['long_exposure'], values='alpha')
beta_1_mil = pd.pivot_table(df_1_mil, index = 'num_stocks', columns=['long_exposure'], values='beta')
vol_1_mil = pd.pivot_table(df_1_mil, index = 'num_stocks', columns=['long_exposure'], values='volatility')
total_r_1_mil = pd.pivot_table(df_1_mil, index = 'num_stocks', columns=['long_exposure'], values='total_returns')
annualized_1_mil = pd.pivot_table(df_1_mil, index = 'num_stocks', columns=['long_exposure'], values='annualized_returns')

sharpe_100_mil = pd.pivot_table(df_100_mil, index = 'num_stocks', columns=['long_exposure'], values='sharpe')
alpha_100_mil = pd.pivot_table(df_100_mil, index = 'num_stocks', columns=['long_exposure'], values='alpha')
beta_100_mil = pd.pivot_table(df_100_mil, index = 'num_stocks', columns=['long_exposure'], values='beta')
vol_100_mil = pd.pivot_table(df_100_mil, index = 'num_stocks', columns=['long_exposure'], values='volatility')
total_r_100_mil = pd.pivot_table(df_100_mil, index = 'num_stocks', columns=['long_exposure'], values='total_returns')
annualized_100_mil = pd.pivot_table(df_100_mil, index = 'num_stocks', columns=['long_exposure'], values='annualized_returns')

# %%
# Prepare different types of heatmaps just in case we need different types:
def get_heatmap(df, metric_str, cap, color_1, color_2, vmax, vmin):
    fig, ax = plt.subplots(figsize=(10,8))         # Sample figsize in inches
    cmap = sns.diverging_palette(color_1, color_2, sep=20, as_cmap=True)
    sns.heatmap(df, cmap = cmap, ax=ax, vmax=vmax, vmin=vmin, annot=True,linewidths=.5)
    plt.title('{} (${}million)'.format(metric_str, cap), fontsize = 14)
    ax.invert_yaxis()
    fig.savefig('{}_{}_{}_mil.png'.format(save_pic_name, metric_str, cap))
    
def get_heatmap_plain(df, metric_str, cap, vmax, vmin):
    fig, ax = plt.subplots(figsize=(10,8))         # Sample figsize in inches
#     cmap = sns.diverging_palette(color_1, color_2, sep=20, as_cmap=True)
    sns.heatmap(df, cmap = 'Blues', ax=ax, vmax=vmax, vmin=vmin, annot=True,linewidths=.5)
    plt.title('{} (${}million)'.format(metric_str, cap), fontsize = 14)
    ax.invert_yaxis()
    fig.savefig('{}_{}_{}_mil.png'.format(save_pic_name, metric_str, cap))
    
def get_heatmap_plain_no_min_max(df, metric_str, cap):
    fig, ax = plt.subplots(figsize=(10,8))         # Sample figsize in inches
#     cmap = sns.diverging_palette(color_1, color_2, sep=20, as_cmap=True)
    sns.heatmap(df, cmap = 'Blues', ax=ax, annot=True,linewidths=.5)
    plt.title('{} (${}million)'.format(metric_str, cap), fontsize = 14)
    ax.invert_yaxis()
    fig.savefig('{}_{}_{}_mil.png'.format(save_pic_name, metric_str, cap))
    
def get_heatmap_plain_no_min_max_vol(df, metric_str, cap):
    fig, ax = plt.subplots(figsize=(10,8))         # Sample figsize in inches
#     cmap = sns.diverging_palette(color_1, color_2, sep=20, as_cmap=True)
    sns.heatmap(df, cmap = 'Greys', ax=ax, annot=True,linewidths=.5)
    plt.title('{} (${}million)'.format(metric_str, cap), fontsize = 14)
    ax.invert_yaxis()
    fig.savefig('{}_{}_{}_mil.png'.format(save_pic_name, metric_str, cap))
    
def get_heatmap_plain_grey(df, metric_str, cap, vmax, vmin):
    fig, ax = plt.subplots(figsize=(10,8))         # Sample figsize in inches
#     cmap = sns.diverging_palette(color_1, color_2, sep=20, as_cmap=True)
    sns.heatmap(df, cmap = 'Greys', ax=ax, vmax=vmax, vmin=vmin, annot=True,linewidths=.5)
    plt.title('{} (${}million)'.format(metric_str, cap), fontsize = 14)
    ax.invert_yaxis()
    fig.savefig('{}_{}_{}_mil.png'.format(save_pic_name, metric_str, cap))

# %%
get_heatmap_plain_no_min_max(sharpe_1_mil, 'Sharpe', '1')

# %%
get_heatmap_plain_no_min_max(sharpe_100_mil, 'Sharpe', '100')

# %%
get_heatmap_plain?

# %%
get_heatmap_plain(alpha_1_mil, 'Alpha', '1', 0.15, 0)

# %%
get_heatmap_plain(alpha_100_mil, 'Alpha', '100', 0.15, 0)

# %%
get_heatmap(beta_1_mil, 'Beta', '1', 10, 100, 1.5, -1.5)

# %%
get_heatmap(beta_100_mil, 'Beta', '100', 10, 100, 1.5, -1.5)

# %%
get_heatmap(total_r_1_mil, 'Total_Returns', '1', 10, 100, 2, -2)

# %%
get_heatmap(total_r_100_mil, 'Total_Returns', '100', 10, 100, 2, -2)

# %%
get_heatmap(annualized_1_mil, 'Annualized_Returns', '1', 10, 200, 0.3, -0.3)

# %%
get_heatmap(annualized_100_mil, 'Annualized_Returns', '100', 10, 200, 0.3, -0.3)

# %%
get_heatmap_plain_grey(vol_1_mil, 'Portfolio_Volatility', '1', 0.2, 0)

# %%
get_heatmap_plain_grey(vol_100_mil, 'Portfolio_Volatility', '100', 0.2, 0)
