# %%
import pandas as pd, numpy as np
from datetime import datetime
pd.set_option('max_colwidth',200)
import yfinance as yf
import time, urllib
import glob
import os

# %% [markdown]
# # US Data

# %%
def sp500():
    sp500_list = ['MMM', 'ABT', 'ABBV', 'ACN', 'ATVI', 'AYI', 'ADBE', 'AMD', 'HII', 'AAP', 'AES', 'AET', 'AMG', 'AFL', 'A', 'APD', 'AKAM', 'ALK', 'ALB', 'ARE', 'ALXN', 'ALGN', 'ALLE', 'AGN', 'ADS', 'LNT', 'ALL', 'GOOGL', 'GOOG', 'MO', 'AMZN', 'AEE', 'AAL', 'AEP', 'AXP', 'AIG', 'AMT', 'AWK', 'AMP', 'ABC', 'AME', 'AMGN', 'APH', 'APC', 'ADI', 'ANDV', 'ANSS', 'ANTM', 'AON', 'AOS', 'APA', 'AIV', 'AAPL', 'AMAT', 'APTV', 'ADM', 'ARNC', 'AJG', 'AIZ', 'T', 'ADSK', 'ADP', 'AZO', 'AVB', 'AVY', 'BHGE', 'BLL', 'BAC', 'BK', 'BAX', 'BBT', 'BDX', 'BRK.B', 'BBY', 'BIIB', 'BLK', 'HRB', 'BA', 'BWA', 'BXP', 'BSX', 'BHF', 'BMY', 'AVGO', 'BF.B', 'CHRW', 'CA', 'COG', 'CDNS', 'CPB', 'COF', 'CAH', 'CBOE', 'KMX', 'CCL', 'CAT', 'CBG', 'CBS', 'CELG', 'CNC', 'CNP', 'CTL', 'CERN', 'CF', 'SCHW', 'CHTR', 'CHK', 'CVX', 'CMG', 'CB', 'CHD', 'CI', 'XEC', 'CINF', 'CTAS', 'CSCO', 'C', 'CFG', 'CTXS', 'CLX', 'CME', 'CMS', 'KO', 'CTSH', 'CL', 'CMCSA', 'CMA', 'CAG', 'CXO', 'COP', 'ED', 'STZ', 'COO', 'GLW', 'COST', 'COTY', 'CCI', 'CSRA', 'CSX', 'CMI', 'CVS', 'DHI', 'DHR', 'DRI', 'DVA', 'DE', 'DAL', 'XRAY', 'DVN', 'DLR', 'DFS', 'DISCA', 'DISCK', 'DISH', 'DG', 'DLTR', 'D', 'DOV', 'DWDP', 'DPS', 'DTE', 'DRE', 'DUK', 'DXC', 'ETFC', 'EMN', 'ETN', 'EBAY', 'ECL', 'EIX', 'EW', 'EA', 'EMR', 'ETR', 'EVHC', 'EOG', 'EQT', 'EFX', 'EQIX', 'EQR', 'ESS', 'EL', 'ES', 'RE', 'EXC', 'EXPE', 'EXPD', 'ESRX', 'EXR', 'XOM', 'FFIV', 'FB', 'FAST', 'FRT', 'FDX', 'FIS', 'FITB', 'FE', 'FISV', 'FLIR', 'FLS', 'FLR', 'FMC', 'FL', 'F', 'FTV', 'FBHS', 'BEN', 'FCX', 'GPS', 'GRMN', 'IT', 'GD', 'GE', 'GGP', 'GIS', 'GM', 'GPC', 'GILD', 'GPN', 'GS', 'GT', 'GWW', 'HAL', 'HBI', 'HOG', 'HRS', 'HIG', 'HAS', 'HCA', 'HCP', 'HP', 'HSIC', 'HSY', 'HES', 'HPE', 'HLT', 'HOLX', 'HD', 'HON', 'HRL', 'HST', 'HPQ', 'HUM', 'HBAN', 'IDXX', 'INFO', 'ITW', 'ILMN', 'IR', 'INTC', 'ICE', 'IBM', 'INCY', 'IP', 'IPG', 'IFF', 'INTU', 'ISRG', 'IVZ', 'IQV', 'IRM', 'JEC', 'JBHT', 'SJM', 'JNJ', 'JCI', 'JPM', 'JNPR', 'KSU', 'K', 'KEY', 'KMB', 'KIM', 'KMI', 'KLAC', 'KSS', 'KHC', 'KR', 'LB', 'LLL', 'LH', 'LRCX', 'LEG', 'LEN', 'LUK', 'LLY', 'LNC', 'LKQ', 'LMT', 'L', 'LOW', 'LYB', 'MTB', 'MAC', 'M', 'MRO', 'MPC', 'MAR', 'MMC', 'MLM', 'MAS', 'MA', 'MAT', 'MKC', 'MCD', 'MCK', 'MDT', 'MRK', 'MET', 'MTD', 'MGM', 'KORS', 'MCHP', 'MU', 'MSFT', 'MAA', 'MHK', 'TAP', 'MDLZ', 'MON', 'MNST', 'MCO', 'MS', 'MOS', 'MSI', 'MYL', 'NDAQ', 'NOV', 'NAVI', 'NTAP', 'NFLX', 'NWL', 'NFX', 'NEM', 'NWSA', 'NWS', 'NEE', 'NLSN', 'NKE', 'NI', 'NBL', 'JWN', 'NSC', 'NTRS', 'NOC', 'NCLH', 'NRG', 'NUE', 'NVDA', 'ORLY', 'OXY', 'OMC', 'OKE', 'ORCL', 'PCAR', 'PKG', 'PH', 'PDCO', 'PAYX', 'PYPL', 'PNR', 'PBCT', 'PEP', 'PKI', 'PRGO', 'PFE', 'PCG', 'PM', 'PSX', 'PNW', 'PXD', 'PNC', 'RL', 'PPG', 'PPL', 'PX', 'PCLN', 'PFG', 'PG', 'PGR', 'PLD', 'PRU', 'PEG', 'PSA', 'PHM', 'PVH', 'QRVO', 'PWR', 'QCOM', 'DGX', 'RRC', 'RJF', 'RTN', 'O', 'RHT', 'REG', 'REGN', 'RF', 'RSG', 'RMD', 'RHI', 'ROK', 'COL', 'ROP', 'ROST', 'RCL', 'CRM', 'SBAC', 'SCG', 'SLB', 'SNI', 'STX', 'SEE', 'SRE', 'SHW', 'SIG', 'SPG', 'SWKS', 'SLG', 'SNA', 'SO', 'LUV', 'SPGI', 'SWK', 'SBUX', 'STT', 'SRCL', 'SYK', 'STI', 'SYMC', 'SYF', 'SNPS', 'SYY', 'TROW', 'TPR', 'TGT', 'TEL', 'FTI', 'TXN', 'TXT', 'TMO', 'TIF', 'TWX', 'TJX', 'TMK', 'TSS', 'TSCO', 'TDG', 'TRV', 'TRIP', 'FOXA', 'FOX', 'TSN', 'UDR', 'ULTA', 'USB', 'UA', 'UAA', 'UNP', 'UAL', 'UNH', 'UPS', 'URI', 'UTX', 'UHS', 'UNM', 'VFC', 'VLO', 'VAR', 'VTR', 'VRSN', 'VRSK', 'VZ', 'VRTX', 'VIAB', 'V', 'VNO', 'VMC', 'WMT', 'WBA', 'DIS', 'WM', 'WAT', 'WEC', 'WFC', 'HCN', 'WDC', 'WU', 'WRK', 'WY', 'WHR', 'WMB', 'WLTW', 'WYN', 'WYNN', 'XEL', 'XRX', 'XLNX', 'XL', 'XYL', 'YUM', 'ZBH', 'ZION', 'ZTS']
    return sp500_list

def all_weather():
    all_weather_portfolio = ["VTI","TLT","IEF","GLD","DBC"]
    return all_weather_portfolio

def us_sectors_etf():
    us_sectors = ["IYM","IYZ","FCL","FCD","IYE","IYG","IYH","IYJ","IYR","IYW","IDU"]
    return us_sectors
    
def today_dt():
    today = str(datetime.now().date())
    return today

def download_yf_data(start, end, us_db_path, ticker_list):
    for ticker in ticker_list:
    #     print("testing")
        # Initial downloading:
        if not os.path.exists(us_db_path+ticker+".csv"):
            print("{} is new, start downloading now...".format(ticker))
            with eventlet.Timeout(60,False):
                try:
                    data = yf.download(ticker, start=start, end=end)
                    data.reset_index(inplace = True)
                    data['Ticker'] = ticker
                    data.to_csv(us_db_path+ticker+".csv", index = False)
                    print("{} data file created: {}".format(ticker, end))
                except Exception as e:
                    print(e)

    #         print("Timed Out: Download Failed!")
        # Check for updates:
        else:
            print("Already have data csv for {}".format(ticker))
            hist_data = pd.read_csv(us_db_path+ticker+".csv")
            try:
                hist_data_first_date = hist_data['Date'].values[0]
                if start >= hist_data_first_date:
                    hist_data_last_date = hist_data['Date'].values[-1]
                    if today > hist_data_last_date:
                        print("Needs to update, start updating new data for {} now...".format(ticker))
                        update_start = hist_data_last_date
                        update_end = today
                        with eventlet.Timeout(60,False):
                            try:
                                new_data = yf.download(ticker, start=update_start, end=update_end)
                                new_data.reset_index(inplace = True)
                                new_data['Ticker'] = ticker
                                new_data.to_csv(us_db_path+ticker+".csv", mode='a', header=False, index = False)
                                updated_duplicated_df = pd.read_csv(us_db_path+ticker+".csv")
                                updated_df = updated_duplicated_df.drop_duplicates("Date")
                                updated_df.sort_values("Date", inplace = True)
                                updated_df.to_csv(us_db_path+ticker+".csv", index = False)
                                print("New data updated till today for {}!".format(ticker))
                            except Exception as e:
                                print(e)
            #             print("Timed Out: Update Failed!")
                    else:
                        print("There's no new data to update for {}.".format(ticker))

                else:
                    print("Setup start date earlier than existing data's, trying to pull data from before...")
                    hist_data_last_date = hist_data['Date'].values[-1]
                    if today > hist_data_last_date:
                        print("Needs to update, start updating new data for {} now...".format(ticker))
                        update_start = start
                        update_end = today
                        with eventlet.Timeout(60,False):
                            try:
                                new_data = yf.download(ticker, start=update_start, end=update_end)
                                new_data.reset_index(inplace = True)
                                new_date = new_data['Date'].values[0]
                                print("New data's first pulled date is {}".format(new_date))
                                new_data['Ticker'] = ticker

                                new_data.to_csv(us_db_path+ticker+".csv", mode='a', header=False, index = False)
                                updated_duplicated_df = pd.read_csv(us_db_path+ticker+".csv")
                                updated_df = updated_duplicated_df.drop_duplicates("Date")
                                updated_df.sort_values("Date", inplace = True)
                                updated_df.to_csv(us_db_path+ticker+".csv", index = False)
                                print("New data updated till today for {}!".format(ticker))
                            except Exception as e:
                                print(e)
                    else:
                        print("There's no new data to update for {}.".format(ticker))
            except Exception as e:
                print(e)

    #     print("Data Download/Update for {} is Finished.".format(ticker))
        print("===============================================")
    print("【Updated Finished for today!】")


start = "2005-01-01"
today = today_dt()
end = today
us_db_path = "/Users/miaoyuesun/Code_Workspace/brad_public_workspace_mac/data/US_database/"
mkt_etf = ["SPY","VXXB","QQQ"]
other_tickers = ["YELP",'UBER','TSLA']
us_sectors = us_sectors_etf()
all_weather = all_weather()
sp500_stocks = sp500()
ticker_list = sp500_stocks+all_weather+us_sectors+mkt_etf+other_tickers

# %%
import eventlet
eventlet.monkey_patch()

download_yf_data(start, end, us_db_path, ticker_list)
# Out:
# Already have data csv for MMM
# Needs to update, start updating new data for MMM now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for MMM!
# ===============================================
# Already have data csv for ABT
# Needs to update, start updating new data for ABT now...
# /Users/miaoyuesun/anaconda3/lib/python3.5/site-packages/ipykernel_launcher.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for ABT!
# ===============================================
# Already have data csv for ABBV
# Setup start date earlier than existing data's, trying to pull data from before...
# Needs to update, start updating new data for ABBV now...
# ===============================================
# Already have data csv for ACN
# Needs to update, start updating new data for ACN now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for ACN!
# ===============================================
# Already have data csv for ATVI
# Needs to update, start updating new data for ATVI now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for ATVI!
# ===============================================
# Already have data csv for AYI
# Needs to update, start updating new data for AYI now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for AYI!
# ===============================================
# Already have data csv for ADBE
# Needs to update, start updating new data for ADBE now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for ADBE!
# ===============================================
# Already have data csv for AMD
# Needs to update, start updating new data for AMD now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for AMD!
# ===============================================
# Already have data csv for HII
# Setup start date earlier than existing data's, trying to pull data from before...
# Needs to update, start updating new data for HII now...
# [*********************100%***********************]  1 of 1 completed
# New data's first pulled date is 2011-03-22T00:00:00.000000000
# New data updated till today for HII!
# ===============================================
# Already have data csv for AAP
# Needs to update, start updating new data for AAP now...
# /Users/miaoyuesun/anaconda3/lib/python3.5/site-packages/ipykernel_launcher.py:81: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for AAP!
# ===============================================
# Already have data csv for AES
# Needs to update, start updating new data for AES now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for AES!
# ===============================================
# Already have data csv for AET
# index 0 is out of bounds for axis 0 with size 0
# ===============================================
# Already have data csv for AMG
# Needs to update, start updating new data for AMG now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for AMG!
# ===============================================
# Already have data csv for AFL
# Needs to update, start updating new data for AFL now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for AFL!
# ===============================================
# Already have data csv for A
# Needs to update, start updating new data for A now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for A!
# ===============================================
# Already have data csv for APD
# Needs to update, start updating new data for APD now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for APD!
# ===============================================
# Already have data csv for AKAM
# Needs to update, start updating new data for AKAM now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for AKAM!
# ===============================================
# Already have data csv for ALK
# Needs to update, start updating new data for ALK now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for ALK!
# ===============================================
# Already have data csv for ALB
# Needs to update, start updating new data for ALB now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for ALB!
# ===============================================
# Already have data csv for ARE
# Needs to update, start updating new data for ARE now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for ARE!
# ===============================================
# Already have data csv for ALXN
# Needs to update, start updating new data for ALXN now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for ALXN!
# ===============================================
# Already have data csv for ALGN
# Needs to update, start updating new data for ALGN now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for ALGN!
# ===============================================
# Already have data csv for ALLE
# Setup start date earlier than existing data's, trying to pull data from before...
# Needs to update, start updating new data for ALLE now...
# [*********************100%***********************]  1 of 1 completed
# New data's first pulled date is 2013-11-18T00:00:00.000000000
# New data updated till today for ALLE!
# ===============================================
# Already have data csv for AGN
# Needs to update, start updating new data for AGN now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for AGN!
# ===============================================
# Already have data csv for ADS
# Needs to update, start updating new data for ADS now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for ADS!
# ===============================================
# Already have data csv for LNT
# Needs to update, start updating new data for LNT now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for LNT!
# ===============================================
# Already have data csv for ALL
# Needs to update, start updating new data for ALL now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for ALL!
# ===============================================
# Already have data csv for GOOGL
# Needs to update, start updating new data for GOOGL now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for GOOGL!
# ===============================================
# Already have data csv for GOOG
# Needs to update, start updating new data for GOOG now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for GOOG!
# ===============================================
# Already have data csv for MO
# Needs to update, start updating new data for MO now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for MO!
# ===============================================
# Already have data csv for AMZN
# Needs to update, start updating new data for AMZN now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for AMZN!
# ===============================================
# Already have data csv for AEE
# Needs to update, start updating new data for AEE now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for AEE!
# ===============================================
# Already have data csv for AAL
# Setup start date earlier than existing data's, trying to pull data from before...
# Needs to update, start updating new data for AAL now...
# [*********************100%***********************]  1 of 1 completed
# /Users/miaoyuesun/anaconda3/lib/python3.5/site-packages/pandas/compat/_optional.py:106: UserWarning: Pandas requires version '2.6.2' or newer of 'numexpr' (version '2.6.1' currently installed).
#   warnings.warn(msg, UserWarning)
# New data's first pulled date is 2005-09-27T00:00:00.000000000
# New data updated till today for AAL!
# ===============================================
# Already have data csv for AEP
# Needs to update, start updating new data for AEP now...
# /Users/miaoyuesun/anaconda3/lib/python3.5/site-packages/ipykernel_launcher.py:81: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for AEP!
# ===============================================
# Already have data csv for AXP
# Needs to update, start updating new data for AXP now...
# /Users/miaoyuesun/anaconda3/lib/python3.5/site-packages/ipykernel_launcher.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for AXP!
# ===============================================
# Already have data csv for AIG
# Needs to update, start updating new data for AIG now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for AIG!
# ===============================================
# Already have data csv for AMT
# Needs to update, start updating new data for AMT now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for AMT!
# ===============================================
# Already have data csv for AWK
# Setup start date earlier than existing data's, trying to pull data from before...
# Needs to update, start updating new data for AWK now...
# [*********************100%***********************]  1 of 1 completed
# New data's first pulled date is 2008-04-23T00:00:00.000000000
# New data updated till today for AWK!
# ===============================================
# Already have data csv for AMP
# Setup start date earlier than existing data's, trying to pull data from before...
# Needs to update, start updating new data for AMP now...
# [*********************100%***********************]  1 of 1 completed
# New data's first pulled date is 2005-09-15T00:00:00.000000000
# New data updated till today for AMP!
# ===============================================
# Already have data csv for ABC
# Needs to update, start updating new data for ABC now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for ABC!
# ===============================================
# Already have data csv for AME
# Needs to update, start updating new data for AME now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for AME!
# ===============================================
# Already have data csv for AMGN
# Needs to update, start updating new data for AMGN now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for AMGN!
# ===============================================
# Already have data csv for APH
# Needs to update, start updating new data for APH now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for APH!
# ===============================================
# Already have data csv for APC
# index 0 is out of bounds for axis 0 with size 0
# ===============================================
# Already have data csv for ADI
# Needs to update, start updating new data for ADI now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for ADI!
# ===============================================
# Already have data csv for ANDV
# Setup start date earlier than existing data's, trying to pull data from before...
# Needs to update, start updating new data for ANDV now...
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ANDV: No data found for this date range, symbol may be delisted
# index 0 is out of bounds for axis 0 with size 0
# ===============================================
# Already have data csv for ANSS
# Needs to update, start updating new data for ANSS now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for ANSS!
# ===============================================
# Already have data csv for ANTM
# Needs to update, start updating new data for ANTM now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for ANTM!
# ===============================================
# Already have data csv for AON
# Needs to update, start updating new data for AON now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for AON!
# ===============================================
# Already have data csv for AOS
# Needs to update, start updating new data for AOS now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for AOS!
# ===============================================
# Already have data csv for APA
# Needs to update, start updating new data for APA now...
# ===============================================
# Already have data csv for AIV
# Needs to update, start updating new data for AIV now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for AIV!
# ===============================================
# Already have data csv for AAPL
# Needs to update, start updating new data for AAPL now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for AAPL!
# ===============================================
# Already have data csv for AMAT
# Needs to update, start updating new data for AMAT now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for AMAT!
# ===============================================
# Already have data csv for APTV
# Setup start date earlier than existing data's, trying to pull data from before...
# Needs to update, start updating new data for APTV now...
# [*********************100%***********************]  1 of 1 completed
# New data's first pulled date is 2011-11-17T00:00:00.000000000
# New data updated till today for APTV!
# ===============================================
# Already have data csv for ADM
# Needs to update, start updating new data for ADM now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for ADM!
# ===============================================
# Already have data csv for ARNC
# Needs to update, start updating new data for ARNC now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for ARNC!
# ===============================================
# Already have data csv for AJG
# Needs to update, start updating new data for AJG now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for AJG!
# ===============================================
# Already have data csv for AIZ
# Needs to update, start updating new data for AIZ now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for AIZ!
# ===============================================
# Already have data csv for T
# Needs to update, start updating new data for T now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for T!
# ===============================================
# Already have data csv for ADSK
# Needs to update, start updating new data for ADSK now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for ADSK!
# ===============================================
# Already have data csv for ADP
# Needs to update, start updating new data for ADP now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for ADP!
# ===============================================
# Already have data csv for AZO
# Needs to update, start updating new data for AZO now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for AZO!
# ===============================================
# Already have data csv for AVB
# Needs to update, start updating new data for AVB now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for AVB!
# ===============================================
# Already have data csv for AVY
# Needs to update, start updating new data for AVY now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for AVY!
# ===============================================
# Already have data csv for BHGE
# Setup start date earlier than existing data's, trying to pull data from before...
# Needs to update, start updating new data for BHGE now...
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - BHGE: No data found, symbol may be delisted
# index 0 is out of bounds for axis 0 with size 0
# ===============================================
# Already have data csv for BLL
# Needs to update, start updating new data for BLL now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for BLL!
# ===============================================
# Already have data csv for BAC
# Needs to update, start updating new data for BAC now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for BAC!
# ===============================================
# Already have data csv for BK
# Needs to update, start updating new data for BK now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for BK!
# ===============================================
# Already have data csv for BAX
# Needs to update, start updating new data for BAX now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for BAX!
# ===============================================
# Already have data csv for BBT
# Needs to update, start updating new data for BBT now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for BBT!
# ===============================================
# Already have data csv for BDX
# Needs to update, start updating new data for BDX now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for BDX!
# ===============================================
# Already have data csv for BRK.B
# index 0 is out of bounds for axis 0 with size 0
# ===============================================
# Already have data csv for BBY
# Needs to update, start updating new data for BBY now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for BBY!
# ===============================================
# Already have data csv for BIIB
# Needs to update, start updating new data for BIIB now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for BIIB!
# ===============================================
# Already have data csv for BLK
# Needs to update, start updating new data for BLK now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for BLK!
# ===============================================
# Already have data csv for HRB
# Needs to update, start updating new data for HRB now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for HRB!
# ===============================================
# Already have data csv for BA
# Needs to update, start updating new data for BA now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for BA!
# ===============================================
# Already have data csv for BWA
# Needs to update, start updating new data for BWA now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for BWA!
# ===============================================
# Already have data csv for BXP
# Needs to update, start updating new data for BXP now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for BXP!
# ===============================================
# Already have data csv for BSX
# Needs to update, start updating new data for BSX now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for BSX!
# ===============================================
# Already have data csv for BHF
# Setup start date earlier than existing data's, trying to pull data from before...
# Needs to update, start updating new data for BHF now...
# [*********************100%***********************]  1 of 1 completed
# New data's first pulled date is 2007-09-11T00:00:00.000000000
# New data updated till today for BHF!
# ===============================================
# Already have data csv for BMY
# Needs to update, start updating new data for BMY now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for BMY!
# ===============================================
# Already have data csv for AVGO
# Setup start date earlier than existing data's, trying to pull data from before...
# Needs to update, start updating new data for AVGO now...
# [*********************100%***********************]  1 of 1 completed
# New data's first pulled date is 2009-08-06T00:00:00.000000000
# New data updated till today for AVGO!
# ===============================================
# Already have data csv for BF.B
# index 0 is out of bounds for axis 0 with size 0
# ===============================================
# Already have data csv for CHRW
# Needs to update, start updating new data for CHRW now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for CHRW!
# ===============================================
# Already have data csv for CA
# Setup start date earlier than existing data's, trying to pull data from before...
# Needs to update, start updating new data for CA now...
# [*********************100%***********************]  1 of 1 completed
# New data's first pulled date is 2018-01-04T00:00:00.000000000
# New data updated till today for CA!
# ===============================================
# Already have data csv for COG
# Needs to update, start updating new data for COG now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for COG!
# ===============================================
# Already have data csv for CDNS
# Needs to update, start updating new data for CDNS now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for CDNS!
# ===============================================
# Already have data csv for CPB
# Needs to update, start updating new data for CPB now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for CPB!
# ===============================================
# Already have data csv for COF
# Needs to update, start updating new data for COF now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for COF!
# ===============================================
# Already have data csv for CAH
# Needs to update, start updating new data for CAH now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for CAH!
# ===============================================
# Already have data csv for CBOE
# Setup start date earlier than existing data's, trying to pull data from before...
# Needs to update, start updating new data for CBOE now...
# [*********************100%***********************]  1 of 1 completed
# New data's first pulled date is 2010-06-15T00:00:00.000000000
# New data updated till today for CBOE!
# ===============================================
# Already have data csv for KMX
# Needs to update, start updating new data for KMX now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for KMX!
# ===============================================
# Already have data csv for CCL
# Needs to update, start updating new data for CCL now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for CCL!
# ===============================================
# Already have data csv for CAT
# Needs to update, start updating new data for CAT now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for CAT!
# ===============================================
# Already have data csv for CBG
# index 0 is out of bounds for axis 0 with size 0
# ===============================================
# Already have data csv for CBS
# Setup start date earlier than existing data's, trying to pull data from before...
# Needs to update, start updating new data for CBS now...
# [*********************100%***********************]  1 of 1 completed
# New data's first pulled date is 2005-12-05T00:00:00.000000000
# New data updated till today for CBS!
# ===============================================
# Already have data csv for CELG
# Needs to update, start updating new data for CELG now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for CELG!
# ===============================================
# Already have data csv for CNC
# Needs to update, start updating new data for CNC now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for CNC!
# ===============================================
# Already have data csv for CNP
# Needs to update, start updating new data for CNP now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for CNP!
# ===============================================
# Already have data csv for CTL
# Needs to update, start updating new data for CTL now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for CTL!
# ===============================================
# Already have data csv for CERN
# Needs to update, start updating new data for CERN now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for CERN!
# ===============================================
# Already have data csv for CF
# Setup start date earlier than existing data's, trying to pull data from before...
# Needs to update, start updating new data for CF now...
# [*********************100%***********************]  1 of 1 completed
# New data's first pulled date is 2005-08-11T00:00:00.000000000
# New data updated till today for CF!
# ===============================================
# Already have data csv for SCHW
# Needs to update, start updating new data for SCHW now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for SCHW!
# ===============================================
# Already have data csv for CHTR
# Setup start date earlier than existing data's, trying to pull data from before...
# Needs to update, start updating new data for CHTR now...
# [*********************100%***********************]  1 of 1 completed
# New data's first pulled date is 2010-01-05T00:00:00.000000000
# New data updated till today for CHTR!
# ===============================================
# Already have data csv for CHK
# Needs to update, start updating new data for CHK now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for CHK!
# ===============================================
# Already have data csv for CVX
# Needs to update, start updating new data for CVX now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for CVX!
# ===============================================
# Already have data csv for CMG
# Setup start date earlier than existing data's, trying to pull data from before...
# Needs to update, start updating new data for CMG now...
# [*********************100%***********************]  1 of 1 completed
# New data's first pulled date is 2006-01-26T00:00:00.000000000
# New data updated till today for CMG!
# ===============================================
# Already have data csv for CB
# Needs to update, start updating new data for CB now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for CB!
# ===============================================
# Already have data csv for CHD
# Needs to update, start updating new data for CHD now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for CHD!
# ===============================================
# Already have data csv for CI
# Needs to update, start updating new data for CI now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for CI!
# ===============================================
# Already have data csv for XEC
# Needs to update, start updating new data for XEC now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for XEC!
# ===============================================
# Already have data csv for CINF
# Needs to update, start updating new data for CINF now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for CINF!
# ===============================================
# Already have data csv for CTAS
# Needs to update, start updating new data for CTAS now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for CTAS!
# ===============================================
# Already have data csv for CSCO
# Needs to update, start updating new data for CSCO now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for CSCO!
# ===============================================
# Already have data csv for C
# Needs to update, start updating new data for C now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for C!
# ===============================================
# Already have data csv for CFG
# Setup start date earlier than existing data's, trying to pull data from before...
# Needs to update, start updating new data for CFG now...
# [*********************100%***********************]  1 of 1 completed
# New data's first pulled date is 2014-09-24T00:00:00.000000000
# New data updated till today for CFG!
# ===============================================
# Already have data csv for CTXS
# Needs to update, start updating new data for CTXS now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for CTXS!
# ===============================================
# Already have data csv for CLX
# Needs to update, start updating new data for CLX now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for CLX!
# ===============================================
# Already have data csv for CME
# Needs to update, start updating new data for CME now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for CME!
# ===============================================
# Already have data csv for CMS
# Needs to update, start updating new data for CMS now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for CMS!
# ===============================================
# Already have data csv for KO
# Needs to update, start updating new data for KO now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for KO!
# ===============================================
# Already have data csv for CTSH
# Needs to update, start updating new data for CTSH now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for CTSH!
# ===============================================
# Already have data csv for CL
# Needs to update, start updating new data for CL now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for CL!
# ===============================================
# Already have data csv for CMCSA
# Needs to update, start updating new data for CMCSA now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for CMCSA!
# ===============================================
# Already have data csv for CMA
# Needs to update, start updating new data for CMA now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for CMA!
# ===============================================
# Already have data csv for CAG
# Needs to update, start updating new data for CAG now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for CAG!
# ===============================================
# Already have data csv for CXO
# Setup start date earlier than existing data's, trying to pull data from before...
# Needs to update, start updating new data for CXO now...
# ===============================================
# Already have data csv for COP
# Needs to update, start updating new data for COP now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for COP!
# ===============================================
# Already have data csv for ED
# Needs to update, start updating new data for ED now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for ED!
# ===============================================
# Already have data csv for STZ
# Needs to update, start updating new data for STZ now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for STZ!
# ===============================================
# Already have data csv for COO
# Needs to update, start updating new data for COO now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for COO!
# ===============================================
# Already have data csv for GLW
# Needs to update, start updating new data for GLW now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for GLW!
# ===============================================
# Already have data csv for COST
# Needs to update, start updating new data for COST now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for COST!
# ===============================================
# Already have data csv for COTY
# Setup start date earlier than existing data's, trying to pull data from before...
# Needs to update, start updating new data for COTY now...
# [*********************100%***********************]  1 of 1 completed
# New data's first pulled date is 2013-06-13T00:00:00.000000000
# New data updated till today for COTY!
# ===============================================
# Already have data csv for CCI
# Needs to update, start updating new data for CCI now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for CCI!
# ===============================================
# Already have data csv for CSRA
# Setup start date earlier than existing data's, trying to pull data from before...
# Needs to update, start updating new data for CSRA now...
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - CSRA: No data found for this date range, symbol may be delisted
# index 0 is out of bounds for axis 0 with size 0
# ===============================================
# Already have data csv for CSX
# Needs to update, start updating new data for CSX now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for CSX!
# ===============================================
# Already have data csv for CMI
# Needs to update, start updating new data for CMI now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for CMI!
# ===============================================
# Already have data csv for CVS
# Needs to update, start updating new data for CVS now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for CVS!
# ===============================================
# Already have data csv for DHI
# Needs to update, start updating new data for DHI now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for DHI!
# ===============================================
# Already have data csv for DHR
# Needs to update, start updating new data for DHR now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for DHR!
# ===============================================
# Already have data csv for DRI
# Needs to update, start updating new data for DRI now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for DRI!
# ===============================================
# Already have data csv for DVA
# Needs to update, start updating new data for DVA now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for DVA!
# ===============================================
# Already have data csv for DE
# Needs to update, start updating new data for DE now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for DE!
# ===============================================
# Already have data csv for DAL
# Setup start date earlier than existing data's, trying to pull data from before...
# Needs to update, start updating new data for DAL now...
# [*********************100%***********************]  1 of 1 completed
# New data's first pulled date is 2007-05-03T00:00:00.000000000
# New data updated till today for DAL!
# ===============================================
# Already have data csv for XRAY
# Needs to update, start updating new data for XRAY now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for XRAY!
# ===============================================
# Already have data csv for DVN
# Needs to update, start updating new data for DVN now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for DVN!
# ===============================================
# Already have data csv for DLR
# Needs to update, start updating new data for DLR now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for DLR!
# ===============================================
# Already have data csv for DFS
# Setup start date earlier than existing data's, trying to pull data from before...
# Needs to update, start updating new data for DFS now...
# [*********************100%***********************]  1 of 1 completed===============================================
# Already have data csv for DISCA
# Setup start date earlier than existing data's, trying to pull data from before...
# Needs to update, start updating new data for DISCA now...
# ===============================================
# Already have data csv for DISCK
# Setup start date earlier than existing data's, trying to pull data from before...
# Needs to update, start updating new data for DISCK now...
# [*********************100%***********************]  1 of 1 completed
# New data's first pulled date is 2008-09-18T00:00:00.000000000
# New data updated till today for DISCK!
# ===============================================
# Already have data csv for DISH
# Needs to update, start updating new data for DISH now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for DISH!
# ===============================================
# Already have data csv for DG
# Setup start date earlier than existing data's, trying to pull data from before...
# Needs to update, start updating new data for DG now...
# [*********************100%***********************]  1 of 1 completed
# 'DG'
# ===============================================
# Already have data csv for DLTR
# Needs to update, start updating new data for DLTR now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for DLTR!
# ===============================================
# Already have data csv for D
# Needs to update, start updating new data for D now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for D!
# ===============================================
# Already have data csv for DOV
# Needs to update, start updating new data for DOV now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for DOV!
# ===============================================
# Already have data csv for DWDP
# index 0 is out of bounds for axis 0 with size 0
# ===============================================
# Already have data csv for DPS
# index 0 is out of bounds for axis 0 with size 0
# ===============================================
# Already have data csv for DTE
# Needs to update, start updating new data for DTE now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for DTE!
# ===============================================
# Already have data csv for DRE
# Needs to update, start updating new data for DRE now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for DRE!
# ===============================================
# Already have data csv for DUK
# Needs to update, start updating new data for DUK now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for DUK!
# ===============================================
# Already have data csv for DXC
# Needs to update, start updating new data for DXC now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for DXC!
# ===============================================
# Already have data csv for ETFC
# Needs to update, start updating new data for ETFC now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for ETFC!
# ===============================================
# Already have data csv for EMN
# Needs to update, start updating new data for EMN now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for EMN!
# ===============================================
# Already have data csv for ETN
# Needs to update, start updating new data for ETN now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for ETN!
# ===============================================
# Already have data csv for EBAY
# Needs to update, start updating new data for EBAY now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for EBAY!
# ===============================================
# Already have data csv for ECL
# Needs to update, start updating new data for ECL now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for ECL!
# ===============================================
# Already have data csv for EIX
# Needs to update, start updating new data for EIX now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for EIX!
# ===============================================
# Already have data csv for EW
# Needs to update, start updating new data for EW now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for EW!
# ===============================================
# Already have data csv for EA
# Needs to update, start updating new data for EA now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for EA!
# ===============================================
# Already have data csv for EMR
# Needs to update, start updating new data for EMR now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for EMR!
# ===============================================
# Already have data csv for ETR
# Needs to update, start updating new data for ETR now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for ETR!
# ===============================================
# Already have data csv for EVHC
# Setup start date earlier than existing data's, trying to pull data from before...
# Needs to update, start updating new data for EVHC now...
# [*********************100%***********************]  1 of 1 completed
# New data's first pulled date is 2013-08-14T00:00:00.000000000
# New data updated till today for EVHC!
# ===============================================
# Already have data csv for EOG
# Needs to update, start updating new data for EOG now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for EOG!
# ===============================================
# Already have data csv for EQT
# Needs to update, start updating new data for EQT now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for EQT!
# ===============================================
# Already have data csv for EFX
# Needs to update, start updating new data for EFX now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for EFX!
# ===============================================
# Already have data csv for EQIX
# Needs to update, start updating new data for EQIX now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for EQIX!
# ===============================================
# Already have data csv for EQR
# Needs to update, start updating new data for EQR now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for EQR!
# ===============================================
# Already have data csv for ESS
# Needs to update, start updating new data for ESS now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for ESS!
# ===============================================
# Already have data csv for EL
# Needs to update, start updating new data for EL now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for EL!
# ===============================================
# Already have data csv for ES
# Needs to update, start updating new data for ES now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for ES!
# ===============================================
# Already have data csv for RE
# Needs to update, start updating new data for RE now...
# [*********************100%***********************]  1 of 1 completed
# ...
# Already have data csv for VFC
# Needs to update, start updating new data for VFC now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for VFC!
# ===============================================
# Already have data csv for VLO
# Needs to update, start updating new data for VLO now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for VLO!
# ===============================================
# Already have data csv for VAR
# Needs to update, start updating new data for VAR now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for VAR!
# ===============================================
# Already have data csv for VTR
# Needs to update, start updating new data for VTR now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for VTR!
# ===============================================
# Already have data csv for VRSN
# Needs to update, start updating new data for VRSN now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for VRSN!
# ===============================================
# Already have data csv for VRSK
# Setup start date earlier than existing data's, trying to pull data from before...
# Needs to update, start updating new data for VRSK now...
# [*********************100%***********************]  1 of 1 completed
# New data's first pulled date is 2009-10-07T00:00:00.000000000
# New data updated till today for VRSK!
# ===============================================
# Already have data csv for VZ
# Needs to update, start updating new data for VZ now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for VZ!
# ===============================================
# Already have data csv for VRTX
# Needs to update, start updating new data for VRTX now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for VRTX!
# ===============================================
# Already have data csv for VIAB
# Setup start date earlier than existing data's, trying to pull data from before...
# Needs to update, start updating new data for VIAB now...
# [*********************100%***********************]  1 of 1 completed
# New data's first pulled date is 2005-12-05T00:00:00.000000000
# New data updated till today for VIAB!
# ===============================================
# Already have data csv for V
# Setup start date earlier than existing data's, trying to pull data from before...
# Needs to update, start updating new data for V now...
# [*********************100%***********************]  1 of 1 completed
# New data's first pulled date is 2008-03-19T00:00:00.000000000
# New data updated till today for V!
# ===============================================
# Already have data csv for VNO
# Needs to update, start updating new data for VNO now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for VNO!
# ===============================================
# Already have data csv for VMC
# Needs to update, start updating new data for VMC now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for VMC!
# ===============================================
# Already have data csv for WMT
# Needs to update, start updating new data for WMT now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for WMT!
# ===============================================
# Already have data csv for WBA
# Needs to update, start updating new data for WBA now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for WBA!
# ===============================================
# Already have data csv for DIS
# Needs to update, start updating new data for DIS now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for DIS!
# ===============================================
# Already have data csv for WM
# Needs to update, start updating new data for WM now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for WM!
# ===============================================
# Already have data csv for WAT
# Needs to update, start updating new data for WAT now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for WAT!
# ===============================================
# Already have data csv for WEC
# Needs to update, start updating new data for WEC now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for WEC!
# ===============================================
# Already have data csv for WFC
# Needs to update, start updating new data for WFC now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for WFC!
# ===============================================
# Already have data csv for HCN
# index 0 is out of bounds for axis 0 with size 0
# ===============================================
# Already have data csv for WDC
# Needs to update, start updating new data for WDC now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for WDC!
# ===============================================
# Already have data csv for WU
# Setup start date earlier than existing data's, trying to pull data from before...
# Needs to update, start updating new data for WU now...
# ===============================================
# Already have data csv for WRK
# Setup start date earlier than existing data's, trying to pull data from before...
# Needs to update, start updating new data for WRK now...
# [*********************100%***********************]  1 of 1 completed
# 'WRK'
# ===============================================
# Already have data csv for WY
# Needs to update, start updating new data for WY now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for WY!
# ===============================================
# Already have data csv for WHR
# Needs to update, start updating new data for WHR now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for WHR!
# ===============================================
# Already have data csv for WMB
# Needs to update, start updating new data for WMB now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for WMB!
# ===============================================
# Already have data csv for WLTW
# Needs to update, start updating new data for WLTW now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for WLTW!
# ===============================================
# Already have data csv for WYN
# index 0 is out of bounds for axis 0 with size 0
# ===============================================
# Already have data csv for WYNN
# Needs to update, start updating new data for WYNN now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for WYNN!
# ===============================================
# Already have data csv for XEL
# Needs to update, start updating new data for XEL now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for XEL!
# ===============================================
# Already have data csv for XRX
# Needs to update, start updating new data for XRX now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for XRX!
# ===============================================
# Already have data csv for XLNX
# Needs to update, start updating new data for XLNX now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for XLNX!
# ===============================================
# Already have data csv for XL
# Setup start date earlier than existing data's, trying to pull data from before...
# Needs to update, start updating new data for XL now...
# [*********************100%***********************]  1 of 1 completed
# New data's first pulled date is 2005-06-07T00:00:00.000000000
# New data updated till today for XL!
# ===============================================
# Already have data csv for XYL
# Setup start date earlier than existing data's, trying to pull data from before...
# Needs to update, start updating new data for XYL now...
# [*********************100%***********************]  1 of 1 completed
# New data's first pulled date is 2011-10-13T00:00:00.000000000
# New data updated till today for XYL!
# ===============================================
# Already have data csv for YUM
# Needs to update, start updating new data for YUM now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for YUM!
# ===============================================
# Already have data csv for ZBH
# Needs to update, start updating new data for ZBH now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for ZBH!
# ===============================================
# Already have data csv for ZION
# Needs to update, start updating new data for ZION now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for ZION!
# ===============================================
# Already have data csv for ZTS
# Setup start date earlier than existing data's, trying to pull data from before...
# Needs to update, start updating new data for ZTS now...
# [*********************100%***********************]  1 of 1 completed
# New data's first pulled date is 2013-02-01T00:00:00.000000000
# New data updated till today for ZTS!
# ===============================================
# Already have data csv for VTI
# Needs to update, start updating new data for VTI now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for VTI!
# ===============================================
# Already have data csv for TLT
# Needs to update, start updating new data for TLT now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for TLT!
# ===============================================
# Already have data csv for IEF
# Needs to update, start updating new data for IEF now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for IEF!
# ===============================================
# Already have data csv for GLD
# Needs to update, start updating new data for GLD now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for GLD!
# ===============================================
# Already have data csv for DBC
# Setup start date earlier than existing data's, trying to pull data from before...
# Needs to update, start updating new data for DBC now...
# [*********************100%***********************]  1 of 1 completed
# New data's first pulled date is 2006-02-06T00:00:00.000000000
# New data updated till today for DBC!
# ===============================================
# Already have data csv for IYM
# Needs to update, start updating new data for IYM now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for IYM!
# ===============================================
# Already have data csv for IYZ
# Needs to update, start updating new data for IYZ now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for IYZ!
# ===============================================
# Already have data csv for FCL
# Needs to update, start updating new data for FCL now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for FCL!
# ===============================================
# Already have data csv for FCD
# Setup start date earlier than existing data's, trying to pull data from before...
# Needs to update, start updating new data for FCD now...
# [*********************100%***********************]  1 of 1 completed
# New data's first pulled date is 2005-01-03T00:00:00.000000000
# New data updated till today for FCD!
# ===============================================
# Already have data csv for IYE
# Needs to update, start updating new data for IYE now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for IYE!
# ===============================================
# Already have data csv for IYG
# Needs to update, start updating new data for IYG now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for IYG!
# ===============================================
# Already have data csv for IYH
# Needs to update, start updating new data for IYH now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for IYH!
# ===============================================
# Already have data csv for IYJ
# Needs to update, start updating new data for IYJ now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for IYJ!
# ===============================================
# Already have data csv for IYR
# Needs to update, start updating new data for IYR now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for IYR!
# ===============================================
# Already have data csv for IYW
# Needs to update, start updating new data for IYW now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for IYW!
# ===============================================
# Already have data csv for IDU
# Needs to update, start updating new data for IDU now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for IDU!
# ===============================================
# Already have data csv for SPY
# Needs to update, start updating new data for SPY now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for SPY!
# ===============================================
# Already have data csv for VXXB
# Setup start date earlier than existing data's, trying to pull data from before...
# Needs to update, start updating new data for VXXB now...
# [*********************100%***********************]  1 of 1 completed
# New data's first pulled date is 2018-01-17T00:00:00.000000000
# New data updated till today for VXXB!
# ===============================================
# Already have data csv for QQQ
# Needs to update, start updating new data for QQQ now...
# [*********************100%***********************]  1 of 1 completed
# New data updated till today for QQQ!
# ===============================================
# Already have data csv for YELP
# Setup start date earlier than existing data's, trying to pull data from before...
# Needs to update, start updating new data for YELP now...
# [*********************100%***********************]  1 of 1 completed
# New data's first pulled date is 2012-03-02T00:00:00.000000000
# New data updated till today for YELP!
# ===============================================
# Already have data csv for UBER
# Setup start date earlier than existing data's, trying to pull data from before...
# Needs to update, start updating new data for UBER now...
# [*********************100%***********************]  1 of 1 completed
# New data's first pulled date is 2019-05-10T00:00:00.000000000
# New data updated till today for UBER!
# ===============================================
# Already have data csv for TSLA
# Setup start date earlier than existing data's, trying to pull data from before...
# Needs to update, start updating new data for TSLA now...
# [*********************100%***********************]  1 of 1 completed
# New data's first pulled date is 2010-06-29T00:00:00.000000000
# New data updated till today for TSLA!
# ===============================================
# 【Updated Finished for today!】
